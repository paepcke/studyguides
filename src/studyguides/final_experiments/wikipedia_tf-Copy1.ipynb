# %%
import os
import nltk
import wikipedia
import re

import numpy as np

from collections import OrderedDict, defaultdict
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from IPython.display import display
from ipywidgets import IntProgress

# %%
documents = OrderedDict()

for name in os.listdir('../../../data/Introduction_to_Databases_Captions'):
    with open('../../../data/Introduction_to_Databases_Captions/' + name) as f:
        lines = []
        for line in f:
            lines.append(line.strip('| \n'))
        documents[name] = ' '.join(lines)
        
keywords = defaultdict(set)
stemmer = nltk.stem.PorterStemmer()

for name in os.listdir('../../../data/keywords/'):
    with open('../../../data/keywords/' + name) as f:
        for line in f:
            lecture_name, key, _, rank = line.strip().split(',')
            rank = int(rank)
            key = key.replace('-', ' ')
            key = ' '.join(stemmer.stem(token) for token in nltk.word_tokenize(key))
            key = key.lower()
            keywords[lecture_name].add(key)

# %%
wikipedia_documents = {}

prog = IntProgress(min=0, max=len(documents))
display(prog)

for name in documents.keys():
    search = re.sub('\d+_\d+', '', name)
    search = re.sub('Part_\d+', '', search)
    search = search.replace('Demo', '')
    search = search.replace('.txt', '')
    search = search.replace('_', ' ')
    search = search.strip()
    search = search.lower()
    
    results = wikipedia.search(search)
    
    for result in results:
        try:
            page = wikipedia.page(result)
            break
        except wikipedia.DisambiguationError:
            pass
        
    wikipedia_documents[name] = page
    
    prog.value += 1
# Out:
# /Users/andrewlamb/miniconda2/lib/python2.7/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "html.parser")
#
#   markup_type=markup_type))

# %%
wikipedia_documents
# Out:
# {'01_01_Introduction.txt': <WikipediaPage 'An Introduction to .....'>,
#  '02_01_The_Relational_Model.txt': <WikipediaPage 'Relational model'>,
#  '02_02_Querying_Relational_Databases.txt': <WikipediaPage 'Query language'>,
#  '03_01_Well_Formed_XML_Part_1.txt': <WikipediaPage 'XML'>,
#  '03_01_Well_Formed_XML_Part_2.txt': <WikipediaPage 'XML'>,
#  '03_02_DTDs_IDs_and_IDREFs.txt': <WikipediaPage 'XML'>,
#  '03_02_XML_Schema.txt': <WikipediaPage 'XML schema'>,
#  '04_01_Introduction_to_JSON_Data_Part_1.txt': <WikipediaPage 'JSON'>,
#  '04_01_Introduction_to_JSON_Data_Part_2.txt': <WikipediaPage 'JSON'>,
#  '04_02_JSON_Demo.txt': <WikipediaPage 'JSON'>,
#  '05_01_Select_Project_Join_Part_1.txt': <WikipediaPage 'Monotonic query'>,
#  '05_01_Select_Project_Join_Part_2.txt': <WikipediaPage 'Monotonic query'>,
#  '05_01_Select_Project_Join_Part_3.txt': <WikipediaPage 'Monotonic query'>,
#  '05_01_Select_Project_Join_Part_4.txt': <WikipediaPage 'Monotonic query'>,
#  '05_02_Set_Operators_Renaming_Notation_Part_1.txt': <WikipediaPage 'Lambda calculus'>,
#  '05_02_Set_Operators_Renaming_Notation_Part_2.txt': <WikipediaPage 'Lambda calculus'>,
#  '05_02_Set_Operators_Renaming_Notation_Part_3.txt': <WikipediaPage 'Lambda calculus'>,
#  '06_01_Introduction_to_SQL.txt': <WikipediaPage 'SQL'>,
#  '06_02_Basic_SELECT_Statement.txt': <WikipediaPage 'Visual Basic'>,
#  '06_03_Table_Variables_and_Set_Operators.txt': <WikipediaPage 'PHP'>,
#  '06_04_Subqueries_in_FROM_and_SELECT.txt': <WikipediaPage 'SQL'>,
#  '06_04_Subqueries_in_WHERE_Clause.txt': <WikipediaPage 'SQL'>,
#  '06_05_Aggregation.txt': <WikipediaPage 'News aggregator'>,
#  '06_06_NULL_Values.txt': <WikipediaPage 'Null pointer'>,
#  '06_07_Data_Modification_Statements.txt': <WikipediaPage 'Insert (SQL)'>,
#  '06_08_The_JOIN_Family_of_Operators.txt': <WikipediaPage 'Association of Independent Tour Operators'>,
#  '07_01_Functional_Dependencies_Part_5.txt': <WikipediaPage 'Functional dependency'>,
#  '07_01_Relational_Design_Overview_Part_1.txt': <WikipediaPage 'Relational database'>,
#  '07_01_Relational_Design_Overview_Part_2.txt': <WikipediaPage 'Relational database'>,
#  '07_01_Relational_Design_Overview_Part_3.txt': <WikipediaPage 'Relational database'>,
#  '07_01_Relational_Design_Overview_Part_4.txt': <WikipediaPage 'Relational database'>,
#  '07_02_Functional_Dependencies_Part_1.txt': <WikipediaPage 'Functional dependency'>,
#  '07_02_Functional_Dependencies_Part_2.txt': <WikipediaPage 'Functional dependency'>,
#  '07_02_Functional_Dependencies_Part_3.txt': <WikipediaPage 'Functional dependency'>,
#  '07_02_Functional_Dependencies_Part_4.txt': <WikipediaPage 'Functional dependency'>,
#  '07_03_Boyce_Codd_Normal_Form_Part_1.txt': <WikipediaPage 'Boyce–Codd normal form'>,
#  '07_03_Boyce_Codd_Normal_Form_Part_2.txt': <WikipediaPage 'Boyce–Codd normal form'>,
#  '07_03_Boyce_Codd_Normal_Form_Part_3.txt': <WikipediaPage 'Boyce–Codd normal form'>,
#  '07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_1.txt': <WikipediaPage 'Fourth normal form'>,
#  '07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_2.txt': <WikipediaPage 'Fourth normal form'>,
#  '07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_3.txt': <WikipediaPage 'Fourth normal form'>,
#  '07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_4.txt': <WikipediaPage 'Fourth normal form'>,
#  '07_05_Shortcomings_of_BCNF_and_4NF.txt': <WikipediaPage 'Fourth normal form'>,
#  '08_01_XPath_Introduction.txt': <WikipediaPage 'XPath'>,
#  '08_02_XPath_Demo.txt': <WikipediaPage 'XPath'>,
#  '08_03_XQuery_Introduction.txt': <WikipediaPage 'XQuery'>,
#  '08_04_XQuery_Demo.txt': <WikipediaPage 'XQuery'>,
#  '08_05_XSLT.txt': <WikipediaPage 'XSLT'>,
#  '09_01_UML_Data_Modeling.txt': <WikipediaPage 'Data modeling'>,
#  '09_02_UML_to_Relations_Part_1.txt': <WikipediaPage 'Diagram'>,
#  '09_02_UML_to_Relations_Part_2.txt': <WikipediaPage 'Diagram'>,
#  '09_02_UML_to_Relations_Part_3.txt': <WikipediaPage 'Diagram'>,
#  '10_01_Indexes_Part_1.txt': <WikipediaPage 'Citation index'>,
#  '10_01_Indexes_Part_2.txt': <WikipediaPage 'Citation index'>,
#  '11_01_Introduction_to_Transactions.txt': <WikipediaPage 'Asclepius of Tralles'>,
#  '11_02_Transactions_Properties_Part_1.txt': <WikipediaPage 'Momotaro Dentetsu'>,
#  '11_02_Transactions_Properties_Part_2.txt': <WikipediaPage 'Momotaro Dentetsu'>,
#  '11_02_Transactions_Properties_Part_3.txt': <WikipediaPage 'Momotaro Dentetsu'>,
#  '11_03_Isolation_Levels_Part_1.txt': <WikipediaPage 'Isolation (database systems)'>,
#  '11_03_Isolation_Levels_Part_2.txt': <WikipediaPage 'Isolation (database systems)'>,
#  '11_03_Isolation_Levels_Part_3.txt': <WikipediaPage 'Isolation (database systems)'>,
#  '11_03_Isolation_Levels_Part_4.txt': <WikipediaPage 'Isolation (database systems)'>,
#  '12_01_Motivation_and_Overview.txt': <WikipediaPage 'Verifiable computing'>,
#  '12_02_Constraints_of_Several_Types_Part_1.txt': <WikipediaPage 'Constraint (mathematics)'>,
#  '12_02_Constraints_of_Several_Types_Part_2.txt': <WikipediaPage 'Constraint (mathematics)'>,
#  '12_03_Referential_Integrity_Part_1.txt': <WikipediaPage 'Referential integrity'>,
#  '12_03_Referential_Integrity_Part_2.txt': <WikipediaPage 'Referential integrity'>,
#  '12_03_Referential_Integrity_Part_3.txt': <WikipediaPage 'Referential integrity'>,
#  '12_04_Triggers_Introduction.txt': <WikipediaPage 'Discourse representation theory'>,
#  '12_05_Triggers_Demo_Part_1.txt': <WikipediaPage 'Spawning trigger'>,
#  '12_05_Triggers_Demo_Part_2.txt': <WikipediaPage 'Spawning trigger'>,
#  '13_01_Defining_and_Using_Views.txt': <WikipediaPage 'AIDS-defining clinical condition'>,
#  '13_02_View_Modifications_Introduction_Part_1.txt': <WikipediaPage 'DNA'>,
#  '13_02_View_Modifications_Introduction_Part_2.txt': <WikipediaPage 'DNA'>,
#  '13_03_View_Modifications_Using_Triggers.txt': <WikipediaPage 'Database trigger'>,
#  '13_04_Automatic_View_Modifications.txt': <WikipediaPage 'M249 light machine gun'>,
#  '13_05_Materialized_Views_Part_1.txt': <WikipediaPage 'Materialized view'>,
#  '13_05_Materialized_Views_Part_2.txt': <WikipediaPage 'Materialized view'>,
#  '13_05_Materialized_Views_Part_3.txt': <WikipediaPage 'Materialized view'>,
#  '14_01_Authorization_Part_1.txt': <WikipediaPage 'Authorization'>,
#  '14_01_Authorization_Part_2.txt': <WikipediaPage 'Authorization'>,
#  '14_01_Authorization_Part_3.txt': <WikipediaPage 'Authorization'>,
#  '14_01_Authorization_Part_4.txt': <WikipediaPage 'Authorization'>,
#  '15_01_Basic_Recursive_WITH_Statement_Introduction.txt': <WikipediaPage 'Recursion (computer science)'>,
#  '15_02_Basic_Recursive_WITH_Statement_Demo.txt': <WikipediaPage 'Recursion (computer science)'>,
#  '15_03_Nonlinear_and_Mutual_Recursion_Part_1.txt': <WikipediaPage 'Coupled map lattice'>,
#  '15_03_Nonlinear_and_Mutual_Recursion_Part_2.txt': <WikipediaPage 'Coupled map lattice'>,
#  '16_01_Introduction_to_OLAP_Part_1.txt': <WikipediaPage 'OLAP cube'>,
#  '16_01_Introduction_to_OLAP_Part_2.txt': <WikipediaPage 'OLAP cube'>,
#  '16_02_OLAP_Demo.txt': <WikipediaPage 'Online analytical processing'>,
#  '17_01_NoSQLMotivation.txt': <WikipediaPage 'Online analytical processing'>,
#  '17_01_NoSQLOverview.txt': <WikipediaPage 'Online analytical processing'>}

# %%
# Fix up some of the pages with bad results.
wikipedia_documents['01_01_Introduction.txt'] = wikipedia.page('database')
wikipedia_documents['06_02_Basic_SELECT_Statement.txt'] = wikipedia.page('select (sql)')
wikipedia_documents['06_03_Table_Variables_and_Set_Operators.txt'] = wikipedia.page('sql')
wikipedia_documents['06_05_Aggregation.txt'] = wikipedia.page('aggregate function')
wikipedia_documents['06_06_NULL_Values.txt'] = wikipedia.page('sql (null)')
wikipedia_documents['06_08_The_JOIN_Family_of_Operators.txt'] = wikipedia.page('join (sql)')
wikipedia_documents['09_01_UML_Data_Modeling.txt'] = wikipedia.page('unified modeling language')
wikipedia_documents['09_02_UML_to_Relations_Part_1.txt'] = wikipedia.page('unified modeling language')
wikipedia_documents['09_02_UML_to_Relations_Part_2.txt'] = wikipedia.page('unified modeling language')
wikipedia_documents['09_02_UML_to_Relations_Part_3.txt'] = wikipedia.page('unified modeling language')
wikipedia_documents['10_01_Indexes_Part_1.txt'] = wikipedia.page('database index')
wikipedia_documents['10_01_Indexes_Part_2.txt'] = wikipedia.page('database index')
wikipedia_documents['11_01_Introduction_to_Transactions.txt'] = wikipedia.page('database transaction')
wikipedia_documents['11_02_Transactions_Properties_Part_1.txt'] = wikipedia.page('database transaction')
wikipedia_documents['11_02_Transactions_Properties_Part_2.txt'] = wikipedia.page('database transaction')
wikipedia_documents['11_02_Transactions_Properties_Part_3.txt'] = wikipedia.page('database transaction')
wikipedia_documents['12_01_Motivation_and_Overview.txt'] = wikipedia.page('database trigger')
wikipedia_documents['12_02_Constraints_of_Several_Types_Part_1.txt'] = wikipedia.page('database')
wikipedia_documents['12_02_Constraints_of_Several_Types_Part_2.txt'] = wikipedia.page('database')
wikipedia_documents['12_04_Triggers_Introduction.txt'] = wikipedia.page('database trigger')
wikipedia_documents['12_05_Triggers_Demo_Part_1.txt'] = wikipedia.page('database trigger')
wikipedia_documents['12_05_Triggers_Demo_Part_2.txt'] = wikipedia.page('database trigger')
wikipedia_documents['13_01_Defining_and_Using_Views.txt'] = wikipedia.page('view (sql)')
wikipedia_documents['13_02_View_Modifications_Introduction_Part_1.txt'] = wikipedia.page('view (sql)')
wikipedia_documents['13_02_View_Modifications_Introduction_Part_2.txt'] = wikipedia.page('view (sql)')
wikipedia_documents['13_04_Automatic_View_Modifications.txt'] = wikipedia.page('view (sql)')
wikipedia_documents['15_03_Nonlinear_and_Mutual_Recursion_Part_1.txt'] = wikipedia.page('recursion (computer science)')
wikipedia_documents['15_03_Nonlinear_and_Mutual_Recursion_Part_2.txt'] = wikipedia.page('recursion (computer science)')
wikipedia_documents['16_01_Introduction_to_OLAP_Part_1.txt'] = wikipedia.page('online analytical processing')
wikipedia_documents['16_01_Introduction_to_OLAP_Part_2.txt'] = wikipedia.page('online analytical processing')
wikipedia_documents['17_01_NoSQLMotivation.txt'] = wikipedia.page('nosql')
wikipedia_documents['17_01_NoSQLOverview.txt'] = wikipedia.page('nosql')

# %%
combined_documents = OrderedDict()

for name, document in documents.items():
    combined_documents[name] = ' '.join([document, wikipedia_documents[name].content])

# %%
stemmed_documents = OrderedDict()

for name, document in documents.items():
    document = document.replace('-', ' ')
    document = ' '.join([stemmer.stem(token) for token in nltk.word_tokenize(document)])
    stemmed_documents[name] = document.lower()
    
stemmed_combined_documents = OrderedDict()

for name, document in combined_documents.items():
    stemmed_combined_document = document.replace('-', ' ')
    stemmed_combined_document = ' '.join([stemmer.stem(token) for token in nltk.word_tokenize(stemmed_combined_document)])
    stemmed_combined_documents[name] = stemmed_combined_document.lower()

# %%
stopwords = []
with open('../../../data/smart.txt') as f:
    for line in f:
        line = line.strip()
        tokens = nltk.word_tokenize(line)
        stopwords.append(' '.join([stemmer.stem(token) for token in tokens]))

lecture_extractor = TfidfVectorizer(stop_words=stopwords, ngram_range=(1,4))
lecture_extractor.fit(stemmed_documents.values())

extractor = TfidfVectorizer(stop_words=stopwords, ngram_range=(1,4), vocabulary=lecture_extractor.vocabulary_)
X = extractor.fit_transform(stemmed_combined_documents.values())
inverse_voc = {v: k for k, v in extractor.vocabulary_.items()}

extracted = {}
for doc_idx, name in enumerate(stemmed_documents.keys()):
    extracted[name] = [inverse_voc[idx] for idx in np.argsort(X[doc_idx,:].toarray().flatten())]

# %%
matches = OrderedDict()
jaccard = OrderedDict()

for name, keys in sorted(keywords.items()):
    extracted_words = extracted[name][-len(keys):]
    matches[name.replace('.keys', '')] = list(set(keys).intersection(extracted_words))
    jaccard[name.replace('.keys', '')] = float(len(set(keys).intersection(extracted_words))) / len(set(keys).union(set(extracted_words)))
    
print('Average jaccard: {}'.format(sum(jaccard.values()) / len(jaccard)))
# Out:
# Average jaccard: 0.120771961881

# %%
sorted(matches.items()[6])

# %%
documents['03_02_DTDs_IDs_and_IDREFs.txt'].lower().count('xml schema')

# %%
wikipedia_documents['03_02_DTDs_IDs_and_IDREFs.txt'].content.lower().count('xml schema')

# %%
keywords['03_02_DTDs_IDs_and_IDREFs.txt']

# %%
matches = OrderedDict()
jaccard = OrderedDict()

for name, keys in sorted(keywords.items()):
    extracted_words = extracted[name][-2*len(keys):]
    matches[name.replace('.keys', '')] = list(set(keys).intersection(extracted_words))
    jaccard[name.replace('.keys', '')] = float(len(set(keys).intersection(extracted_words))) / len(set(keys).union(set(extracted_words)))
    
print('Average jaccard: {}'.format(sum(jaccard.values()) / len(jaccard)))
# Out:
# Average jaccard: 0.103789342372

# %%
with open('wikipedia_tf_keys.csv', 'w') as f:
    for document, keys in sorted(extracted.items()):
        keys = list(reversed(keys))
        for i, key in enumerate(keys[:10]):
            if i < 5:
                f.write('{},{},{}\n'.format(document, key, i + 1))
            else:
                f.write('{},{},{}\n'.format(document, key, 0))

# %%
list(reversed(extracted['10_01_Indexes_Part_1.txt']))
# Out:
# [u'index',
#  u'student',
#  u'tupl',
#  u'column',
#  u'scan',
#  u'build index',
#  u'condit',
#  u'hash tabl',
#  u'queri',
#  u'hash',
#  u'tabl',
#  u'condit column',
#  u'balanc tree',
#  u'tupl index',
#  u'index student',
#  u'index case',
#  u'tree',
#  u'index index',
#  u'equal',
#  u'balanc',
#  u'case',
#  u'index column',
#  u'scienc',
#  u'cat',
#  u'base index',
#  u'queri execut engin',
#  u'equal condit',
#  u'index tupl',
#  u'build index column',
#  u'scan tabl',
#  u'column build',
#  u'condit column build index',
#  u'index queri',
#  u'column build index column',
#  u'condit column build',
#  u'column build index',
#  u'mari',
#  u'attribut',
#  u'index order',
#  u'index attribut',
#  u'question',
#  u'gpa',
#  u'academ',
#  u'execut engin',
#  u'student mari',
#  u'build',
#  u'student id',
#  u'tupl tupl',
#  u'gpa greater',
#  u'sort order',
#  u'sid',
#  u'databas',
#  u'evalu condit',
#  u'tabl index',
#  u'greater',
#  u'appli',
#  u'order',
#  u'public',
#  u'googl',
#  u'speed',
#  u'scientif',
#  u'tupl cat',
#  u'index column question equal',
#  u'index queri execut',
#  u'familiar structur',
#  u'index queri execut engin',
#  u'index prefer',
#  u'question equal',
#  u'index case index',
#  u'student id index',
#  u'index automat',
#  u'index column question',
#  u'evalu condit column build',
#  u'column question equal',
#  u'tabl balanc tree',
#  u'quickli tupl',
#  u'tree base index',
#  u'cow',
#  u'tupl index case',
#  u'evalu condit column',
#  u'equal index',
#  u'hash tabl balanc',
#  u'hash tabl balanc tree',
#  u'question tupl',
#  u'student mari gpa greater',
#  u'tupl cow',
#  u'tabl balanc tree index',
#  u'tabl balanc',
#  u'column question',
#  u'condit hash',
#  u'index video',
#  u'index tupl tupl',
#  u'balanc tree index',
#  u'id index',
#  u'index student id',
#  u'equal condit hash',
#  u'case index',
#  u'build index column question',
#  u'mari gpa greater',
#  u'relat sort order',
#  u'find',
#  u'id',
#  u'legal',
#  u'quickli',
#  u'run time',
#  u'tree base',
#  u'student mari gpa',
#  u'video import',
#  u'mari gpa',
#  u'databas index',
#  u'case queri',
#  u'document',
#  u'report',
#  u'relat',
#  u'queri execut',
#  u'relat sort',
#  u'inequ',
#  u'list case',
#  u'import',
#  u'onlin',
#  u'appli relat',
#  u'match student',
#  u'column column',
#  u'simpl tabl',
#  u'logarithm',
#  u'suppos',
#  u'primari',
#  u'primari key',
#  u'structur',
#  u'case system',
#  u'relat case',
#  u'tree index',
#  u'prefer',
#  u'match',
#  u'queri involv',
#  u'social',
#  u'attribut equal',
#  u'find match',
#  u'student relat',
#  u'interest',
#  u'tabl case',
#  u'mention',
#  u'includ',
#  u'decis',
#  u'establish',
#  u'evalu',
#  u'area',
#  u'declar',
#  u'automat',
#  u'gener',
#  u'video',
#  u'key',
#  u'volum',
#  u'run',
#  u'engin',
#  u'student appli',
#  u'implement',
#  u'kind',
#  u'find student',
#  u'system',
#  u'cover',
#  u'sort',
#  u'student colleg',
#  u'relat student',
#  u'subject',
#  u'human',
#  u'data structur',
#  u'call index column index',
#  u'video import understand basic',
#  u'match condit locat tupl',
#  u'magnitud perform import',
#  u'order find colleg student',
#  u'student mari check gpa',
#  u'mention inequ condit import',
#  u'select mention cover implement',
#  u'select mention cover',
#  u'select mention',
#  u'order kind merg',
#  u'suppos interest condit column',
#  u'call index column',
#  u'order kind',
#  u'final index',
#  u'hand equal condit',
#  u'mention inequ condit',
#  u'equal familiar',
#  u'good thing check',
#  u'tree index condit form',
#  u'cow scan',
#  u'condit attribut',
#  u'order find colleg',
#  u'tree index flexibl',
#  u'tree index flexibl small',
#  u'column anim column',
#  u'column anim column integ',
#  u'order kind merg oper',
#  u'equal familiar structur ll',
#  u'mention index',
#  u'mention index prefer',
#  u'condit attribut equal',
#  u'mention index prefer equival',
#  u'condit attribut equal familiar',
#  u'altern index gpa case',
#  u'altern index gpa',
#  u'altern index',
#  u'equal familiar structur',
#  u'student mari check',
#  u'mention inequ',
#  u'match condit locat',
#  u'equal addit condit queri',
#  u'tabl constant run time',
#  u'mention databas system automat',
#  u'order index',
#  u'system index find',
#  u'import databas build index',
#  u'import databas build',
#  u'system index',
#  u'small downsid familiar',
#  u'cow question index',
#  u'small downsid',
#  u'column call',
#  u'column call index',
#  u'index directli',
#  u'index directli tupl',
#  u'index directli tupl satisfi',
#  u'column call index column',
#  u'hand equal',
#  u'column column column string',
#  u'appli relat altern suppos',
#  u'appli relat altern',
#  u'cow question',
#  u'tabl column focu column',
#  u'tabl column focu',
#  u'queri languag implement',
#  u'video import topic',
#  u'column column string',
#  u'system index find student',
#  u'databas logarithm equal condit',
#  u'magnitud perform import databas',
#  u'order index attribut',
#  u'databas logarithm',
#  u'hand equal condit attribut',
#  u'cow question index index',
#  u'tabl constant run',
#  u'equal attribut attribut shown',
#  u'equal attribut attribut',
#  u'suppos interest condit',
#  u'sid quickli',
#  u'tabl constant',
#  u'final index attribut',
#  u'gpa greater altern index',
#  u'video import understand',
#  u'gpa greater altern',
#  u'final index attribut gpa',
#  u'databas logarithm equal',
#  u'queri languag implement effici',
#  u'video import topic start',
#  u'column column string column',
#  u'order index attribut suppos',
#  u'small downsid familiar structur',
#  u'cow scan tabl',
#  u'tree logarithm run',
#  u'tree logarithm run time',
#  u'tree logarithm',
#  u'index column index',
#  u'tree index condit',
#  u'attribut shown earlier hash',
#  u'appli relat case',
#  u'locat tupl index',
#  u'relat student sid quickli',
#  u'relat student sid',
#  u'locat tupl',
#  u'gpa greater mari final',
#  u'index automat good thing',
#  u'index automat good',
#  u'index automat attribut declar',
#  u'index automat attribut',
#  u'gpa greater mention',
#  u'index attribut suppos student',
#  u'gpa greater mention inequ',
#  u'index attribut suppos',
#  u'sid equal addit condit',
#  u'equal case',
#  u'equal case ll',
#  u'suppos index sid',
#  u'suppos index sid attribut',
#  u'index attribut gpa index',
#  u'attribut shown earlier',
#  u'index attribut gpa',
#  u'index attribut frequent condit',
#  u'index attribut frequent',
#  u'attribut shown',
#  u'involv condit',
#  u'student gpa greater mari',
#  u'attribut student relat case',
#  u'appli relat case queri',
#  u'gpa greater mari',
#  u'familiar structur run',
#  u'locat tupl index order',
#  u'satisfi condit scan',
#  u'index column call index',
#  u'index column call',
#  u'index column index case',
#  u'index case tupl wow',
#  u'index case tupl',
#  u'index case queri processor',
#  u'index case queri',
#  u'index case index tupl',
#  u'index case index make',
#  u'index condit',
#  u'index condit form',
#  u'short video import',
#  u'short video',
#  u'index condit form attribut',
#  u'familiar structur ll',
#  u'involv condit column',
#  u'familiar structur ll limit',
#  u'involv condit column order',
#  u'key number addit key',
#  u'key number addit',
#  u'import gpa',
#  u'import gpa tree',
#  u'import gpa tree base',
#  u'slightli complic student',
#  u'short video import topic',
#  u'slightli complic student mari',
#  u'familiar structur run time',
#  u'index area queri plan',
#  u'na queri',
#  u'altern suppos',
#  u'tupl find',
#  u'cat index',
#  u'cat greater tupl inequ',
#  u'return student colleg suppos',
#  u'tree hash',
#  u'tree hash tabl',
#  u'tree hash tabl balanc',
#  u'attribut suppos student relat',
#  u'cat greater tupl',
#  u'choic index area queri',
#  u'cat greater',
#  u'altern suppos index sid',
#  u'altern suppos index',
#  u'satisfi condit scan tabl',
#  u'index area queri',
#  u'cow scan tabl index',
#  u'choic index area',
#  u'main util index',
#  u'main util',
#  u'choic index',
#  u'column anim',
#  u'form attribut equal attribut',
#  u'talk index',
#  u'talk index short',
#  u'talk index short video',
#  u'form attribut equal',
#  u'na queri involv condit',
#  u'na queri involv',
#  u'cat index question',
#  u'equal condit hash tabl',
#  u'equal condit hash base',
#  u'interest area implement',
#  u'index area',
#  u'sid equal addit',
#  u'equal case ll tupl',
#  u'equal cat',
#  u'equal cat greater',
#  u'interest area implement databas',
#  u'video gener',
#  u'equal cat greater tupl',
#  u'return student colleg',
#  u'video gener focus',
#  u'time larg',
#  u'video gener focus perspect',
#  u'time larg databas',
#  u'relat case queri',
#  u'relat case queri execut',
#  u'time larg databas logarithm',
#  u'cat interest evalu condit',
#  u'relat case system',
#  u'relat case system scan',
#  u'order magnitud perform import',
#  u'tupl find match student',
#  u'cat interest evalu',
#  u'cat interest',
#  u'cat index question tupl',
#  u'equal condit attribut',
#  u'tupl find match',
#  u'equal condit attribut equal',
#  u'main util index tabl',
#  u'question tupl tupl',
#  u'sid quickli find',
#  u'colleg databas simpl queri',
#  u'flexibl small downsid familiar',
#  u'idea simpl tabl index',
#  u'databas simpl queri',
#  u'databas simpl queri student',
#  u'idea simpl tabl',
#  u'idea simpl',
#  u'flexibl small downsid',
#  u'flexibl small',
#  u'question equal cat greater',
#  u'question equal index',
#  u'key index',
#  u'key index automat',
#  u'key index automat good',
#  u'question equal index index',
#  u'larg databas logarithm',
#  u'topic start',
#  u'data structur specif',
#  u'prefer term index',
#  u'data structur specif structur',
#  u'question equal cat',
#  u'suppos student relat sort',
#  u'gener focus',
#  u'gener focus perspect',
#  u'gener focus perspect user',
#  u'substanti typic call tree',
#  u'substanti typic call',
#  u'substanti typic',
#  u'tupl case lastli suppos',
#  u'column string column anim',
#  u'column string column',
#  u'topic start mention index',
#  u'column string',
#  u'tupl case lastli',
#  u'topic start mention',
#  u'larg databas logarithm equal',
#  u'student appli return student',
#  u'question greater',
#  u'check type queri',
#  u'order appli relat',
#  u'focu column',
#  u'focu column column',
#  u'focu column column column',
#  u'order appli relat sort',
#  u'tabl absolut',
#  u'tabl absolut gigant',
#  u'tabl absolut gigant databas',
#  u'time oper',
#  u'run time larg databas',
#  u'result idea simpl tabl',
#  u'result idea simpl',
#  u'result idea',
#  u'run time larg',
#  u'util index',
#  u'order appli',
#  u'time oper balanc',
#  u'time oper balanc tree',
#  u'question greater equal index',
#  u'student appli return',
#  u'merg oper index match',
#  u'merg oper index',
#  u'merg oper',
#  u'check type queri common',
#  u'question greater equal',
#  u'question index',
#  u'run time oper',
#  u'question index index',
#  u'queri optim excit',
#  u'queri optim excit interest',
#  u'question index index quickli',
#  u'tupl tupl tupl cat',
#  u'run time oper balanc',
#  u'prefer term index index',
#  u'prefer term',
#  u'good thing check type',
#  u'number addit key label',
#  u'tupl wow complic question',
#  u'tupl wow complic',
#  u'kind merg',
#  u'kind merg oper',
#  u'tupl wow',
#  u'excit interest',
#  u'student id declar',
#  u'absolut gigant',
#  u'student id declar primari',
#  u'excit interest area',
#  u'excit interest area implement',
#  u'kind merg oper index',
#  u'absolut gigant databas',
#  u'absolut gigant databas scan',
#  u'structur balanc tree substanti',
#  u'student appli tabl order',
#  u'number addit key',
#  u'prefer sql queri index',
#  u'number addit',
#  u'plan queri',
#  u'plan queri optim',
#  u'plan queri optim excit',
#  u'tupl cow question index',
#  u'tupl cow scan',
#  u'tupl cow scan tabl',
#  u'suppos simpl',
#  u'll talk applic index',
#  u'll talk applic',
#  u'student id attribut appli',
#  u'gpa case system',
#  u'gpa case system index',
#  u'student id appli tupl',
#  u'suppos simpl tabl',
#  u'suppos simpl tabl column',
#  u'suppos starter',
#  u'suppos starter index',
#  u'suppos starter index student',
#  u'structur balanc tree',
#  u'check gpa greater altern',
#  u'databas scan',
#  u'databas scan tabl',
#  u'databas scan tabl find',
#  u'll student colleg databas',
#  u'constraint video tabl',
#  u'constraint video tabl primari',
#  u'tupl cat interest evalu',
#  u'student id index queri',
#  u'student id index student',
#  u'tupl cat interest',
#  u'tupl cat index question',
#  u'tupl cat index',
#  u'prefer sql',
#  u'prefer sql queri',
#  u'optim excit',
#  u'prefer equival person prefer',
#  u'prefer equival person',
#  u'interest implement issu index',
#  u'structur balanc',
#  u'improv perform databas index',
#  u'basic data structur specif',
#  u'id declar',
#  u'id declar primari',
#  u'id declar primari key',
#  u'equival person prefer term',
#  u'prefer equival',
#  u'equival person prefer',
#  u'equival person',
#  u'll tupl result',
#  u'll tupl result idea',
#  u'optim excit interest area',
#  u'optim excit interest',
#  u'column question equal index',
#  u'column question equal cat',
#  u'util index tabl',
#  u'column focu column',
#  u'queri process find',
#  u'queri process find quickli',
#  u'area queri plan queri',
#  u'design hash tabl constant',
#  u'design hash tabl',
#  u'area queri plan',
#  u'design hash',
#  u'uniqu slightli complic student',
#  u'uniqu slightli complic',
#  u'uniqu slightli',
#  u'area queri',
#  u'appli tupl find match',
#  u'uniqu remind constraint video',
#  u'uniqu remind constraint',
#  u'uniqu remind',
#  u'column focu',
#  u'balanc tree substanti typic',
#  u'util index tabl absolut',
#  u'column focu column column',
#  u'simpl tabl index directli',
#  u'key label uniqu slightli',
#  u'student index student',
#  u'student index student case',
#  u'tree substanti typic call',
#  u'tree substanti typic',
#  u'tree substanti',
#  u'key applic student id',
#  u'key applic student',
#  u'key applic',
#  u'balanc tree index condit',
#  u'balanc tree index flexibl',
#  u'balanc tree logarithm',
#  u'balanc tree logarithm run',
#  u'balanc tree substanti',
#  u'appli tupl find',
#  u'question tupl cow',
#  u'question tupl cow question',
#  u'equal addit',
#  u'pretti straight tupl',
#  u'pretti straight tupl index',
#  u'speed perform',
#  u'question tupl tupl tupl',
#  u'sid quickli find match',
#  u'interest condit column build',
#  u'execut engin pretti',
#  u'execut engin pretti straight',
#  u'interest condit column',
#  u'execut engin scan',
#  u'execut engin scan student',
#  u'execut engin speed',
#  u'execut engin speed process',
#  u'interest condit',
#  u'system declar queri languag',
#  u'speed perform suppos',
#  u'speed perform suppos simpl',
#  u'speed process',
#  u'column equal case',
#  u'equal index index tupl',
#  u'equal index index',
#  u'equal index case index',
#  u'equal index case',
#  u'area implement databas system',
#  u'column equal case ll',
#  u'area implement databas',
#  u'queri processor question tupl',
#  u'speed queri evalu condit',
#  u'speed queri evalu',
#  u'speed process ll student',
#  u'speed process ll',
#  u'queri processor question',
#  u'area implement',
#  u'simpl tabl index',
#  u'simpl tabl column focu',
#  u'simpl tabl column',
#  u'involv joint',
#  u'simpl queri student student',
#  u'appli record sid',
#  u'interest evalu condit column',
#  u'appli record sid equal',
#  u'import topic start mention',
#  u'import topic start',
#  u'databas system automat build',
#  u'interest evalu condit',
#  u'tupl tupl index case',
#  u'limit hash',
#  u'limit hash tabl',
#  u'limit hash tabl balanc',
#  u'tupl tupl index',
#  u'interest evalu',
#  u'involv joint join student',
#  u'import understand basic',
#  u'mari gpa greater student',
#  u'mari gpa greater mention',
#  u'relat sort order appli',
#  u'student appli record sid',
#  u'run time design hash',
#  u'run time design',
#  u'mari check',
#  u'mari check gpa',
#  u'mari check gpa greater',
#  u'relat sort order kind',
#  u'import understand basic data',
#  u'column order speed queri',
#  u'mari final',
#  u'mari final index',
#  u'mari final index attribut',
#  u'column order speed',
#  u'queri evalu condit column',
#  u'involv joint join',
#  u'student id student tupl',
#  u'student index',
#  u'queri plan',
#  u'column integ column',
#  u'column integ',
#  u'column index case queri',
#  u'column index case',
#  u'column index',
#  u'queri execut engin pretti',
#  u'queri execut engin scan',
#  u'queri execut engin speed',
#  u'key label',
#  u'column gon na queri',
#  u'column gon na',
#  u'column gon',
#  u'tree tree hash tabl',
#  u'tree tree hash',
#  u'key label uniqu',
#  u'column integ column gon',
#  u'oper balanc',
#  u'oper balanc tree',
#  u'focus perspect user applic',
#  u'queri plan queri',
#  u'queri plan queri optim',
#  u'tupl tupl cow scan',
#  u'tupl tupl cow',
#  u'focus perspect',
#  u'focus perspect user',
#  u'structur ll limit',
#  u'oper balanc tree logarithm',
#  u'structur ll limit hash',
#  u'tupl tupl cat interest',
#  u'expand queri process find',
#  u'expand queri process',
#  u'tupl tupl cat',
#  u'tupl tupl case lastli',
#  u'equal addit condit',
#  u'index flexibl small downsid',
#  u'student case expand',
#  u'greater mention inequ condit',
#  u'frequent condit condit',
#  u'frequent condit',
#  u'student relat case system',
#  u'base index tree',
#  u'base index queri involv',
#  u'base index queri',
#  u'base index order support',
#  u'base index order',
#  u'start mention index',
#  u'start mention index prefer',
#  u'applic index',
#  u'applic index speed',
#  u'applic index speed perform',
#  u'find student mari gpa',
#  u'find student mari',
#  u'frequent condit condit select',
#  u'student relat case',
#  u'tabl primari key number',
#  u'lastli suppos',
#  u'student tabl scan mention',
#  u'student tabl scan',
#  u'straight tupl',
#  u'straight tupl index',
#  u'straight tupl index student',
#  u'greater tupl',
#  u'lastli suppos interest',
#  u'greater student index',
#  u'lastli suppos interest condit',
#  u'case lastli suppos interest',
#  u'case lastli suppos',
#  u'case lastli',
#  u'base index tree base',
#  u'greater student index student',
#  u'thing check type queri',
#  u'system automat build index',
#  u'greater tupl inequ column',
#  u'system automat build',
#  u'wow complic question greater',
#  u'wow complic question',
#  u'colleg suppos starter index',
#  u'colleg suppos starter',
#  u'automat attribut',
#  u'automat attribut declar',
#  u'automat attribut declar uniqu',
#  u'issu index video gener',
#  u'issu index video',
#  u'downsid familiar',
#  u'downsid familiar structur',
#  u'shown earlier hash tabl',
#  u'student relat sort',
#  u'student relat sort order',
#  u'shown earlier hash',
#  u'faster detail index relat',
#  u'faster detail index',
#  u'faster detail',
#  u'case index make',
#  u'greater mention inequ',
#  u'greater mention',
#  u'appli relat sort',
#  u'case index tupl tupl',
#  u'case index tupl',
#  u'case index make queri',
#  u'appli relat sort order',
#  u'greater mari',
#  u'condit locat',
#  u'condit locat tupl',
#  u'condit locat tupl index',
#  u'thing check type',
#  u'greater mari final index',
#  u'greater mari final',
#  u'greater tupl inequ',
#  u'case ll tupl',
#  u'downsid familiar structur run',
#  u'relat access sort order',
#  u'hash tabl index',
#  u'hash tabl index prefer',
#  u'tupl index case index',
#  u'tree base index queri',
#  u'addit key label uniqu',
#  u'addit key label',
#  u'addit key',
#  u'tupl index order',
#  u'tupl index order magnitud',
#  u'tupl index student',
#  u'tupl index student tabl',
#  u'tupl inequ',
#  u'condit form attribut',
#  u'condit form attribut equal',
#  u'person prefer term index',
#  u'hash tabl hand equal',
#  u'hash tabl hand',
#  u'hash tabl constant run',
#  u'id student tupl index',
#  u'inequ column equal case',
#  u'inequ condit',
#  u'inequ condit import',
#  u'inequ condit import gpa',
#  u'tupl satisfi condit scan',
#  u'student equal condit hash',
#  u'id student tupl',
#  u'hash tabl constant',
#  u'hash base',
#  u'hash base index',
#  u'hash base index tree',
#  u'student equal condit',
#  u'specif structur balanc tree',
#  u'specif structur balanc',
#  u'person prefer term',
#  u'relat access sort',
#  u'case ll tupl result',
#  u'relat access',
#  u'applic student id declar',
#  u'typic call',
#  u'typic call tree',
#  u'typic call tree tree',
#  u'tupl result idea simpl',
#  u'tupl result idea',
#  u'perform import',
#  u'perform import databas',
#  u'condit import',
#  u'condit import gpa',
#  u'condit import gpa tree',
#  u'perform import databas build',
#  u'anim column integ column',
#  u'anim column integ',
#  u'anim column',
#  u'tabl order find colleg',
#  u'tabl order find',
#  u'cover implement',
#  u'gigant databas scan tabl',
#  u'person prefer',
#  u'tupl inequ column',
#  u'system build index automat',
#  u'system build index',
#  u'find tupl match condit',
#  u'gigant databas scan',
#  u'condit hash base',
#  u'cover implement index',
#  u'condit hash base index',
#  u'condit hash tabl',
#  u'condit hash tabl index',
#  u'find tupl match',
#  u'tupl inequ column equal',
#  u'cover implement index video',
#  u'shown earlier',
#  u'attribut declar uniqu',
#  u'inequ column',
#  u'tabl scan mention',
#  u'build index primari',
#  u'complic student mari',
#  u'complic student',
#  u'perform suppos simpl tabl',
#  u'perform suppos simpl',
#  u'perform suppos',
#  u'greater altern index gpa',
#  u'greater altern index',
#  u'string column',
#  u'build index column call',
#  u'student sid quickli find',
#  u'student sid quickli',
#  u'video talk index short',
#  u'video talk index',
#  u'build index automat attribut',
#  u'build index primari key',
#  u'tupl match condit',
#  u'tupl match condit locat',
#  u'condit scan tabl',
#  u'attribut equal familiar',
#  u'attribut equal familiar structur',
#  u'make queri run',
#  u'implement index video import',
#  u'implement index video',
#  u'condit scan',
#  u'condit scan tabl main',
#  u'complic student mari gpa',
#  u'implement index',
#  u'condit select mention',
#  u'condit select mention cover',
#  u'make queri run faster',
#  u'student colleg suppos starter',
#  u'student colleg suppos',
#  u'tabl scan',
#  u'tabl scan mention databas',
#  u'complic question greater',
#  u'build index automat',
#  u'evalu condit student equal',
#  u'declar uniqu remind constraint',
#  u'declar uniqu remind',
#  u'label uniqu',
#  u'attribut frequent',
#  u'evalu condit student',
#  u'attribut frequent condit',
#  u'declar queri languag implement',
#  u'attribut frequent condit condit',
#  u'label uniqu slightli',
#  u'condit student equal',
#  u'condit student equal condit',
#  u'label uniqu slightli complic',
#  u'user applic ll',
#  u'user applic ll talk',
#  u'video tabl primari',
#  u'starter index student id',
#  u'starter index student',
#  u'find match student id',
#  u'build index attribut frequent',
#  u'build index attribut',
#  u'join student appli tabl',
#  u'string column anim',
#  u'string column anim column',
#  u'greater altern',
#  u'find match student',
#  u'declar primari key index',
#  u'attribut gpa index simultan',
#  u'attribut gpa index',
#  u'video tabl primari key',
#  u'find match sid appli',
#  u'starter index',
#  u'find match sid',
#  u'complic question greater equal',
#  u'attribut equal attribut attribut',
#  u'attribut declar uniqu remind',
#  u'sql queri index',
#  u'engin scan student relat',
#  u'engin scan student',
#  u'engin scan',
#  u'find quickli tupl student',
#  u'find quickli tupl',
#  u'find quickli',
#  u'engin pretti straight tupl',
#  u'engin pretti straight',
#  u'case expand queri process',
#  u'case expand queri',
#  u'record sid equal addit',
#  u'engin pretti',
#  u'record sid equal',
#  u'condit queri choic',
#  u'condit queri choic index',
#  u'engin speed',
#  u'engin speed process',
#  u'engin speed process ll',
#  u'system scan appli relat',
#  u'automat build',
#  u'automat build index',
#  u'automat build index primari',
#  u'greater equal index case',
#  u'greater equal index',
#  u'student relat student sid',
#  u'system scan appli',
#  u'applic ll talk applic',
#  u'system scan',
#  u'implement databas system declar',
#  u'support evalu',
#  u'support evalu condit',
#  u'support evalu condit student',
#  u'applic ll talk',
#  u'record sid',
#  u'time design hash tabl',
#  u'complic question',
#  u'time design hash',
#  u'addit condit queri',
#  u'detail index relat access',
#  u'queri choic',
#  u'detail index relat',
#  u'detail index',
#  u'queri choic index',
#  u'queri choic index area',
#  u'appli return',
#  u'appli return student',
#  u'appli return student colleg',
#  u'databas build index attribut',
#  u'implement issu index video',
#  u'queri common system build',
#  u'queri common system',
#  u'implement issu index',
#  u'addit condit queri choic',
#  u'automat good thing check',
#  u'automat good thing',
#  u'common system build index',
#  u'joint join student appli',
#  u'joint join student',
#  u'joint join',
#  u'queri run faster detail',
#  u'gon na queri',
#  u'gon na queri involv',
#  u'common system build',
#  u'automat good',
#  u'common system',
#  u'run faster detail index',
#  u'run faster detail',
#  u'colleg student appli return',
#  u'student student id index',
#  u'sql queri index queri',
#  u'inequ column equal',
#  u'tupl index case tupl',
#  u'find colleg student appli',
#  u'scan mention databas',
#  u'scan student',
#  u'scan student relat',
#  u'scan student relat student',
#  u'scan tabl find',
#  u'scan tabl find tupl',
#  u'scan tabl index',
#  u'scan tabl index tupl',
#  u'scan tabl main',
#  u'scan tabl main util',
#  u'index relat',
#  u'index relat access',
#  u'index relat access sort',
#  u'll limit hash tabl',
#  ...]

# %%
matches['11_03_Isolation_Levels_Part_1.txt']
# Out:
# [u'serializ',
#  u'dirti read',
#  u'isol level',
#  u'transact',
#  u'isol',
#  u'repeat read',
#  u'read commit',
#  u'concurr control']

# %%
list(reversed(extracted['11_03_Isolation_Levels_Part_1.txt']))
# Out:
# [u'transact',
#  u'isol',
#  u'isol level',
#  u'read',
#  u'lock',
#  u'commit',
#  u'concurr',
#  u'level',
#  u'serializ',
#  u'dirti',
#  u'repeat read',
#  u'concurr control',
#  u'dirti read',
#  u'transact commit',
#  u't1',
#  u'uncommit',
#  u'read commit',
#  u't2',
#  u'transact isol',
#  u'repeat',
#  u'control',
#  u'transact read',
#  u'transact isol level',
#  u't1 t2',
#  u'read uncommit',
#  u'databas',
#  u'roll back',
#  u'row',
#  u'read transact',
#  u'roll',
#  u'data',
#  u'queri',
#  u'commit transact',
#  u'perform',
#  u'updat',
#  u'gpa',
#  u'select',
#  u'client',
#  u'system',
#  u'read isol',
#  u'repeat read isol',
#  u'phantom',
#  u'oper',
#  u'occur',
#  u'serial',
#  u'snapshot',
#  u'behavior',
#  u'read isol level',
#  u'repeat read isol level',
#  u'level read',
#  u'execut',
#  u'high school',
#  u'read read',
#  u'rang',
#  u'overhead',
#  u'averag',
#  u'gpa transact',
#  u'isol level transact',
#  u'undon transact',
#  u'level transact',
#  u'mode',
#  u'transact transact',
#  u'school',
#  u'guarante',
#  u'high',
#  u'transact roll back',
#  u'transact roll',
#  u'transact modifi',
#  u'modifi',
#  u'failur',
#  u'size',
#  u'increas',
#  u'statement',
#  u'result',
#  u'select data',
#  u'transact ll',
#  u'reduc',
#  u'return',
#  u'age',
#  u'requir',
#  u'acid',
#  u'back',
#  u'equival transact',
#  u'transact commit roll back',
#  u'set isol level',
#  u'set transact',
#  u'commit roll back',
#  u'read dirti',
#  u'commit roll',
#  u'level default',
#  u'transact commit roll',
#  u'concurr transact',
#  u'isol level read',
#  u'isol level default',
#  u'read commit transact',
#  u'transact updat',
#  u'transact t1',
#  u'set isol',
#  u'size high school',
#  u'size high',
#  u'properti',
#  u'set',
#  u'undon',
#  u'data read',
#  u'transact queri',
#  u'end transact',
#  u'purchas order',
#  u'sql',
#  u'order',
#  u'enrol',
#  u'correct',
#  u'consist',
#  u'affect',
#  u'visibl',
#  u'read data',
#  u'equival',
#  u'block',
#  u'typic',
#  u'access',
#  u'select oper',
#  u'databas transact',
#  u'dirti data',
#  u'modifi transact',
#  u'transact dirti',
#  u'size high school read',
#  u'gpa updat',
#  u'level ll',
#  u'level read uncommit',
#  u'client set',
#  u'high school read',
#  u'reduc concurr',
#  u'isol level ll',
#  u'isol level transact isol',
#  u'level transact isol',
#  u'transact modifi gpa student',
#  u'set isol level transact',
#  u'level transact isol level',
#  u'client submit',
#  u'written transact',
#  u'isol level sql standard',
#  u'school read',
#  u'isol level sql',
#  u'commit point',
#  u'base',
#  u'method',
#  u'write',
#  u'lower',
#  u'user',
#  u'manag',
#  u'school size',
#  u'high school size',
#  u'standford enrol',
#  u't2 read',
#  u'transact modifi gpa',
#  u'transact read averag',
#  u'modifi high school size',
#  u'averag comput',
#  u'modifi high school',
#  u'modifi gpa student',
#  u't9',
#  u'level sql',
#  u't10',
#  u'consist guarante',
#  u'level sql standard',
#  u'modifi high',
#  u'highest',
#  u'select queri',
#  u'releas',
#  u'relax',
#  u'queri perform',
#  u'purchas',
#  u'updat gpa',
#  u'behavior equival',
#  u'data item',
#  u't1 t2 t2',
#  u't3',
#  u'transact sequenc',
#  u'dirti read read',
#  u'transact client',
#  u'transact t1 t2',
#  u'higher',
#  u'end',
#  u'stronger',
#  u'transact read uncommit',
#  u'perform repeat read',
#  u'read dirti read',
#  u'dirti read transact',
#  u'read repeat',
#  u'read repeat read',
#  u'read averag',
#  u'perform repeat',
#  u'commit repeat read',
#  u'transact affect',
#  u't2 t2',
#  u'level stronger',
#  u'transact run',
#  u't2 transact',
#  u't1 t2 transact',
#  u'transact repeat',
#  u'system failur',
#  u'read lock',
#  u'repeat read transact',
#  u'commit repeat',
#  u't2 t1',
#  u'isol level stronger',
#  u'made transact',
#  u'time',
#  u'avoid',
#  u'mechan',
#  u'time transact',
#  u'databas start',
#  u'return time',
#  u'durat',
#  u'submit',
#  u'atom consist',
#  u'modifi gpa',
#  u'student',
#  u'defin',
#  u'gpa student',
#  u'anomali',
#  u'execut statement',
#  u'compromis',
#  u'standford',
#  u'case',
#  u'transact execut',
#  u'promis',
#  u'highest level',
#  u'object',
#  u'implement',
#  u'oper perform',
#  u'mind',
#  u'snapshot databas',
#  u'durabl',
#  u'weaker',
#  u've',
#  u'standard',
#  u'start transact',
#  u'proceed',
#  u'set row',
#  u'll',
#  u'attempt',
#  u'header',
#  u'middl',
#  u'tabl',
#  u'sql standard',
#  u'default',
#  u'sequenc',
#  u'strategi',
#  u'maintain',
#  u'prevent',
#  u'care',
#  u'run',
#  u'queri execut',
#  u'suffici',
#  u'ambigu',
#  u'comput',
#  u'commerci',
#  u'thing',
#  u'encount',
#  u'queri data',
#  u'box',
#  u'execut queri',
#  u'creat',
#  u'critic',
#  u'moment',
#  u'record',
#  u'remind',
#  u'number',
#  u'start',
#  u'underli',
#  u'type',
#  u'overhead reduc concurr system',
#  u'transact commit transact ll',
#  u'transact commit system',
#  u'transact commit ve',
#  u'transact commit system failur',
#  u'transact commit ve drop',
#  u'transact commit transact',
#  u't9 t1',
#  u'level weakest call read',
#  u'level weakest call',
#  u't9 t1 t2 t10',
#  u'level weakest',
#  u'level weaker stronger complet',
#  u't9 t1 t2',
#  u'transact commit point',
#  u'level weaker stronger',
#  u'guarante ve list',
#  u'guarante transact wo affect',
#  u'guarante transact wo',
#  u'guarante transact',
#  u'colleg enrol standford enrol',
#  u'colleg enrol standford',
#  u'altern isol level weaker',
#  u'altern isol level',
#  u'altern isol',
#  u'submit sequenc',
#  u'submit sequenc transact',
#  u'submit sequenc transact client',
#  u'submit transact databas set',
#  u't2 transact updat gpa',
#  u't2 transact updat',
#  u'similarli t2 t1 applic',
#  u'similarli t2 t1',
#  u't2 t9 t10 t11',
#  u'similarli t2',
#  u'talk proceed',
#  u'guarante ve',
#  u'guarante ve list altern',
#  u'level weaker',
#  u'call dirti',
#  u'transact commit point time',
#  u'transact client t1 t2',
#  u'transact client t1',
#  u'transact client set isol',
#  u'transact client set',
#  u't3 ve modifi size',
#  u't3 ve modifi',
#  u't3 ve',
#  u't3 transact modifi gpa',
#  u't3 transact modifi',
#  u't3 transact',
#  u'transact box assum implicitli',
#  u'transact box assum',
#  u'transact box',
#  u'transact affect behavior transact',
#  u'transact affect behavior',
#  u't9 t10 t11 transact',
#  u'call dirti read data',
#  u'call dirti read',
#  u'overhead reduc concurr',
#  u'dirti data read trio',
#  u'overhead reduc',
#  u'transact t2 read',
#  u'transact solut concurr',
#  u'transact solut concurr control',
#  u'transact specif',
#  u'transact specif isol',
#  u'transact specif isol level',
#  u'transact t1 dirti',
#  u'transact t1 dirti gpa',
#  u'transact t2 read commit',
#  u'overhead perform understand reduc',
#  u'transact t3',
#  u'transact t3 ve',
#  u'transact t3 ve modifi',
#  u'transact t9',
#  u'transact t9 t1',
#  u'transact t9 t1 t2',
#  u'video put transact box',
#  u'transact solut',
#  u'transact size high school',
#  u'transact size high',
#  u'transact size',
#  u'transact read undon',
#  u'transact read undon transact',
#  u'transact reflect video',
#  u'transact reflect video focu',
#  u'transact remind multipl',
#  u'transact remind multipl client',
#  u'transact repeat read client',
#  u'transact roll back rough',
#  u'transact roll back undon',
#  u'transact run concurr',
#  u'transact run concurr client',
#  u'transact run isol system',
#  u'transact sequenc statement serializ',
#  u'transact serializ ll',
#  u'transact serializ ll behavior',
#  u'video put transact',
#  u'video put',
#  u'transact transact modifi',
#  u'size high school notic',
#  u'size student 234',
#  u'size student 234 gpa',
#  u'size suffici',
#  u'size suffici larg',
#  u'size suffici larg transact',
#  u'order suppos add transact',
#  u'order suppos add',
#  u'order suppos',
#  u'repeat read client set',
#  u'repeat read client',
#  u'behold show client submit',
#  u'behold show client',
#  u'behold show',
#  u'student number 123 transact',
#  u'student number 123',
#  u'size high school transact',
#  u'eye behold show',
#  u'transact transact modifi gpa',
#  u'eye behold show client',
#  u'transact typic',
#  u'transact typic written',
#  u'transact typic written transact',
#  u'transact updat gpa',
#  u'transact updat gpa ve',
#  u'transact updat standford',
#  u'transact updat standford enrol',
#  u'transact wo affect',
#  u'matter transact',
#  u'matter transact isol',
#  u'matter transact isol level',
#  u'transact wo affect isol',
#  u'databas transact commit',
#  u'databas transact commit system',
#  u'databas transact sequenc oper',
#  u'transact read uncommit properti',
#  u'transact read read exist',
#  u'transact read read',
#  u'transact dirti read',
#  u'student tabl transact read',
#  u'student tabl transact',
#  u'transact execut serial',
#  u'transact execut serial order',
#  u'transact find',
#  u'transact find gpa',
#  u'transact find gpa student',
#  u'transact gpa',
#  u'transact gpa updat',
#  u'focu isol portion',
#  u'focu isol portion transact',
#  u'transact gpa updat gpa',
#  u'transact isol level affect',
#  u'transact isol level eye',
#  u'transact isol level ll',
#  u'transact dirti read read',
#  u'transact dirti data item',
#  u'transact isol level weakest',
#  u'focu concept isol level',
#  u'overhead perform understand',
#  u'overhead perform',
#  u'overhead involv lock protocol',
#  u'overhead involv lock',
#  u'rest video put transact',
#  u'rest video put',
#  u'rest video',
#  u'overhead higher concurr cost',
#  u'transact databas set',
#  u'transact databas set isol',
#  u'overhead higher concurr',
#  u'overhead higher',
#  u'transact dirti data',
#  u'focu concept',
#  u'focu concept isol',
#  u'transact isol level perform',
#  u'dirti data item',
#  u'transact read averag enrol',
#  u'dirti read thing dirti',
#  u'dirti read uncommit',
#  u'dirti read uncommit modifi',
#  u'transact ll focu concept',
#  u'dirti transact',
#  u'dirti transact read',
#  u'dirti transact read read',
#  u'dirti word',
#  u'dirti word uncommit',
#  u'dirti word uncommit gpa',
#  u'dirti written',
#  u'dirti written transact',
#  u'dirti written transact commit',
#  u'video transact ll focu',
#  u'video transact ll',
#  u'video transact',
#  u'dirti read transact t3',
#  u'dirti read thing',
#  u'dirti data item clarif',
#  u'focus data read transact',
#  u'dirti data read',
#  u'written transact t1 t2',
#  u'dirti gpa',
#  u'dirti gpa transact',
#  u'dirti gpa transact commit',
#  u'transact ll call',
#  u'dirti read data',
#  u'dirti read data item',
#  u'transact ll call t1',
#  u'transact ll detail',
#  u'dirti read read dirti',
#  u'dirti read read modifi',
#  u'transact ll detail start',
#  u'transact ll focu',
#  u'focus data read',
#  u'talk proceed learn',
#  u'detail start defin concept',
#  u'written transact t1',
#  u'thing isol',
#  u'system enforc behavior',
#  u't1 case serializ',
#  u't1 case serializ behavior',
#  u'ad transact',
#  u'ad transact commit',
#  u'ad transact commit point',
#  u'thing dirti',
#  u'thing dirti read',
#  u'thing dirti read transact',
#  u't1 dirti',
#  u't1 dirti gpa',
#  u't1 dirti gpa transact',
#  u'pictur bottom fourth serializ',
#  u'pictur bottom fourth',
#  u'pictur bottom',
#  u'wo matter transact isol',
#  u'wo matter transact',
#  u'system enforc behavior equival',
#  u'system fail',
#  u'system fail transact',
#  u'system failur transact',
#  u'set modif',
#  u'set modif perform',
#  u'set modif perform t1',
#  u'lower consist',
#  u'lower consist guarante',
#  u'lower consist guarante ve',
#  u'system failur transact roll',
#  u'lower overhead',
#  u'system fail transact reflect',
#  u'lower overhead higher',
#  u'lower overhead higher concurr',
#  u'left set transact',
#  u'left set transact repeat',
#  u't1 applic',
#  u't1 applic care',
#  u't1 applic care exact',
#  u'wo matter',
#  u'thing isol level',
#  u'data read transact',
#  u'thing isol level transact',
#  u'perform understand reduc consist',
#  u'perform understand reduc',
#  u'perform understand',
#  u'roll back undon transact',
#  u'roll back undon',
#  u'roll back rough approxim',
#  u'roll back rough',
#  u'roll back case dirti',
#  u'roll back case',
#  u'perform t1 case serializ',
#  u'perform t1 case',
#  u'perform t1',
#  u'data read trio transact',
#  u'data read trio',
#  u'add transact',
#  u'add transact specif',
#  u'add transact specif isol',
#  u'gpa end undon transact',
#  u'gpa end undon',
#  u'gpa end',
#  u'box assum',
#  u'box write time transact',
#  u'box write time',
#  u'box write',
#  u'wo affect isol level',
#  u'wo affect isol',
#  u'box assum implicitli commit',
#  u'box assum implicitli',
#  u'rough approxim gpa isol',
#  u'bottom fourth',
#  u'rough approxim gpa',
#  u'rough approxim',
#  u'set transact read uncommit',
#  u'set transact repeat',
#  u'set transact repeat read',
#  u'bottom fourth serializ ve',
#  u'bottom fourth serializ',
#  u'final video transact',
#  u'final video transact ll',
#  u'word uncommit',
#  u'word uncommit gpa',
#  u'serializ system',
#  u'serializ system inter',
#  u'serializ system inter leav',
#  u'properti guarante transact',
#  u'serializ understand',
#  u'serializ understand behavior',
#  u'serializ understand behavior consist',
#  u'serializ ve',
#  u'serializ ve talk',
#  u'serializ ve talk proceed',
#  u'properti guarante transact wo',
#  u'serializ wo',
#  u'serializ wo matter',
#  u'serializ wo matter transact',
#  u'point transact dirti data',
#  u'point transact dirti',
#  u'databas equival transact execut',
#  u'serializ ll behavior guarante',
#  u'serializ ll behavior',
#  u'serializ behavior t1 t2',
#  u'learn isol mention',
#  u'leav execut',
#  u'leav execut statement',
#  u'leav execut statement statement',
#  u'lock protocol',
#  u'lock protocol reduc',
#  u'lock protocol reduc concurr',
#  u'learn isol mention coupl',
#  u'learn isol',
#  u'serializ behavior t1',
#  u'sequenc statement serializ',
#  u'sequenc statement serializ system',
#  u'sequenc transact client t1',
#  u'run isol system fail',
#  u'run isol system',
#  u'serial order case',
#  u'serial order case system',
#  u'databas equival transact',
#  u'databas dirti written transact',
#  u'databas dirti written',
#  u'databas client',
#  u'protocol reduc concurr',
#  u'sentenc isol level sql',
#  u'sentenc isol level',
#  u'sentenc isol',
#  u'protocol reduc concurr result',
#  u'databas client submit sequenc',
#  u'databas client submit',
#  u'find gpa student number',
#  u'larg transact',
#  u'system inter leav execut',
#  u'system inter leav',
#  u'system inter',
#  u'ad 1000',
#  u'ad 1000 transact',
#  u'ad 1000 transact read',
#  u'word uncommit gpa modif',
#  u'protocol reduc',
#  u'larg transact find',
#  u'databas dirti',
#  u'clarif dirti',
#  u'point time dirti transact',
#  u'point time dirti',
#  u'run concurr client left',
#  u'run concurr client',
#  u'long sentenc isol',
#  u'long sentenc isol level',
#  u'clarif',
#  u'clarif dirti read',
#  u'larg transact find gpa',
#  u'clarif dirti read thing',
#  u'portion transact',
#  u'portion transact remind',
#  u'portion transact remind multipl',
#  u'system offer weaker isol',
#  u'system offer weaker',
#  u'system offer',
#  u'data read transact typic',
#  u'put transact',
#  u'written transact commit transact',
#  u'behavior transact run',
#  u'level lower overhead',
#  u'level lower overhead higher',
#  u'affect isol',
#  u'affect isol level',
#  u'affect isol level specif',
#  u'affect transact',
#  u'affect transact affect',
#  u'affect transact affect behavior',
#  u't2 read commit',
#  u't2 read commit transact',
#  u't2 read middl',
#  u't2 read middl t1',
#  u't2 rest',
#  u't2 rest video',
#  u't2 rest video put',
#  u'time transact updat',
#  u'time transact updat standford',
#  u'level lower',
#  u'level ll increas concurr',
#  u'level ll increas',
#  u'gpa ve',
#  u'data item clarif dirti',
#  u'data item clarif',
#  u'gpa transact t2 read',
#  u'gpa updat gpa',
#  u'gpa updat gpa updat',
#  u'gpa updat remind',
#  u'gpa updat remind order',
#  u'gpa ve averag',
#  u'level ll focus data',
#  u'gpa ve averag read',
#  u'affect behavior',
#  u'affect behavior transact',
#  u'affect behavior transact run',
#  u'suppos add transact specif',
#  u'suppos add transact',
#  u'level ll focus',
#  u'detail start defin',
#  u'level perform',
#  u'put transact box',
#  u'level perform dirti',
#  u'level specif',
#  u'level specif read',
#  u'level specif read transact',
#  u'level sql standard isol',
#  u'level sql standard level',
#  u't2 t10 serializ understand',
#  u't2 t2 read',
#  u't2 t2 read middl',
#  u'fail transact reflect video',
#  u'fail transact reflect',
#  u't2 t2 t1 transact',
#  u't2 t3 transact',
#  u'level transact client',
#  u'level transact client set',
#  u't2 t3 transact modifi',
#  u'talk proceed learn isol',
#  u'written transact commit',
#  u't2 t10 serializ',
#  u't2 t10',
#  u't2 t1 transact gpa',
#  u'level remind',
#  u'level perform dirti read',
#  u'suffici larg transact find',
#  u'suffici larg transact',
#  u'level read uncommit long',
#  u'level read uncommit read',
#  u'result overhead reduc concurr',
#  u't2 t1 applic',
#  u'level remind transact',
#  u't2 t1 transact',
#  u'level remind transact solut',
#  u't2 t1 applic care',
#  u'result overhead reduc',
#  u'result overhead',
#  u'failur transact roll back',
#  u'failur transact roll',
#  u'failur problem databas transact',
#  u't11 transact sequenc statement',
#  u't11 transact sequenc',
#  u't11 transact',
#  u'data item databas dirti',
#  u'gpa modif',
#  u'gpa modif case',
#  u'gpa modif case averag',
#  u'perform client behavior databas',
#  u'perform client behavior',
#  u'client behavior',
#  u'client behavior databas',
#  u'client behavior databas equival',
#  u'client left',
#  u'client left set',
#  u'client left set transact',
#  u't1 t2 rest',
#  u't1 t2 rest video',
#  u't1 t2 t10',
#  u'client oper databas client',
#  u't1 t2 t10 serializ',
#  u't1 t2 t2 read',
#  u'weaker isol level sql',
#  u'weaker stronger',
#  u'level affect transact affect',
#  u'weakest call read commit',
#  u'put transact box assum',
#  u'gpa isol',
#  u'gpa isol level',
#  u'gpa isol level ll',
#  u'show client',
#  u'show client submit',
#  u'show client submit transact',
#  u'weakest call read',
#  u'level affect transact',
#  u'weakest call',
#  u't1 similarli',
#  u't1 similarli t2',
#  u't1 similarli t2 t1',
#  u'weaker stronger complet pictur',
#  u'weaker stronger complet',
#  u'level affect',
#  u'client set isol',
#  u't1 t2 t3 transact',
#  u'client set isol level',
#  u'databas set isol level',
#  u'level eye behold show',
#  u'gpa student tabl transact',
#  u'gpa transact commit',
#  u'gpa transact commit roll',
#  u't10 serializ',
#  u't10 serializ understand',
#  u'databas set isol',
#  u't10 serializ understand behavior',
#  u'level eye',
#  u'gpa transact serializ',
#  u'write time transact',
#  u'write time transact updat',
#  u'gpa transact serializ ll',
#  u't10 t11 transact',
#  u't10 t11 transact sequenc',
#  u'gpa transact t2',
#  u'level eye behold',
#  u'gpa student number 123',
#  u'level default serializ',
#  u'client submit transact databas',
#  u'level default serializ wo',
#  u't1 t2 transact updat',
#  u'client set transact',
#  u'client set transact read',
#  u'client submit sequenc',
#  u'client submit sequenc transact',
#  u'client submit transact',
#  u'client t1',
#  u'gpa student number',
#  u'client t1 t2',
#  u'client t1 t2 t9',
#  u't1 transact gpa',
#  u't1 transact gpa updat',
#  u'time dirti',
#  u'time dirti transact',
#  u'time dirti transact read',
#  u'behavior transact run concurr',
#  u'video focu isol portion',
#  u'read read exist databas',
#  u'concept isol level remind',
#  u'read client set',
#  u'read client',
#  u'1000',
#  u'standard level',
#  u'read averag gpa transact',
#  u'standard level read',
#  u'read averag enrol colleg',
#  u'standard level read uncommit',
#  u'assum implicitli',
#  u'assum implicitli commit',
#  u'read averag enrol',
#  u'school notic',
#  u'assum implicitli commit end',
#  u'concept call dirti',
#  u'school notic modifi',
#  u'school notic modifi high',
#  u'defin concept',
#  u'defin concept call',
#  u'defin concept call dirti',
#  u'trio transact size high',
#  u'trio transact size',
#  u'trio transact',
#  u'concept call dirti read',
#  u'trio',
#  u'specif read transact ll',
#  u'specif read transact',
#  u'concept isol',
#  u'concept isol level',
#  u'proceed learn',
#  u'1000 transact',
#  u'1000 transact read',
#  u'tabl transact read averag',
#  u'read data item',
#  u'equival transact t9',
#  u'equival transact execut serial',
#  u'equival transact execut',
#  u'read dirti word',
#  u'll detail start defin',
#  u'll detail start',
#  u'read dirti read uncommit',
#  u'applic care exact consist',
#  u'equival order suppos add',
#  u'equival order suppos',
#  u'applic care exact',
#  u'applic care',
#  u'read data item databas',
#  u'read commit transact t1',
#  u'1000 transact read averag',
#  u'read commit transact isol',
#  u'occur behavior',
#  u'occur behavior equival',
#  u'occur behavior equival order',
#  u'equival order',
#  u'read commit point transact',
#  u'standard isol',
#  u'read commit point',
#  u'standard isol level',
#  u'standard isol level default',
#  u'read client set transact',
#  u'tabl transact',
#  u'tabl transact read',
#  u'proceed learn isol',
#  u'proceed learn isol mention',
#  u'fourth serializ ve',
#  u'standford enrol 000',
#  u'statement statement perform client',
#  u'll increas concurr decreas',
#  u'commit roll back case',
#  u'commit repeat read isol',
#  u'statement statement perform',
#  u'commit point transact dirti',
#  u'commit point transact',
#  u'commit point time dirti',
#  u'commit point time',
#  u'commit end box write',
#  u'commit end box',
#  u'commit end',
#  u'execut serial',
#  u'execut serial order',
#  u'execut serial order case',
#  u'statement serializ system inter',
#  u'statement serializ system',
#  u'statement serializ',
#  u'execut statement statement',
#  u'offer weaker',
#  u'offer weaker isol',
#  u'offer weaker isol level',
#  u'averag enrol colleg tabl',
#  u'student 234 gpa',
#  u'student 234 gpa transact',
#  u'modif perform t1 case',
#  u'modif perform t1',
#  u'understand reduc consist guarante',
#  u'specif isol level read',
#  u'undon transact read',
#  u'undon transact read undon',
#  u'll increas concurr',
#  u'undon transact roll',
#  u'standford enrol 000 ad',
#  u'standford enrol ad',
#  u'standford enrol ad 1000',
#  u'commit ve drop transact',
#  u'commit ve drop',
#  u'commit ve',
#  u'commit transact t1 dirti',
#  u'll call t1',
#  u'll call t1 t2',
#  u'school read commit',
#  u'undon transact t1 t2',
#  u'undon transact t1',
#  u'undon transact roll back',
#  u'school read commit point',
#  u'll increas',
#  u'school read size',
#  u'school read size high',
#  u'commit transact t1',
#  u'commit transact ll call',
#  u'commit transact ll',
#  u'commit transact isol level',
#  u'commit transact isol',
#  u'commit system failur transact',
#  u'commit system failur',
#  u'case serializ',
#  u'case serializ behavior',
#  u'case serializ behavior t1',
#  u'commit system',
#  u'fourth serializ',
#  u'fourth serializ ve talk',
#  u'specif isol',
#  u'modifi transact isol',
#  u'approxim gpa',
#  u'read undon transact t1',
#  u'read undon transact',
#  u'approxim gpa isol',
#  u'read undon',
#  u'approxim gpa isol level',
#  u'sql standard isol',
#  u'read uncommit properti guarante',
#  u'care exact consist mind',
#  u'care exact consist',
#  u'sql standard isol level',
#  u'read uncommit properti',
#  u'read uncommit modifi transact',
#  u'read uncommit modifi',
#  u'sql standard level',
#  u'read uncommit long sentenc',
#  u'read uncommit long',
#  u'sql standard level read',
#  u'read trio transact size',
#  u'updat gpa ve averag',
#  u'read trio transact',
#  u'read trio',
#  u'updat gpa ve',
#  u'read transact typic written',
#  u'read transact typic',
#  u'read transact t3 ve',
#  u'read transact t3',
#  u'read transact ll detail',
#  u'read transact ll',
#  u'decreas overhead perform understand',
#  u'decreas overhead perform',
#  u'updat remind order',
#  u'control system failur problem',
#  u'll behavior guarante',
#  u'll behavior guarante equival',
#  u'averag gpa transact',
#  u'averag gpa transact serializ',
#  u'averag increas',
#  u'averag increas gpa',
#  u'averag increas gpa end',
#  u'exact consist',
#  u'averag enrol colleg',
#  u'averag enrol',
#  u'exact consist mind',
#  u'exact consist mind averag',
#  u'averag comput mind comput',
#  u'averag comput mind',
#  u'stronger complet pictur bottom',
#  u'averag read dirti',
#  u'averag read dirti word',
#  u'averag comput comput middl',
#  u'complet pictur bottom fourth',
#  u'complet pictur bottom',
#  u'complet pictur',
#  u'averag comput comput',
#  u'problem databas transact sequenc',
#  u'problem databas transact',
#  ...]
