# %%
import os
import nltk

import numpy as np

from collections import OrderedDict, defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# %%
documents = OrderedDict()

for name in os.listdir('../../../data/Introduction_to_Databases_Captions'):
    with open('../../../data/Introduction_to_Databases_Captions/' + name) as f:
        lines = []
        for line in f:
            lines.append(line.strip('| \n'))
        documents[name] = ' '.join(lines)
        
keywords = defaultdict(set)
stemmer = nltk.stem.PorterStemmer()

for name in os.listdir('../../../data/keywords/'):
    with open('../../../data/keywords/' + name) as f:
        for line in f:
            lecture_name, key, _, rank = line.strip().split(',')
            rank = int(rank)
            key = key.replace('-', ' ')
            key = ' '.join(stemmer.stem(token) for token in nltk.word_tokenize(key))
            key = key.lower()
            keywords[lecture_name].add(key)

# %%
stopwords = []
with open('../../../data/smart.txt') as f:
    for line in f:
        line = line.strip()
        tokens = nltk.word_tokenize(line)
        stopwords.append(' '.join([stemmer.stem(token) for token in tokens]))
    
stemmed_documents = OrderedDict()

for name, document in documents.items():
    document = document.replace('-', ' ')
    document = ' '.join([stemmer.stem(token) for token in nltk.word_tokenize(document)])
    stemmed_documents[name] = document.lower()

extractor = TfidfVectorizer(stop_words=stopwords, ngram_range=(1,4))
X = extractor.fit_transform(stemmed_documents.values())
inverse_voc = {v: k for k, v in extractor.vocabulary_.items()}

extracted = OrderedDict()
for doc_idx, name in enumerate(stemmed_documents.keys()):
    extracted[name] = [inverse_voc[idx] for idx in np.argsort(X[doc_idx,:].toarray().flatten())]

# %%
matches = OrderedDict()
jaccard = OrderedDict()

for name, keys in sorted(keywords.items()):
    extracted_words = extracted[name][-len(keys):]
    matches[name.replace('.keys', '')] = list(set(keys).intersection(extracted_words))
    jaccard[name.replace('.keys', '')] = float(len(set(keys).intersection(extracted_words))) / len(set(keys).union(set(extracted_words)))
    
print('Average jaccard: {}'.format(sum(jaccard.values()) / len(jaccard)))
# Out:
# Average jaccard: 0.116370291814

# %%
matches = OrderedDict()
jaccard = OrderedDict()

for name, keys in sorted(keywords.items()):
    extracted_words = extracted[name][-2*len(keys):]
    matches[name.replace('.keys', '')] = list(set(keys).intersection(extracted_words))
    jaccard[name.replace('.keys', '')] = float(len(set(keys).intersection(extracted_words))) / len(set(keys).union(set(extracted_words)))
    
print('Average jaccard: {}'.format(sum(jaccard.values()) / len(jaccard)))
# Out:
# Average jaccard: 0.105646126594

# %%
with open('tfidf_keys.csv', 'w') as f:
    for document, keys in sorted(extracted.items()):
        keys = list(reversed(keys))
        for i, key in enumerate(keys[:10]):
            if i < 5:
                f.write('{},{},{}\n'.format(document, key, i + 1))
            else:
                f.write('{},{},{}\n'.format(document, key, 0))

# %%
matches
# Out:
# OrderedDict([('01_01_Introduction.txt',
#               [u'applic',
#                u'databas manag system',
#                u'databas',
#                u'data model',
#                u'framework',
#                u'design',
#                u'user',
#                u'databas system',
#                u'data']),
#              ('02_01_The_Relational_Model.txt',
#               [u'relat model',
#                u'relat',
#                u'queri',
#                u'tabl',
#                u'key',
#                u'tupl',
#                u'null',
#                u'attribut']),
#              ('02_02_Querying_Relational_Databases.txt',
#               [u'relat databas',
#                u'queri',
#                u'relat',
#                u'queri languag',
#                u'sql',
#                u'relat algebra']),
#              ('03_01_Well_Formed_XML_Part_1.txt',
#               [u'open tag',
#                u'xml',
#                u'remark',
#                u'close tag',
#                u'relat model',
#                u'structur',
#                u'html',
#                u'attribut',
#                u'order',
#                u'schema']),
#              ('03_01_Well_Formed_XML_Part_2.txt',
#               [u'xml',
#                u'xml parser',
#                u'css',
#                u'xml document',
#                u'pars xml',
#                u'xsl']),
#              ('03_02_DTDs_IDs_and_IDREFs.txt',
#               [u'remark',
#                u'dtd',
#                u'valid',
#                u'xsd',
#                u'id',
#                u'id ref',
#                u'attribut']),
#              ('03_02_XML_Schema.txt',
#               [u'xml schema', u'dtd', u'xsd', u'key', u'valid']),
#              ('04_01_Introduction_to_JSON_Data_Part_1.txt',
#               [u'relat model', u'object', u'array', u'json']),
#              ('04_01_Introduction_to_JSON_Data_Part_2.txt',
#               [u'json schema', u'xml', u'json', u'valid', u'schema']),
#              ('04_02_JSON_Demo.txt',
#               [u'json data',
#                u'string',
#                u'object',
#                u'properti',
#                u'integ',
#                u'json schema',
#                u'valid',
#                u'array',
#                u'schema']),
#              ('05_01_Select_Project_Join_Part_1.txt',
#               [u'oper',
#                u'project oper',
#                u'queri',
#                u'relat algebra',
#                u'select oper',
#                u'sigma']),
#              ('05_01_Select_Project_Join_Part_2.txt', [u'cross product']),
#              ('05_01_Select_Project_Join_Part_3.txt',
#               [u'cross product', u'natur join']),
#              ('05_01_Select_Project_Join_Part_4.txt',
#               [u'theta', u'theta join', u'theta join oper']),
#              ('05_02_Set_Operators_Renaming_Notation_Part_1.txt',
#               [u'intersect']),
#              ('05_02_Set_Operators_Renaming_Notation_Part_2.txt',
#               [u'renam oper']),
#              ('05_02_Set_Operators_Renaming_Notation_Part_3.txt',
#               [u'oper',
#                u'express tree',
#                u'relat algebra express',
#                u'relat algebra',
#                u'assign statement',
#                u'natur join']),
#              ('06_01_Introduction_to_SQL.txt',
#               [u'data manipul', u'sql', u'select', u'select statement']),
#              ('06_02_Basic_SELECT_Statement.txt',
#               [u'queri', u'join', u'select', u'attribut']),
#              ('06_03_Table_Variables_and_Set_Operators.txt',
#               [u'tabl variabl']),
#              ('06_04_Subqueries_in_FROM_and_SELECT.txt', [u'select']),
#              ('06_04_Subqueries_in_WHERE_Clause.txt', [u'exist']),
#              ('06_05_Aggregation.txt',
#               [u'count',
#                u'group',
#                u'aggreg function',
#                u'aggreg',
#                u'select claus',
#                u'averag']),
#              ('06_06_NULL_Values.txt', [u'null']),
#              ('06_07_Data_Modification_Statements.txt', [u'insert', u'delet']),
#              ('06_08_The_JOIN_Family_of_Operators.txt',
#               [u'join', u'theta join', u'natur join', u'outer join']),
#              ('07_01_Functional_Dependencies_Part_5.txt',
#               [u'function depend']),
#              ('07_01_Relational_Design_Overview_Part_1.txt',
#               [u'design', u'anomali']),
#              ('07_01_Relational_Design_Overview_Part_2.txt',
#               [u'function depend']),
#              ('07_01_Relational_Design_Overview_Part_3.txt', []),
#              ('07_01_Relational_Design_Overview_Part_4.txt', []),
#              ('07_02_Functional_Dependencies_Part_1.txt',
#               [u'function depend']),
#              ('07_02_Functional_Dependencies_Part_2.txt',
#               [u'function depend']),
#              ('07_02_Functional_Dependencies_Part_3.txt',
#               [u'closur', u'trivial', u'function depend', u'key']),
#              ('07_02_Functional_Dependencies_Part_4.txt',
#               [u'function depend']),
#              ('07_03_Boyce_Codd_Normal_Form_Part_1.txt',
#               [u'function depend', u'key', u'decomposit']),
#              ('07_03_Boyce_Codd_Normal_Form_Part_2.txt',
#               [u'function depend', u'decomposit']),
#              ('07_03_Boyce_Codd_Normal_Form_Part_3.txt',
#               [u'bcnf', u'function depend', u'decompos']),
#              ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_1.txt',
#               [u'function depend']),
#              ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_2.txt',
#               [u'multivalu depend']),
#              ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_3.txt',
#               [u'function depend', u'rule', u'key', u'multivalu depend']),
#              ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_4.txt',
#               [u'depend']),
#              ('07_05_Shortcomings_of_BCNF_and_4NF.txt', [u'function depend']),
#              ('08_01_XPath_Introduction.txt',
#               [u'function',
#                u'xml',
#                u'xpath',
#                u'xslt',
#                u'path express',
#                u'tree',
#                u'descend',
#                u'slash',
#                u'squar bracket',
#                u'condit',
#                u'axi']),
#              ('08_02_XPath_Demo.txt',
#               [u'xpath', u'remark', u'navig', u'queri', u'slash', u'condit']),
#              ('08_03_XQuery_Introduction.txt',
#               [u'xpath',
#                u'xqueri',
#                u'queri',
#                u'relat',
#                u'flwor',
#                u'flwor express']),
#              ('08_04_XQuery_Demo.txt',
#               [u'xml', u'queri', u'xqueri', u'return claus', u'construct']),
#              ('08_05_XSLT.txt',
#               [u'xpath',
#                u'templat match',
#                u'xslt',
#                u'replac',
#                u'tree',
#                u'transform',
#                u'templat',
#                u'ambigu',
#                u'html']),
#              ('09_01_UML_Data_Modeling.txt',
#               [u'primari key',
#                u'diamond',
#                u'composit',
#                u'data model',
#                u'overlap',
#                u'uml',
#                u'disjoint',
#                u'multipl',
#                u'star',
#                u'class',
#                u'complet']),
#              ('09_02_UML_to_Relations_Part_1.txt',
#               [u'relat', u'translat', u'key', u'class']),
#              ('09_02_UML_to_Relations_Part_2.txt',
#               [u'super class', u'relat', u'translat', u'key', u'attribut']),
#              ('09_02_UML_to_Relations_Part_3.txt', [u'composit', u'translat']),
#              ('10_01_Indexes_Part_1.txt',
#               [u'condit', u'hash tabl', u'balanc tree', u'index']),
#              ('10_01_Indexes_Part_2.txt', [u'index', u'design advisor']),
#              ('11_01_Introduction_to_Transactions.txt', [u'transact']),
#              ('11_02_Transactions_Properties_Part_1.txt',
#               [u'transact', u'isol']),
#              ('11_02_Transactions_Properties_Part_2.txt', [u'transact']),
#              ('11_02_Transactions_Properties_Part_3.txt',
#               [u'transact', u'rollback']),
#              ('11_03_Isolation_Levels_Part_1.txt',
#               [u'isol level',
#                u'transact',
#                u'serializ',
#                u'dirti read',
#                u'isol']),
#              ('11_03_Isolation_Levels_Part_2.txt', [u'isol level']),
#              ('11_03_Isolation_Levels_Part_3.txt', [u'repeat read']),
#              ('11_03_Isolation_Levels_Part_4.txt',
#               [u'isol level', u'transact', u'repeat read']),
#              ('12_01_Motivation_and_Overview.txt',
#               [u'trigger', u'constraint']),
#              ('12_02_Constraints_of_Several_Types_Part_1.txt',
#               [u'key constraint',
#                u'assert',
#                u'check constraint',
#                u'constraint']),
#              ('12_02_Constraints_of_Several_Types_Part_2.txt', []),
#              ('12_03_Referential_Integrity_Part_1.txt', [u'referenti integr']),
#              ('12_03_Referential_Integrity_Part_2.txt', [u'foreign key']),
#              ('12_03_Referential_Integrity_Part_3.txt',
#               [u'referenti integr constraint', u'referenti integr']),
#              ('12_04_Triggers_Introduction.txt',
#               [u'statement level', u'trigger']),
#              ('12_05_Triggers_Demo_Part_1.txt',
#               [u'delet', u'sqlite', u'trigger', u'insert']),
#              ('12_05_Triggers_Demo_Part_2.txt', []),
#              ('13_01_Defining_and_Using_Views.txt', [u'view']),
#              ('13_02_View_Modifications_Introduction_Part_1.txt',
#               [u'base tabl', u'modif']),
#              ('13_02_View_Modifications_Introduction_Part_2.txt', []),
#              ('13_03_View_Modifications_Using_Triggers.txt',
#               [u'insert', u'trigger']),
#              ('13_04_Automatic_View_Modifications.txt',
#               [u'delet', u'check option', u'modif', u'insert', u'updat']),
#              ('13_05_Materialized_Views_Part_1.txt',
#               [u'virtual view', u'queri', u'materi view']),
#              ('13_05_Materialized_Views_Part_2.txt',
#               [u'view queri', u'modif', u'materi view', u'queri']),
#              ('13_05_Materialized_Views_Part_3.txt', []),
#              ('14_01_Authorization_Part_1.txt', [u'read', u'privileg']),
#              ('14_01_Authorization_Part_2.txt', [u'privileg', u'view']),
#              ('14_01_Authorization_Part_3.txt',
#               [u'revok', u'privileg', u'revok privileg', u'cascad']),
#              ('14_01_Authorization_Part_4.txt', []),
#              ('15_01_Basic_Recursive_WITH_Statement_Introduction.txt',
#               [u'queri', u'recurs', u'recurs queri']),
#              ('15_02_Basic_Recursive_WITH_Statement_Demo.txt',
#               [u'recurs', u'superior', u'root']),
#              ('15_03_Nonlinear_and_Mutual_Recursion_Part_1.txt', [u'recurs']),
#              ('15_03_Nonlinear_and_Mutual_Recursion_Part_2.txt',
#               [u'mutual recurs', u'recurs', u'hub', u'author']),
#              ('16_01_Introduction_to_OLAP_Part_1.txt',
#               [u'olap', u'star schema', u'cube', u'aggreg']),
#              ('16_01_Introduction_to_OLAP_Part_2.txt',
#               [u'olap', u'cube', u'rollup']),
#              ('16_02_OLAP_Demo.txt',
#               [u'cube', u'slice', u'aggreg', u'data cube']),
#              ('17_01_NoSQLMotivation.txt', [u'nosql system', u'nosql']),
#              ('17_01_NoSQLOverview.txt',
#               [u'reduc',
#                u'mapper',
#                u'mapreduc',
#                u'graph databas system',
#                u'nosql',
#                u'map',
#                u'reduc function',
#                u'hadoop',
#                u'hive',
#                u'pig',
#                u'user',
#                u'key',
#                u'reader',
#                u'map function',
#                u'mapreduc framework'])])

# %%
list(reversed(extracted['17_01_NoSQLOverview.txt']))
# Out:
# [u'reduc',
#  u'function',
#  u'record',
#  u'mapreduc',
#  u'map',
#  u'node',
#  u'key',
#  u'reduc function',
#  u'domain',
#  u'map function',
#  u'framework',
#  u'mapreduc framework',
#  u'key store',
#  u'system',
#  u'store',
#  u'output',
#  u'data',
#  u'record key',
#  u'user',
#  u'file',
#  u'graph',
#  u'hadoop',
#  u'pig',
#  u'document',
#  u'edg',
#  u'count',
#  u'graph databas',
#  u'produc output',
#  u'mapper',
#  u'hive',
#  u'input',
#  u'nosql',
#  u'job',
#  u'oper',
#  u'produc',
#  u'url',
#  u'process',
#  u'output record',
#  u'novemb 2011',
#  u'toler',
#  u'reader',
#  u'graph databas system',
#  u'access domain',
#  u'novemb',
#  u'input record',
#  u'document store',
#  u'scalabl',
#  u'extract',
#  u'model',
#  u'score',
#  u'massiv',
#  u'addit inform',
#  u'2011',
#  u'function reduc function',
#  u'map reduc',
#  u'fault toler',
#  u'function reduc',
#  u'db',
#  u'hive pig',
#  u'rdf',
#  u'friend',
#  u'access',
#  u'languag',
#  u'fetch',
#  u'key pair',
#  u'googl',
#  u'writer',
#  u'fault',
#  u'databas',
#  u'll',
#  u'problem',
#  u'list',
#  u'combin',
#  u'grade',
#  u'nosql system',
#  u'data model',
#  u'send',
#  u'open sourc',
#  u'function map function',
#  u'store graph',
#  u'record ll',
#  u'function map',
#  u'produc output record',
#  u'function produc',
#  u'store graph databas',
#  u'workflow',
#  u'writer function',
#  u'function system',
#  u'addit',
#  u'tradit',
#  u'null',
#  u'small',
#  u'parallel',
#  u'insid',
#  u'machin',
#  u'implement',
#  u'databas system',
#  u'simpl',
#  u'pair',
#  u'call',
#  u'base',
#  u'thing',
#  u'column',
#  u'set',
#  u'sourc',
#  u'amount data',
#  u'distribut',
#  u'task',
#  u'inform',
#  u'base key',
#  u'amount',
#  u'code',
#  u'analysi',
#  u'perform',
#  u'function domain',
#  u'ben',
#  u'set record key',
#  u'list null',
#  u'map function record',
#  u'open sourc implement',
#  u'sourc implement',
#  u'document store graph',
#  u'domain count',
#  u'll send',
#  u'function record',
#  u'reduc function produc',
#  u'map function reduc',
#  u'edg make',
#  u'hadoop open sourc implement',
#  u'hadoop open sourc',
#  u'store graph databas system',
#  u'data process',
#  u'driad',
#  u'column store',
#  u'store document',
#  u'massiv databas',
#  u'data model key',
#  u'specif function',
#  u'hadoop open',
#  u'sit top',
#  u'document store graph databas',
#  u'map function reduc function',
#  u'open',
#  u'sort',
#  u'box',
#  u'key key',
#  u'applic',
#  u'effici',
#  u'typic',
#  u'simpl oper',
#  u'glue',
#  u'count access',
#  u'carol',
#  u'combin function',
#  u'model key',
#  u'node edg',
#  u'compil',
#  u'type',
#  u'mention',
#  u'bit',
#  u'higher',
#  u'consist',
#  u'properti',
#  u'set record',
#  u'tradit databas',
#  u'make',
#  u'pre',
#  u'divid',
#  u'process data',
#  u'import',
#  u'remind',
#  u'object',
#  u'format',
#  u'start',
#  u'sql',
#  u'transact',
#  u'data set',
#  u'comput',
#  u'requir',
#  u'singl',
#  u'larg',
#  u'similar',
#  u'queri',
#  u'relat databas system',
#  u'time',
#  u'structur',
#  u'data file',
#  u'sit',
#  u'involv',
#  u'separ',
#  u'sum',
#  u'top',
#  u'key fetch',
#  u'pair record',
#  u'reduc function domain',
#  u'system fault toler',
#  u'extract record file',
#  u'extract record',
#  u'node id',
#  u'small oper',
#  u'base addit inform',
#  u'base addit',
#  u'node id grade',
#  u'record file',
#  u'function output',
#  u'singl record',
#  u'sort pre',
#  u'system fault',
#  u'node properti',
#  u'function produc output',
#  u'domain list',
#  u'domain key',
#  u'domain insid url',
#  u'domain insid',
#  u'2011 thing',
#  u'eventu consist',
#  u'count access domain',
#  u'insid url',
#  u'remind previou video nosql',
#  u'map box',
#  u'perform task',
#  u'domain comput',
#  u'relax consist model',
#  u'record map',
#  u'file final',
#  u'reduc reduc',
#  u'reduc function reduc function',
#  u'type edg',
#  u'writer function write',
#  u'call map',
#  u'function domain list',
#  u'model key store',
#  u'id grade',
#  u'mapreduc framework key',
#  u'exhaust list',
#  u'output domain',
#  u'ship record',
#  u'node edg node',
#  u'ship',
#  u'key delet',
#  u'reduc function reduc',
#  u'mapreduc framework key store',
#  u'key delet record',
#  u'gener hive pig',
#  u'll discuss',
#  u'mapreduc job',
#  u'simpl data model key',
#  u'consist model',
#  u'reduc function map',
#  u'reduc function map function',
#  u'gener hive',
#  u'object node',
#  u'function map function reduc',
#  u'reduc function produc output',
#  u'data function',
#  u'object node edg',
#  u'time mapreduc',
#  u'combin sort',
#  u'count sum',
#  u'record output',
#  u'bit statement',
#  u'hadoop mapreduc framework',
#  u'user reader function',
#  u'previou video nosql system',
#  u'direct edg',
#  u'data model key store',
#  u'key store document',
#  u'user reader',
#  u'modifi map',
#  u'novemb 2011 thing',
#  u'function reduc function map',
#  u'function remind',
#  u'key record',
#  u'divid problem',
#  u'reader function',
#  u'function user',
#  u'call combin',
#  u'reader writer',
#  u'previou video nosql',
#  u'repres peopl',
#  u'label roll',
#  u'option function',
#  u'stringent',
#  u'access domain comput',
#  u'key produc output',
#  u'compil workflow',
#  u'key produc',
#  u'framework key',
#  u'url domain',
#  u'edg node',
#  u'total access',
#  u'hadoop mapreduc',
#  u'data mapreduc',
#  u'data mapreduc framework',
#  u'store document store',
#  u'key pair record',
#  u'function write',
#  u'produc domain',
#  u'list count',
#  u'grade ll',
#  u'languag sit',
#  u'total access domain',
#  u'framework key store',
#  u'languag sit top',
#  u'hadoop job',
#  u'term',
#  u'modifi',
#  u'piec',
#  u'id',
#  u'direct',
#  u'option',
#  u'ami',
#  u'occur',
#  u'lot',
#  u'point time',
#  u'massiv amount data',
#  u'data model data',
#  u'languag call',
#  u'languag program',
#  u'record user',
#  u'oper transact',
#  u'simpl data model',
#  u'relax consist',
#  u'comput node',
#  u'architectur',
#  u'remind previou',
#  u'remind previou video',
#  u'combin ll',
#  u'k1',
#  u'insid addit',
#  u'user id',
#  u'valuabl',
#  u'oltp',
#  u'node node',
#  u'simpl data',
#  u'delet record',
#  u'insid addit inform',
#  u'video nosql',
#  u'video nosql system',
#  u'imagin',
#  u'pictur',
#  u'kind',
#  u'excit',
#  u'larg amount',
#  u'sql sql',
#  u'larg amount data',
#  u'system care',
#  u'analyt',
#  u'function call',
#  u'massiv amount',
#  u'promin',
#  u'thing bit',
#  u'pre aggreg',
#  u'uniform',
#  u'higher perform',
#  u'concret',
#  u'queri languag',
#  u'content',
#  u'level',
#  u'specif',
#  u'program',
#  u'repres',
#  u'write',
#  u'field',
#  u'overview',
#  u'touch',
#  u'exhaust',
#  u'import thing',
#  u'eventu',
#  u'relax',
#  u'data analysi',
#  u'model data',
#  u'file system',
#  u'olap',
#  u'number',
#  u'discuss',
#  u'made',
#  u'embed',
#  u'basic oper',
#  u'recogn',
#  u'web',
#  u'count number',
#  u'earlier video',
#  u'onlin',
#  u'categori',
#  u'relat databas',
#  u'video',
#  u'declar queri',
#  u'roll',
#  u'talk',
#  u'previou video',
#  u'relat',
#  u'guarante',
#  u'solv',
#  u'mistak',
#  u'downsid',
#  u'surprisingli',
#  u'peopl',
#  u'end',
#  u'bunch',
#  u'origin',
#  u'total',
#  u'final',
#  u'put',
#  u'ten',
#  u'data ll',
#  u'idea',
#  u'declar',
#  u'design',
#  u'complex',
#  u'previou',
#  u'execut',
#  u'sql languag',
#  u'relationship',
#  u'aggreg',
#  u'interest',
#  u'pretti',
#  u'schema',
#  u'manag',
#  u'social',
#  u'work',
#  u'add',
#  u'point',
#  u'draw',
#  u'find',
#  u'label',
#  u'attach mapper kind',
#  u'specif oper standard',
#  u'resourc descript',
#  u'resourc',
#  u'data file writer function',
#  u'term sort roughli mapreduc',
#  u'specif oper',
#  u'offer schema languag',
#  u'store discuss term nosql',
#  u'data item input produc',
#  u'term evolv',
#  u'term evolv sql sql',
#  u'momentarili solut',
#  u'quick straight node fact',
#  u'data javascript',
#  u'data javascript object',
#  u'store key',
#  u'quick straight node',
#  u'quick straight',
#  u'develop languag',
#  u'data javascript object notat',
#  u'term evolv sql',
#  u'develop languag sit',
#  u'develop languag sit top',
#  u'specif key import',
#  u'data item input',
#  u'specif key import fetch',
#  u'data file writer',
#  u'offer schema languag sql',
#  u'resourc descript framework',
#  u'resourc descript framework rdf',
#  u'store graph databas data',
#  u'inform valuabl user user',
#  u'travers arbitrari depth graph',
#  u'offer schema',
#  u'occur system distribut',
#  u'occur system',
#  u'batch record key reduc',
#  u'effici lightli',
#  u'inform user separ addit',
#  u'travers arbitrari depth',
#  u'exchang data machin parallel',
#  u'store model',
#  u'store model base',
#  u'effici lightli load',
#  u'store model base column',
#  u'inform user separ',
#  u'effici lightli load node',
#  u'failur scalabl',
#  u'store discuss term',
#  u'travers arbitrari',
#  u'failur scalabl assign',
#  u'store discuss',
#  u'occur system distribut machin',
#  u'exchang data machin',
#  u'store key store',
#  u'specif oper standard fetch',
#  u'store key store document',
#  u'data file record writer',
#  u'data machin',
#  u'copi record',
#  u'data file record',
#  u'data machin parallel',
#  u'inform valuabl user',
#  u'data file real origin',
#  u'inform valuabl',
#  u'data machin parallel occur',
#  u'data file real',
#  u'built data',
#  u'store list',
#  u'batch record',
#  u'batch record key',
#  u'built data model',
#  u'built data model data',
#  u'store list googl',
#  u'store list googl big',
#  u'momentarili solut summar',
#  u'term sort',
#  u'momentarili solut summar mapreduc',
#  u'data function system fault',
#  u'specif function map function',
#  u'specif function map',
#  u'fail notion action key',
#  u'term nosql column store',
#  u'term nosql column',
#  u'store extrem simpl data',
#  u'term mapreduc open sourc',
#  u'failur scalabl assign process',
#  u'term mapreduc open',
#  u'effect involv join data',
#  u'effect involv join',
#  u'ship record output domain',
#  u'term mapreduc',
#  u'algebra back',
#  u'effici fault',
#  u'effici fault toler',
#  u'ship record output',
#  u'effect involv',
#  u'ship record node perform',
#  u'store exhaust',
#  u'specif function surprisingli',
#  u'fail notion action',
#  u'store extrem simpl',
#  u'inform start fairli simpl',
#  u'complic relationship case idea',
#  u'complic relationship case',
#  u'complic relationship',
#  u'store exhaust list novemb',
#  u'path express women friend',
#  u'path express women',
#  u'store extrem',
#  u'store insert document base',
#  u'specif function surprisingli function',
#  u'specif function user call',
#  u'data ll draw pictur',
#  u'data ll draw',
#  u'specif function user',
#  u'store insert document',
#  u'store insert',
#  u'store exhaust list',
#  u'fail notion',
#  u'understand architectur',
#  u'data ll start',
#  u'infrastructur piec',
#  u'algebra back addit',
#  u'mongo db simpl db',
#  u'mongo db simpl',
#  u'store file input',
#  u'set user id',
#  u'store document data model',
#  u'copi record case',
#  u'mongo db',
#  u'store file input output',
#  u'gon na repres',
#  u'gon na repres peopl',
#  u'infrastructur piec distribut multipl',
#  u'inform start fairli',
#  u'shortli concret',
#  u'shortli concret make',
#  u'store document data',
#  u'term sort roughli',
#  u'shortli concret make understand',
#  u'mongo',
#  u'infrastructur piec distribut',
#  u'determin score',
#  u'set user id age',
#  u'quicker cheaper set gear',
#  u'gon na key key',
#  u'data function system',
#  u'ship record node',
#  u'data function scalabl effici',
#  u'data ll start map',
#  u'effici fault toler time',
#  u'algebra back addit loop',
#  u'copi record case simpl',
#  u'determin score base addit',
#  u'gon na key',
#  u'effici applic',
#  u'store document store key',
#  u'data function scalabl',
#  u'store document store graph',
#  u'effici applic key store',
#  u'effici applic key',
#  u'understand architectur function',
#  u'understand architectur function process',
#  u'determin score base',
#  u'attach mapper kind put',
#  u'made novemb',
#  u'attach mapper',
#  u'modifi similar modif',
#  u'repres access',
#  u'repres access domain',
#  u'repres access domain reduc',
#  u'oper analyt oper involv',
#  u'oper analyt oper',
#  u'oper analyt',
#  u'modifi similar',
#  u'modifi similar modif made',
#  u'thing effici send',
#  u'data count',
#  u'data count access',
#  u'ami grade ll node',
#  u'ami grade ll',
#  u'ami grade',
#  u'data count access domain',
#  u'store typic type structur',
#  u'relat databas system addit',
#  u'thing effici send data',
#  u'job instanc map',
#  u'thing end output',
#  u'data combin ll put',
#  u'replic multipl',
#  u'amount data complex analys',
#  u'amount data complex',
#  u'replic multipl node',
#  u'replic multipl node effici',
#  u'thing end output method',
#  u'javascript object notat xml',
#  u'box set record key',
#  u'data complex analys',
#  u'data complex analys key',
#  u'thing end',
#  u'replica',
#  u'replica singl',
#  u'replica singl record',
#  u'replica singl record diverg',
#  u'store typic type',
#  u'store typic',
#  u'repres peopl properti',
#  u'thing bit sloppi idea',
#  u'assum reader extract record',
#  u'part data',
#  u'part data document',
#  u'show thing mention novemb',
#  u'show thing mention',
#  u'show thing',
#  u'part data document store',
#  u'thing bit sloppi',
#  u'repres peopl properti node',
#  u'thing bit complex map',
#  u'job gener',
#  u'job gener hive',
#  u'job gener hive pig',
#  u'job hadoop',
#  u'job hadoop open',
#  u'job hadoop open sourc',
#  u'assum reader extract',
#  u'assum reader',
#  u'ami ben',
#  u'ami ben direct',
#  u'repres peopl social',
#  u'repres peopl social graph',
#  u'store thing import requir',
#  u'store thing import',
#  u'store thing',
#  u'open sourc voldemort base',
#  u'open sourc voldemort',
#  u'open sourc system wide',
#  u'open sourc implement releas',
#  u'ami carol friend ll',
#  u'ami carol friend',
#  u'ami carol',
#  u'open sourc implement map',
#  u'open sourc implement hadoop',
#  u'ami ben direct edg',
#  u'data combin ll',
#  u'amount data function',
#  u'amount data function scalabl',
#  u'modifi map reduc',
#  u'video suppos addit',
#  u'video suppos addit web',
#  u'direct edg make',
#  u'analysi applic touch larg',
#  u'analysi applic touch',
#  u'modifi map function',
#  u'modifi map function stay',
#  u'modifi map reduc function',
#  u'straight node',
#  u'analys key store oltp',
#  u'analys key store',
#  u'analys key',
#  u'thing import requir uniform',
#  u'thing import requir',
#  u'thing import',
#  u'straight node fact record',
#  u'video suppos',
#  u'direct edg make type',
#  u'direct edg properti',
#  u'analysi data solv',
#  u'analyt oper involv scan',
#  u'analyt oper involv',
#  u'analyt oper',
#  u'bought modifi map reduc',
#  u'make thing effici send',
#  u'make thing effici',
#  u'execut glue guarante',
#  u'execut glue',
#  u'analysi talk import function',
#  u'analysi talk import',
#  u'analysi talk',
#  u'analysi problem divid problem',
#  u'analysi problem divid',
#  u'direct edg properti ben',
#  u'analysi data solv relat',
#  u'straight node fact',
#  u'assign process',
#  u'data combin',
#  u'box mapbox record',
#  u'make run faster',
#  u'make run',
#  u'box map function',
#  u'box map function input',
#  u'box mapbox',
#  u'amount data stringent perform',
#  u'amount data stringent',
#  u'box mapbox record produc',
#  u'assign process task',
#  u'amount data process pretti',
#  u'amount data process',
#  u'box set',
#  u'box set record',
#  u'data clear',
#  u'data clear mapreduc',
#  u'data clear mapreduc framework',
#  u'make run faster system',
#  u'box map',
#  u'relat databas system higher',
#  u'box input record map',
#  u'assign process task increas',
#  u'oper base document content',
#  u'oper base document',
#  u'modifi problem',
#  u'data call',
#  u'data call function',
#  u'data call function larg',
#  u'modifi problem ll',
#  u'modifi problem ll data',
#  u'oper base',
#  u'amount time mapreduc mapreduc',
#  u'amount time mapreduc',
#  u'relat databas system problem',
#  u'box input',
#  u'box input record',
#  u'job instanc',
#  u'job instanc map reduc',
#  u'olap type',
#  u'store pair key surprisingli',
#  u'oltp style applic small',
#  u'oltp style applic',
#  u'oltp style',
#  u'complic make work record',
#  u'requir properti',
#  u'requir properti edg',
#  u'requir properti edg label',
#  u'store pair key',
#  u'complic make',
#  u'input record start data',
#  u'input record start',
#  u'input record process separ',
#  u'input record process',
#  u'input record output record',
#  u'input record output',
#  u'input record map function',
#  u'complic make work',
#  u'oltp world',
#  u'job languag',
#  u'onlin transact process lot',
#  u'store run',
#  u'store remind hadoop mapreduc',
#  u'store remind hadoop',
#  u'store remind',
#  u'excit pretti excit write',
#  u'data document store graph',
#  u'excit pretti excit',
#  u'excit pretti',
#  u'oltp world remind',
#  u'high level complic',
#  u'high level complic make',
#  u'store rdf base object',
#  u'store rdf base',
#  u'store rdf',
#  u'onlin analyt process analysi',
#  u'oltp world remind onlin',
#  u'input record map',
#  u'input record ll problem',
#  u'input record ll',
#  u'input divid',
#  u'input file final',
#  u'input file',
#  u'input divid problem base',
#  u'join data',
#  u'join data set',
#  u'join data set support',
#  u'input divid problem',
#  u'store node properti insid',
#  u'input record job reader',
#  u'store node properti',
#  u'store node',
#  u'olap type oper analyt',
#  u'olap type oper',
#  u'make ami grade ll',
#  u'make ami grade',
#  u'make ami',
#  u'input file final output',
#  u'input output',
#  u'input output googl',
#  u'input output googl mapreduc',
#  u'input record job',
#  u'store pair',
#  u'input produc output key',
#  u'input produc output',
#  u'requir type',
#  u'requir type implement',
#  u'requir type implement imagin',
#  u'understand small social network',
#  u'requir uniform column',
#  u'requir uniform column key',
#  u'understand small social',
#  u'understand small',
#  u'store oltp world remind',
#  u'store oltp world',
#  u'store oltp',
#  u'store run queri',
#  u'store run queri oper',
#  u'fact record replic multipl',
#  u'uniform column',
#  u'uniform key pair',
#  u'uniform key',
#  u'store strict structur relat',
#  u'store strict structur',
#  u'store strict',
#  u'uniform column key store',
#  u'uniform column key',
#  u'googl mapreduc implement googl',
#  u'thing applic',
#  u'googl mapreduc implement',
#  u'googl mapreduc',
#  u'googl invent term mapreduc',
#  u'googl invent term',
#  u'googl invent',
#  u'googl hadoop open sourc',
#  u'thing applic massiv amount',
#  u'make friend',
#  u'make friend edg',
#  u'make friend edg make',
#  u'uniform key pair system',
#  u'job languag call',
#  u'job languag call driadlink',
#  u'thing bit complex',
#  u'job mapper',
#  u'job mapper pretti',
#  u'job mapper pretti simpl',
#  u'job move',
#  u'job move talk',
#  u'job move talk key',
#  u'job reader',
#  u'job reader file',
#  u'job reader file extract',
#  u'job reduc',
#  u'job reduc function',
#  u'job reduc function reduc',
#  u'thing applic massiv',
#  u'googl hadoop open',
#  u'fact record replic',
#  u'excit write coupl',
#  u'store sens organ',
#  u'store sens',
#  u'undoubtedli sql system cover',
#  u'undoubtedli sql system',
#  u'undoubtedli sql',
#  u'undoubtedli',
#  u'excit write coupl simpl',
#  u'excit write',
#  u'googl hadoop',
#  u'requir graph',
#  u'requir graph databas',
#  u'requir graph databas system',
#  u'fact record',
#  u'requir implement',
#  u'requir implement work',
#  u'requir implement work high',
#  u'store sens organ relat',
#  u'store simpl',
#  u'store simpl oper',
#  u'store simpl oper transact',
#  u'googl file system gf',
#  u'googl file system',
#  u'googl file',
#  u'googl big tabl amazon',
#  u'googl big tabl',
#  u'googl big',
#  u'make edg ami ben',
#  u'make edg ami',
#  u'make edg',
#  u'amazon dynamo cassandra open',
#  u'amazon dynamo cassandra',
#  u'amazon dynamo',
#  u'store small transact massiv',
#  u'store small transact',
#  u'store small',
#  u'data document store',
#  u'move talk',
#  u'inform reduc function domain',
#  u'comput node mapreduc framework',
#  u'put combin sort mapper',
#  u'put combin sort',
#  u'put combin',
#  u'base key fetch',
#  u'base key extract input',
#  u'base key extract',
#  u'key fetch base',
#  u'key fetch base key',
#  u'key fetch record',
#  u'key fetch record key',
#  u'comput node base',
#  u'comput node base key',
#  u'code find domain insid',
#  u'key find record',
#  u'key find record key',
#  u'code find domain',
#  u'code find',
#  u'base key fetch base',
#  u'lot excit',
#  u'lot excit pretti',
#  u'voldemort base',
#  u'addit web blog separ',
#  u'addit web blog',
#  u'base key modifi content',
#  u'base key modifi',
#  u'code inform determin score',
#  u'code inform determin',
#  u'voldemort',
#  u'voldemort base talk',
#  u'lot excit pretti excit',
#  u'voldemort base talk document',
#  u'code inform',
#  u'base key hash key',
#  u'base key hash',
#  u'key extract',
#  u'key extract input',
#  u'key extract input record',
#  u'comput node mapreduc',
#  u'base insid addit inform',
#  u'talk realiti start',
#  u'base insid addit',
#  u'addit node edg node',
#  u'addit node edg',
#  u'addit node',
#  u'key import fetch oper',
#  u'fetch queri',
#  u'fetch queri languag',
#  u'fetch queri languag point',
#  u'fetch rang',
#  u'fetch rang key',
#  u'fetch rang key key',
#  u'addit loop languag user',
#  u'addit loop languag',
#  u'addit loop',
#  u'gear massiv scalabl relax',
#  u'gear massiv scalabl',
#  u'gear massiv',
#  u'fetch record key',
#  u'key import fetch',
#  u'fetch oper base document',
#  u'fetch oper base',
#  u'gender find total access',
#  u'base insid',
#  u'code count number null',
#  u'code count number',
#  u'code count',
#  u'code code find domain',
#  u'code code find',
#  u'talk nosql term evolv',
#  u'gender find total',
#  u'fetch oper',
#  u'gender find',
#  u'key hash',
#  u'key hash key',
#  u'key hash key find',
#  u'fetch base',
#  u'fetch base key',
#  u'fetch base key modifi',
#  u'talk realiti',
#  u'talk realiti start input',
#  u'design olap type oper',
#  u'hive hive',
#  u'content record key delet',
#  u'content record key',
#  u'content record',
#  u'content key delet record',
#  u'content key delet',
#  u'content key',
#  u'hit limit',
#  u'hit limit conveni',
#  ...]

# %%
stemmed_documents['07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_1.txt'].count('multivalu depend')
# Out:
# 3

# %%
sum(1 for doc in stemmed_documents.values() if 'enumer domain' in doc)

# %%
matches['11_03_Isolation_Levels_Part_1.txt']

# %%
list(reversed(extracted['11_03_Isolation_Levels_Part_1.txt']))[:16]

# %%
matches['10_01_Indexes_Part_1.txt']

# %%
matches
