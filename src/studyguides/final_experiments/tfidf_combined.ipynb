# %%
import os
import nltk

import numpy as np

from collections import OrderedDict, defaultdict, Counter
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# %%
documents = OrderedDict()

for name in os.listdir('/Users/andrewlamb/Google_Drive/Stanford/CS199/DB_SelfPaced/Flat'):
    with open('/Users/andrewlamb/Google_Drive/Stanford/CS199/DB_SelfPaced/Flat/' + name) as f:
        lines = []
        for line in f:
            lines.append(line.strip('| \n'))
        documents[name] = (' '.join(lines))
        
keywords = defaultdict(set)
stemmer = nltk.stem.PorterStemmer()

for name in os.listdir('/Users/andrewlamb/Google_Drive/Stanford/CS199/studyguides/data/keywords'):
    with open('/Users/andrewlamb/Google_Drive/Stanford/CS199/studyguides/data/keywords/' + name) as f:
        for line in f:
            lecture_name, key, _, rank = line.strip().split(',')
            rank = int(rank)
            if rank > -1:
                key = key.replace('-', ' ')
                key = ' '.join(stemmer.stem(token) for token in nltk.word_tokenize(key))
                key = key.lower()
                keywords[lecture_name].add(key)

# %%
stopwords = []
with open('/Users/andrewlamb/Google_Drive/Stanford/CS199/RAKE-tutorial/SmartStoplistAdditional.txt') as f:
    for line in f:
        stopwords.append(line.strip())
        
external_tfidfs = Counter()
with open('tfidf_tf_log.out') as f:
    for line in f:
        word, tfidf = line.strip().split(':')
        tokens = nltk.word_tokenize(word)
        if tokens[0] in stopwords or tokens[-1] in stopwords: continue
        if len(tokens) < 2: continue
        if len(word) < 4: continue
        stemmed = ' '.join(stemmer.stem(token) for token in tokens)
        external_tfidfs[stemmed] += float(tfidf)

sorted(external_tfidfs.items(), key=lambda (k, v): (v, k), reverse=True)
# Out:
# [(u'multi valu depend', 331549013952.0),
#  (u'insert command', 165777991514.2),
#  (u'tupl base constraint', 165774506976.0),
#  (u'modif command', 165774506976.0),
#  (u'book sub element', 165774506976.0),
#  (u'author element', 165774506976.0),
#  (u'transit rule', 138147164749.1),
#  (u'multivalu depend', 135393059867.7),
#  (u'xslt specif', 110516337984.0),
#  (u'xml schema descriptor', 110516337984.0),
#  (u'student tupl', 110516337984.0),
#  (u'standford student', 110516337984.0),
#  (u'sql video', 110516337984.0),
#  (u'specif tupl', 110516337984.0),
#  (u'select privileg', 110516337984.0),
#  (u'select express', 110516337984.0),
#  (u'relat s1', 110516337984.0),
#  (u'relat algebra video', 110516337984.0),
#  (u'referenti integr violat', 110516337984.0),
#  (u'queri n time', 110516337984.0),
#  (u'post risk', 110516337984.0),
#  (u'physic design advisor', 110516337984.0),
#  (u'natur function depend', 110516337984.0),
#  (u'modif statement', 110516337984.0),
#  (u'mega relat', 110516337984.0),
#  (u'label valu pair', 110516337984.0),
#  (u'key valu store', 110516337984.0),
#  (u'json queri languag', 110516337984.0),
#  (u'json editor', 110516337984.0),
#  (u'item dimens tabl', 110516337984.0),
#  (u'id ref attribut', 110516337984.0),
#  (u'graph databas system', 110516337984.0),
#  (u'grant diagram', 110516337984.0),
#  (u'good schema', 110516337984.0),
#  (u'good decomposit', 110516337984.0),
#  (u'entir author sub element', 110516337984.0),
#  (u'document type descriptor', 110516337984.0),
#  (u'distinct student id', 110516337984.0),
#  (u'distinct gpa', 110516337984.0),
#  (u'decis column', 110516337984.0),
#  (u'current constraint', 110516337984.0),
#  (u'constraint video', 110516337984.0),
#  (u'boyc codd', 110516337984.0),
#  (u'bigger relat', 110516337984.0),
#  (u'base check constraint', 110516337984.0),
#  (u'balanc tree index', 110516337984.0),
#  (u'automat view modif', 110516337984.0),
#  (u'author sub element', 110516337984.0),
#  (u'auth element', 110516337984.0),
#  (u'appli tupl', 110516337984.0),
#  (u'appli tabl', 110516337984.0),
#  (u'ancestor tupl', 110516337984.0),
#  (u'intersect oper', 101311387888.0),
#  (u'relat algebra express', 87497037333.2),
#  (u'view queri', 82890014919.2),
#  (u'xml schema descript', 82888995757.1),
#  (u'tabl t3', 82888995757.1),
#  (u'tabl r1', 82888995757.1),
#  (u'result sql', 82888995757.1),
#  (u'previou trigger', 82888995757.1),
#  (u'outermost construct', 82888995757.1),
#  (u'normal form relat', 82888995757.1),
#  (u'item tabl', 82888995757.1),
#  (u'extens style sheet languag', 82888995757.1),
#  (u'exact same result', 82888995757.1),
#  (u'trigger chain', 73679881681.5),
#  (u'maximum gpa', 73679881681.5),
#  (u'low level trigger', 73679881681.5),
#  (u'ancestor relationship', 73679881681.5),
#  (u'ambigu error', 73679881681.5),
#  (u'high school size', 69075324643.7),
#  (u'isol level', 66845178294.869995),
#  (u'associ class', 66772773615.681),
#  (u'complic queri', 66312590421.0),
#  (u'map box', 64471447047.24),
#  (u'constraint system', 63155179880.75),
#  (u'complet relationship', 62168489086.94),
#  (u'lesser privileg', 61401062913.97),
#  (u'function depend', 59989544514.64),
#  (u'arbitrari depth', 59866210568.03),
#  (u'student id', 59494047095.26),
#  (u'store id', 58512114974.26),
#  (u'mutual recurs', 57893826599.59),
#  (u'open tag', 57773600700.69),
#  (u'item id', 57235948545.98),
#  (u'special attribut', 56969868023.099),
#  (u'cs applic', 55436856706.82),
#  (u'statement level trigger', 55265698953.8),
#  (u'key violat', 55265138068.4),
#  (u'row level trigger', 55264414961.4),
#  (u'relat algebra queri', 55262672692.3),
#  (u'nontrivi function depend', 55261653530.2),
#  (u'hub relat', 55261653530.2),
#  (u'author node', 55261653530.2),
#  (u'xsd line', 55258168992.0),
#  (u'xsd languag', 55258168992.0),
#  (u'xqueri exampl', 55258168992.0),
#  (u'xml schema specif', 55258168992.0),
#  (u'xml queri result insid', 55258168992.0),
#  (u'xml look result', 55258168992.0),
#  (u'xml link featur', 55258168992.0),
#  (u'xml documentthey', 55258168992.0),
#  (u'wrong trigger', 55258168992.0),
#  (u'wonder schema', 55258168992.0),
#  (u'width cube', 55258168992.0),
#  (u'weird queri', 55258168992.0),
#  (u'weblog applic', 55258168992.0),
#  (u'webkit transit time function', 55258168992.0),
#  (u'webkit transit properti', 55258168992.0),
#  (u'webkit transit durat', 55258168992.0),
#  (u'webkit transit delay', 55258168992.0),
#  (u'webkit box shadow', 55258168992.0),
#  (u'web access record', 55258168992.0),
#  (u'weakest guarante', 55258168992.0),
#  (u'weaker isol level', 55258168992.0),
#  (u'weaker consist guarante', 55258168992.0),
#  (u'washington jacket', 55258168992.0),
#  (u'view tupl', 55258168992.0),
#  (u'view non uniqu', 55258168992.0),
#  (u'view modif command', 55258168992.0),
#  (u'view cs burk', 55258168992.0),
#  (u'view cs berk', 55258168992.0),
#  (u'view cs accept', 55258168992.0),
#  (u'view creator', 55258168992.0),
#  (u'venn diagram format', 55258168992.0),
#  (u'variabl key list', 55258168992.0),
#  (u'variabl concurr', 55258168992.0),
#  (u'variabl claus', 55258168992.0),
#  (u'variabl b2', 55258168992.0),
#  (u'variabl b1', 55258168992.0),
#  (u'valid command', 55258168992.0),
#  (u'valid button', 55258168992.0),
#  (u'usual simpl colleg admiss databas', 55258168992.0),
#  (u'usual sampl databas', 55258168992.0),
#  (u'user u2', 55258168992.0),
#  (u'user u1', 55258168992.0),
#  (u'user queri queue', 55258168992.0),
#  (u'user privileg', 55258168992.0),
#  (u'upper left window', 55258168992.0),
#  (u'unreli student', 55258168992.0),
#  (u'unord model', 55258168992.0),
#  (u'unlik queri overview', 55258168992.0),
#  (u'uniqu student id', 55258168992.0),
#  (u'uniqu key constraint', 55258168992.0),
#  (u'uniqu enrol', 55258168992.0),
#  (u'union differ', 55258168992.0),
#  (u'uniform key valu pair', 55258168992.0),
#  (u'understand algebra', 55258168992.0),
#  (u'underli modif', 55258168992.0),
#  (u'uncondit action rule', 55258168992.0),
#  (u'uncommit valu', 55258168992.0),
#  (u'uncommit gpa modif', 55258168992.0),
#  (u'unaccept hobbi', 55258168992.0),
#  (u'umo model', 55258168992.0),
#  (u'uml model video', 55258168992.0),
#  (u'uml languag', 55258168992.0),
#  (u'uml data model subset', 55258168992.0),
#  (u'ullman jefferi', 55258168992.0),
#  (u'typic middl ware', 55258168992.0),
#  (u'typic comput system', 55258168992.0),
#  (u'type sql queri', 55258168992.0),
#  (u'twenti five tupl', 55258168992.0),
#  (u'tuppl refer', 55258168992.0),
#  (u'tuppl insert', 55258168992.0),
#  (u'tupl t2', 55258168992.0),
#  (u'tupl t1', 55258168992.0),
#  (u'tupl level insert', 55258168992.0),
#  (u'tupl gener depend', 55258168992.0),
#  (u'tupl base check constraint', 55258168992.0),
#  (u'trivial sql queri', 55258168992.0),
#  (u'trivial multivalu depend', 55258168992.0),
#  (u'trivial multi valu depend', 55258168992.0),
#  (u'trivial depend rule', 55258168992.0),
#  (u'trivial depend', 55258168992.0),
#  (u'tripl null', 55258168992.0),
#  (u'trigger writer', 55258168992.0),
#  (u'trigger t3', 55258168992.0),
#  (u'trigger r3', 55258168992.0),
#  (u'trigger r2', 55258168992.0),
#  (u'trigger r1', 55258168992.0),
#  (u'trigger process stop', 55258168992.0),
#  (u'trigger process session', 55258168992.0),
#  (u'trigger monitor', 55258168992.0),
#  (u'trigger execut', 55258168992.0),
#  (u'trickier issu', 55258168992.0),
#  (u'transit closur flavor', 55258168992.0),
#  (u'transit case', 55258168992.0),
#  (u'transact t9', 55258168992.0),
#  (u'transact roll back', 55258168992.0),
#  (u'transact guarente', 55258168992.0),
#  (u'transact guarante', 55258168992.0),
#  (u'tradit templat match style', 55258168992.0),
#  (u'tradit relat data base manag system', 55258168992.0),
#  (u'tradit databas queri process', 55258168992.0),
#  (u'toy databas', 55258168992.0),
#  (u'toy applic code', 55258168992.0),
#  (u'total total sale', 55258168992.0),
#  (u'total sub cost', 55258168992.0),
#  (u'total salari class', 55258168992.0),
#  (u'titl subel', 55258168992.0),
#  (u'titl sub element', 55258168992.0),
#  (u'time tupl', 55258168992.0),
#  (u'thaql standard', 55258168992.0),
#  (u'text leaf valu', 55258168992.0),
#  (u'text leaf', 55258168992.0),
#  (u'terribl type', 55258168992.0),
#  (u'terminolog pk', 55258168992.0),
#  (u'term mapreduc', 55258168992.0),
#  (u'templat match rule', 55258168992.0),
#  (u'tag html', 55258168992.0),
#  (u'tabl v now queri', 55258168992.0),
#  (u'tabl t assert', 55258168992.0),
#  (u'tabl t 1', 55258168992.0),
#  (u'tabl relat', 55258168992.0),
#  (u'tabl level variabl', 55258168992.0),
#  (u'system failur problem', 55258168992.0),
#  (u'system failur manag', 55258168992.0),
#  (u'system couch db', 55258168992.0),
#  (u'system concurr', 55258168992.0),
#  (u'syntact necess', 55258168992.0),
#  (u'symant error', 55258168992.0),
#  (u'support view modif', 55258168992.0),
#  (u'super larg colleg', 55258168992.0),
#  (u'super class key', 55258168992.0),
#  (u'subset a bar', 55258168992.0),
#  (u'subscript theta', 55258168992.0),
#  (u'subqueri return', 55258168992.0),
#  (u'subel structur', 55258168992.0),
#  (u'subclass relationship', 55258168992.0),
#  (u'student name bob', 55258168992.0),
#  (u'student id tabl', 55258168992.0),
#  (u'student id match', 55258168992.0),
#  (u'student id colleg name combin', 55258168992.0),
#  (u'student id attribut', 55258168992.0),
#  (u'student dot sid', 55258168992.0),
#  (u'structur tabl format', 55258168992.0),
#  (u'string march', 55258168992.0),
#  (u'string leaf', 55258168992.0),
#  (u'straightforward mistak', 55258168992.0),
#  (u'straight forward translat', 55258168992.0),
#  (u'straight forward topic', 55258168992.0),
#  (u'store s3', 55258168992.0),
#  (u'store id valu', 55258168992.0),
#  (u'store domain', 55258168992.0),
#  (u'store dimens tabl', 55258168992.0),
#  (u'statement level insert', 55258168992.0),
#  (u'statement level equival', 55258168992.0),
#  (u'state/gend combin', 55258168992.0),
#  (u'start tabl', 55258168992.0),
#  (u'stanfordedu domain', 55258168992.0),
#  (u'stanford view', 55258168992.0),
#  (u'stanford standford', 55258168992.0),
#  (u'stanford berkeley', 55258168992.0),
#  (u'stanford applic', 55258168992.0),
#  (u'standard simpl colleg admiss databas', 55258168992.0),
#  (u'standard set union', 55258168992.0),
#  (u'standard construct', 55258168992.0),
#  (u'standard colleg admiss sampl databas', 55258168992.0),
#  (u'squar bracket a1', 55258168992.0),
#  (u'sqlite trigger', 55258168992.0),
#  (u'sqlite system', 55258168992.0),
#  (u'sqlite specif construct rais ignor', 55258168992.0),
#  (u'sqlite session', 55258168992.0),
#  (u'sql3 standard', 55258168992.0),
#  (u'sql2 standard', 55258168992.0),
#  (u'sql wear condit', 55258168992.0),
#  (u'sql standard semant', 55258168992.0),
#  (u'sql recurs', 55258168992.0),
#  (u'sql queri processor', 55258168992.0),
#  (u'sql like solut', 55258168992.0),
#  (u'sql like queri', 55258168992.0),
#  (u'sql like predic', 55258168992.0),
#  (u'sql like languag', 55258168992.0),
#  (u'sql light', 55258168992.0),
#  (u'sql inject error', 55258168992.0),
#  (u'sql exercis', 55258168992.0),
#  (u'sql demo', 55258168992.0),
#  (u'sql context', 55258168992.0),
#  (u'specif nosql solut', 55258168992.0),
#  (u'specif locat', 55258168992.0),
#  (u'specif formal notion', 55258168992.0),
#  (u'specif costum', 55258168992.0),
#  (u'specif attributesonli', 55258168992.0),
#  (u'special type associ', 55258168992.0),
#  (u'special queri process techniqu', 55258168992.0),
#  (u'special name public', 55258168992.0),
#  (u'special multipl', 55258168992.0),
#  (u'special index techniqu', 55258168992.0),
#  (u'special index structur', 55258168992.0),
#  (u'special element symbol', 55258168992.0),
#  (u'social secur number pair', 55258168992.0),
#  (u'social secur number multi', 55258168992.0),
#  (u'smiley photo', 55258168992.0),
#  (u'smart databas system', 55258168992.0),
#  (u'small littl trick', 55258168992.0),
#  (u'small downsid', 55258168992.0),
#  (u'slice relat', 55258168992.0),
#  (u'sixth import', 55258168992.0),
#  (u'singular id ref', 55258168992.0),
#  (u'singl step queri', 55258168992.0),
#  (u'singl map function', 55258168992.0),
#  (u'singl intricaci', 55258168992.0),
#  (u'singl element name ms widom', 55258168992.0),
#  (u'singl bookstor', 55258168992.0),
#  (u'simul integr constraint', 55258168992.0),
#  (u'simpler trigger', 55258168992.0),
#  (u'simpler queri', 55258168992.0),
#  (u'simpl templat match', 55258168992.0),
#  (u'simpl tabl level oper', 55258168992.0),
#  (u'simpl syntact correct', 55258168992.0),
#  (u'simpl path express', 55258168992.0),
#  (u'simpl exampl databas', 55258168992.0),
#  (u'simpl delet command', 55258168992.0),
#  (u'simpl colleg admiss relat databas', 55258168992.0),
#  (u'simpl colleg admiss databas', 55258168992.0),
#  (u'simpl ancestor comput', 55258168992.0),
#  (u'similar parallel joke', 55258168992.0),
#  (u'sid attribut', 55258168992.0),
#  (u'shop cart addit', 55258168992.0),
#  (u'serializ behavior', 55258168992.0),
#  (u'sequenti serial orderof', 55258168992.0),
#  (u'sequel languag', 55258168992.0),
#  (u'sequal system', 55258168992.0),
#  (u'separ tupl', 55258168992.0),
#  (u'separ privileg privileg', 55258168992.0),
#  (u'separ label valu pair', 55258168992.0),
#  (u'separ associ class', 55258168992.0),
#  (u'select student id', 55258168992.0),
#  (u'select star version', 55258168992.0),
#  (u'select row', 55258168992.0),
#  (u'select predic', 55258168992.0),
#  (u'select gpa', 55258168992.0),
#  (u'schema like specif', 55258168992.0),
#  (u'schema like element', 55258168992.0),
#  (u'schema [ sp', 55258168992.0),
#  (u'satellit home campu', 55258168992.0),
#  (u'sampl demonstr databas', 55258168992.0),
#  (u'sale transact action', 55258168992.0),
#  (u'sale domain', 55258168992.0),
#  (u'sale databas store', 55258168992.0),
#  (u'salari burden', 55258168992.0),
#  (u'safeti multi user', 55258168992.0),
#  (u'safe multi user storag', 55258168992.0),
#  (u'runtim execut error', 55258168992.0),
#  (u'rule base languag', 55258168992.0),
#  (u'row row level trigger', 55258168992.0),
#  (u'row level variabl', 55258168992.0),
#  (u'row level modif', 55258168992.0),
#  (u'row level chang', 55258168992.0),
#  (u'rough approxim gpa', 55258168992.0),
#  (u'root tuppl', 55258168992.0),
#  (u'rollup command', 55258168992.0),
#  (u'rollup claus', 55258168992.0),
#  (u'rollback command', 55258168992.0),
#  (u'roll up command', 55258168992.0),
#  (u'roll level trigger', 55258168992.0),
#  (u'role level trigger', 55258168992.0),
#  (u'rigid relat model', 55258168992.0),
#  (u'result tupl', 55258168992.0),
#  (u'result sub queri', 55258168992.0),
#  (u'result sqlite', 55258168992.0),
#  (u'result berkeley', 55258168992.0),
#  (u'repeat null valu', 55258168992.0),
#  (u'rep attribut', 55258168992.0),
#  (u'remind transact', 55258168992.0),
#  (u'remind constraint', 55258168992.0),
#  (u'remark subel', 55258168992.0),
#  (u'remark occurr constraint', 55258168992.0),
#  (u'remark compon', 55258168992.0),
#  (u'remaind boyc codd', 55258168992.0),
#  (u'relat tip', 55258168992.0),
#  (u'relat specif', 55258168992.0),
#  (u'relat rout', 55258168992.0),
#  (u'relat rabcd', 55258168992.0),
#  (u'relat rabc', 55258168992.0),
#  (u'relat queri exampl', 55258168992.0),
#  (u'relat queri', 55258168992.0),
#  (u'relat model video', 55258168992.0),
#  (u'relat model schema', 55258168992.0),
#  (u'relat joint', 55258168992.0),
#  (u'relat dot data model', 55258168992.0),
#  (u'relat data base system', 55258168992.0),
#  (u'relat data base design', 55258168992.0),
#  (u'relat content', 55258168992.0),
#  (u'relat algebra tree', 55258168992.0),
#  (u'relat algebra style', 55258168992.0),
#  (u'relat algebra queri languag', 55258168992.0),
#  (u'regular sql queri', 55258168992.0),
#  (u'regular sql construct', 55258168992.0),
#  (u'referenti integr talk', 55258168992.0),
#  (u'referenti integr system', 55258168992.0),
#  (u'referenti integr point', 55258168992.0),
#  (u'referenti integr constraint violat', 55258168992.0),
#  (u'referenti integr constraint enforc', 55258168992.0),
#  (u'refer relat r1', 55258168992.0),
#  (u'reduc function', 55258168992.0),
#  (u'recurs with statement', 55258168992.0),
#  (u'recurs trigger', 55258168992.0),
#  (u'recurs templat match', 55258168992.0),
#  (u'recurs sub queri', 55258168992.0),
#  (u'recurs statement', 55258168992.0),
#  (u'recurs specif', 55258168992.0),
#  (u'recurs sort', 55258168992.0),
#  (u'recurs rn', 55258168992.0),
#  (u'recurs r1', 55258168992.0),
#  (u'recurs modifi', 55258168992.0),
#  (u'recurs half', 55258168992.0),
#  (u'recurs construct', 55258168992.0),
#  (u'recent trigger fire', 55258168992.0),
#  (u'reason index', 55258168992.0),
#  (u'reason high school size', 55258168992.0),
#  (u'reason gpa', 55258168992.0),
#  (u'reason craig', 55258168992.0),
#  (u'real world constraint', 55258168992.0),
#  (u'real world assumpt', 55258168992.0),
#  (u'real origin data', 55258168992.0),
#  (u'real airport code', 55258168992.0),
#  (u'read privileg', 55258168992.0),
#  (u'rate label properti', 55258168992.0),
#  (u'raise/ignor command', 55258168992.0),
#  (u'r1 natur', 55258168992.0),
#  (u'quick cross check', 55258168992.0),
#  (u'question q2', 55258168992.0),
#  (u'queri workload', 55258168992.0),
#  (u'queri tomorrow', 55258168992.0),
#  (u'queri overview', 55258168992.0),
#  (u'queri find', 55258168992.0),
#  (u'queri cue', 55258168992.0),
#  (u'quantiti time price', 55258168992.0),
#  (u'put author', 55258168992.0),
#  (u'properti valu pair', 55258168992.0),
#  (u'properti like', 55258168992.0),
#  (u'propag trigger', 55258168992.0),
#  (u'promin key valu store', 55258168992.0),
#  (u'promin databas system', 55258168992.0),
#  (u'project name text', 55258168992.0),
#  (u'project list', 55258168992.0),
#  (u'program secur issu', 55258168992.0),
#  (u'proceed sibl axi', 55258168992.0),
#  (u'prioriti attribut', 55258168992.0),
#  (u'primari sort order', 55258168992.0),
#  (u'primari open sourc system', 55258168992.0),
#  (u'primari key statement', 55258168992.0),
#  (u'predefin aggreg', 55258168992.0),
#  (u'preced tupl', 55258168992.0),
#  (u'pre reduc phase', 55258168992.0),
#  (u'pre defin user', 55258168992.0),
#  (u'pre aggreg data', 55258168992.0),
#  (u'pre aggreg', 55258168992.0),
#  (u'postgr system', 55258168992.0),
#  (u'postgr implement', 55258168992.0),
#  (u'post risk command line interfac', 55258168992.0),
#  (u'post grist system', 55258168992.0),
#  (u'posari system', 55258168992.0),
#  (u'popular oper', 55258168992.0),
#  (u'popular high level languag', 55258168992.0),
#  (u'pointer work', 55258168992.0),
#  (u'point trigger process', 55258168992.0),
#  (u'plural id ref', 55258168992.0),
#  (u'plain sql queri', 55258168992.0),
#  (u'pig script', 55258168992.0),
#  (u'phantom tupl', 55258168992.0),
#  (u'peski attribut', 55258168992.0),
#  (u'past sever video', 55258168992.0),
#  (u'partial full effect', 55258168992.0),
#  (u'parent tupl', 55258168992.0),
#  (u'parent tag', 55258168992.0),
#  (u'parent navig axi', 55258168992.0),
#  (u'parent element tag', 55258168992.0),
#  (u'palo alto sale', 55258168992.0),
#  (u'pad top', 55258168992.0),
#  (u'pad left', 55258168992.0),
#  (u'pad bottom', 55258168992.0),
#  (u'overlap sub class relationship', 55258168992.0),
#  (u'outermost object', 55258168992.0),
#  (u'outer refer tabl', 55258168992.0),
#  (u'origin tuple1', 55258168992.0),
#  (u'origin queri result', 55258168992.0),
#  (u'origin queri group', 55258168992.0),
#  (u'origin mega relat', 55258168992.0),
#  (u'origin fact data', 55258168992.0),
#  (u'origin data cube', 55258168992.0),
#  (u'option remark', 55258168992.0),
#  (u'open tag isbn', 55258168992.0),
#  (u'open sourc databas system', 55258168992.0),
#  (u'onlin json schema valid', 55258168992.0),
#  (u'onlin analyt process olap', 55258168992.0),
#  (u'oltp world', 55258168992.0),
#  (u'oltp style applic', 55258168992.0),
#  (u'oltp sourc', 55258168992.0),
#  (u'oltp data base', 55258168992.0),
#  (u'olap environ', 55258168992.0),
#  (u'olap demonstr', 55258168992.0),
#  (u'olap camp', 55258168992.0),
#  (u'occurr constraint', 55258168992.0),
#  (u'object kind', 55258168992.0),
#  (u'number tupl', 55258168992.0),
#  (u'null major', 55258168992.0),
#  (u'null gpa', 55258168992.0),
#  (u'null edit', 55258168992.0),
#  (u'null decis', 55258168992.0),
#  (u'nosql type applic', 55258168992.0),
#  (u'normal set cross product', 55258168992.0),
#  (u'normal form violat', 55258168992.0),
#  (u'nil type', 55258168992.0),
#  (u'nice underli algebra', 55258168992.0),
#  (u'nice theori', 55258168992.0),
#  (u'nice setup', 55258168992.0),
#  (u'nice queri', 55258168992.0),
#  (u'nice languag', 55258168992.0),
#  (u'nice high level languag', 55258168992.0),
#  (u'nice error', 55258168992.0),
#  (u'nice big queri', 55258168992.0),
#  (u'nest trigger invoc', 55258168992.0),
#  (u'nest sub queri', 55258168992.0),
#  (u'nest develop', 55258168992.0),
#  (u'nest composit object', 55258168992.0),
#  (u'nest behavior', 55258168992.0),
#  (u'neg subqueri', 55258168992.0),
#  (u'navig axi', 55258168992.0),
#  (u'navig axe', 55258168992.0),
#  (u'natur recurs queri', 55258168992.0),
#  (u'natur queri', 55258168992.0),
#  (u'naiv recurs', 55258168992.0),
#  (u'mysteri cmh', 55258168992.0),
#  (u'mysql today', 55258168992.0),
#  (u'multipl sub class', 55258168992.0),
#  (u'multiattribut foreign key constraint', 55258168992.0),
#  (u'multi valu depend a multi', 55258168992.0),
#  (u'multi set oper', 55258168992.0),
#  (u'multi set model', 55258168992.0),
#  (u'multi set', 55258168992.0),
#  (u'multi doubt valu depend', 55258168992.0),
#  (u'multi attribut key', 55258168992.0),
#  (u'multi attribut', 55258168992.0),
#  (u'ms widom', 55258168992.0),
#  (u'mongo db', 55258168992.0),
#  (u'modif overview', 55258168992.0),
#  (u'modif combin', 55258168992.0),
#  (u'mit done chang', 55258168992.0),
#  (u'minu mn', 55258168992.0),
#  (u'minu express', 55258168992.0),
#  (u'minoccur specif', 55258168992.0),
#  (u'minimum cost flight', 55258168992.0),
#  (u'min gpa', 55258168992.0),
#  (u'min aggreg function', 55258168992.0),
#  (u'million billion', 55258168992.0),
#  (u'middl selector', 55258168992.0),
#  (u'middl match element', 55258168992.0),
#  (u'merg like oper', 55258168992.0),
#  (u'mega view', 55258168992.0),
#  (u'mega templat', 55258168992.0),
#  (u'medium downsid', 55258168992.0),
#  (u'maximum number item', 55258168992.0),
#  (u'max gpa', 55258168992.0),
#  (u'match transform', 55258168992.0),
#  (u'match student tupl', 55258168992.0),
#  (u'match student id', 55258168992.0),
#  (u'match sid', 55258168992.0),
#  (u'match schema', 55258168992.0),
#  (u'match close tag', 55258168992.0),
#  (u'match book element', 55258168992.0),
#  (u'match book', 55258168992.0),
#  (u'mass produc architectur', 55258168992.0),
#  (u'mari tupl', 55258168992.0),
#  (u'margin top', 55258168992.0),
#  (u'margin downsid', 55258168992.0),
#  (u'margin bottom', 55258168992.0),
#  (u'manag employe relationship', 55258168992.0),
#  (u'major one at a time', 55258168992.0),
#  (u'major mani time', 55258168992.0),
#  (u'major equal cs', 55258168992.0),
#  (u'magazin sub element', 55258168992.0),
#  (u'made up exampl', 55258168992.0),
#  (u'lower consist guarante', 55258168992.0),
#  (u'loos type data', 55258168992.0),
#  (u'longer condit', 55258168992.0),
#  (u'long first part', 55258168992.0),
#  (u'long bit', 55258168992.0),
#  (u'logic implic symbol', 55258168992.0),
#  (u'log in mechan', 55258168992.0),
#  (u'line tgat', 55258168992.0),
#  (u'limit trigger train', 55258168992.0),
#  (u'limit command', 55258168992.0),
#  (u'like edg', 55258168992.0),
#  (u'left hand side object', 55258168992.0),
#  (u'leaf text element', 55258168992.0),
#  (u'larg social graph', 55258168992.0),
#  (u'larg scale data analys', 55258168992.0),
#  (u'larg realist databas', 55258168992.0),
#  (u'larg onlin vendor', 55258168992.0),
#  (u'larg databas applic', 55258168992.0),
#  (u'languag like construct', 55258168992.0),
#  (u'label properti', 55258168992.0),
#  (u'label magazin', 55258168992.0),
#  (u'label column', 55258168992.0),
#  (u'kinda glue', 55258168992.0),
#  (u'keyword valu', 55258168992.0),
#  (u'keyword recurs', 55258168992.0),
#  (u'key word combin', 55258168992.0),
#  (u'key ref', 55258168992.0),
#  (u'key document pair', 55258168992.0),
#  (u'key declar', 55258168992.0),
#  (u'key constraint violat', 55258168992.0),
#  (u'k2 02', 55258168992.0),
#  (u'k1 01', 55258168992.0),
#  (u'json path languag', 55258168992.0),
#  (u'json path', 55258168992.0),
#  (u'json demo', 55258168992.0),
#  (u'john tupl', 55258168992.0),
#  (u'jeffrey widom', 55258168992.0),
#  (u'jefferey ullman', 55258168992.0),
#  (u'java script object notat', 55258168992.0),
#  (u'iter variabl', 55258168992.0),
#  (u'item i32', 55258168992.0),
#  (u'item costum', 55258168992.0),
#  (u'isol portion', 55258168992.0),
#  (u'isbn price titl', 55258168992.0),
#  (u'isbn attribut', 55258168992.0),
#  (u'invert bookstor', 55258168992.0),
#  (u'intuit trigger', 55258168992.0),
#  (u'intra tabl referenti integr', 55258168992.0),
#  (u'intersect express', 55258168992.0),
#  (u'interfac mean null', 55258168992.0),
#  (u'interest queri', 55258168992.0),
#  (u'interest implement issu', 55258168992.0),
#  (u'interact action', 55258168992.0),
#  (u'inter relat schema', 55258168992.0),
#  (u'inter lead oper', 55258168992.0),
#  (u'intend insert', 55258168992.0),
#  (u'insert tuppl', 55258168992.0),
#  (u'insert trigger', 55258168992.0),
#  (u'insert rita', 55258168992.0),
#  (u'insert bob', 55258168992.0),
#  (u'insert attempt', 55258168992.0),
#  (u'insert ami', 55258168992.0),
#  (u'individu subclass relat', 55258168992.0),
#  (u'indispens companion', 55258168992.0),
#  (u'increment mainten algorithm', 55258168992.0),
#  (u'incomplet disjoint', 55258168992.0),
#  (u'incomplet complet subclass relationship', 55258168992.0),
#  (u'includ transform', 55258168992.0),
#  (u'implicit prioriti scheme', 55258168992.0),
#  (u'implicit existenti quantif', 55258168992.0),
#  (u'impli function depend', 55258168992.0),
#  (u'imaginari modif', 55258168992.0),
#  (u'imaginari databas', 55258168992.0),
#  (u'imaginari colleg admiss databas', 55258168992.0),
#  (u'identifi hg', 55258168992.0),
#  (u'id rep', 55258168992.0),
#  (u'hudson author', 55258168992.0),
#  (u'hub start relat', 55258168992.0),
#  (u'hub note', 55258168992.0),
#  (u'hub author', 55258168992.0),
#  (u'hot queri', 55258168992.0),
#  (u'highest ee major', 55258168992.0),
#  (u'higher prioriti templat', 55258168992.0),
#  (u'higher level design tool', 55258168992.0),
#  (u'higher level design model', 55258168992.0),
#  (u'higher level databas design', 55258168992.0),
#  (u'high school code', 55258168992.0),
#  (u'high level queri languag', 55258168992.0),
#  (u'high level design model', 55258168992.0),
#  (u'high gpa applic', 55258168992.0),
#  (u'high enough gpa', 55258168992.0),
#  (u'hector garcia molina', 55258168992.0),
#  (u'hector garcia melina', 55258168992.0),
#  (u'hash base index', 55258168992.0),
#  (u'guaranteesthat constraint', 55258168992.0),
#  (u'greek symbol rho', 55258168992.0),
#  (u'greek pi symbol', 55258168992.0),
#  (u'great mood today', 55258168992.0),
#  (u'great grandpar relationship', 55258168992.0),
#  (u'grandpar relationship', 55258168992.0),
#  (u'grand final queri', 55258168992.0),
#  (u'gpa prioriti', 55258168992.0),
#  (u'gpa column', 55258168992.0),
#  (u'gpa arrow prioriti', 55258168992.0),
#  (u'good schema design', 55258168992.0),
#  (u'good relat design', 55258168992.0),
#  (u'good queri processor', 55258168992.0),
#  (u'good old jet blue', 55258168992.0),
#  (u'good constraint check system', 55258168992.0),
#  (u'gigant warehous', 55258168992.0),
#  (u'gigant queri', 55258168992.0),
#  (u'gigant disk', 55258168992.0),
#  (u'gigant databas', 55258168992.0),
#  (u'gener virtual view', 55258168992.0),
#  (u'gener mason', 55258168992.0),
#  (u'gener insert', 55258168992.0),
#  (u'gener class c1', 55258168992.0),
#  (u'gener assert featur', 55258168992.0),
#  (u'full uml', 55258168992.0),
#  (u'full trigger syntax', 55258168992.0),
#  (u'full star join', 55258168992.0),
#  (u'full featur queri languag', 55258168992.0),
#  (u'full aggreg', 55258168992.0),
#  (u'friend edg', 55258168992.0),
#  (u'free float apart', 55258168992.0),
#  (u'fourth tupl', 55258168992.0),
#  (u'fourth normal form relat', 55258168992.0),
#  (u'foreign key attribut', 55258168992.0),
#  (u'flight relat', 55258168992.0),
#  (u'flight databas', 55258168992.0),
#  (u'flat db', 55258168992.0),
#  (u'final queri', 55258168992.0),
#  (u'final destinationand', 55258168992.0),
#  (u'final decompos relat', 55258168992.0),
#  (u'fictiti databas', 55258168992.0),
#  (u'favorit tradit notion', 55258168992.0),
#  (u'favorit queri', 55258168992.0),
#  (u'favorit oper', 55258168992.0),
#  (u'favorit misspel', 55258168992.0),
#  (u'fact tabl sort', 55258168992.0),
#  (u'fact json schema', 55258168992.0),
#  (u'fact graph databas', 55258168992.0),
#  (u'fact fact tabl', 55258168992.0),
#  (u'fact author', 55258168992.0),
#  (u'face edg', 55258168992.0),
#  (u'extran text', 55258168992.0),
#  (u'express trigger system', 55258168992.0),
#  (u'express integr constraint', 55258168992.0),
#  (u'express e2', 55258168992.0),
#  (u'express e1 minu e2', 55258168992.0),
#  (u'express e1', 55258168992.0),
#  (u'experienc databas applic develop', 55258168992.0),
#  (u'exist constraint', 55258168992.0),
#  (u'execut glue', 55258168992.0),
#  (u'exact transit', 55258168992.0),
#  (u'exact sequenti order', 55258168992.0),
#  (u'exact same issu', 55258168992.0),
#  (u'exact same bookstor data', 55258168992.0),
#  (u'exact delet', 55258168992.0),
#  (u'event trigger event', 55258168992.0),
#  (u'event condit action rule', 55258168992.0),
#  (u'event condit action role', 55258168992.0),
#  (u'error rais command', 55258168992.0),
#  (u'equival specif', 55258168992.0),
#  (u'equival serial order', 55258168992.0),
#  (u'equival sequenti order', 55258168992.0),
#  (u'equal student', 55258168992.0),
#  (u'enumer domain', 55258168992.0),
#  (u'enumer constraint', 55258168992.0),
#  (u'entir xpath languag', 55258168992.0),
#  (u'entir xml specif', 55258168992.0),
#  (u'entir ven diagram', 55258168992.0),
#  (u'entir tupl', 55258168992.0),
#  (u'entir sub tree', 55258168992.0),
#  (u'entir student tabl', 55258168992.0),
#  (u'entir sql queri languag', 55258168992.0),
#  (u'entir read', 55258168992.0),
#  (u'entir input data', 55258168992.0),
#  (u'entir dtd', 55258168992.0),
#  (u'entir current element', 55258168992.0),
#  (u'entir circl e1', 55258168992.0),
#  (u'entir author structur', 55258168992.0),
#  (u'empti object', 55258168992.0),
#  (u'embed key valu store', 55258168992.0),
#  (u'element type kleen', 55258168992.0),
#  (u'econom databas hint', 55258168992.0),
#  (u'earlier path express', 55258168992.0),
#  (u'e2 dot a2', 55258168992.0),
#  (u'e1 natur', 55258168992.0),
#  (u'e1 minu e2', 55258168992.0),
#  (u'e1 minu', 55258168992.0),
#  (u'e1 intersect e2', 55258168992.0),
#  (u'duplic titl', 55258168992.0),
#  (u'duplic issu', 55258168992.0),
#  (u'dtd specif', 55258168992.0),
#  (u'draw databas', 55258168992.0),
#  (u'dramat databas modif', 55258168992.0),
#  (u'dot dot star', 55258168992.0),
#  (u'document databas system', 55258168992.0),
#  (u'doc bookstor', 55258168992.0),
#  (u'distinct colleg name', 55258168992.0),
#  (u'dirti data item', 55258168992.0),
#  (u'direct programmig', 55258168992.0),
#  (u'direct jet blue flight', 55258168992.0),
#  (u'determinist answer', 55258168992.0),
#  (u'desir normal form', 55258168992.0),
#  (u'descend descend', 55258168992.0),
#  (u'depend a multi', 55258168992.0),
#  (u'demonstr simpl', 55258168992.0),
#  (u'demo queri', 55258168992.0),
#  (u'demo postgr', 55258168992.0),
#  (u'delet tuppl', 55258168992.0),
#  (u'delet tupl', 55258168992.0),
#  (u'delet major', 55258168992.0),
#  (u'delet coupl', 55258168992.0),
#  (u'defer constraint check', 55258168992.0),
#  (u'default minoccur', 55258168992.0),
#  (u'deep compani hierarchi', 55258168992.0),
#  (u'decompos relat', 55258168992.0),
#  (u'declar high level languag', 55258168992.0),
#  (u'de normal relat', 55258168992.0),
#  (u'datath system', 55258168992.0),
#  (u'databas v1', 55258168992.0),
#  (u'databas privileg', 55258168992.0),
#  (u'databas peopl', 55258168992.0),
#  (u'databas manag system system', 55258168992.0),
#  (u'databas implement', 55258168992.0),
#  (u'databas hint', 55258168992.0),
#  (u'databas design pick', 55258168992.0),
#  (u'databas construct', 55258168992.0),
#  (u'databas connoisseur', 55258168992.0),
#  (u'databas base author', 55258168992.0),
#  (u'databas author', 55258168992.0),
#  (u'data scenario', 55258168992.0),
#  (u'data model subset', 55258168992.0),
#  (u'data model portion', 55258168992.0),
#  (u'data mine type oper', 55258168992.0),
#  (u'data level modif', 55258168992.0),
#  (u'data kind', 55258168992.0),
#  (u'data javascript object notat', 55258168992.0),
#  (u'data clean process', 55258168992.0),
#  (u'data base stay', 55258168992.0),
#  (u'data base activ', 55258168992.0),
#  (u'cycl lot', 55258168992.0),
#  (u'current time sqlite', 55258168992.0),
#  (u'cube tabl', 55258168992.0),
#  (u'cube queri', 55258168992.0),
#  (u'cube extens', 55258168992.0),
#  (u'csee view', 55258168992.0),
#  (u'cse major', 55258168992.0),
#  (u'cs gpa', 55258168992.0),
#  (u'cs burk', 55258168992.0),
#  (u'cs accept view', 55258168992.0),
#  (u'cs accept relat', 55258168992.0),
#  (u'cross bay rival berkeley', 55258168992.0),
#  (u'coupl tuppl', 55258168992.0),
#  (u'count queri', 55258168992.0),
#  (u'costum id', 55258168992.0),
#  (u'correct modif', 55258168992.0),
#  (u'correct json file', 55258168992.0),
#  (u'correct json', 55258168992.0),
#  (u'correct function depend', 55258168992.0),
#  (u'correct decomposit', 55258168992.0),
#  (u'correct bcnf answer', 55258168992.0),
#  (u'cornel offer ee', 55258168992.0),
#  (u'constraintless check', 55258168992.0),
#  (u'constraint violat error', 55258168992.0),
#  (u'constraint repair logic', 55258168992.0),
#  (u'constraint featur', 55258168992.0),
#  (u'constraint enforc system', 55258168992.0),
#  (u'constraint enforc sub system', 55258168992.0),
#  (u'constraint check featur', 55258168992.0),
#  (u'consist restraint', 55258168992.0),
#  (u'consist properti talk', 55258168992.0),
#  (u'conserv travel', 55258168992.0),
#  (u'concurr control problem', 55258168992.0),
#  (u'conclus transact', 55258168992.0),
#  (u'comput closur', 55258168992.0),
#  (u'composit relationship', 55258168992.0),
#  (u'complic xslt program', 55258168992.0),
#  (u'complic queri languag', 55258168992.0),
#  (u'complic purpos', 55258168992.0),
#  (u'complic like relationship', 55258168992.0),
#  (u'complic insert command', 55258168992.0),
#  (u'complex oper overload', 55258168992.0),
#  (u'complet subclass relationship', 55258168992.0),
#  (u'complet student tabl', 55258168992.0),
#  (u'complet disjoint', 55258168992.0),
#  (u'common mispel', 55258168992.0),
#  (u'combin relat', 55258168992.0),
#  (u'colleg tupl', 55258168992.0),
#  (u'colleg stanford', 55258168992.0),
#  (u'colleg standford', 55258168992.0),
#  (u'colleg pair', 55258168992.0),
#  (u'colleg name statement enrol', 55258168992.0),
#  (u'colleg name refer', 55258168992.0),
#  (u'colleg name column', 55258168992.0),
#  (u'colleg name attribut', 55258168992.0),
#  (u'colleg enrol databas', 55258168992.0),
#  (u'colleg applic inform databas', 55258168992.0),
#  (u'colleg applic databas', 55258168992.0),
#  (u'close tag book titl', 55258168992.0),
#  (u'clear constraint', 55258168992.0),
#  (u'clean underli algebra', 55258168992.0),
#  (u'claus product', 55258168992.0),
#  (u'class c2 object', 55258168992.0),
#  (u'cheapest fashion', 55258168992.0),
#  (u'charact isbn', 55258168992.0),
#  (u'central fact tabl', 55258168992.0),
#  (u'categori california', 55258168992.0),
#  (u'case tabl student', 55258168992.0),
#  (u'cascad option', 55258168992.0),
#  (u'cascad case', 55258168992.0),
#  (u'carol dave', 55258168992.0),
#  (u'carnegi melon univers', 55258168992.0),
#  (u'californian male', 55258168992.0),
#  (u'c2 object', 55258168992.0),
#  (u'c1 natur', 55258168992.0),
#  (u'burn modif', 55258168992.0),
#  (u'built in predic', 55258168992.0),
#  (u'built in oper', 55258168992.0),
#  (u'built in notion', 55258168992.0),
#  (u'built in label', 55258168992.0),
#  (u'built in data model', 55258168992.0),
#  (u'built in concept', 55258168992.0),
#  (u'boys codd', 55258168992.0),
#  (u'boyc codd normal form violat', 55258168992.0),
#  (u'boyc codd normal form', 55258168992.0),
#  (u'box shadow', 55258168992.0),
#  (u'border width', 55258168992.0),
#  (u'border top width', 55258168992.0),
#  (u'border top style', 55258168992.0),
#  (u'border right width', 55258168992.0),
#  (u'border right style', 55258168992.0),
#  (u'border left width', 55258168992.0),
#  (u'border left style', 55258168992.0),
#  (u'border bottom width', 55258168992.0),
#  (u'border bottom style', 55258168992.0),
#  (u'bookstor element', 55258168992.0),
#  (u'bookstor databas', 55258168992.0),
#  (u'bookstor data', 55258168992.0),
#  (u'book titl element', 55258168992.0),
#  (u'book store element', 55258168992.0),
#  (u'book store databas', 55258168992.0),
#  (u'book store data', 55258168992.0),
#  (u'book properti', 55258168992.0),
#  (u'book author/author', 55258168992.0),
#  (u'book /remark/bookref', 55258168992.0),
#  (u'biolog type major', 55258168992.0),
#  (u'bio view', 55258168992.0),
#  (u'biggest uml diagram', 55258168992.0),
#  (u'biggest function depend', 55258168992.0),
#  (u'big venn diagram', 55258168992.0),
#  (u'big sub tree', 55258168992.0),
#  (u'big sub queri', 55258168992.0),
#  (u'big parenthes', 55258168992.0),
#  (u'big express', 55258168992.0),
#  (u'big diagram', 55258168992.0),
#  (u'big cross product', 55258168992.0),
#  (u'berkeley stanford', 55258168992.0),
#  (u'berkeley mit', 55258168992.0),
#  (u'berkeley biolog', 55258168992.0),
#  (u'berk view', 55258168992.0),
#  (u'berk relat', 55258168992.0),
#  (u'begin end bracket', 55258168992.0),
#  (u'bcnf violat', 55258168992.0),
#  (u'bcnf decomposit algorithm', 55258168992.0),
#  (u'bcnf decomposit', 55258168992.0),
#  (u'bcnf composit', 55258168992.0),
#  (u'batch data analysi applic', 55258168992.0),
#  (u'basic syntact error', 55258168992.0),
#  (u'basic structur requir', 55258168992.0),
#  (u'basic sql languag', 55258168992.0),
#  (u'basic select statement', 55258168992.0),
#  (u'basic select from where structur', 55258168992.0),
#  (u'basic oper languag', 55258168992.0),
#  (u'basic nativ data model', 55258168992.0),
#  (u'basic atom valu', 55258168992.0),
#  (u'basic aggreg function', 55258168992.0),
#  (u'base tabl r1', 55258168992.0),
#  (u'base queri union', 55258168992.0),
#  (u'bang attribut list', 55258168992.0),
#  (u'balanc tree', 55258168992.0),
#  (u'bad relat design', 55258168992.0),
#  (u'bad relat algebra', 55258168992.0),
#  (u'b2 bar', 55258168992.0),
#  (u'b1 bar', 55258168992.0),
#  (u'b1 b2 comma bm', 55258168992.0),
#  (u'averag aggreg function', 55258168992.0),
#  (u'automat view translat', 55258168992.0),
#  (u'automat tupl', 55258168992.0),
#  (u'automat insert', 55258168992.0),
#  (u'automat decomposit work', 55258168992.0),
#  (u'author start relat', 55258168992.0),
#  (u'author standpoint', 55258168992.0),
#  (u'author object', 55258168992.0),
#  (u'author key', 55258168992.0),
#  (u'author concern', 55258168992.0),
#  (u'author concept', 55258168992.0),
#  (u'author array', 55258168992.0),
#  (u'attribut price', 55258168992.0),
#  (u'attribut isbn', 55258168992.0),
#  (u'attribut date', 55258168992.0),
#  (u'attribut base constraint', 55258168992.0),
#  (u'attribut base check constraint', 55258168992.0),
#  (u'attribut addit', 55258168992.0),
#  (u'attribut a refer', 55258168992.0),
#  (u'attribut a 1', 55258168992.0),
#  (u'attempt insert', 55258168992.0),
#  (u'atom properti', 55258168992.0),
#  (u'atom deal', 55258168992.0),
#  (u'atima citi', 55258168992.0),
#  (u'associ multipl', 55258168992.0),
#  (u'applic develop build', 55258168992.0),
#  (u'appli record', 55258168992.0),
#  (u'appli coupl', 55258168992.0),
#  (u'appli associ', 55258168992.0),
#  (u'ap student subclass', 55258168992.0),
#  (u'ap student sub class', 55258168992.0),
#  (u'ap student relat', 55258168992.0),
#  (u'ap cours ap cours', 55258168992.0),
#  (u'answer condit', 55258168992.0),
#  (u'ancestor recurs', 55258168992.0),
#  (u'ancestor comput', 55258168992.0),
#  (u'ami tupl', 55258168992.0),
#  (u'ambigu warn', 55258168992.0),
#  ...]

# %%
external_tfidf_idxs = [extractor.vocabulary_[word] for word in sorted(external_tfidfs.keys()) if word in extractor.vocabulary_]
external_tfidf_vals = np.array([value for word, value in sorted(external_tfidfs.items()) if word in extractor.vocabulary_])
external_tfidf_vals /= external_tfidf_vals.sum()

# %%
stemmed_documents = OrderedDict()

for name, document in documents.items():
    document = document.replace('-', ' ')
    document = ' '.join([stemmer.stem(token) for token in nltk.word_tokenize(document)])
    stemmed_documents[name] = document.lower()

extractor = TfidfVectorizer(ngram_range=(1,4), stop_words=stopwords)
X = extractor.fit_transform(stemmed_documents.values())
X = X / X.sum(axis=1)
X[:, external_tfidf_idxs] += external_tfidf_vals
inverse_voc = {v: k for k, v in extractor.vocabulary_.items()}

extracted = OrderedDict()
for doc_idx, name in enumerate(stemmed_documents.keys()):
    extracted[name] = [inverse_voc[idx] for idx in np.argsort(np.array(X[doc_idx,:])).flatten()]

# %%
matches = OrderedDict()
jaccard = OrderedDict()

for name, keys in sorted(keywords.items()):
    extracted_words = extracted[name][-len(keys):]
    matches[name.replace('.keys', '')] = list(set(keys).intersection(extracted_words))
    jaccard[name.replace('.keys', '')] = float(len(set(keys).intersection(extracted_words))) / len(set(keys).union(set(extracted_words)))
    
print('Average jaccard: {}'.format(sum(jaccard.values()) / len(jaccard)))
# Out:
# Average jaccard: 0.120458904278

# %%
matches = OrderedDict()
jaccard = OrderedDict()

for name, keys in sorted(keywords.items()):
    extracted_words = extracted[name][-2*len(keys):]
    matches[name.replace('.keys', '')] = list(set(keys).intersection(extracted_words))
    jaccard[name.replace('.keys', '')] = float(len(set(keys).intersection(extracted_words))) / len(set(keys).union(set(extracted_words)))
    
print('Average jaccard: {}'.format(sum(jaccard.values()) / len(jaccard)))

# %%
sorted(matches.items()[6])

# %%
stemmed_documents.values()[5].count('xml schema')

# %%
list(reversed(extracted['03_02_DTDs_IDs_and_IDREFs.txt'])).index('xml schema')

# %%
with open('tfidf_keys.csv', 'w') as f:
    for document, keys in sorted(extracted.items()):
        keys = list(reversed(keys))
        for i, key in enumerate(keys[:10]):
            if i < 5:
                f.write('{},{},{}\n'.format(document, key, i + 1))
            else:
                f.write('{},{},{}\n'.format(document, key, 0))
