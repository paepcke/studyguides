# %%
import nltk
import os

from collections import defaultdict

import numpy as np

# %%
stemmer = nltk.PorterStemmer()
ngrams = defaultdict(set)
raters = []

for name in os.listdir('../../../data/keywords/'):
    with open('../../../data/keywords/' + name) as f:
        rater = {}
        for line in f:
            file, term, _, rank = line.strip().split(',')
            rank = int(rank)
            tokens = term.lower().split(' ')
            stemmed = ' '.join(stemmer.stem(token) for token in tokens)
            rater[file, stemmed] = rank
            
            if len(tokens) > 1:
                ngrams[file].add(stemmed)
                
        raters.append(rater)
            
all_keys = set()

for name in os.listdir('/Users/andrewlamb/Google_Drive/Stanford/CS199/DB_SelfPaced/Flat'):
    with open('/Users/andrewlamb/Google_Drive/Stanford/CS199/DB_SelfPaced/Flat/' + name) as f:
        lines = []
        for line in f:
            line = line.strip('.| \n')

            stemmed = ' '.join([stemmer.stem(token) for token in line.split(' ')])
            lines.append(stemmed)
        document = ' '.join(lines)
        document = document.lower()

        
        for ngram in ngrams[name]:
            document = document.replace(ngram, '')
            all_keys.add((name, ngram))
            
        for token in document.split(' '):
            all_keys.add((name, token))

data = []
for key in all_keys:
    for i, rater in enumerate(raters):
        if key in rater:
            rank = rater[key]
            if rank > 0:
                data.append((i, key, 1))
            else:
                pass
                data.append((i, key, 2))
        else:
            data.append((i, key, 2))
        
# Make sure all raters have all files
intersection_files = set(list(zip(*raters[0].keys()))[0])
for rater in raters[1:]:
    intersection_files = intersection_files.intersection(set(list(zip(*rater.keys()))[0]))

data = [item for item in data if item[1][0] in intersection_files]

# %%
float(len([item for item in data if item[2] == 2])) / len(os.listdir('/Users/andrewlamb/Google_Drive/Stanford/CS199/DB_SelfPaced/Flat'))

# %%
# Print a few random data points to spot check
for i in np.random.choice(range(len(data)), size=10, replace=False):
    print(data[i])
    
print('#'*80)

# Print a few that are definitely included in the index
cat_1 = [item for item in data if item[2] == 1]
for i in np.random.choice(range(len(cat_1)), size=10, replace=False):
    print(cat_1[i])
print('#'*80)
    
# Print a few in category 2
# cat_2 = [item for item in data if item[2] == 2]
# for i in np.random.choice(range(len(cat_2)), size=10, replace=False):
#     print(cat_2[i])

# %%
t = nltk.AnnotationTask(data=data)
t.kappa()
# Out:
# 0.2956056216880689

# %%
data
# Out:
# [(0, ('13_05_Materialized_Views_Part_1.txt', 'caus'), 2),
#  (1, ('13_05_Materialized_Views_Part_1.txt', 'caus'), 2),
#  (0, ('12_03_Referential_Integrity_Part_3.txt', '"colleg'), 2),
#  (1, ('12_03_Referential_Integrity_Part_3.txt', '"colleg'), 2),
#  (0, ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', 'union'), 2),
#  (1, ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', 'union'), 2),
#  (0, ('09_01_UML_Data_Modeling.txt', 'see'), 2),
#  (1, ('09_01_UML_Data_Modeling.txt', 'see'), 2),
#  (0, ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', "let'"), 2),
#  (1, ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', "let'"), 2),
#  (0, ('07_03_Boyce_Codd_Normal_Form_Part_1.txt', 'contain'), 2),
#  (1, ('07_03_Boyce_Codd_Normal_Form_Part_1.txt', 'contain'), 2),
#  (0, ('08_01_XPath_Introduction.txt', 'through'), 2),
#  (1, ('08_01_XPath_Introduction.txt', 'through'), 2),
#  (0, ('12_04_Triggers_Introduction.txt', 'call'), 2),
#  (1, ('12_04_Triggers_Introduction.txt', 'call'), 2),
#  (0, ('13_03_View_Modifications_Using_Triggers.txt', 'up'), 2),
#  (1, ('13_03_View_Modifications_Using_Triggers.txt', 'up'), 2),
#  (0, ('13_03_View_Modifications_Using_Triggers.txt', 'it,'), 2),
#  (1, ('13_03_View_Modifications_Using_Triggers.txt', 'it,'), 2),
#  (0,
#   ('13_02_View_Modifications_Introduction_Part_1.txt',
#    'three-level idea of databas'),
#   2),
#  (1,
#   ('13_02_View_Modifications_Introduction_Part_1.txt',
#    'three-level idea of databas'),
#   1),
#  (0, ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', 'now'), 2),
#  (1, ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', 'now'), 2),
#  (0, ('12_05_Triggers_Demo_Part_1.txt', 'oper'), 2),
#  (1, ('12_05_Triggers_Demo_Part_1.txt', 'oper'), 2),
#  (0, ('12_02_Constraints_of_Several_Types_Part_1.txt', 'queries,'), 2),
#  (1, ('12_02_Constraints_of_Several_Types_Part_1.txt', 'queries,'), 2),
#  (0, ('09_02_UML_to_Relations_Part_2.txt', 'star'), 2),
#  (1, ('09_02_UML_to_Relations_Part_2.txt', 'star'), 2),
#  (0, ('17_01_NoSQLOverview.txt', 'json'), 2),
#  (1, ('17_01_NoSQLOverview.txt', 'json'), 2),
#  (0, ('17_01_NoSQLOverview.txt', 'friend'), 2),
#  (1, ('17_01_NoSQLOverview.txt', 'friend'), 2),
#  (0,
#   ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_1.txt', 'specif'),
#   2),
#  (1,
#   ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_1.txt', 'specif'),
#   2),
#  (0, ('13_01_Defining_and_Using_Views.txt', 'though'), 2),
#  (1, ('13_01_Defining_and_Using_Views.txt', 'though'), 2),
#  (0, ('07_01_Relational_Design_Overview_Part_1.txt', 'view,'), 2),
#  (1, ('07_01_Relational_Design_Overview_Part_1.txt', 'view,'), 2),
#  (0, ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', 'itself,'), 2),
#  (1, ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', 'itself,'), 2),
#  (0, ('12_03_Referential_Integrity_Part_3.txt', 'with'), 2),
#  (1, ('12_03_Referential_Integrity_Part_3.txt', 'with'), 2),
#  (0, ('07_01_Relational_Design_Overview_Part_3.txt', 'design'), 2),
#  (1, ('07_01_Relational_Design_Overview_Part_3.txt', 'design'), 2),
#  (0, ('12_04_Triggers_Introduction.txt', 'sql'), 2),
#  (1, ('12_04_Triggers_Introduction.txt', 'sql'), 2),
#  (0, ('06_06_NULL_Values.txt', 'behavior'), 2),
#  (1, ('06_06_NULL_Values.txt', 'behavior'), 2),
#  (0, ('07_02_Functional_Dependencies_Part_3.txt', 'explicit,'), 2),
#  (1, ('07_02_Functional_Dependencies_Part_3.txt', 'explicit,'), 2),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', 'right'), 2),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', 'right'), 2),
#  (0, ('07_01_Relational_Design_Overview_Part_1.txt', 'all,'), 2),
#  (1, ('07_01_Relational_Design_Overview_Part_1.txt', 'all,'), 2),
#  (0, ('03_01_Well_Formed_XML_Part_1.txt', 'sometim'), 2),
#  (1, ('03_01_Well_Formed_XML_Part_1.txt', 'sometim'), 2),
#  (0, ('09_02_UML_to_Relations_Part_3.txt', "that'"), 2),
#  (1, ('09_02_UML_to_Relations_Part_3.txt', "that'"), 2),
#  (0, ('07_01_Functional_Dependencies_Part_5.txt', 'good'), 2),
#  (1, ('07_01_Functional_Dependencies_Part_5.txt', 'good'), 2),
#  (0, ('07_01_Functional_Dependencies_Part_5.txt', 'gave,'), 2),
#  (1, ('07_01_Functional_Dependencies_Part_5.txt', 'gave,'), 2),
#  (0, ('13_02_View_Modifications_Introduction_Part_1.txt', 'view,'), 2),
#  (1, ('13_02_View_Modifications_Introduction_Part_1.txt', 'view,'), 2),
#  (0, ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', 'write'), 2),
#  (1, ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', 'write'), 2),
#  (0, ('14_01_Authorization_Part_1.txt', 'gpa'), 2),
#  (1, ('14_01_Authorization_Part_1.txt', 'gpa'), 2),
#  (0, ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', 'note'), 2),
#  (1, ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', 'note'), 2),
#  (0, ('03_02_XML_Schema.txt', 'fee'), 2),
#  (1, ('03_02_XML_Schema.txt', 'fee'), 2),
#  (0, ('08_01_XPath_Introduction.txt', 'translat'), 2),
#  (1, ('08_01_XPath_Introduction.txt', 'translat'), 2),
#  (0, ('03_02_XML_Schema.txt', 'show'), 2),
#  (1, ('03_02_XML_Schema.txt', 'show'), 2),
#  (0, ('11_02_Transactions_Properties_Part_3.txt', 'city,'), 2),
#  (1, ('11_02_Transactions_Properties_Part_3.txt', 'city,'), 2),
#  (0, ('11_03_Isolation_Levels_Part_3.txt', 'run'), 2),
#  (1, ('11_03_Isolation_Levels_Part_3.txt', 'run'), 2),
#  (0, ('11_03_Isolation_Levels_Part_1.txt', 'undon'), 2),
#  (1, ('11_03_Isolation_Levels_Part_1.txt', 'undon'), 2),
#  (0, ('06_04_Subqueries_in_FROM_and_SELECT.txt', 'the'), 2),
#  (1, ('06_04_Subqueries_in_FROM_and_SELECT.txt', 'the'), 2),
#  (0, ('17_01_NoSQLOverview.txt', 'reader function'), 2),
#  (1, ('17_01_NoSQLOverview.txt', 'reader function'), 2),
#  (0, ('12_03_Referential_Integrity_Part_2.txt', 'our'), 2),
#  (1, ('12_03_Referential_Integrity_Part_2.txt', 'our'), 2),
#  (0, ('17_01_NoSQLOverview.txt', 'system,'), 2),
#  (1, ('17_01_NoSQLOverview.txt', 'system,'), 2),
#  (0, ('08_04_XQuery_Demo.txt', 'are'), 2),
#  (1, ('08_04_XQuery_Demo.txt', 'are'), 2),
#  (0, ('12_03_Referential_Integrity_Part_3.txt', 'someon'), 2),
#  (1, ('12_03_Referential_Integrity_Part_3.txt', 'someon'), 2),
#  (0, ('17_01_NoSQLOverview.txt', 'sql,'), 2),
#  (1, ('17_01_NoSQLOverview.txt', 'sql,'), 2),
#  (0, ('16_01_Introduction_to_OLAP_Part_1.txt', 'decis'), 2),
#  (1, ('16_01_Introduction_to_OLAP_Part_1.txt', 'decis'), 2),
#  (0, ('11_02_Transactions_Properties_Part_1.txt', 'system'), 2),
#  (1, ('11_02_Transactions_Properties_Part_1.txt', 'system'), 2),
#  (0, ('04_02_JSON_Demo.txt', 'entir'), 2),
#  (1, ('04_02_JSON_Demo.txt', 'entir'), 2),
#  (0, ('07_01_Relational_Design_Overview_Part_1.txt', 'attribut'), 2),
#  (1, ('07_01_Relational_Design_Overview_Part_1.txt', 'attribut'), 2),
#  (0, ('12_01_Motivation_and_Overview.txt', 'when'), 2),
#  (1, ('12_01_Motivation_and_Overview.txt', 'when'), 2),
#  (0, ('12_05_Triggers_Demo_Part_2.txt', '2s,'), 2),
#  (1, ('12_05_Triggers_Demo_Part_2.txt', '2s,'), 2),
#  (0, ('07_03_Boyce_Codd_Normal_Form_Part_1.txt', 'down'), 2),
#  (1, ('07_03_Boyce_Codd_Normal_Form_Part_1.txt', 'down'), 2),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_2.txt', 'decad'), 2),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_2.txt', 'decad'), 2),
#  (0, ('06_06_NULL_Values.txt', 'for'), 2),
#  (1, ('06_06_NULL_Values.txt', 'for'), 2),
#  (0, ('03_02_XML_Schema.txt', 'took'), 2),
#  (1, ('03_02_XML_Schema.txt', 'took'), 2),
#  (0, ('07_01_Relational_Design_Overview_Part_1.txt', 'twelv'), 2),
#  (1, ('07_01_Relational_Design_Overview_Part_1.txt', 'twelv'), 2),
#  (0, ('12_01_Motivation_and_Overview.txt', 'one'), 2),
#  (1, ('12_01_Motivation_and_Overview.txt', 'one'), 2),
#  (0, ('03_02_XML_Schema.txt', 'us'), 2),
#  (1, ('03_02_XML_Schema.txt', 'us'), 2),
#  (0, ('13_04_Automatic_View_Modifications.txt', 'known'), 2),
#  (1, ('13_04_Automatic_View_Modifications.txt', 'known'), 2),
#  (0, ('14_01_Authorization_Part_3.txt', "it'"), 2),
#  (1, ('14_01_Authorization_Part_3.txt', "it'"), 2),
#  (0, ('13_02_View_Modifications_Introduction_Part_1.txt', 'see'), 2),
#  (1, ('13_02_View_Modifications_Introduction_Part_1.txt', 'see'), 2),
#  (0, ('07_01_Relational_Design_Overview_Part_1.txt', 'call'), 2),
#  (1, ('07_01_Relational_Design_Overview_Part_1.txt', 'call'), 2),
#  (0, ('16_02_OLAP_Demo.txt', 'particular'), 2),
#  (1, ('16_02_OLAP_Demo.txt', 'particular'), 2),
#  (0, ('12_03_Referential_Integrity_Part_3.txt', 'default'), 2),
#  (1, ('12_03_Referential_Integrity_Part_3.txt', 'default'), 2),
#  (0, ('12_05_Triggers_Demo_Part_1.txt', 'is,'), 2),
#  (1, ('12_05_Triggers_Demo_Part_1.txt', 'is,'), 2),
#  (0, ('13_04_Automatic_View_Modifications.txt', 'interest'), 2),
#  (1, ('13_04_Automatic_View_Modifications.txt', 'interest'), 2),
#  (0, ('06_04_Subqueries_in_WHERE_Clause.txt', 'stanford'), 2),
#  (1, ('06_04_Subqueries_in_WHERE_Clause.txt', 'stanford'), 2),
#  (0, ('10_01_Indexes_Part_1.txt', ','), 2),
#  (1, ('10_01_Indexes_Part_1.txt', ','), 2),
#  (0, ('09_01_UML_Data_Modeling.txt', 'case'), 2),
#  (1, ('09_01_UML_Data_Modeling.txt', 'case'), 2),
#  (0, ('17_01_NoSQLMotivation.txt', 'features?'), 2),
#  (1, ('17_01_NoSQLMotivation.txt', 'features?'), 2),
#  (0, ('08_04_XQuery_Demo.txt', 'let'), 2),
#  (1, ('08_04_XQuery_Demo.txt', 'let'), 2),
#  (0, ('08_01_XPath_Introduction.txt', 't'), 2),
#  (1, ('08_01_XPath_Introduction.txt', 't'), 2),
#  (0, ('06_04_Subqueries_in_WHERE_Clause.txt', 'unabl'), 2),
#  (1, ('06_04_Subqueries_in_WHERE_Clause.txt', 'unabl'), 2),
#  (0, ('16_01_Introduction_to_OLAP_Part_1.txt', 'corner'), 2),
#  (1, ('16_01_Introduction_to_OLAP_Part_1.txt', 'corner'), 2),
#  (0,
#   ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_1.txt', 'codd'),
#   2),
#  (1,
#   ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_1.txt', 'codd'),
#   2),
#  (0, ('06_01_Introduction_to_SQL.txt', 'attribut'), 2),
#  (1, ('06_01_Introduction_to_SQL.txt', 'attribut'), 2),
#  (0, ('13_02_View_Modifications_Introduction_Part_2.txt', 'demo'), 2),
#  (1, ('13_02_View_Modifications_Introduction_Part_2.txt', 'demo'), 2),
#  (0, ('03_01_Well_Formed_XML_Part_1.txt', ','), 2),
#  (1, ('03_01_Well_Formed_XML_Part_1.txt', ','), 2),
#  (0, ('09_02_UML_to_Relations_Part_2.txt', 'certainli'), 2),
#  (1, ('09_02_UML_to_Relations_Part_2.txt', 'certainli'), 2),
#  (0, ('14_01_Authorization_Part_3.txt', 'cascad option'), 1),
#  (1, ('14_01_Authorization_Part_3.txt', 'cascad option'), 2),
#  (0, ('06_03_Table_Variables_and_Set_Operators.txt', 'you'), 2),
#  (1, ('06_03_Table_Variables_and_Set_Operators.txt', 'you'), 2),
#  (0, ('05_01_Select_Project_Join_Part_3.txt', 'which,'), 2),
#  (1, ('05_01_Select_Project_Join_Part_3.txt', 'which,'), 2),
#  (0, ('12_02_Constraints_of_Several_Types_Part_1.txt', 'middle,'), 2),
#  (1, ('12_02_Constraints_of_Several_Types_Part_1.txt', 'middle,'), 2),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', 'januari'), 2),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', 'januari'), 2),
#  (0, ('07_02_Functional_Dependencies_Part_3.txt', 'sinc'), 2),
#  (1, ('07_02_Functional_Dependencies_Part_3.txt', 'sinc'), 2),
#  (0, ('05_01_Select_Project_Join_Part_2.txt', 'here'), 2),
#  (1, ('05_01_Select_Project_Join_Part_2.txt', 'here'), 2),
#  (0, ('12_03_Referential_Integrity_Part_3.txt', 'is'), 2),
#  (1, ('12_03_Referential_Integrity_Part_3.txt', 'is'), 2),
#  (0, ('12_01_Motivation_and_Overview.txt', 'certain'), 2),
#  (1, ('12_01_Motivation_and_Overview.txt', 'certain'), 2),
#  (0, ('06_04_Subqueries_in_WHERE_Clause.txt', 'origin'), 2),
#  (1, ('06_04_Subqueries_in_WHERE_Clause.txt', 'origin'), 2),
#  (0, ('11_03_Isolation_Levels_Part_3.txt', 'read commit'), 2),
#  (1, ('11_03_Isolation_Levels_Part_3.txt', 'read commit'), 1),
#  (0, ('14_01_Authorization_Part_2.txt', 'how'), 2),
#  (1, ('14_01_Authorization_Part_2.txt', 'how'), 2),
#  (0, ('13_01_Defining_and_Using_Views.txt', 'a'), 2),
#  (1, ('13_01_Defining_and_Using_Views.txt', 'a'), 2),
#  (0, ('12_04_Triggers_Introduction.txt', 'reiterate,'), 2),
#  (1, ('12_04_Triggers_Introduction.txt', 'reiterate,'), 2),
#  (0,
#   ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_1.txt', 'than'),
#   2),
#  (1,
#   ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_1.txt', 'than'),
#   2),
#  (0, ('09_02_UML_to_Relations_Part_1.txt', 'frequent'), 2),
#  (1, ('09_02_UML_to_Relations_Part_1.txt', 'frequent'), 2),
#  (0, ('12_03_Referential_Integrity_Part_3.txt', 'constraint,'), 2),
#  (1, ('12_03_Referential_Integrity_Part_3.txt', 'constraint,'), 2),
#  (0, ('13_04_Automatic_View_Modifications.txt', "we'r"), 2),
#  (1, ('13_04_Automatic_View_Modifications.txt', "we'r"), 2),
#  (0, ('07_02_Functional_Dependencies_Part_3.txt', 'number,'), 2),
#  (1, ('07_02_Functional_Dependencies_Part_3.txt', 'number,'), 2),
#  (0, ('07_02_Functional_Dependencies_Part_3.txt', 'togeth'), 2),
#  (1, ('07_02_Functional_Dependencies_Part_3.txt', 'togeth'), 2),
#  (0, ('06_08_The_JOIN_Family_of_Operators.txt', 'all'), 2),
#  (1, ('06_08_The_JOIN_Family_of_Operators.txt', 'all'), 2),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_2.txt', 'script'), 2),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_2.txt', 'script'), 2),
#  (0, ('10_01_Indexes_Part_1.txt', 'starter'), 2),
#  (1, ('10_01_Indexes_Part_1.txt', 'starter'), 2),
#  (0, ('12_02_Constraints_of_Several_Types_Part_1.txt', 'itself,'), 2),
#  (1, ('12_02_Constraints_of_Several_Types_Part_1.txt', 'itself,'), 2),
#  (0, ('05_01_Select_Project_Join_Part_3.txt', 'for'), 2),
#  (1, ('05_01_Select_Project_Join_Part_3.txt', 'for'), 2),
#  (0, ('07_02_Functional_Dependencies_Part_1.txt', 'bm,'), 2),
#  (1, ('07_02_Functional_Dependencies_Part_1.txt', 'bm,'), 2),
#  (0, ('09_01_UML_Data_Modeling.txt', 'unit'), 2),
#  (1, ('09_01_UML_Data_Modeling.txt', 'unit'), 2),
#  (0, ('13_03_View_Modifications_Using_Triggers.txt', 'inserted,'), 2),
#  (1, ('13_03_View_Modifications_Using_Triggers.txt', 'inserted,'), 2),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', 'book,'), 2),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', 'book,'), 2),
#  (0, ('09_02_UML_to_Relations_Part_3.txt', 'at'), 2),
#  (1, ('09_02_UML_to_Relations_Part_3.txt', 'at'), 2),
#  (0, ('06_02_Basic_SELECT_Statement.txt', 'on'), 2),
#  (1, ('06_02_Basic_SELECT_Statement.txt', 'on'), 2),
#  (0, ('15_02_Basic_Recursive_WITH_Statement_Demo.txt', "we'll"), 2),
#  (1, ('15_02_Basic_Recursive_WITH_Statement_Demo.txt', "we'll"), 2),
#  (0,
#   ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_1.txt', 'case,'),
#   2),
#  (1,
#   ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_1.txt', 'case,'),
#   2),
#  (0, ('09_02_UML_to_Relations_Part_1.txt', 'underlin'), 2),
#  (1, ('09_02_UML_to_Relations_Part_1.txt', 'underlin'), 2),
#  (0, ('15_02_Basic_Recursive_WITH_Statement_Demo.txt', 'say,'), 2),
#  (1, ('15_02_Basic_Recursive_WITH_Statement_Demo.txt', 'say,'), 2),
#  (0, ('12_05_Triggers_Demo_Part_1.txt', 'now,'), 2),
#  (1, ('12_05_Triggers_Demo_Part_1.txt', 'now,'), 2),
#  (0, ('06_03_Table_Variables_and_Set_Operators.txt', 'look'), 2),
#  (1, ('06_03_Table_Variables_and_Set_Operators.txt', 'look'), 2),
#  (0, ('10_01_Indexes_Part_1.txt', 'three'), 2),
#  (1, ('10_01_Indexes_Part_1.txt', 'three'), 2),
#  (0, ('01_01_Introduction.txt', 'quit'), 2),
#  (1, ('01_01_Introduction.txt', 'quit'), 2),
#  (0,
#   ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_1.txt', 'talk'),
#   2),
#  (1,
#   ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_1.txt', 'talk'),
#   2),
#  (0, ('11_03_Isolation_Levels_Part_1.txt', 'number'), 2),
#  (1, ('11_03_Isolation_Levels_Part_1.txt', 'number'), 2),
#  (0, ('12_05_Triggers_Demo_Part_2.txt', 'two,'), 2),
#  (1, ('12_05_Triggers_Demo_Part_2.txt', 'two,'), 2),
#  (0, ('08_02_XPath_Demo.txt', 'colon,'), 2),
#  (1, ('08_02_XPath_Demo.txt', 'colon,'), 2),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_2.txt', 'for,'), 2),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_2.txt', 'for,'), 2),
#  (0, ('04_02_JSON_Demo.txt', 'addition,'), 2),
#  (1, ('04_02_JSON_Demo.txt', 'addition,'), 2),
#  (0, ('16_01_Introduction_to_OLAP_Part_2.txt', 'specif'), 2),
#  (1, ('16_01_Introduction_to_OLAP_Part_2.txt', 'specif'), 2),
#  (0, ('12_03_Referential_Integrity_Part_3.txt', "can't"), 2),
#  (1, ('12_03_Referential_Integrity_Part_3.txt', "can't"), 2),
#  (0, ('12_03_Referential_Integrity_Part_3.txt', '"234",'), 2),
#  (1, ('12_03_Referential_Integrity_Part_3.txt', '"234",'), 2),
#  (0, ('07_03_Boyce_Codd_Normal_Form_Part_1.txt', 'databas'), 2),
#  (1, ('07_03_Boyce_Codd_Normal_Form_Part_1.txt', 'databas'), 2),
#  (0, ('11_02_Transactions_Properties_Part_3.txt', 'implement'), 2),
#  (1, ('11_02_Transactions_Properties_Part_3.txt', 'implement'), 2),
#  (0, ('16_01_Introduction_to_OLAP_Part_2.txt', 'look'), 2),
#  (1, ('16_01_Introduction_to_OLAP_Part_2.txt', 'look'), 2),
#  (0, ('10_01_Indexes_Part_2.txt', 'structur'), 2),
#  (1, ('10_01_Indexes_Part_2.txt', 'structur'), 2),
#  (0, ('12_05_Triggers_Demo_Part_1.txt', 'recent'), 2),
#  (1, ('12_05_Triggers_Demo_Part_1.txt', 'recent'), 2),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', 'noth'), 2),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', 'noth'), 2),
#  (0, ('13_03_View_Modifications_Using_Triggers.txt', 'saw'), 2),
#  (1, ('13_03_View_Modifications_Using_Triggers.txt', 'saw'), 2),
#  (0, ('12_05_Triggers_Demo_Part_2.txt', 'show'), 2),
#  (1, ('12_05_Triggers_Demo_Part_2.txt', 'show'), 2),
#  (0, ('05_01_Select_Project_Join_Part_2.txt', 'convention,'), 2),
#  (1, ('05_01_Select_Project_Join_Part_2.txt', 'convention,'), 2),
#  (0, ('06_03_Table_Variables_and_Set_Operators.txt', 'default,'), 2),
#  (1, ('06_03_Table_Variables_and_Set_Operators.txt', 'default,'), 2),
#  (0, ('02_02_Querying_Relational_Databases.txt', 'fairli'), 2),
#  (1, ('02_02_Querying_Relational_Databases.txt', 'fairli'), 2),
#  (0, ('06_08_The_JOIN_Family_of_Operators.txt', 'becaus'), 2),
#  (1, ('06_08_The_JOIN_Family_of_Operators.txt', 'becaus'), 2),
#  (0, ('08_01_XPath_Introduction.txt', 'their'), 2),
#  (1, ('08_01_XPath_Introduction.txt', 'their'), 2),
#  (0, ('12_04_Triggers_Introduction.txt', 'chang'), 2),
#  (1, ('12_04_Triggers_Introduction.txt', 'chang'), 2),
#  (0, ('12_02_Constraints_of_Several_Types_Part_1.txt', 'match'), 2),
#  (1, ('12_02_Constraints_of_Several_Types_Part_1.txt', 'match'), 2),
#  (0, ('07_03_Boyce_Codd_Normal_Form_Part_1.txt', 'like'), 2),
#  (1, ('07_03_Boyce_Codd_Normal_Form_Part_1.txt', 'like'), 2),
#  (0, ('09_02_UML_to_Relations_Part_3.txt', 'association,'), 2),
#  (1, ('09_02_UML_to_Relations_Part_3.txt', 'association,'), 2),
#  (0, ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', 'way'), 2),
#  (1, ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', 'way'), 2),
#  (0, ('03_02_XML_Schema.txt', 'sinc'), 2),
#  (1, ('03_02_XML_Schema.txt', 'sinc'), 2),
#  (0, ('12_02_Constraints_of_Several_Types_Part_1.txt', 'should'), 2),
#  (1, ('12_02_Constraints_of_Several_Types_Part_1.txt', 'should'), 2),
#  (0, ('07_02_Functional_Dependencies_Part_1.txt', 'idea'), 2),
#  (1, ('07_02_Functional_Dependencies_Part_1.txt', 'idea'), 2),
#  (0, ('07_01_Relational_Design_Overview_Part_3.txt', 'time'), 2),
#  (1, ('07_01_Relational_Design_Overview_Part_3.txt', 'time'), 2),
#  (0, ('08_05_XSLT.txt', 'programmat style'), 2),
#  (1, ('08_05_XSLT.txt', 'programmat style'), 2),
#  (0, ('06_05_Aggregation.txt', 'somewher'), 2),
#  (1, ('06_05_Aggregation.txt', 'somewher'), 2),
#  (0, ('15_01_Basic_Recursive_WITH_Statement_Introduction.txt', 'over'), 2),
#  (1, ('15_01_Basic_Recursive_WITH_Statement_Introduction.txt', 'over'), 2),
#  (0, ('06_08_The_JOIN_Family_of_Operators.txt', 'result'), 2),
#  (1, ('06_08_The_JOIN_Family_of_Operators.txt', 'result'), 2),
#  (0, ('02_02_Querying_Relational_Databases.txt', 'particular'), 2),
#  (1, ('02_02_Querying_Relational_Databases.txt', 'particular'), 2),
#  (0, ('12_03_Referential_Integrity_Part_1.txt', 'the'), 2),
#  (1, ('12_03_Referential_Integrity_Part_1.txt', 'the'), 2),
#  (0, ('12_04_Triggers_Introduction.txt', 'system'), 2),
#  (1, ('12_04_Triggers_Introduction.txt', 'system'), 2),
#  (0, ('16_01_Introduction_to_OLAP_Part_1.txt', 'fall'), 2),
#  (1, ('16_01_Introduction_to_OLAP_Part_1.txt', 'fall'), 2),
#  (0, ('08_02_XPath_Demo.txt', 'put'), 2),
#  (1, ('08_02_XPath_Demo.txt', 'put'), 2),
#  (0, ('16_02_OLAP_Demo.txt', 'messag'), 2),
#  (1, ('16_02_OLAP_Demo.txt', 'messag'), 2),
#  (0, ('15_01_Basic_Recursive_WITH_Statement_Introduction.txt', 'schema,'), 2),
#  (1, ('15_01_Basic_Recursive_WITH_Statement_Introduction.txt', 'schema,'), 2),
#  (0, ('13_03_View_Modifications_Using_Triggers.txt', 'match'), 2),
#  (1, ('13_03_View_Modifications_Using_Triggers.txt', 'match'), 2),
#  (0, ('13_03_View_Modifications_Using_Triggers.txt', 'third'), 2),
#  (1, ('13_03_View_Modifications_Using_Triggers.txt', 'third'), 2),
#  (0, ('12_03_Referential_Integrity_Part_2.txt', 'state'), 2),
#  (1, ('12_03_Referential_Integrity_Part_2.txt', 'state'), 2),
#  (0, ('09_02_UML_to_Relations_Part_2.txt', ','), 2),
#  (1, ('09_02_UML_to_Relations_Part_2.txt', ','), 2),
#  (0, ('07_02_Functional_Dependencies_Part_1.txt', 'me'), 2),
#  (1, ('07_02_Functional_Dependencies_Part_1.txt', 'me'), 2),
#  (0, ('11_03_Isolation_Levels_Part_1.txt', 'that,'), 2),
#  (1, ('11_03_Isolation_Levels_Part_1.txt', 'that,'), 2),
#  (0, ('12_05_Triggers_Demo_Part_1.txt', 'appli'), 2),
#  (1, ('12_05_Triggers_Demo_Part_1.txt', 'appli'), 2),
#  (0, ('03_02_XML_Schema.txt', 'id'), 2),
#  (1, ('03_02_XML_Schema.txt', 'id'), 2),
#  (0, ('12_03_Referential_Integrity_Part_3.txt', 'action'), 2),
#  (1, ('12_03_Referential_Integrity_Part_3.txt', 'action'), 2),
#  (0, ('06_02_Basic_SELECT_Statement.txt', 'mit'), 2),
#  (1, ('06_02_Basic_SELECT_Statement.txt', 'mit'), 2),
#  (0, ('08_05_XSLT.txt', 'perhap'), 2),
#  (1, ('08_05_XSLT.txt', 'perhap'), 2),
#  (0,
#   ('15_01_Basic_Recursive_WITH_Statement_Introduction.txt', 'typically,'),
#   2),
#  (1,
#   ('15_01_Basic_Recursive_WITH_Statement_Introduction.txt', 'typically,'),
#   2),
#  (0, ('12_02_Constraints_of_Several_Types_Part_1.txt', 'actual'), 2),
#  (1, ('12_02_Constraints_of_Several_Types_Part_1.txt', 'actual'), 2),
#  (0, ('10_01_Indexes_Part_1.txt', 'typic'), 2),
#  (1, ('10_01_Indexes_Part_1.txt', 'typic'), 2),
#  (0, ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', 'order'), 2),
#  (1, ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', 'order'), 2),
#  (0, ('11_03_Isolation_Levels_Part_1.txt', 'increas'), 2),
#  (1, ('11_03_Isolation_Levels_Part_1.txt', 'increas'), 2),
#  (0, ('13_03_View_Modifications_Using_Triggers.txt', 'bound'), 2),
#  (1, ('13_03_View_Modifications_Using_Triggers.txt', 'bound'), 2),
#  (0, ('07_01_Relational_Design_Overview_Part_1.txt', 'could'), 2),
#  (1, ('07_01_Relational_Design_Overview_Part_1.txt', 'could'), 2),
#  (0,
#   ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_3.txt', 'input'),
#   2),
#  (1,
#   ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_3.txt', 'input'),
#   2),
#  (0, ('03_02_XML_Schema.txt', 'key'), 2),
#  (1, ('03_02_XML_Schema.txt', 'key'), 1),
#  (0, ('13_02_View_Modifications_Introduction_Part_1.txt', 'r.'), 2),
#  (1, ('13_02_View_Modifications_Introduction_Part_1.txt', 'r.'), 2),
#  (0, ('16_02_OLAP_Demo.txt', 'slicing,'), 2),
#  (1, ('16_02_OLAP_Demo.txt', 'slicing,'), 2),
#  (0, ('09_02_UML_to_Relations_Part_2.txt', 'noticed,'), 2),
#  (1, ('09_02_UML_to_Relations_Part_2.txt', 'noticed,'), 2),
#  (0, ('13_01_Defining_and_Using_Views.txt', 'bunch'), 2),
#  (1, ('13_01_Defining_and_Using_Views.txt', 'bunch'), 2),
#  (0, ('07_02_Functional_Dependencies_Part_1.txt', 'a2'), 2),
#  (1, ('07_02_Functional_Dependencies_Part_1.txt', 'a2'), 2),
#  (0, ('12_03_Referential_Integrity_Part_3.txt', 'show'), 2),
#  (1, ('12_03_Referential_Integrity_Part_3.txt', 'show'), 2),
#  (0, ('07_03_Boyce_Codd_Normal_Form_Part_1.txt', 'gpa'), 2),
#  (1, ('07_03_Boyce_Codd_Normal_Form_Part_1.txt', 'gpa'), 2),
#  (0, ('09_02_UML_to_Relations_Part_3.txt', 'usual,'), 2),
#  (1, ('09_02_UML_to_Relations_Part_3.txt', 'usual,'), 2),
#  (0, ('13_04_Automatic_View_Modifications.txt', 'import'), 2),
#  (1, ('13_04_Automatic_View_Modifications.txt', 'import'), 2),
#  (0, ('04_02_JSON_Demo.txt', 'pattern'), 2),
#  (1, ('04_02_JSON_Demo.txt', 'pattern'), 2),
#  (0, ('02_01_The_Relational_Model.txt', 'coast'), 2),
#  (1, ('02_01_The_Relational_Model.txt', 'coast'), 2),
#  (0, ('17_01_NoSQLOverview.txt', 'ance,'), 2),
#  (1, ('17_01_NoSQLOverview.txt', 'ance,'), 2),
#  (0, ('12_01_Motivation_and_Overview.txt', 'five'), 2),
#  (1, ('12_01_Motivation_and_Overview.txt', 'five'), 2),
#  (0, ('13_02_View_Modifications_Introduction_Part_1.txt', 'number'), 2),
#  (1, ('13_02_View_Modifications_Introduction_Part_1.txt', 'number'), 2),
#  (0, ('06_05_Aggregation.txt', 'break'), 2),
#  (1, ('06_05_Aggregation.txt', 'break'), 2),
#  (0, ('13_05_Materialized_Views_Part_1.txt', 'lots,'), 2),
#  (1, ('13_05_Materialized_Views_Part_1.txt', 'lots,'), 2),
#  (0, ('09_02_UML_to_Relations_Part_2.txt', 'base'), 2),
#  (1, ('09_02_UML_to_Relations_Part_2.txt', 'base'), 2),
#  (0, ('05_01_Select_Project_Join_Part_1.txt', 'project oper'), 1),
#  (1, ('05_01_Select_Project_Join_Part_1.txt', 'project oper'), 1),
#  (0, ('07_02_Functional_Dependencies_Part_3.txt', 'databas'), 2),
#  (1, ('07_02_Functional_Dependencies_Part_3.txt', 'databas'), 2),
#  (0, ('13_03_View_Modifications_Using_Triggers.txt', 'new'), 2),
#  (1, ('13_03_View_Modifications_Using_Triggers.txt', 'new'), 2),
#  (0, ('08_04_XQuery_Demo.txt', 'whose'), 2),
#  (1, ('08_04_XQuery_Demo.txt', 'whose'), 2),
#  (0, ('13_05_Materialized_Views_Part_1.txt', 'tables,'), 2),
#  (1, ('13_05_Materialized_Views_Part_1.txt', 'tables,'), 2),
#  (0,
#   ('15_01_Basic_Recursive_WITH_Statement_Introduction.txt', 'with construct'),
#   2),
#  (1,
#   ('15_01_Basic_Recursive_WITH_Statement_Introduction.txt', 'with construct'),
#   2),
#  (0, ('08_02_XPath_Demo.txt', 'refer'), 2),
#  (1, ('08_02_XPath_Demo.txt', 'refer'), 2),
#  (0, ('16_01_Introduction_to_OLAP_Part_2.txt', 'would'), 2),
#  (1, ('16_01_Introduction_to_OLAP_Part_2.txt', 'would'), 2),
#  (0, ('05_01_Select_Project_Join_Part_2.txt', 'no'), 2),
#  (1, ('05_01_Select_Project_Join_Part_2.txt', 'no'), 2),
#  (0, ('06_05_Aggregation.txt', 'presum'), 2),
#  (1, ('06_05_Aggregation.txt', 'presum'), 2),
#  (0,
#   ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_3.txt', 'no'),
#   2),
#  (1,
#   ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_3.txt', 'no'),
#   2),
#  (0, ('09_02_UML_to_Relations_Part_3.txt', 'give'), 2),
#  (1, ('09_02_UML_to_Relations_Part_3.txt', 'give'), 2),
#  (0, ('09_02_UML_to_Relations_Part_2.txt', 'mega'), 2),
#  (1, ('09_02_UML_to_Relations_Part_2.txt', 'mega'), 2),
#  (0, ('08_01_XPath_Introduction.txt', 'much,'), 2),
#  (1, ('08_01_XPath_Introduction.txt', 'much,'), 2),
#  (0, ('08_01_XPath_Introduction.txt', 'html'), 2),
#  (1, ('08_01_XPath_Introduction.txt', 'html'), 2),
#  (0, ('13_01_Defining_and_Using_Views.txt', 'cs-berk,'), 2),
#  (1, ('13_01_Defining_and_Using_Views.txt', 'cs-berk,'), 2),
#  (0, ('09_01_UML_Data_Modeling.txt', 'knew'), 2),
#  (1, ('09_01_UML_Data_Modeling.txt', 'knew'), 2),
#  (0, ('06_02_Basic_SELECT_Statement.txt', 'select from where structur'), 2),
#  (1, ('06_02_Basic_SELECT_Statement.txt', 'select from where structur'), 2),
#  (0, ('17_01_NoSQLMotivation.txt', "we'v"), 2),
#  (1, ('17_01_NoSQLMotivation.txt', "we'v"), 2),
#  (0, ('06_03_Table_Variables_and_Set_Operators.txt', 'it,'), 2),
#  (1, ('06_03_Table_Variables_and_Set_Operators.txt', 'it,'), 2),
#  (0, ('06_05_Aggregation.txt', 'go'), 2),
#  (1, ('06_05_Aggregation.txt', 'go'), 2),
#  (0, ('13_04_Automatic_View_Modifications.txt', 'ami'), 2),
#  (1, ('13_04_Automatic_View_Modifications.txt', 'ami'), 2),
#  (0, ('17_01_NoSQLOverview.txt', "doesn't"), 2),
#  (1, ('17_01_NoSQLOverview.txt', "doesn't"), 2),
#  (0, ('12_03_Referential_Integrity_Part_3.txt', 'cannot'), 2),
#  (1, ('12_03_Referential_Integrity_Part_3.txt', 'cannot'), 2),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', 'pars'), 2),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', 'pars'), 2),
#  (0, ('13_02_View_Modifications_Introduction_Part_2.txt', 'now,'), 2),
#  (1, ('13_02_View_Modifications_Introduction_Part_2.txt', 'now,'), 2),
#  (0, ('13_05_Materialized_Views_Part_1.txt', 'just'), 2),
#  (1, ('13_05_Materialized_Views_Part_1.txt', 'just'), 2),
#  (0, ('17_01_NoSQLOverview.txt', 'too,'), 2),
#  (1, ('17_01_NoSQLOverview.txt', 'too,'), 2),
#  (0, ('08_02_XPath_Demo.txt', 'gonna'), 2),
#  (1, ('08_02_XPath_Demo.txt', 'gonna'), 2),
#  (0, ('12_03_Referential_Integrity_Part_3.txt', 'put'), 2),
#  (1, ('12_03_Referential_Integrity_Part_3.txt', 'put'), 2),
#  (0, ('08_04_XQuery_Demo.txt', 'get'), 2),
#  (1, ('08_04_XQuery_Demo.txt', 'get'), 2),
#  (0, ('01_01_Introduction.txt', 'databas system'), 2),
#  (1, ('01_01_Introduction.txt', 'databas system'), 2),
#  (0, ('12_05_Triggers_Demo_Part_2.txt', 'fashion,'), 2),
#  (1, ('12_05_Triggers_Demo_Part_2.txt', 'fashion,'), 2),
#  (0, ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', 'becaus'), 2),
#  (1, ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', 'becaus'), 2),
#  (0, ('06_07_Data_Modification_Statements.txt', 'format'), 2),
#  (1, ('06_07_Data_Modification_Statements.txt', 'format'), 2),
#  (0, ('09_01_UML_Data_Modeling.txt', 'could'), 2),
#  (1, ('09_01_UML_Data_Modeling.txt', 'could'), 2),
#  (0, ('14_01_Authorization_Part_2.txt', "didn't"), 2),
#  (1, ('14_01_Authorization_Part_2.txt', "didn't"), 2),
#  (0, ('08_05_XSLT.txt', 'recursively,'), 2),
#  (1, ('08_05_XSLT.txt', 'recursively,'), 2),
#  (0, ('17_01_NoSQLOverview.txt', 'do'), 2),
#  (1, ('17_01_NoSQLOverview.txt', 'do'), 2),
#  (0, ('04_02_JSON_Demo.txt', 'much'), 2),
#  (1, ('04_02_JSON_Demo.txt', 'much'), 2),
#  (0, ('09_02_UML_to_Relations_Part_2.txt', 'automat translat'), 2),
#  (1, ('09_02_UML_to_Relations_Part_2.txt', 'automat translat'), 1),
#  (0, ('13_01_Defining_and_Using_Views.txt', 'disk'), 2),
#  (1, ('13_01_Defining_and_Using_Views.txt', 'disk'), 2),
#  (0, ('06_02_Basic_SELECT_Statement.txt', 'rememb'), 2),
#  (1, ('06_02_Basic_SELECT_Statement.txt', 'rememb'), 2),
#  (0, ('12_02_Constraints_of_Several_Types_Part_1.txt', 'mysql'), 2),
#  (1, ('12_02_Constraints_of_Several_Types_Part_1.txt', 'mysql'), 2),
#  (0, ('12_02_Constraints_of_Several_Types_Part_1.txt', 'littl'), 2),
#  (1, ('12_02_Constraints_of_Several_Types_Part_1.txt', 'littl'), 2),
#  (0, ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', 'column'), 2),
#  (1, ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', 'column'), 2),
#  (0, ('07_02_Functional_Dependencies_Part_3.txt', 'an'), 2),
#  (1, ('07_02_Functional_Dependencies_Part_3.txt', 'an'), 2),
#  (0, ('09_02_UML_to_Relations_Part_2.txt', 'let'), 2),
#  (1, ('09_02_UML_to_Relations_Part_2.txt', 'let'), 2),
#  (0, ('14_01_Authorization_Part_3.txt', 'basically,'), 2),
#  (1, ('14_01_Authorization_Part_3.txt', 'basically,'), 2),
#  (0, ('15_02_Basic_Recursive_WITH_Statement_Demo.txt', 'support'), 2),
#  (1, ('15_02_Basic_Recursive_WITH_Statement_Demo.txt', 'support'), 2),
#  (0, ('09_02_UML_to_Relations_Part_2.txt', 'key'), 2),
#  (1, ('09_02_UML_to_Relations_Part_2.txt', 'key'), 2),
#  (0, ('13_02_View_Modifications_Introduction_Part_2.txt', 'into'), 2),
#  (1, ('13_02_View_Modifications_Introduction_Part_2.txt', 'into'), 2),
#  (0,
#   ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_3.txt', 'regard'),
#   2),
#  (1,
#   ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_3.txt', 'regard'),
#   2),
#  (0, ('06_04_Subqueries_in_WHERE_Clause.txt', 'inde'), 2),
#  (1, ('06_04_Subqueries_in_WHERE_Clause.txt', 'inde'), 2),
#  (0, ('06_04_Subqueries_in_WHERE_Clause.txt', 'either'), 2),
#  (1, ('06_04_Subqueries_in_WHERE_Clause.txt', 'either'), 2),
#  (0, ('06_05_Aggregation.txt', "we'v"), 2),
#  (1, ('06_05_Aggregation.txt', "we'v"), 2),
#  (0, ('06_02_Basic_SELECT_Statement.txt', 'idea'), 2),
#  (1, ('06_02_Basic_SELECT_Statement.txt', 'idea'), 2),
#  (0, ('16_02_OLAP_Demo.txt', 'red,'), 2),
#  (1, ('16_02_OLAP_Demo.txt', 'red,'), 2),
#  (0, ('03_01_Well_Formed_XML_Part_1.txt', 'whatsoev'), 2),
#  (1, ('03_01_Well_Formed_XML_Part_1.txt', 'whatsoev'), 2),
#  (0, ('03_01_Well_Formed_XML_Part_1.txt', 'want'), 2),
#  (1, ('03_01_Well_Formed_XML_Part_1.txt', 'want'), 2),
#  (0, ('11_03_Isolation_Levels_Part_4.txt', 'ani'), 2),
#  (1, ('11_03_Isolation_Levels_Part_4.txt', 'ani'), 2),
#  (0, ('11_03_Isolation_Levels_Part_3.txt', 'again'), 2),
#  (1, ('11_03_Isolation_Levels_Part_3.txt', 'again'), 2),
#  (0, ('12_05_Triggers_Demo_Part_1.txt', "don't"), 2),
#  (1, ('12_05_Triggers_Demo_Part_1.txt', "don't"), 2),
#  (0, ('15_03_Nonlinear_and_Mutual_Recursion_Part_1.txt', 'version,'), 2),
#  (1, ('15_03_Nonlinear_and_Mutual_Recursion_Part_1.txt', 'version,'), 2),
#  (0, ('06_02_Basic_SELECT_Statement.txt', 'might'), 2),
#  (1, ('06_02_Basic_SELECT_Statement.txt', 'might'), 2),
#  (0, ('12_04_Triggers_Introduction.txt', 'reminder,'), 2),
#  (1, ('12_04_Triggers_Introduction.txt', 'reminder,'), 2),
#  (0, ('05_01_Select_Project_Join_Part_1.txt', 'a'), 2),
#  (1, ('05_01_Select_Project_Join_Part_1.txt', 'a'), 2),
#  (0, ('16_02_OLAP_Demo.txt', 'sequel'), 2),
#  (1, ('16_02_OLAP_Demo.txt', 'sequel'), 2),
#  (0, ('16_02_OLAP_Demo.txt', 'more'), 2),
#  (1, ('16_02_OLAP_Demo.txt', 'more'), 2),
#  (0, ('16_02_OLAP_Demo.txt', 'tuple,'), 2),
#  (1, ('16_02_OLAP_Demo.txt', 'tuple,'), 2),
#  (0,
#   ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_1.txt', 'get'),
#   2),
#  (1,
#   ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_1.txt', 'get'),
#   2),
#  (0, ('12_05_Triggers_Demo_Part_1.txt', 'after-trigger,'), 2),
#  (1, ('12_05_Triggers_Demo_Part_1.txt', 'after-trigger,'), 2),
#  (0, ('07_01_Relational_Design_Overview_Part_2.txt', 'work?'), 2),
#  (1, ('07_01_Relational_Design_Overview_Part_2.txt', 'work?'), 2),
#  (0, ('10_01_Indexes_Part_1.txt', 'main'), 2),
#  (1, ('10_01_Indexes_Part_1.txt', 'main'), 2),
#  (0, ('13_04_Automatic_View_Modifications.txt', 'bob,'), 2),
#  (1, ('13_04_Automatic_View_Modifications.txt', 'bob,'), 2),
#  (0, ('11_02_Transactions_Properties_Part_2.txt', 'major'), 2),
#  (1, ('11_02_Transactions_Properties_Part_2.txt', 'major'), 2),
#  (0, ('06_07_Data_Modification_Statements.txt', 'no'), 2),
#  (1, ('06_07_Data_Modification_Statements.txt', 'no'), 2),
#  (0, ('16_01_Introduction_to_OLAP_Part_2.txt', 'creat'), 2),
#  (1, ('16_01_Introduction_to_OLAP_Part_2.txt', 'creat'), 2),
#  (0, ('07_01_Relational_Design_Overview_Part_3.txt', 'addition,'), 2),
#  (1, ('07_01_Relational_Design_Overview_Part_3.txt', 'addition,'), 2),
#  (0, ('17_01_NoSQLOverview.txt', 'you'), 2),
#  (1, ('17_01_NoSQLOverview.txt', 'you'), 2),
#  (0, ('15_02_Basic_Recursive_WITH_Statement_Demo.txt', 'add'), 2),
#  (1, ('15_02_Basic_Recursive_WITH_Statement_Demo.txt', 'add'), 2),
#  (0, ('06_07_Data_Modification_Statements.txt', 'final'), 2),
#  (1, ('06_07_Data_Modification_Statements.txt', 'final'), 2),
#  (0, ('12_04_Triggers_Introduction.txt', 'ever'), 2),
#  (1, ('12_04_Triggers_Introduction.txt', 'ever'), 2),
#  (0, ('11_02_Transactions_Properties_Part_2.txt', 'simultan'), 2),
#  (1, ('11_02_Transactions_Properties_Part_2.txt', 'simultan'), 2),
#  (0, ('07_01_Relational_Design_Overview_Part_2.txt', 'veri'), 2),
#  (1, ('07_01_Relational_Design_Overview_Part_2.txt', 'veri'), 2),
#  (0, ('14_01_Authorization_Part_2.txt', 'just'), 2),
#  (1, ('14_01_Authorization_Part_2.txt', 'just'), 2),
#  (0, ('06_02_Basic_SELECT_Statement.txt', 'get,'), 2),
#  (1, ('06_02_Basic_SELECT_Statement.txt', 'get,'), 2),
#  (0, ('07_03_Boyce_Codd_Normal_Form_Part_1.txt', 'where'), 2),
#  (1, ('07_03_Boyce_Codd_Normal_Form_Part_1.txt', 'where'), 2),
#  (0, ('06_05_Aggregation.txt', 'among'), 2),
#  (1, ('06_05_Aggregation.txt', 'among'), 2),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_1.txt', 'specif'), 2),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_1.txt', 'specif'), 2),
#  (0, ('01_01_Introduction.txt', 'great'), 2),
#  (1, ('01_01_Introduction.txt', 'great'), 2),
#  (0, ('12_03_Referential_Integrity_Part_3.txt', '"235"'), 2),
#  (1, ('12_03_Referential_Integrity_Part_3.txt', '"235"'), 2),
#  (0, ('12_05_Triggers_Demo_Part_1.txt', 'normal;'), 2),
#  (1, ('12_05_Triggers_Demo_Part_1.txt', 'normal;'), 2),
#  (0, ('01_01_Introduction.txt', 'widom'), 2),
#  (1, ('01_01_Introduction.txt', 'widom'), 2),
#  (0, ('15_02_Basic_Recursive_WITH_Statement_Demo.txt', '10'), 2),
#  (1, ('15_02_Basic_Recursive_WITH_Statement_Demo.txt', '10'), 2),
#  (0, ('12_03_Referential_Integrity_Part_1.txt', 'see'), 2),
#  (1, ('12_03_Referential_Integrity_Part_1.txt', 'see'), 2),
#  (0, ('03_02_XML_Schema.txt', 'miss'), 2),
#  (1, ('03_02_XML_Schema.txt', 'miss'), 2),
#  (0, ('17_01_NoSQLOverview.txt', 'efficient,'), 2),
#  (1, ('17_01_NoSQLOverview.txt', 'efficient,'), 2),
#  (0, ('16_01_Introduction_to_OLAP_Part_2.txt', 'depend attribut'), 2),
#  (1, ('16_01_Introduction_to_OLAP_Part_2.txt', 'depend attribut'), 2),
#  (0, ('07_01_Relational_Design_Overview_Part_3.txt', 'h'), 2),
#  (1, ('07_01_Relational_Design_Overview_Part_3.txt', 'h'), 2),
#  (0, ('01_01_Introduction.txt', 'them,'), 2),
#  (1, ('01_01_Introduction.txt', 'them,'), 2),
#  (0, ('17_01_NoSQLOverview.txt', 'both,'), 2),
#  (1, ('17_01_NoSQLOverview.txt', 'both,'), 2),
#  (0, ('06_05_Aggregation.txt', "they'v"), 2),
#  (1, ('06_05_Aggregation.txt', "they'v"), 2),
#  (0, ('11_02_Transactions_Properties_Part_2.txt', 'somewhat'), 2),
#  (1, ('11_02_Transactions_Properties_Part_2.txt', 'somewhat'), 2),
#  (0, ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', 'part'), 2),
#  (1, ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', 'part'), 2),
#  (0, ('08_02_XPath_Demo.txt', 'explain'), 2),
#  (1, ('08_02_XPath_Demo.txt', 'explain'), 2),
#  (0, ('12_04_Triggers_Introduction.txt', 'make'), 2),
#  (1, ('12_04_Triggers_Introduction.txt', 'make'), 2),
#  (0, ('14_01_Authorization_Part_2.txt', 'user'), 2),
#  (1, ('14_01_Authorization_Part_2.txt', 'user'), 2),
#  (0, ('12_01_Motivation_and_Overview.txt', 'cours'), 2),
#  (1, ('12_01_Motivation_and_Overview.txt', 'cours'), 2),
#  (0, ('13_03_View_Modifications_Using_Triggers.txt', 'provid'), 2),
#  (1, ('13_03_View_Modifications_Using_Triggers.txt', 'provid'), 2),
#  (0, ('09_01_UML_Data_Modeling.txt', 'grade'), 2),
#  (1, ('09_01_UML_Data_Modeling.txt', 'grade'), 2),
#  (0, ('08_01_XPath_Introduction.txt', 'technic'), 2),
#  (1, ('08_01_XPath_Introduction.txt', 'technic'), 2),
#  (0, ('12_02_Constraints_of_Several_Types_Part_1.txt', 'however,'), 2),
#  (1, ('12_02_Constraints_of_Several_Types_Part_1.txt', 'however,'), 2),
#  (0, ('13_05_Materialized_Views_Part_1.txt', 'views,'), 2),
#  (1, ('13_05_Materialized_Views_Part_1.txt', 'views,'), 2),
#  (0, ('07_01_Relational_Design_Overview_Part_3.txt', 'still'), 2),
#  (1, ('07_01_Relational_Design_Overview_Part_3.txt', 'still'), 2),
#  (0, ('09_02_UML_to_Relations_Part_1.txt', 'relation,'), 2),
#  (1, ('09_02_UML_to_Relations_Part_1.txt', 'relation,'), 2),
#  (0, ('13_03_View_Modifications_Using_Triggers.txt', 'finally,'), 2),
#  (1, ('13_03_View_Modifications_Using_Triggers.txt', 'finally,'), 2),
#  (0, ('16_02_OLAP_Demo.txt', 'limit'), 2),
#  (1, ('16_02_OLAP_Demo.txt', 'limit'), 2),
#  (0, ('07_01_Relational_Design_Overview_Part_1.txt', 'directli'), 2),
#  (1, ('07_01_Relational_Design_Overview_Part_1.txt', 'directli'), 2),
#  (0, ('15_01_Basic_Recursive_WITH_Statement_Introduction.txt', 'employe'), 2),
#  (1, ('15_01_Basic_Recursive_WITH_Statement_Introduction.txt', 'employe'), 2),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_2.txt', 'just'), 2),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_2.txt', 'just'), 2),
#  (0, ('17_01_NoSQLOverview.txt', 'with'), 2),
#  (1, ('17_01_NoSQLOverview.txt', 'with'), 2),
#  (0, ('12_04_Triggers_Introduction.txt', 'fell'), 2),
#  (1, ('12_04_Triggers_Introduction.txt', 'fell'), 2),
#  (0, ('12_02_Constraints_of_Several_Types_Part_1.txt', 'inform'), 2),
#  (1, ('12_02_Constraints_of_Several_Types_Part_1.txt', 'inform'), 2),
#  (0, ('05_01_Select_Project_Join_Part_4.txt', "we'v"), 2),
#  (1, ('05_01_Select_Project_Join_Part_4.txt', "we'v"), 2),
#  (0, ('06_07_Data_Modification_Statements.txt', "there'"), 2),
#  (1, ('06_07_Data_Modification_Statements.txt', "there'"), 2),
#  (0, ('09_02_UML_to_Relations_Part_2.txt', 'distinguish'), 2),
#  (1, ('09_02_UML_to_Relations_Part_2.txt', 'distinguish'), 2),
#  (0, ('05_01_Select_Project_Join_Part_3.txt', 'do'), 2),
#  (1, ('05_01_Select_Project_Join_Part_3.txt', 'do'), 2),
#  (0,
#   ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_3.txt', 'never'),
#   2),
#  (1,
#   ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_3.txt', 'never'),
#   2),
#  (0, ('12_04_Triggers_Introduction.txt', 'depend'), 2),
#  (1, ('12_04_Triggers_Introduction.txt', 'depend'), 2),
#  (0, ('11_02_Transactions_Properties_Part_1.txt', 'sequenti'), 2),
#  (1, ('11_02_Transactions_Properties_Part_1.txt', 'sequenti'), 2),
#  (0, ('08_02_XPath_Demo.txt', 'execut the queri'), 2),
#  (1, ('08_02_XPath_Demo.txt', 'execut the queri'), 2),
#  (0, ('05_01_Select_Project_Join_Part_1.txt', 'be'), 2),
#  (1, ('05_01_Select_Project_Join_Part_1.txt', 'be'), 2),
#  (0, ('10_01_Indexes_Part_2.txt', 'second'), 2),
#  (1, ('10_01_Indexes_Part_2.txt', 'second'), 2),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_1.txt', 'e,'), 2),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_1.txt', 'e,'), 2),
#  (0, ('12_05_Triggers_Demo_Part_1.txt', 'have'), 2),
#  (1, ('12_05_Triggers_Demo_Part_1.txt', 'have'), 2),
#  (0, ('12_04_Triggers_Introduction.txt', "we'r"), 2),
#  (1, ('12_04_Triggers_Introduction.txt', "we'r"), 2),
#  (0, ('07_02_Functional_Dependencies_Part_1.txt', 'list'), 2),
#  (1, ('07_02_Functional_Dependencies_Part_1.txt', 'list'), 2),
#  (0, ('14_01_Authorization_Part_1.txt', 'there'), 2),
#  (1, ('14_01_Authorization_Part_1.txt', 'there'), 2),
#  (0, ('12_05_Triggers_Demo_Part_1.txt', 'think'), 2),
#  (1, ('12_05_Triggers_Demo_Part_1.txt', 'think'), 2),
#  (0, ('12_05_Triggers_Demo_Part_2.txt', 'usual'), 2),
#  (1, ('12_05_Triggers_Demo_Part_2.txt', 'usual'), 2),
#  (0, ('15_02_Basic_Recursive_WITH_Statement_Demo.txt', 'where'), 2),
#  (1, ('15_02_Basic_Recursive_WITH_Statement_Demo.txt', 'where'), 2),
#  (0, ('17_01_NoSQLMotivation.txt', 'veri'), 2),
#  (1, ('17_01_NoSQLMotivation.txt', 'veri'), 2),
#  (0, ('08_05_XSLT.txt', 'is...whoops,'), 2),
#  (1, ('08_05_XSLT.txt', 'is...whoops,'), 2),
#  (0,
#   ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_1.txt', 'well'),
#   2),
#  (1,
#   ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_1.txt', 'well'),
#   2),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', 'explain'), 2),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', 'explain'), 2),
#  (0, ('13_03_View_Modifications_Using_Triggers.txt', 'abl'), 2),
#  (1, ('13_03_View_Modifications_Using_Triggers.txt', 'abl'), 2),
#  (0, ('06_05_Aggregation.txt', 'subtl'), 2),
#  (1, ('06_05_Aggregation.txt', 'subtl'), 2),
#  (0, ('06_05_Aggregation.txt', 'group'), 1),
#  (1, ('06_05_Aggregation.txt', 'group'), 2),
#  (0, ('06_07_Data_Modification_Statements.txt', 'evalu'), 2),
#  (1, ('06_07_Data_Modification_Statements.txt', 'evalu'), 2),
#  (0, ('05_01_Select_Project_Join_Part_1.txt', 'actual'), 2),
#  (1, ('05_01_Select_Project_Join_Part_1.txt', 'actual'), 2),
#  (0, ('17_01_NoSQLOverview.txt', 'glue,'), 2),
#  (1, ('17_01_NoSQLOverview.txt', 'glue,'), 2),
#  (0, ('17_01_NoSQLMotivation.txt', 'over'), 2),
#  (1, ('17_01_NoSQLMotivation.txt', 'over'), 2),
#  (0, ('13_01_Defining_and_Using_Views.txt', 'oper'), 2),
#  (1, ('13_01_Defining_and_Using_Views.txt', 'oper'), 2),
#  (0, ('07_01_Relational_Design_Overview_Part_3.txt', 'want'), 2),
#  (1, ('07_01_Relational_Design_Overview_Part_3.txt', 'want'), 2),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', 'author'), 2),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', 'author'), 2),
#  (0, ('16_02_OLAP_Demo.txt', 'inform'), 2),
#  (1, ('16_02_OLAP_Demo.txt', 'inform'), 2),
#  (0, ('13_02_View_Modifications_Introduction_Part_2.txt', 'exist'), 2),
#  (1, ('13_02_View_Modifications_Introduction_Part_2.txt', 'exist'), 2),
#  (0, ('06_07_Data_Modification_Statements.txt', 'times,'), 2),
#  (1, ('06_07_Data_Modification_Statements.txt', 'times,'), 2),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_2.txt', "what'"), 2),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_2.txt', "what'"), 2),
#  (0, ('11_02_Transactions_Properties_Part_1.txt', 'on,'), 2),
#  (1, ('11_02_Transactions_Properties_Part_1.txt', 'on,'), 2),
#  (0, ('11_02_Transactions_Properties_Part_3.txt', 'open'), 2),
#  (1, ('11_02_Transactions_Properties_Part_3.txt', 'open'), 2),
#  (0, ('08_05_XSLT.txt', 'demonstr'), 2),
#  (1, ('08_05_XSLT.txt', 'demonstr'), 2),
#  (0, ('15_03_Nonlinear_and_Mutual_Recursion_Part_2.txt', 'r'), 2),
#  (1, ('15_03_Nonlinear_and_Mutual_Recursion_Part_2.txt', 'r'), 2),
#  (0, ('17_01_NoSQLOverview.txt', 'them'), 2),
#  (1, ('17_01_NoSQLOverview.txt', 'them'), 2),
#  (0, ('13_03_View_Modifications_Using_Triggers.txt', 'select'), 2),
#  (1, ('13_03_View_Modifications_Using_Triggers.txt', 'select'), 2),
#  (0, ('11_03_Isolation_Levels_Part_4.txt', 'differ'), 2),
#  (1, ('11_03_Isolation_Levels_Part_4.txt', 'differ'), 2),
#  (0, ('09_02_UML_to_Relations_Part_2.txt', 'how'), 2),
#  (1, ('09_02_UML_to_Relations_Part_2.txt', 'how'), 2),
#  (0, ('07_03_Boyce_Codd_Normal_Form_Part_1.txt', 'notat'), 2),
#  (1, ('07_03_Boyce_Codd_Normal_Form_Part_1.txt', 'notat'), 2),
#  (0, ('13_03_View_Modifications_Using_Triggers.txt', 'took'), 2),
#  (1, ('13_03_View_Modifications_Using_Triggers.txt', 'took'), 2),
#  (0, ('06_04_Subqueries_in_WHERE_Clause.txt', 'by'), 2),
#  (1, ('06_04_Subqueries_in_WHERE_Clause.txt', 'by'), 2),
#  (0, ('06_04_Subqueries_in_FROM_and_SELECT.txt', 'remember,'), 2),
#  (1, ('06_04_Subqueries_in_FROM_and_SELECT.txt', 'remember,'), 2),
#  (0, ('08_01_XPath_Introduction.txt', 'pick'), 2),
#  (1, ('08_01_XPath_Introduction.txt', 'pick'), 2),
#  (0, ('17_01_NoSQLMotivation.txt', 'convert'), 2),
#  (1, ('17_01_NoSQLMotivation.txt', 'convert'), 2),
#  (0, ('03_01_Well_Formed_XML_Part_1.txt', 'import'), 2),
#  (1, ('03_01_Well_Formed_XML_Part_1.txt', 'import'), 2),
#  (0, ('13_02_View_Modifications_Introduction_Part_1.txt', "let'"), 2),
#  (1, ('13_02_View_Modifications_Introduction_Part_1.txt', "let'"), 2),
#  (0, ('12_03_Referential_Integrity_Part_3.txt', "everything'"), 2),
#  (1, ('12_03_Referential_Integrity_Part_3.txt', "everything'"), 2),
#  (0, ('07_01_Relational_Design_Overview_Part_1.txt', 'what'), 2),
#  (1, ('07_01_Relational_Design_Overview_Part_1.txt', 'what'), 2),
#  (0, ('12_02_Constraints_of_Several_Types_Part_1.txt', 'example,'), 2),
#  (1, ('12_02_Constraints_of_Several_Types_Part_1.txt', 'example,'), 2),
#  (0, ('16_02_OLAP_Demo.txt', 'yet,'), 2),
#  (1, ('16_02_OLAP_Demo.txt', 'yet,'), 2),
#  (0, ('12_05_Triggers_Demo_Part_1.txt', 'on,'), 2),
#  (1, ('12_05_Triggers_Demo_Part_1.txt', 'on,'), 2),
#  (0, ('09_02_UML_to_Relations_Part_2.txt', 'do'), 2),
#  (1, ('09_02_UML_to_Relations_Part_2.txt', 'do'), 2),
#  (0, ('06_04_Subqueries_in_WHERE_Clause.txt', 'further'), 2),
#  (1, ('06_04_Subqueries_in_WHERE_Clause.txt', 'further'), 2),
#  (0, ('13_04_Automatic_View_Modifications.txt', 'proper'), 2),
#  (1, ('13_04_Automatic_View_Modifications.txt', 'proper'), 2),
#  (0, ('09_02_UML_to_Relations_Part_2.txt', 'sibl'), 2),
#  (1, ('09_02_UML_to_Relations_Part_2.txt', 'sibl'), 2),
#  (0, ('14_01_Authorization_Part_3.txt', 'relation,'), 2),
#  (1, ('14_01_Authorization_Part_3.txt', 'relation,'), 2),
#  (0, ('05_01_Select_Project_Join_Part_2.txt', 'but'), 2),
#  (1, ('05_01_Select_Project_Join_Part_2.txt', 'but'), 2),
#  (0, ('13_01_Defining_and_Using_Views.txt', 'criteria'), 2),
#  (1, ('13_01_Defining_and_Using_Views.txt', 'criteria'), 2),
#  (0, ('05_01_Select_Project_Join_Part_4.txt', 'mention'), 2),
#  (1, ('05_01_Select_Project_Join_Part_4.txt', 'mention'), 2),
#  (0, ('14_01_Authorization_Part_2.txt', 'by'), 2),
#  (1, ('14_01_Authorization_Part_2.txt', 'by'), 2),
#  (0, ('08_01_XPath_Introduction.txt', 'conjunct'), 2),
#  (1, ('08_01_XPath_Introduction.txt', 'conjunct'), 2),
#  (0, ('15_02_Basic_Recursive_WITH_Statement_Demo.txt', 'seventi'), 2),
#  (1, ('15_02_Basic_Recursive_WITH_Statement_Demo.txt', 'seventi'), 2),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', 'requirements:'), 2),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', 'requirements:'), 2),
#  (0, ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', 'sets,'), 2),
#  (1, ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', 'sets,'), 2),
#  (0, ('06_04_Subqueries_in_FROM_and_SELECT.txt', 'error'), 2),
#  (1, ('06_04_Subqueries_in_FROM_and_SELECT.txt', 'error'), 2),
#  (0, ('06_04_Subqueries_in_FROM_and_SELECT.txt', 'student'), 2),
#  (1, ('06_04_Subqueries_in_FROM_and_SELECT.txt', 'student'), 2),
#  (0, ('13_02_View_Modifications_Introduction_Part_1.txt', "what'"), 2),
#  (1, ('13_02_View_Modifications_Introduction_Part_1.txt', "what'"), 2),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_2.txt', 'standard'), 2),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_2.txt', 'standard'), 2),
#  (0, ('07_01_Relational_Design_Overview_Part_2.txt', 'back'), 2),
#  (1, ('07_01_Relational_Design_Overview_Part_2.txt', 'back'), 2),
#  (0, ('06_01_Introduction_to_SQL.txt', 'ha'), 2),
#  (1, ('06_01_Introduction_to_SQL.txt', 'ha'), 2),
#  (0, ('09_01_UML_Data_Modeling.txt', 'particip'), 2),
#  (1, ('09_01_UML_Data_Modeling.txt', 'particip'), 2),
#  (0, ('16_01_Introduction_to_OLAP_Part_1.txt', 'again,'), 2),
#  (1, ('16_01_Introduction_to_OLAP_Part_1.txt', 'again,'), 2),
#  (0, ('09_02_UML_to_Relations_Part_1.txt', 'into'), 2),
#  (1, ('09_02_UML_to_Relations_Part_1.txt', 'into'), 2),
#  (0, ('13_04_Automatic_View_Modifications.txt', 'actual'), 2),
#  (1, ('13_04_Automatic_View_Modifications.txt', 'actual'), 2),
#  (0, ('06_04_Subqueries_in_WHERE_Clause.txt', 'names,'), 2),
#  (1, ('06_04_Subqueries_in_WHERE_Clause.txt', 'names,'), 2),
#  (0, ('11_02_Transactions_Properties_Part_2.txt', 'have'), 2),
#  (1, ('11_02_Transactions_Properties_Part_2.txt', 'have'), 2),
#  (0, ('03_01_Well_Formed_XML_Part_1.txt', 'would'), 2),
#  (1, ('03_01_Well_Formed_XML_Part_1.txt', 'would'), 2),
#  (0, ('10_01_Indexes_Part_2.txt', 'compon'), 2),
#  (1, ('10_01_Indexes_Part_2.txt', 'compon'), 2),
#  (0, ('05_01_Select_Project_Join_Part_2.txt', 'here,'), 2),
#  (1, ('05_01_Select_Project_Join_Part_2.txt', 'here,'), 2),
#  (0, ('17_01_NoSQLMotivation.txt', 'basic'), 2),
#  (1, ('17_01_NoSQLMotivation.txt', 'basic'), 2),
#  (0, ('07_02_Functional_Dependencies_Part_3.txt', 'question...'), 2),
#  (1, ('07_02_Functional_Dependencies_Part_3.txt', 'question...'), 2),
#  (0, ('15_03_Nonlinear_and_Mutual_Recursion_Part_2.txt', 'goe'), 2),
#  (1, ('15_03_Nonlinear_and_Mutual_Recursion_Part_2.txt', 'goe'), 2),
#  (0, ('13_04_Automatic_View_Modifications.txt', 'automat view modif'), 1),
#  (1, ('13_04_Automatic_View_Modifications.txt', 'automat view modif'), 2),
#  (0, ('09_02_UML_to_Relations_Part_1.txt', "we'd"), 2),
#  (1, ('09_02_UML_to_Relations_Part_1.txt', "we'd"), 2),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_1.txt', 'kinda'), 2),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_1.txt', 'kinda'), 2),
#  (0, ('17_01_NoSQLOverview.txt', 'result,'), 2),
#  (1, ('17_01_NoSQLOverview.txt', 'result,'), 2),
#  (0, ('15_02_Basic_Recursive_WITH_Statement_Demo.txt', 'place'), 2),
#  (1, ('15_02_Basic_Recursive_WITH_Statement_Demo.txt', 'place'), 2),
#  (0, ('08_02_XPath_Demo.txt', 'if'), 2),
#  (1, ('08_02_XPath_Demo.txt', 'if'), 2),
#  (0, ('07_01_Functional_Dependencies_Part_5.txt', 'have'), 2),
#  (1, ('07_01_Functional_Dependencies_Part_5.txt', 'have'), 2),
#  (0, ('06_04_Subqueries_in_WHERE_Clause.txt', 'okay?'), 2),
#  (1, ('06_04_Subqueries_in_WHERE_Clause.txt', 'okay?'), 2),
#  (0, ('12_05_Triggers_Demo_Part_1.txt', 'back,'), 2),
#  (1, ('12_05_Triggers_Demo_Part_1.txt', 'back,'), 2),
#  (0, ('07_03_Boyce_Codd_Normal_Form_Part_1.txt', "we'v"), 2),
#  (1, ('07_03_Boyce_Codd_Normal_Form_Part_1.txt', "we'v"), 2),
#  (0, ('15_01_Basic_Recursive_WITH_Statement_Introduction.txt', 'continu'), 2),
#  (1, ('15_01_Basic_Recursive_WITH_Statement_Introduction.txt', 'continu'), 2),
#  (0, ('12_05_Triggers_Demo_Part_1.txt', 'behavior'), 2),
#  (1, ('12_05_Triggers_Demo_Part_1.txt', 'behavior'), 2),
#  (0, ('13_01_Defining_and_Using_Views.txt', 'can'), 2),
#  (1, ('13_01_Defining_and_Using_Views.txt', 'can'), 2),
#  (0, ('07_02_Functional_Dependencies_Part_1.txt', 'dot'), 2),
#  (1, ('07_02_Functional_Dependencies_Part_1.txt', 'dot'), 2),
#  (0, ('08_04_XQuery_Demo.txt', 'bound'), 2),
#  (1, ('08_04_XQuery_Demo.txt', 'bound'), 2),
#  (0,
#   ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_3.txt', 'hold'),
#   2),
#  (1,
#   ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_3.txt', 'hold'),
#   2),
#  (0, ('01_01_Introduction.txt', "it'"), 2),
#  (1, ('01_01_Introduction.txt', "it'"), 2),
#  (0, ('17_01_NoSQLMotivation.txt', 'avoid'), 2),
#  (1, ('17_01_NoSQLMotivation.txt', 'avoid'), 2),
#  (0, ('16_01_Introduction_to_OLAP_Part_1.txt', 'many,'), 2),
#  (1, ('16_01_Introduction_to_OLAP_Part_1.txt', 'many,'), 2),
#  (0, ('07_02_Functional_Dependencies_Part_1.txt', 'so'), 2),
#  (1, ('07_02_Functional_Dependencies_Part_1.txt', 'so'), 2),
#  (0,
#   ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_1.txt',
#    'attributes,'),
#   2),
#  (1,
#   ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_1.txt',
#    'attributes,'),
#   2),
#  (0, ('07_02_Functional_Dependencies_Part_3.txt', 'seem'), 2),
#  (1, ('07_02_Functional_Dependencies_Part_3.txt', 'seem'), 2),
#  (0, ('16_01_Introduction_to_OLAP_Part_2.txt', 'us'), 2),
#  (1, ('16_01_Introduction_to_OLAP_Part_2.txt', 'us'), 2),
#  (0, ('07_03_Boyce_Codd_Normal_Form_Part_1.txt', 'multi-doubt'), 2),
#  (1, ('07_03_Boyce_Codd_Normal_Form_Part_1.txt', 'multi-doubt'), 2),
#  (0, ('06_05_Aggregation.txt', 'aggreg function'), 2),
#  (1, ('06_05_Aggregation.txt', 'aggreg function'), 2),
#  (0, ('06_03_Table_Variables_and_Set_Operators.txt', 'colleg'), 2),
#  (1, ('06_03_Table_Variables_and_Set_Operators.txt', 'colleg'), 2),
#  (0, ('08_04_XQuery_Demo.txt', 'for claus'), 2),
#  (1, ('08_04_XQuery_Demo.txt', 'for claus'), 1),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', 'actually,'), 2),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', 'actually,'), 2),
#  (0, ('12_04_Triggers_Introduction.txt', 'through'), 2),
#  (1, ('12_04_Triggers_Introduction.txt', 'through'), 2),
#  (0, ('06_06_NULL_Values.txt', 'so,'), 2),
#  (1, ('06_06_NULL_Values.txt', 'so,'), 2),
#  (0, ('03_02_XML_Schema.txt', 'all'), 2),
#  (1, ('03_02_XML_Schema.txt', 'all'), 2),
#  (0, ('06_01_Introduction_to_SQL.txt', 'start'), 2),
#  (1, ('06_01_Introduction_to_SQL.txt', 'start'), 2),
#  (0, ('06_05_Aggregation.txt', 'attribut'), 2),
#  (1, ('06_05_Aggregation.txt', 'attribut'), 2),
#  (0, ('08_01_XPath_Introduction.txt', 'is'), 2),
#  (1, ('08_01_XPath_Introduction.txt', 'is'), 2),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', 'instead'), 2),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', 'instead'), 2),
#  (0, ('08_02_XPath_Demo.txt', 'wild'), 2),
#  (1, ('08_02_XPath_Demo.txt', 'wild'), 2),
#  (0, ('12_05_Triggers_Demo_Part_2.txt', 'likewis'), 2),
#  (1, ('12_05_Triggers_Demo_Part_2.txt', 'likewis'), 2),
#  (0, ('04_02_JSON_Demo.txt', 'on'), 2),
#  (1, ('04_02_JSON_Demo.txt', 'on'), 2),
#  (0, ('16_02_OLAP_Demo.txt', "i'v"), 2),
#  (1, ('16_02_OLAP_Demo.txt', "i'v"), 2),
#  (0, ('03_01_Well_Formed_XML_Part_2.txt', 'mention,'), 2),
#  (1, ('03_01_Well_Formed_XML_Part_2.txt', 'mention,'), 2),
#  (0, ('12_02_Constraints_of_Several_Types_Part_1.txt', 'ad'), 2),
#  (1, ('12_02_Constraints_of_Several_Types_Part_1.txt', 'ad'), 2),
#  (0, ('16_02_OLAP_Demo.txt', 'inde'), 2),
#  (1, ('16_02_OLAP_Demo.txt', 'inde'), 2),
#  (0, ('07_02_Functional_Dependencies_Part_1.txt', 'throughout'), 2),
#  (1, ('07_02_Functional_Dependencies_Part_1.txt', 'throughout'), 2),
#  (0, ('12_01_Motivation_and_Overview.txt', '7000'), 2),
#  (1, ('12_01_Motivation_and_Overview.txt', '7000'), 2),
#  (0, ('08_04_XQuery_Demo.txt', 'littl'), 2),
#  (1, ('08_04_XQuery_Demo.txt', 'littl'), 2),
#  (0, ('15_03_Nonlinear_and_Mutual_Recursion_Part_2.txt', 'r2'), 2),
#  (1, ('15_03_Nonlinear_and_Mutual_Recursion_Part_2.txt', 'r2'), 2),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', 'parser'), 2),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', 'parser'), 2),
#  (0, ('06_02_Basic_SELECT_Statement.txt', 'associ'), 2),
#  (1, ('06_02_Basic_SELECT_Statement.txt', 'associ'), 2),
#  (0, ('12_03_Referential_Integrity_Part_3.txt', 'c,'), 2),
#  (1, ('12_03_Referential_Integrity_Part_3.txt', 'c,'), 2),
#  (0, ('08_03_XQuery_Introduction.txt', "we'll"), 2),
#  (1, ('08_03_XQuery_Introduction.txt', "we'll"), 2),
#  (0, ('06_02_Basic_SELECT_Statement.txt', 'duplic'), 2),
#  (1, ('06_02_Basic_SELECT_Statement.txt', 'duplic'), 2),
#  (0, ('13_01_Defining_and_Using_Views.txt', 'to'), 2),
#  (1, ('13_01_Defining_and_Using_Views.txt', 'to'), 2),
#  (0, ('15_03_Nonlinear_and_Mutual_Recursion_Part_2.txt', 'p.'), 2),
#  (1, ('15_03_Nonlinear_and_Mutual_Recursion_Part_2.txt', 'p.'), 2),
#  (0, ('04_02_JSON_Demo.txt', 'object'), 1),
#  (1, ('04_02_JSON_Demo.txt', 'object'), 1),
#  (0, ('08_02_XPath_Demo.txt', 'after'), 2),
#  (1, ('08_02_XPath_Demo.txt', 'after'), 2),
#  (0, ('12_05_Triggers_Demo_Part_1.txt', 'text-transform:'), 2),
#  (1, ('12_05_Triggers_Demo_Part_1.txt', 'text-transform:'), 2),
#  (0, ('15_02_Basic_Recursive_WITH_Statement_Demo.txt', 'fact,'), 2),
#  (1, ('15_02_Basic_Recursive_WITH_Statement_Demo.txt', 'fact,'), 2),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', 'kleen'), 1),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', 'kleen'), 2),
#  (0, ('03_01_Well_Formed_XML_Part_1.txt', 'numer'), 2),
#  (1, ('03_01_Well_Formed_XML_Part_1.txt', 'numer'), 2),
#  (0, ('08_03_XQuery_Introduction.txt', 'subsequ'), 2),
#  (1, ('08_03_XQuery_Introduction.txt', 'subsequ'), 2),
#  (0, ('13_04_Automatic_View_Modifications.txt', 'ani'), 2),
#  (1, ('13_04_Automatic_View_Modifications.txt', 'ani'), 2),
#  (0, ('11_02_Transactions_Properties_Part_3.txt', 'end'), 2),
#  (1, ('11_02_Transactions_Properties_Part_3.txt', 'end'), 2),
#  (0, ('06_04_Subqueries_in_WHERE_Clause.txt', 'typic'), 2),
#  (1, ('06_04_Subqueries_in_WHERE_Clause.txt', 'typic'), 2),
#  (0, ('12_02_Constraints_of_Several_Types_Part_2.txt', 'is'), 2),
#  (1, ('12_02_Constraints_of_Several_Types_Part_2.txt', 'is'), 2),
#  (0, ('16_01_Introduction_to_OLAP_Part_1.txt', 'quit'), 2),
#  (1, ('16_01_Introduction_to_OLAP_Part_1.txt', 'quit'), 2),
#  (0, ('12_02_Constraints_of_Several_Types_Part_1.txt', 'suppos'), 2),
#  (1, ('12_02_Constraints_of_Several_Types_Part_1.txt', 'suppos'), 2),
#  (0, ('04_02_JSON_Demo.txt', 'between'), 2),
#  (1, ('04_02_JSON_Demo.txt', 'between'), 2),
#  (0, ('13_01_Defining_and_Using_Views.txt', 'forward'), 2),
#  (1, ('13_01_Defining_and_Using_Views.txt', 'forward'), 2),
#  (0, ('12_02_Constraints_of_Several_Types_Part_1.txt', 'unique,'), 2),
#  (1, ('12_02_Constraints_of_Several_Types_Part_1.txt', 'unique,'), 2),
#  (0, ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', 'finally,'), 2),
#  (1, ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', 'finally,'), 2),
#  (0, ('03_01_Well_Formed_XML_Part_2.txt', 'way'), 2),
#  (1, ('03_01_Well_Formed_XML_Part_2.txt', 'way'), 2),
#  (0, ('15_01_Basic_Recursive_WITH_Statement_Introduction.txt', 'r1-rn'), 2),
#  (1, ('15_01_Basic_Recursive_WITH_Statement_Introduction.txt', 'r1-rn'), 2),
#  (0, ('06_04_Subqueries_in_FROM_and_SELECT.txt', 'rest'), 2),
#  (1, ('06_04_Subqueries_in_FROM_and_SELECT.txt', 'rest'), 2),
#  (0, ('03_01_Well_Formed_XML_Part_2.txt', 'string'), 2),
#  (1, ('03_01_Well_Formed_XML_Part_2.txt', 'string'), 2),
#  (0, ('08_02_XPath_Demo.txt', 'molina'), 2),
#  (1, ('08_02_XPath_Demo.txt', 'molina'), 2),
#  (0, ('14_01_Authorization_Part_1.txt', 'command'), 2),
#  (1, ('14_01_Authorization_Part_1.txt', 'command'), 2),
#  (0, ('13_03_View_Modifications_Using_Triggers.txt', "aren't"), 2),
#  (1, ('13_03_View_Modifications_Using_Triggers.txt', "aren't"), 2),
#  (0, ('12_05_Triggers_Demo_Part_1.txt', 'alreadi'), 2),
#  (1, ('12_05_Triggers_Demo_Part_1.txt', 'alreadi'), 2),
#  (0, ('06_05_Aggregation.txt', 'group by'), 2),
#  (1, ('06_05_Aggregation.txt', 'group by'), 1),
#  (0, ('08_04_XQuery_Demo.txt', 'ion,'), 2),
#  (1, ('08_04_XQuery_Demo.txt', 'ion,'), 2),
#  (0, ('13_02_View_Modifications_Introduction_Part_2.txt', 'one'), 2),
#  (1, ('13_02_View_Modifications_Introduction_Part_2.txt', 'one'), 2),
#  (0, ('06_05_Aggregation.txt', 'long'), 2),
#  (1, ('06_05_Aggregation.txt', 'long'), 2),
#  (0, ('11_02_Transactions_Properties_Part_1.txt', 'transact'), 1),
#  (1, ('11_02_Transactions_Properties_Part_1.txt', 'transact'), 1),
#  (0,
#   ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_1.txt', '-valu'),
#   2),
#  (1,
#   ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_1.txt', '-valu'),
#   2),
#  (0, ('06_05_Aggregation.txt', 'count function'), 1),
#  (1, ('06_05_Aggregation.txt', 'count function'), 2),
#  (0, ('08_05_XSLT.txt', 'look'), 2),
#  (1, ('08_05_XSLT.txt', 'look'), 2),
#  (0, ('08_05_XSLT.txt', 'behavior'), 2),
#  (1, ('08_05_XSLT.txt', 'behavior'), 2),
#  ...]
