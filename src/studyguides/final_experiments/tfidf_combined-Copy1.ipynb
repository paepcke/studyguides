# %%
import os
import nltk

import numpy as np

from collections import OrderedDict, defaultdict, Counter
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# %%
documents = OrderedDict()

for name in os.listdir('../../../data/Introduction_to_Databases_Captions'):
    with open('../../../data/Introduction_to_Databases_Captions/' + name) as f:
        lines = []
        for line in f:
            lines.append(line.strip('| \n'))
        documents[name] = ' '.join(lines)
        
keywords = defaultdict(set)
stemmer = nltk.stem.PorterStemmer()

for name in os.listdir('../../../data/keywords/'):
    with open('../../../data/keywords/' + name) as f:
        for line in f:
            lecture_name, key, _, rank = line.strip().split(',')
            rank = int(rank)
            key = key.replace('-', ' ')
            key = ' '.join(stemmer.stem(token) for token in nltk.word_tokenize(key))
            key = key.lower()
            keywords[lecture_name].add(key)

# %%
stopwords = []
with open('../../../data/smart.txt') as f:
    for line in f:
        line = line.strip()
        tokens = nltk.word_tokenize(line)
        stopwords.append(' '.join([stemmer.stem(token) for token in tokens]))
        
external_tfidfs = Counter()
with open('tfidf_log.out') as f:
    for line in f:
        word, tfidf = line.strip().split(':')
        tokens = nltk.word_tokenize(word)
        stemmed_tokens = [stemmer.stem(token) for token in tokens]
        if stemmed_tokens[0] in stopwords or stemmed_tokens[-1] in stopwords: continue
        if len(tokens) < 2: continue
        if len(word) < 4: continue
        stemmed = ' '.join(stemmed_tokens)
        external_tfidfs[stemmed] += float(tfidf)

sorted(external_tfidfs.items(), key=lambda (k, v): (v, k), reverse=True)
# Out:
# [(u'multi valu depend', 1083615.0372300001),
#  (u'insert command', 707193.69361),
#  (u'multivalu depend', 689619.0859930001),
#  (u'project oper', 590944.77306),
#  (u'tupl base constraint', 541807.5186150001),
#  (u'modif command', 541807.5186150001),
#  (u'book sub element', 541807.5186150001),
#  (u'author element', 541807.5186150001),
#  (u'transit rule', 534199.35301),
#  (u'intersect oper', 522150.877535),
#  (u'relat algebra express', 514545.96228800004),
#  (u'isol level', 490936.59172300005),
#  (u'function depend', 473030.468914),
#  (u'cs applic', 465570.303777),
#  (u'close tag', 465103.240337),
#  (u'aggreg function', 463055.75694500003),
#  (u'student id', 456515.445573),
#  (u'special attribut', 450994.003364),
#  (u'express languag', 435175.875601),
#  (u'databas design', 423099.10559700005),
#  (u'xslt specif', 361205.01241),
#  (u'xml schema descriptor', 361205.01241),
#  (u'student tupl', 361205.01241),
#  (u'standford student', 361205.01241),
#  (u'sql video', 361205.01241),
#  (u'specif tupl', 361205.01241),
#  (u'select privileg', 361205.01241),
#  (u'select express', 361205.01241),
#  (u'relat s1', 361205.01241),
#  (u'relat algebra video', 361205.01241),
#  (u'referenti integr violat', 361205.01241),
#  (u'queri n time', 361205.01241),
#  (u'post risk', 361205.01241),
#  (u'physic design advisor', 361205.01241),
#  (u'natur function depend', 361205.01241),
#  (u'modif statement', 361205.01241),
#  (u'mega relat', 361205.01241),
#  (u'label valu pair', 361205.01241),
#  (u'key valu store', 361205.01241),
#  (u'json queri languag', 361205.01241),
#  (u'json editor', 361205.01241),
#  (u'item dimens tabl', 361205.01241),
#  (u'id ref attribut', 361205.01241),
#  (u'graph databas system', 361205.01241),
#  (u'grant diagram', 361205.01241),
#  (u'good schema', 361205.01241),
#  (u'good decomposit', 361205.01241),
#  (u'document type descriptor', 361205.01241),
#  (u'distinct student id', 361205.01241),
#  (u'distinct gpa', 361205.01241),
#  (u'decis column', 361205.01241),
#  (u'constraint video', 361205.01241),
#  (u'boyc codd', 361205.01241),
#  (u'bigger relat', 361205.01241),
#  (u'base check constraint', 361205.01241),
#  (u'balanc tree index', 361205.01241),
#  (u'automat view modif', 361205.01241),
#  (u'author sub element', 361205.01241),
#  (u'auth element', 361205.01241),
#  (u'appli tupl', 361205.01241),
#  (u'appli tabl', 361205.01241),
#  (u'ancestor tupl', 361205.01241),
#  (u'view queri', 353603.227696),
#  (u'xml schema descript', 353596.846805),
#  (u'tabl t3', 353596.846805),
#  (u'tabl r1', 353596.846805),
#  (u'result sql', 353596.846805),
#  (u'previou trigger', 353596.846805),
#  (u'outermost construct', 353596.846805),
#  (u'item tabl', 353596.846805),
#  (u'extens style sheet languag', 353596.846805),
#  (u'exact same result', 353596.846805),
#  (u'high school', 351857.922233),
#  (u'trigger chain', 349150.320447),
#  (u'maximum gpa', 349150.320447),
#  (u'low level trigger', 349150.320447),
#  (u'ancestor relationship', 349150.320447),
#  (u'ambigu error', 349150.320447),
#  (u'statement level trigger', 346014.009266),
#  (u'key violat', 346010.497608),
#  (u'row level trigger', 346005.970295),
#  (u'high school size', 345998.14804600005),
#  (u'relat algebra queri', 345995.062091),
#  (u'nontrivi function depend', 345988.6812),
#  (u'hub relat', 345988.6812),
#  (u'author node', 345988.6812),
#  (u'complic queri', 343555.16319500003),
#  (u'map box', 341572.596727),
#  (u'unbound comput', 341548.37133),
#  (u'xpath queri', 341542.154842),
#  (u'higher level model', 341542.154842),
#  (u'constraint system', 339875.807181),
#  (u'complet relationship', 338417.42207),
#  (u'outermost element', 338389.982441),
#  (u'lesser privileg', 337132.045112),
#  (u'transact t1', 337101.844972),
#  (u'magazin element', 337095.628484),
#  (u'appli relat', 335953.006957),
#  (u'writer function', 335946.99759),
#  (u'arbitrari depth', 333997.247276),
#  (u'updat view', 333955.772414),
#  (u'select claus', 333952.560239),
#  (u'constraint violat', 333949.555926),
#  (u'tradit relat databas manag system', 333943.456083),
#  (u'small relat', 333943.456083),
#  (u'key valu pair', 333943.456083),
#  (u'depend attribut', 333943.456083),
#  (u'uml design', 331521.01739199995),
#  (u'manag relationship', 331500.471232),
#  (u'hub node', 330807.811276),
#  (u'store id', 330221.675787),
#  (u'colleg tabl', 329519.784889),
#  (u'split rule', 329506.033881),
#  (u'tradit relat databas system', 328360.408041),
#  (u'mutual recurs', 327980.972896),
#  (u'xml stream', 327826.988157),
#  (u'open tag', 327444.076575),
#  (u'previou queri', 326362.730107),
#  (u'meaning translat', 326362.730107),
#  (u'tradit databas system', 326353.86147999996),
#  (u'nosql solut', 326353.86147999996),
#  (u'item id', 324889.190176),
#  (u'author relat', 324712.600862),
#  (u'major combin', 323954.02618499997),
#  (u'dimens attribut', 323944.912949),
#  (u'relat design', 323940.383552),
#  (u'student gpa', 323210.557706),
#  (u'select condit', 322259.626004),
#  (u'student coupl', 322231.830905),
#  (u'price attribut', 320767.572855),
#  (u'book pair', 320767.572855),
#  (u'automat applic', 320292.75968300004),
#  (u'ab pair', 319557.873581),
#  (u'high gpa', 319339.621544),
#  (u'equal condit', 318778.9543),
#  (u'applic record', 318773.135504),
#  (u'xml queri', 318177.280877),
#  (u'parent child relationship', 315476.569093),
#  (u'trigger condit', 314688.584633),
#  (u'recurs queri', 314671.399675),
#  (u'combin function', 313663.249435),
#  (u'referenti integr constraint', 313615.407969),
#  (u'star schema', 313343.391234),
#  (u'friend relationship', 313169.840879),
#  (u'input record', 312710.203479),
#  (u'select oper', 312598.66843900003),
#  (u'mapreduc job', 312192.112956),
#  (u'highest gpa', 310419.660798),
#  (u'relat schema', 310365.848941),
#  (u'privileg system', 310338.82796799997),
#  (u'specif specif', 309924.279978),
#  (u'check constraint', 309800.81766199996),
#  (u'gener assert', 309533.176127),
#  (u'complex queri', 308951.760817),
#  (u'book element', 307917.24135200004),
#  (u'nosql system', 307785.172108),
#  (u'custom id', 307256.119344),
#  (u'virtual view', 306874.28403800004),
#  (u'super class', 305794.015473),
#  (u'persist data structur', 305716.64506400004),
#  (u'foreign key constraint', 304389.81539),
#  (u'built in function', 304376.022359),
#  (u'altern notat', 304170.978017),
#  (u'output record', 303665.979695),
#  (u'simpl queri', 303338.685295),
#  (u'set oper', 302446.418823),
#  (u'xpath express', 301577.21275199996),
#  (u'larg number', 301310.869325),
#  (u'share attribut', 301248.095821),
#  (u'regular tabl', 301109.287461),
#  (u'map function', 300957.095398),
#  (u'joint condit', 300136.109326),
#  (u'automat translat', 299976.941535),
#  (u'path express', 298923.826292),
#  (u'select statement', 298254.99650799995),
#  (u'formal foundat', 298218.95999799995),
#  (u'fact tabl', 297891.45854),
#  (u'massiv databas', 297853.65766200004),
#  (u'express tree', 297815.68527799996),
#  (u'specif queri', 297624.770106),
#  (u'singl attribut', 297480.974221),
#  (u'dimens tabl', 296645.05342300003),
#  (u'relat system', 294824.952667),
#  (u'sql system', 294394.849055),
#  (u'user queri', 293557.950657),
#  (u'separ relat', 293159.826202),
#  (u'graph databas', 292512.086078),
#  (u'transit closur', 292447.69062500005),
#  (u'key constraint', 291521.270664),
#  (u'specif major', 291208.19047599996),
#  (u'sql standard', 290705.704379),
#  (u'queri optim', 289793.60753200005),
#  (u'psycholog major', 289495.672562),
#  (u'integr constraint', 289488.68856499996),
#  (u'total salari', 289417.86455199996),
#  (u'tabl variabl', 289387.34470899997),
#  (u'biolog major', 289165.53193399997),
#  (u'trigger action', 288390.450448),
#  (u'independ fact', 288232.338009),
#  (u'econom major', 287983.496725),
#  (u'refer relat', 287846.88670699997),
#  (u'total price', 286725.84423),
#  (u'id attribut', 285311.806553),
#  (u'open sourc system', 285040.897762),
#  (u'nice featur', 284160.140029),
#  (u'colleg enrol', 281714.465855),
#  (u'isbn number', 280589.790812),
#  (u'web log', 280219.112372),
#  (u'earlier video', 279651.504233),
#  (u'addit attribut', 278600.014454),
#  (u'larg high school', 277860.922607),
#  (u'nation geograph', 276397.989566),
#  (u'relat databas system', 275905.293514),
#  (u'sibl relationship', 275859.78102),
#  (u'uniqu code', 275657.645234),
#  (u'id ref', 275459.478199),
#  (u'small high school', 275435.396696),
#  (u'exam question', 274816.356884),
#  (u'databas schema', 274351.872976),
#  (u'reserv word', 274043.053254),
#  (u'subsequ video', 272941.27371700003),
#  (u'colleg applic', 272319.792032),
#  (u'primari key', 271867.527786),
#  (u'queri result', 271847.174403),
#  (u'foreign key', 271773.687248),
#  (u'live demo', 271641.400921),
#  (u'good design', 271202.172112),
#  (u'logic express', 271191.148071),
#  (u'venn diagram', 270914.77500100003),
#  (u'databas administr', 270090.883247),
#  (u'specif attribut', 269973.448531),
#  (u'ap student', 269578.04851999995),
#  (u'sql queri', 268647.380296),
#  (u'system crash', 268623.439302),
#  (u'effici implement', 268102.26472800004),
#  (u'berkeley student', 268086.39518700005),
#  (u'domest student', 267588.682472),
#  (u'arbitrari number', 262334.813524),
#  (u'california colleg', 262245.066323),
#  (u'sql statement', 261818.816726),
#  (u'cartesian product', 259520.28597199998),
#  (u'left hand side', 259262.29313499999),
#  (u'direct edg', 257416.967626),
#  (u'xml schema', 257286.642682),
#  (u'databas applic', 256817.820664),
#  (u'addit constraint', 256647.79279099999),
#  (u'cross product', 256150.812183),
#  (u'base tabl', 255905.46203300002),
#  (u'ee applic', 255011.81958100002),
#  (u'queri languag', 254820.683761),
#  (u'student relat', 254443.48686),
#  (u'addit condit', 253935.15503199998),
#  (u'decis support system', 251426.830042),
#  (u'structur data', 250710.615241),
#  (u'system failur', 249667.297002),
#  (u'previou video', 249442.280322),
#  (u'larg databas', 249165.703538),
#  (u'data item', 248387.717947),
#  (u'xml document', 247280.651815),
#  (u'style sheet', 246404.307565),
#  (u'magazin titl', 245352.633478),
#  (u'data model', 245297.75504299998),
#  (u'basic oper', 244889.069195),
#  (u'basic structur', 244319.948232),
#  (u'act score', 242221.571283),
#  (u'tradit system', 241440.145802),
#  (u'social secur number', 241365.233799),
#  (u'regular express', 240520.83715500002),
#  (u'applic develop', 239593.538003),
#  (u'interest thing', 239006.071653),
#  (u'databas manag system', 238056.34079599997),
#  (u'key word', 236944.127865),
#  (u'import concept', 236545.60861400003),
#  (u'bank system', 236543.540662),
#  (u'regular class', 236383.88686),
#  (u'squar bracket', 236070.778134),
#  (u'joint oper', 236053.740238),
#  (u'program languag', 235371.526974),
#  (u'databas system', 234590.419119),
#  (u'colleg class', 234154.498322),
#  (u'relat databas', 233499.44851000002),
#  (u'ap class', 233072.071944),
#  (u'special type', 232681.371368),
#  (u'file system', 230367.58205199998),
#  (u'page view', 230309.36548600002),
#  (u'book titl', 227937.294501),
#  (u'direct flight', 226827.572711),
#  (u'great thing', 226049.071532),
#  (u'import thing', 225300.48072300002),
#  (u'larg portion', 224906.112938),
#  (u'data structur', 224615.240879),
#  (u'import aspect', 221534.112906),
#  (u'foreign student', 221355.97668700002),
#  (u'specif type', 221288.697857),
#  (u'xsd line', 180602.506205),
#  (u'xsd languag', 180602.506205),
#  (u'xml schema specif', 180602.506205),
#  (u'xml queri result insid', 180602.506205),
#  (u'xml look result', 180602.506205),
#  (u'xml link featur', 180602.506205),
#  (u'xml documentthey', 180602.506205),
#  (u'wrong trigger', 180602.506205),
#  (u'width cube', 180602.506205),
#  (u'weird queri', 180602.506205),
#  (u'weblog applic', 180602.506205),
#  (u'webkit transit time function', 180602.506205),
#  (u'webkit transit properti', 180602.506205),
#  (u'webkit transit durat', 180602.506205),
#  (u'webkit transit delay', 180602.506205),
#  (u'webkit box shadow', 180602.506205),
#  (u'web access record', 180602.506205),
#  (u'weakest guarante', 180602.506205),
#  (u'weaker isol level', 180602.506205),
#  (u'weaker consist guarante', 180602.506205),
#  (u'washington jacket', 180602.506205),
#  (u'view tupl', 180602.506205),
#  (u'view non uniqu', 180602.506205),
#  (u'view modif command', 180602.506205),
#  (u'view cs burk', 180602.506205),
#  (u'view cs berk', 180602.506205),
#  (u'view cs accept', 180602.506205),
#  (u'view creator', 180602.506205),
#  (u'venn diagram format', 180602.506205),
#  (u'variabl key list', 180602.506205),
#  (u'variabl concurr', 180602.506205),
#  (u'variabl claus', 180602.506205),
#  (u'variabl b2', 180602.506205),
#  (u'variabl b1', 180602.506205),
#  (u'valid command', 180602.506205),
#  (u'valid button', 180602.506205),
#  (u'user u2', 180602.506205),
#  (u'user u1', 180602.506205),
#  (u'user queri queue', 180602.506205),
#  (u'user privileg', 180602.506205),
#  (u'upper left window', 180602.506205),
#  (u'unreli student', 180602.506205),
#  (u'unord model', 180602.506205),
#  (u'uniqu student id', 180602.506205),
#  (u'uniqu key constraint', 180602.506205),
#  (u'uniqu enrol', 180602.506205),
#  (u'uniform key valu pair', 180602.506205),
#  (u'understand algebra', 180602.506205),
#  (u'underli modif', 180602.506205),
#  (u'uncondit action rule', 180602.506205),
#  (u'uncommit gpa modif', 180602.506205),
#  (u'unaccept hobbi', 180602.506205),
#  (u'umo model', 180602.506205),
#  (u'uml model video', 180602.506205),
#  (u'uml languag', 180602.506205),
#  (u'uml data model subset', 180602.506205),
#  (u'ullman jefferi', 180602.506205),
#  (u'typic middl ware', 180602.506205),
#  (u'typic comput system', 180602.506205),
#  (u'type sql queri', 180602.506205),
#  (u'twenti five tupl', 180602.506205),
#  (u'tuppl refer', 180602.506205),
#  (u'tuppl insert', 180602.506205),
#  (u'tupl t2', 180602.506205),
#  (u'tupl t1', 180602.506205),
#  (u'tupl level insert', 180602.506205),
#  (u'tupl gener depend', 180602.506205),
#  (u'tupl base check constraint', 180602.506205),
#  (u'trivial sql queri', 180602.506205),
#  (u'trivial multivalu depend', 180602.506205),
#  (u'trivial multi valu depend', 180602.506205),
#  (u'trivial depend rule', 180602.506205),
#  (u'trivial depend', 180602.506205),
#  (u'tripl null', 180602.506205),
#  (u'trigger writer', 180602.506205),
#  (u'trigger t3', 180602.506205),
#  (u'trigger r3', 180602.506205),
#  (u'trigger r2', 180602.506205),
#  (u'trigger r1', 180602.506205),
#  (u'trigger process stop', 180602.506205),
#  (u'trigger process session', 180602.506205),
#  (u'trigger monitor', 180602.506205),
#  (u'trigger execut', 180602.506205),
#  (u'trickier issu', 180602.506205),
#  (u'transit closur flavor', 180602.506205),
#  (u'transit case', 180602.506205),
#  (u'transact t9', 180602.506205),
#  (u'transact roll back', 180602.506205),
#  (u'transact guarente', 180602.506205),
#  (u'transact guarante', 180602.506205),
#  (u'tradit templat match style', 180602.506205),
#  (u'tradit relat data base manag system', 180602.506205),
#  (u'tradit databas queri process', 180602.506205),
#  (u'toy databas', 180602.506205),
#  (u'toy applic code', 180602.506205),
#  (u'total total sale', 180602.506205),
#  (u'total sub cost', 180602.506205),
#  (u'total salari class', 180602.506205),
#  (u'titl subel', 180602.506205),
#  (u'titl sub element', 180602.506205),
#  (u'time tupl', 180602.506205),
#  (u'thaql standard', 180602.506205),
#  (u'text leaf', 180602.506205),
#  (u'terribl type', 180602.506205),
#  (u'terminolog pk', 180602.506205),
#  (u'term mapreduc', 180602.506205),
#  (u'templat match rule', 180602.506205),
#  (u'tag html', 180602.506205),
#  (u'tabl v now queri', 180602.506205),
#  (u'tabl t assert', 180602.506205),
#  (u'tabl t 1', 180602.506205),
#  (u'tabl relat', 180602.506205),
#  (u'tabl level variabl', 180602.506205),
#  (u'system failur problem', 180602.506205),
#  (u'system failur manag', 180602.506205),
#  (u'system couch db', 180602.506205),
#  (u'system concurr', 180602.506205),
#  (u'syntact necess', 180602.506205),
#  (u'symant error', 180602.506205),
#  (u'support view modif', 180602.506205),
#  (u'super larg colleg', 180602.506205),
#  (u'super class key', 180602.506205),
#  (u'subset a bar', 180602.506205),
#  (u'subscript theta', 180602.506205),
#  (u'subqueri return', 180602.506205),
#  (u'subel structur', 180602.506205),
#  (u'subclass relationship', 180602.506205),
#  (u'student name bob', 180602.506205),
#  (u'student id tabl', 180602.506205),
#  (u'student id match', 180602.506205),
#  (u'student id colleg name combin', 180602.506205),
#  (u'student id attribut', 180602.506205),
#  (u'student dot sid', 180602.506205),
#  (u'structur tabl format', 180602.506205),
#  (u'string march', 180602.506205),
#  (u'string leaf', 180602.506205),
#  (u'straightforward mistak', 180602.506205),
#  (u'straight forward translat', 180602.506205),
#  (u'straight forward topic', 180602.506205),
#  (u'store s3', 180602.506205),
#  (u'store domain', 180602.506205),
#  (u'store dimens tabl', 180602.506205),
#  (u'statement level insert', 180602.506205),
#  (u'statement level equival', 180602.506205),
#  (u'state/gend combin', 180602.506205),
#  (u'start tabl', 180602.506205),
#  (u'stanfordedu domain', 180602.506205),
#  (u'stanford view', 180602.506205),
#  (u'stanford standford', 180602.506205),
#  (u'stanford berkeley', 180602.506205),
#  (u'stanford applic', 180602.506205),
#  (u'standard simpl colleg admiss databas', 180602.506205),
#  (u'standard set union', 180602.506205),
#  (u'standard construct', 180602.506205),
#  (u'standard colleg admiss sampl databas', 180602.506205),
#  (u'squar bracket a1', 180602.506205),
#  (u'sqlite trigger', 180602.506205),
#  (u'sqlite system', 180602.506205),
#  (u'sqlite session', 180602.506205),
#  (u'sql3 standard', 180602.506205),
#  (u'sql2 standard', 180602.506205),
#  (u'sql wear condit', 180602.506205),
#  (u'sql standard semant', 180602.506205),
#  (u'sql recurs', 180602.506205),
#  (u'sql queri processor', 180602.506205),
#  (u'sql like solut', 180602.506205),
#  (u'sql like queri', 180602.506205),
#  (u'sql like predic', 180602.506205),
#  (u'sql like languag', 180602.506205),
#  (u'sql light', 180602.506205),
#  (u'sql inject error', 180602.506205),
#  (u'sql exercis', 180602.506205),
#  (u'sql demo', 180602.506205),
#  (u'sql context', 180602.506205),
#  (u'specif nosql solut', 180602.506205),
#  (u'specif locat', 180602.506205),
#  (u'specif formal notion', 180602.506205),
#  (u'specif costum', 180602.506205),
#  (u'specif attributesonli', 180602.506205),
#  (u'special queri process techniqu', 180602.506205),
#  (u'special name public', 180602.506205),
#  (u'special multipl', 180602.506205),
#  (u'special index techniqu', 180602.506205),
#  (u'special index structur', 180602.506205),
#  (u'special element symbol', 180602.506205),
#  (u'social secur number pair', 180602.506205),
#  (u'social secur number multi', 180602.506205),
#  (u'smiley photo', 180602.506205),
#  (u'smart databas system', 180602.506205),
#  (u'small strang thing', 180602.506205),
#  (u'small littl trick', 180602.506205),
#  (u'small downsid', 180602.506205),
#  (u'slice relat', 180602.506205),
#  (u'sixth import', 180602.506205),
#  (u'singular id ref', 180602.506205),
#  (u'singl step queri', 180602.506205),
#  (u'singl map function', 180602.506205),
#  (u'singl intricaci', 180602.506205),
#  (u'singl element name ms widom', 180602.506205),
#  (u'singl bookstor', 180602.506205),
#  (u'simul integr constraint', 180602.506205),
#  (u'simpler trigger', 180602.506205),
#  (u'simpler queri', 180602.506205),
#  (u'simpl templat match', 180602.506205),
#  (u'simpl tabl level oper', 180602.506205),
#  (u'simpl syntact correct', 180602.506205),
#  (u'simpl path express', 180602.506205),
#  (u'simpl exampl databas', 180602.506205),
#  (u'simpl delet command', 180602.506205),
#  (u'simpl colleg admiss relat databas', 180602.506205),
#  (u'simpl colleg admiss databas', 180602.506205),
#  (u'simpl ancestor comput', 180602.506205),
#  (u'similar parallel joke', 180602.506205),
#  (u'sid attribut', 180602.506205),
#  (u'shop cart addit', 180602.506205),
#  (u'serializ behavior', 180602.506205),
#  (u'sequenti serial orderof', 180602.506205),
#  (u'sequel languag', 180602.506205),
#  (u'sequal system', 180602.506205),
#  (u'separ tupl', 180602.506205),
#  (u'separ privileg privileg', 180602.506205),
#  (u'separ label valu pair', 180602.506205),
#  (u'separ associ class', 180602.506205),
#  (u'select student id', 180602.506205),
#  (u'select star version', 180602.506205),
#  (u'select row', 180602.506205),
#  (u'select predic', 180602.506205),
#  (u'select gpa', 180602.506205),
#  (u'schema like specif', 180602.506205),
#  (u'schema like element', 180602.506205),
#  (u'schema [ sp', 180602.506205),
#  (u'satellit home campu', 180602.506205),
#  (u'sampl demonstr databas', 180602.506205),
#  (u'sale transact action', 180602.506205),
#  (u'sale domain', 180602.506205),
#  (u'sale databas store', 180602.506205),
#  (u'salari burden', 180602.506205),
#  (u'safeti multi user', 180602.506205),
#  (u'safe multi user storag', 180602.506205),
#  (u'runtim execut error', 180602.506205),
#  (u'rule base languag', 180602.506205),
#  (u'row row level trigger', 180602.506205),
#  (u'row level variabl', 180602.506205),
#  (u'row level modif', 180602.506205),
#  (u'rough approxim gpa', 180602.506205),
#  (u'root tuppl', 180602.506205),
#  (u'rollup command', 180602.506205),
#  (u'rollup claus', 180602.506205),
#  (u'rollback command', 180602.506205),
#  (u'roll up command', 180602.506205),
#  (u'roll level trigger', 180602.506205),
#  (u'role level trigger', 180602.506205),
#  (u'rigid relat model', 180602.506205),
#  (u'result tupl', 180602.506205),
#  (u'result sub queri', 180602.506205),
#  (u'result sqlite', 180602.506205),
#  (u'result berkeley', 180602.506205),
#  (u'rep attribut', 180602.506205),
#  (u'remind transact', 180602.506205),
#  (u'remind constraint', 180602.506205),
#  (u'remark subel', 180602.506205),
#  (u'remark occurr constraint', 180602.506205),
#  (u'remark compon', 180602.506205),
#  (u'remaind boyc codd', 180602.506205),
#  (u'relat tip', 180602.506205),
#  (u'relat specif', 180602.506205),
#  (u'relat rout', 180602.506205),
#  (u'relat rabcd', 180602.506205),
#  (u'relat rabc', 180602.506205),
#  (u'relat queri', 180602.506205),
#  (u'relat model video', 180602.506205),
#  (u'relat model schema', 180602.506205),
#  (u'relat joint', 180602.506205),
#  (u'relat dot data model', 180602.506205),
#  (u'relat data base system', 180602.506205),
#  (u'relat data base design', 180602.506205),
#  (u'relat content', 180602.506205),
#  (u'relat algebra tree', 180602.506205),
#  (u'relat algebra style', 180602.506205),
#  (u'relat algebra queri languag', 180602.506205),
#  (u'regular sql queri', 180602.506205),
#  (u'regular sql construct', 180602.506205),
#  (u'referenti integr talk', 180602.506205),
#  (u'referenti integr system', 180602.506205),
#  (u'referenti integr point', 180602.506205),
#  (u'referenti integr constraint violat', 180602.506205),
#  (u'referenti integr constraint enforc', 180602.506205),
#  (u'refer relat r1', 180602.506205),
#  (u'reduc function', 180602.506205),
#  (u'recurs with statement', 180602.506205),
#  (u'recurs trigger', 180602.506205),
#  (u'recurs templat match', 180602.506205),
#  (u'recurs sub queri', 180602.506205),
#  (u'recurs statement', 180602.506205),
#  (u'recurs specif', 180602.506205),
#  (u'recurs sort', 180602.506205),
#  (u'recurs rn', 180602.506205),
#  (u'recurs r1', 180602.506205),
#  (u'recurs modifi', 180602.506205),
#  (u'recurs half', 180602.506205),
#  (u'recurs construct', 180602.506205),
#  (u'recent trigger fire', 180602.506205),
#  (u'real world constraint', 180602.506205),
#  (u'real world assumpt', 180602.506205),
#  (u'real origin data', 180602.506205),
#  (u'real airport code', 180602.506205),
#  (u'read privileg', 180602.506205),
#  (u'rate label properti', 180602.506205),
#  (u'raise/ignor command', 180602.506205),
#  (u'r1 natur', 180602.506205),
#  (u'quick cross check', 180602.506205),
#  (u'question q2', 180602.506205),
#  (u'queri workload', 180602.506205),
#  (u'queri tomorrow', 180602.506205),
#  (u'queri overview', 180602.506205),
#  (u'queri find', 180602.506205),
#  (u'queri cue', 180602.506205),
#  (u'quantiti time price', 180602.506205),
#  (u'put author', 180602.506205),
#  (u'properti valu pair', 180602.506205),
#  (u'propag trigger', 180602.506205),
#  (u'promin key valu store', 180602.506205),
#  (u'promin databas system', 180602.506205),
#  (u'project name text', 180602.506205),
#  (u'project list', 180602.506205),
#  (u'program secur issu', 180602.506205),
#  (u'proceed sibl axi', 180602.506205),
#  (u'prioriti attribut', 180602.506205),
#  (u'primari sort order', 180602.506205),
#  (u'primari open sourc system', 180602.506205),
#  (u'primari key statement', 180602.506205),
#  (u'predefin aggreg', 180602.506205),
#  (u'preced tupl', 180602.506205),
#  (u'pre reduc phase', 180602.506205),
#  (u'pre defin user', 180602.506205),
#  (u'pre aggreg data', 180602.506205),
#  (u'pre aggreg', 180602.506205),
#  (u'postgr system', 180602.506205),
#  (u'postgr implement', 180602.506205),
#  (u'post risk command line interfac', 180602.506205),
#  (u'post grist system', 180602.506205),
#  (u'posari system', 180602.506205),
#  (u'popular oper', 180602.506205),
#  (u'popular high level languag', 180602.506205),
#  (u'pointer work', 180602.506205),
#  (u'point trigger process', 180602.506205),
#  (u'plural id ref', 180602.506205),
#  (u'plain sql queri', 180602.506205),
#  (u'pig script', 180602.506205),
#  (u'phantom tupl', 180602.506205),
#  (u'peski attribut', 180602.506205),
#  (u'past sever video', 180602.506205),
#  (u'partial full effect', 180602.506205),
#  (u'parent tupl', 180602.506205),
#  (u'parent tag', 180602.506205),
#  (u'parent navig axi', 180602.506205),
#  (u'parent element tag', 180602.506205),
#  (u'palo alto sale', 180602.506205),
#  (u'pad top', 180602.506205),
#  (u'pad left', 180602.506205),
#  (u'pad bottom', 180602.506205),
#  (u'overlap sub class relationship', 180602.506205),
#  (u'outermost object', 180602.506205),
#  (u'outer refer tabl', 180602.506205),
#  (u'origin tuple1', 180602.506205),
#  (u'origin queri result', 180602.506205),
#  (u'origin queri group', 180602.506205),
#  (u'origin mega relat', 180602.506205),
#  (u'origin fact data', 180602.506205),
#  (u'origin data cube', 180602.506205),
#  (u'option remark', 180602.506205),
#  (u'open tag isbn', 180602.506205),
#  (u'open sourc databas system', 180602.506205),
#  (u'onlin json schema valid', 180602.506205),
#  (u'onlin analyt process olap', 180602.506205),
#  (u'oltp world', 180602.506205),
#  (u'oltp style applic', 180602.506205),
#  (u'oltp sourc', 180602.506205),
#  (u'oltp data base', 180602.506205),
#  (u'olap environ', 180602.506205),
#  (u'olap demonstr', 180602.506205),
#  (u'olap camp', 180602.506205),
#  (u'occurr constraint', 180602.506205),
#  (u'object kind', 180602.506205),
#  (u'number tupl', 180602.506205),
#  (u'null major', 180602.506205),
#  (u'null gpa', 180602.506205),
#  (u'null edit', 180602.506205),
#  (u'null decis', 180602.506205),
#  (u'nosql type applic', 180602.506205),
#  (u'nil type', 180602.506205),
#  (u'nice underli algebra', 180602.506205),
#  (u'nice theori', 180602.506205),
#  (u'nice setup', 180602.506205),
#  (u'nice queri', 180602.506205),
#  (u'nice languag', 180602.506205),
#  (u'nice high level languag', 180602.506205),
#  (u'nice error', 180602.506205),
#  (u'nice big queri', 180602.506205),
#  (u'nest trigger invoc', 180602.506205),
#  (u'nest sub queri', 180602.506205),
#  (u'nest develop', 180602.506205),
#  (u'nest composit object', 180602.506205),
#  (u'nest behavior', 180602.506205),
#  (u'neg subqueri', 180602.506205),
#  (u'navig axi', 180602.506205),
#  (u'navig axe', 180602.506205),
#  (u'natur recurs queri', 180602.506205),
#  (u'natur queri', 180602.506205),
#  (u'naiv recurs', 180602.506205),
#  (u'mysteri cmh', 180602.506205),
#  (u'mysql today', 180602.506205),
#  (u'multipl sub class', 180602.506205),
#  (u'multiattribut foreign key constraint', 180602.506205),
#  (u'multi valu depend a multi', 180602.506205),
#  (u'multi set oper', 180602.506205),
#  (u'multi set model', 180602.506205),
#  (u'multi set', 180602.506205),
#  (u'multi doubt valu depend', 180602.506205),
#  (u'multi attribut key', 180602.506205),
#  (u'multi attribut', 180602.506205),
#  (u'ms widom', 180602.506205),
#  (u'mongo db', 180602.506205),
#  (u'modif overview', 180602.506205),
#  (u'modif combin', 180602.506205),
#  (u'minu mn', 180602.506205),
#  (u'minu express', 180602.506205),
#  (u'minoccur specif', 180602.506205),
#  (u'minimum cost flight', 180602.506205),
#  (u'min gpa', 180602.506205),
#  (u'min aggreg function', 180602.506205),
#  (u'million billion', 180602.506205),
#  (u'middl selector', 180602.506205),
#  (u'middl match element', 180602.506205),
#  (u'merg like oper', 180602.506205),
#  (u'mega view', 180602.506205),
#  (u'mega templat', 180602.506205),
#  (u'medium downsid', 180602.506205),
#  (u'maximum number item', 180602.506205),
#  (u'max gpa', 180602.506205),
#  (u'match transform', 180602.506205),
#  (u'match student tupl', 180602.506205),
#  (u'match student id', 180602.506205),
#  (u'match sid', 180602.506205),
#  (u'match schema', 180602.506205),
#  (u'match close tag', 180602.506205),
#  (u'match book element', 180602.506205),
#  (u'match book', 180602.506205),
#  (u'mass produc architectur', 180602.506205),
#  (u'mari tupl', 180602.506205),
#  (u'margin top', 180602.506205),
#  (u'margin downsid', 180602.506205),
#  (u'margin bottom', 180602.506205),
#  (u'manag employe relationship', 180602.506205),
#  (u'major one at a time', 180602.506205),
#  (u'major mani time', 180602.506205),
#  (u'major equal cs', 180602.506205),
#  (u'magazin sub element', 180602.506205),
#  (u'lower consist guarante', 180602.506205),
#  (u'loos type data', 180602.506205),
#  (u'longer condit', 180602.506205),
#  (u'long first part', 180602.506205),
#  (u'long bit', 180602.506205),
#  (u'logic implic symbol', 180602.506205),
#  (u'log in mechan', 180602.506205),
#  (u'line tgat', 180602.506205),
#  (u'limit trigger train', 180602.506205),
#  (u'limit command', 180602.506205),
#  (u'left hand side object', 180602.506205),
#  (u'leaf text element', 180602.506205),
#  (u'larg social graph', 180602.506205),
#  (u'larg scale data analys', 180602.506205),
#  (u'larg realist databas', 180602.506205),
#  (u'larg onlin vendor', 180602.506205),
#  (u'larg databas applic', 180602.506205),
#  (u'languag like construct', 180602.506205),
#  (u'label properti', 180602.506205),
#  (u'label magazin', 180602.506205),
#  (u'label column', 180602.506205),
#  (u'kinda glue', 180602.506205),
#  (u'keyword recurs', 180602.506205),
#  (u'key word combin', 180602.506205),
#  (u'key ref', 180602.506205),
#  (u'key document pair', 180602.506205),
#  (u'key declar', 180602.506205),
#  (u'key constraint violat', 180602.506205),
#  (u'k2 02', 180602.506205),
#  (u'k1 01', 180602.506205),
#  (u'json path languag', 180602.506205),
#  (u'json path', 180602.506205),
#  (u'json demo', 180602.506205),
#  (u'john tupl', 180602.506205),
#  (u'jeffrey widom', 180602.506205),
#  (u'jefferey ullman', 180602.506205),
#  (u'java script object notat', 180602.506205),
#  (u'iter variabl', 180602.506205),
#  (u'item i32', 180602.506205),
#  (u'item costum', 180602.506205),
#  (u'isol portion', 180602.506205),
#  (u'isbn price titl', 180602.506205),
#  (u'isbn attribut', 180602.506205),
#  (u'invert bookstor', 180602.506205),
#  (u'intuit trigger', 180602.506205),
#  (u'intra tabl referenti integr', 180602.506205),
#  (u'intersect express', 180602.506205),
#  (u'interfac mean null', 180602.506205),
#  (u'interest queri', 180602.506205),
#  (u'interest implement issu', 180602.506205),
#  (u'interact action', 180602.506205),
#  (u'inter relat schema', 180602.506205),
#  (u'inter lead oper', 180602.506205),
#  (u'intend insert', 180602.506205),
#  (u'insert tuppl', 180602.506205),
#  (u'insert trigger', 180602.506205),
#  (u'insert rita', 180602.506205),
#  (u'insert bob', 180602.506205),
#  (u'insert attempt', 180602.506205),
#  (u'insert ami', 180602.506205),
#  (u'individu subclass relat', 180602.506205),
#  (u'indispens companion', 180602.506205),
#  (u'increment mainten algorithm', 180602.506205),
#  (u'incomplet disjoint', 180602.506205),
#  (u'incomplet complet subclass relationship', 180602.506205),
#  (u'includ transform', 180602.506205),
#  (u'implicit prioriti scheme', 180602.506205),
#  (u'implicit existenti quantif', 180602.506205),
#  (u'impli function depend', 180602.506205),
#  (u'imaginari modif', 180602.506205),
#  (u'imaginari databas', 180602.506205),
#  (u'imaginari colleg admiss databas', 180602.506205),
#  (u'identifi hg', 180602.506205),
#  (u'id rep', 180602.506205),
#  (u'hudson author', 180602.506205),
#  (u'hub start relat', 180602.506205),
#  (u'hub note', 180602.506205),
#  (u'hub author', 180602.506205),
#  (u'hot queri', 180602.506205),
#  (u'highest ee major', 180602.506205),
#  (u'higher prioriti templat', 180602.506205),
#  (u'higher level design tool', 180602.506205),
#  (u'higher level design model', 180602.506205),
#  (u'higher level databas design', 180602.506205),
#  (u'high school code', 180602.506205),
#  (u'high level queri languag', 180602.506205),
#  (u'high level design model', 180602.506205),
#  (u'high gpa applic', 180602.506205),
#  (u'high enough gpa', 180602.506205),
#  (u'hector garcia molina', 180602.506205),
#  (u'hector garcia melina', 180602.506205),
#  (u'hash base index', 180602.506205),
#  (u'guaranteesthat constraint', 180602.506205),
#  (u'greek symbol rho', 180602.506205),
#  (u'greek pi symbol', 180602.506205),
#  (u'great mood today', 180602.506205),
#  (u'great grandpar relationship', 180602.506205),
#  (u'grandpar relationship', 180602.506205),
#  (u'grand final queri', 180602.506205),
#  (u'gpa prioriti', 180602.506205),
#  (u'gpa column', 180602.506205),
#  (u'gpa arrow prioriti', 180602.506205),
#  (u'good schema design', 180602.506205),
#  (u'good relat design', 180602.506205),
#  (u'good queri processor', 180602.506205),
#  (u'good old jet blue', 180602.506205),
#  (u'good constraint check system', 180602.506205),
#  (u'gigant warehous', 180602.506205),
#  (u'gigant queri', 180602.506205),
#  (u'gigant disk', 180602.506205),
#  (u'gigant databas', 180602.506205),
#  (u'gener virtual view', 180602.506205),
#  (u'gener mason', 180602.506205),
#  (u'gener insert', 180602.506205),
#  (u'gener class c1', 180602.506205),
#  (u'gener assert featur', 180602.506205),
#  (u'full uml', 180602.506205),
#  (u'full trigger syntax', 180602.506205),
#  (u'full star join', 180602.506205),
#  (u'full featur queri languag', 180602.506205),
#  (u'full aggreg', 180602.506205),
#  (u'friend edg', 180602.506205),
#  (u'fourth tupl', 180602.506205),
#  (u'fourth normal form relat', 180602.506205),
#  (u'foreign key attribut', 180602.506205),
#  (u'flight relat', 180602.506205),
#  (u'flight databas', 180602.506205),
#  (u'flat db', 180602.506205),
#  (u'final queri', 180602.506205),
#  (u'final destinationand', 180602.506205),
#  (u'final decompos relat', 180602.506205),
#  (u'fictiti databas', 180602.506205),
#  (u'favorit tradit notion', 180602.506205),
#  (u'favorit queri', 180602.506205),
#  (u'favorit oper', 180602.506205),
#  (u'favorit misspel', 180602.506205),
#  (u'fact tabl sort', 180602.506205),
#  (u'fact json schema', 180602.506205),
#  (u'fact graph databas', 180602.506205),
#  (u'fact fact tabl', 180602.506205),
#  (u'fact author', 180602.506205),
#  (u'face edg', 180602.506205),
#  (u'extran text', 180602.506205),
#  (u'express trigger system', 180602.506205),
#  (u'express integr constraint', 180602.506205),
#  (u'express e2', 180602.506205),
#  (u'express e1 minu e2', 180602.506205),
#  (u'express e1', 180602.506205),
#  (u'experienc databas applic develop', 180602.506205),
#  (u'exist constraint', 180602.506205),
#  (u'execut glue', 180602.506205),
#  (u'exact transit', 180602.506205),
#  (u'exact sequenti order', 180602.506205),
#  (u'exact same issu', 180602.506205),
#  (u'exact same bookstor data', 180602.506205),
#  (u'exact delet', 180602.506205),
#  (u'event trigger event', 180602.506205),
#  (u'event condit action rule', 180602.506205),
#  (u'event condit action role', 180602.506205),
#  (u'error rais command', 180602.506205),
#  (u'equival specif', 180602.506205),
#  (u'equival serial order', 180602.506205),
#  (u'equival sequenti order', 180602.506205),
#  (u'equal student', 180602.506205),
#  (u'enumer domain', 180602.506205),
#  (u'enumer constraint', 180602.506205),
#  (u'empti object', 180602.506205),
#  (u'embed key valu store', 180602.506205),
#  (u'element type kleen', 180602.506205),
#  (u'econom databas hint', 180602.506205),
#  (u'earlier path express', 180602.506205),
#  (u'e2 dot a2', 180602.506205),
#  (u'e1 natur', 180602.506205),
#  (u'e1 minu e2', 180602.506205),
#  (u'e1 minu', 180602.506205),
#  (u'e1 intersect e2', 180602.506205),
#  (u'duplic titl', 180602.506205),
#  (u'duplic issu', 180602.506205),
#  (u'dtd specif', 180602.506205),
#  (u'draw databas', 180602.506205),
#  (u'dramat databas modif', 180602.506205),
#  (u'dot dot star', 180602.506205),
#  (u'document databas system', 180602.506205),
#  (u'doc bookstor', 180602.506205),
#  (u'dirti data item', 180602.506205),
#  (u'direct programmig', 180602.506205),
#  (u'direct jet blue flight', 180602.506205),
#  (u'determinist answer', 180602.506205),
#  (u'desir normal form', 180602.506205),
#  (u'descend descend', 180602.506205),
#  (u'depend a multi', 180602.506205),
#  (u'demonstr simpl', 180602.506205),
#  (u'demo queri', 180602.506205),
#  (u'demo postgr', 180602.506205),
#  (u'delet tuppl', 180602.506205),
#  (u'delet tupl', 180602.506205),
#  (u'delet major', 180602.506205),
#  (u'delet coupl', 180602.506205),
#  (u'defer constraint check', 180602.506205),
#  (u'default minoccur', 180602.506205),
#  (u'deep compani hierarchi', 180602.506205),
#  (u'decompos relat', 180602.506205),
#  (u'declar high level languag', 180602.506205),
#  (u'de normal relat', 180602.506205),
#  (u'datath system', 180602.506205),
#  (u'databas v1', 180602.506205),
#  (u'databas privileg', 180602.506205),
#  (u'databas peopl', 180602.506205),
#  (u'databas manag system system', 180602.506205),
#  (u'databas implement', 180602.506205),
#  (u'databas hint', 180602.506205),
#  (u'databas design pick', 180602.506205),
#  (u'databas construct', 180602.506205),
#  (u'databas connoisseur', 180602.506205),
#  (u'databas base author', 180602.506205),
#  (u'databas author', 180602.506205),
#  (u'data scenario', 180602.506205),
#  (u'data model subset', 180602.506205),
#  (u'data model portion', 180602.506205),
#  (u'data mine type oper', 180602.506205),
#  (u'data level modif', 180602.506205),
#  (u'data kind', 180602.506205),
#  (u'data javascript object notat', 180602.506205),
#  (u'data clean process', 180602.506205),
#  (u'data base stay', 180602.506205),
#  (u'data base activ', 180602.506205),
#  (u'cycl lot', 180602.506205),
#  (u'cube tabl', 180602.506205),
#  (u'cube queri', 180602.506205),
#  (u'cube extens', 180602.506205),
#  (u'csee view', 180602.506205),
#  (u'cse major', 180602.506205),
#  (u'cs gpa', 180602.506205),
#  (u'cs burk', 180602.506205),
#  (u'cs accept view', 180602.506205),
#  (u'cs accept relat', 180602.506205),
#  (u'cross bay rival berkeley', 180602.506205),
#  (u'coupl tuppl', 180602.506205),
#  (u'count queri', 180602.506205),
#  (u'costum id', 180602.506205),
#  (u'correct modif', 180602.506205),
#  (u'correct json file', 180602.506205),
#  (u'correct json', 180602.506205),
#  (u'correct function depend', 180602.506205),
#  (u'correct decomposit', 180602.506205),
#  (u'correct bcnf answer', 180602.506205),
#  (u'cornel offer ee', 180602.506205),
#  (u'constraintless check', 180602.506205),
#  ...]

# %%
stemmed_documents = OrderedDict()

for name, document in documents.items():
    document = document.replace('-', ' ')
    document = ' '.join([stemmer.stem(token) for token in nltk.word_tokenize(document)])
    stemmed_documents[name] = document.lower()

extractor = TfidfVectorizer(ngram_range=(1,4), stop_words=stopwords)
X = extractor.fit_transform(stemmed_documents.values())
X = X / X.sum(axis=1)
inverse_voc = {v: k for k, v in extractor.vocabulary_.items()}

# %%
external_tfidf_idxs = [extractor.vocabulary_[word] for word in sorted(external_tfidfs.keys()) if word in extractor.vocabulary_]
external_tfidf_vals = np.array([value for word, value in sorted(external_tfidfs.items()) if word in extractor.vocabulary_])
external_tfidf_vals /= external_tfidf_vals.sum()
X[:, external_tfidf_idxs] += external_tfidf_vals

# %%
extracted = OrderedDict()
for doc_idx, name in enumerate(stemmed_documents.keys()):
    extracted[name] = [inverse_voc[idx] for idx in np.argsort(np.array(X[doc_idx,:])).flatten()]

# %%
matches = OrderedDict()
jaccard = OrderedDict()

for name, keys in sorted(keywords.items()):
    extracted_words = extracted[name][-len(keys):]
    matches[name.replace('.keys', '')] = list(set(keys).intersection(extracted_words))
    jaccard[name.replace('.keys', '')] = float(len(set(keys).intersection(extracted_words))) / len(set(keys).union(set(extracted_words)))
    
print('Average jaccard: {}'.format(sum(jaccard.values()) / len(jaccard)))
# Out:
# Average jaccard: 0.12790217467

# %%
matches = OrderedDict()
jaccard = OrderedDict()

for name, keys in sorted(keywords.items()):
    extracted_words = extracted[name][-2*len(keys):]
    matches[name.replace('.keys', '')] = list(set(keys).intersection(extracted_words))
    jaccard[name.replace('.keys', '')] = float(len(set(keys).intersection(extracted_words))) / len(set(keys).union(set(extracted_words)))
    
print('Average jaccard: {}'.format(sum(jaccard.values()) / len(jaccard)))
# Out:
# Average jaccard: 0.104138252084

# %%
with open('tfidf_combined_keys.csv', 'w') as f:
    for document, keys in sorted(extracted.items()):
        keys = list(reversed(keys))
        for i, key in enumerate(keys[:10]):
            if i < 5:
                f.write('{},{},{}\n'.format(document, key, i + 1))
            else:
                f.write('{},{},{}\n'.format(document, key, 0))

# %%
list(reversed(extracted['03_01_Well_Formed_XML_Part_2.txt'])).index('extens style sheet languag')

# %%
zip(*sorted(external_tfidfs.items(), key=lambda (k, v): (v, k), reverse=True))[0].index('document type descriptor')

# %%
len(keywords['03_02_DTDs_IDs_and_IDREFs.txt'])

# %%
stemmed_documents['11_03_Isolation_Levels_Part_3.txt'].count('repeat read isol level')

# %%
list(reversed(extracted['03_02_DTDs_IDs_and_IDREFs.txt']))
# Out:
# [u'dtd',
#  u'book',
#  u'element',
#  u'document',
#  u'xml',
#  u'author',
#  u'valid',
#  u'id',
#  u'id ref',
#  u'remark',
#  u'attribut',
#  u'author element',
#  u'string',
#  u'refer',
#  u'book refer',
#  u'ref',
#  u'book element',
#  u'type',
#  u'data',
#  u'titl',
#  u'document type descriptor',
#  u'pc data',
#  u'structur',
#  u'xsd',
#  u'magazin',
#  u'edit',
#  u'pc',
#  u'xml schema',
#  u'close tag',
#  u'subel',
#  u'id ref attribut',
#  u'insert command',
#  u'id attribut',
#  u'hg',
#  u'valid document',
#  u'multivalu depend',
#  u'special attribut',
#  u'project oper',
#  u'pointer',
#  u'regular express',
#  u'valid xml',
#  u'ju',
#  u'element call',
#  u'specif',
#  u'bookstor',
#  u'document document',
#  u'isbn number',
#  u'id rep',
#  u'rep attribut',
#  u'll',
#  u'modif command',
#  u'tupl base constraint',
#  u'type descriptor',
#  u'descriptor',
#  u'basic structur',
#  u'transit rule',
#  u'specif specif',
#  u'author author',
#  u'intersect oper',
#  u'isbn',
#  u'requir',
#  u'error',
#  u'element element',
#  u'relat algebra express',
#  u'special type',
#  u'document type',
#  u'dtd xsd',
#  u'languag',
#  u'program',
#  u'isol level',
#  u'tag',
#  u'ident',
#  u'basic structur requir',
#  u'function depend',
#  u'xml schema descript',
#  u'extens style sheet languag',
#  u'parser',
#  u'attribut element',
#  u'cs applic',
#  u'aggreg function',
#  u'style sheet',
#  u'xml valid',
#  u'element type',
#  u'student id',
#  u'outermost element',
#  u'element author',
#  u'learn',
#  u'call',
#  u'structur requir',
#  u'express languag',
#  u'remark subel',
#  u'option remark',
#  u'structur document',
#  u'databas design',
#  u'xml document',
#  u'attribut isbn',
#  u'bookstor element',
#  u'empti element',
#  u'pars xml',
#  u'special',
#  u'string data',
#  u'requir attribut',
#  u'nation geograph',
#  u'check',
#  u'style sheet languag',
#  u'ident attribut',
#  u'addit attribut',
#  u'id rep attribut',
#  u'call id',
#  u'xml valid xml',
#  u'edit document',
#  u'dtd dtd',
#  u'refer id',
#  u'program assum',
#  u'command',
#  u'author book',
#  u'uniqu attribut',
#  u'mega relat',
#  u'item dimens tabl',
#  u'xml schema descriptor',
#  u'select privileg',
#  u'boyc codd',
#  u'sql video',
#  u'appli tupl',
#  u'relat algebra video',
#  u'ancestor tupl',
#  u'json editor',
#  u'relat s1',
#  u'natur function depend',
#  u'select express',
#  u'base check constraint',
#  u'student tupl',
#  u'good schema',
#  u'distinct gpa',
#  u'json queri languag',
#  u'post risk',
#  u'modif statement',
#  u'auth element',
#  u'distinct student id',
#  u'decis column',
#  u'graph databas system',
#  u'bigger relat',
#  u'xslt specif',
#  u'balanc tree index',
#  u'standford student',
#  u'physic design advisor',
#  u'automat view modif',
#  u'specif tupl',
#  u'good decomposit',
#  u'appli tabl',
#  u'referenti integr violat',
#  u'constraint video',
#  u'grant diagram',
#  u'adher',
#  u'benefit',
#  u'specif structur',
#  u'view queri',
#  u'tabl t3',
#  u'outermost construct',
#  u'previou trigger',
#  u'item tabl',
#  u'result sql',
#  u'tabl r1',
#  u'magazin titl',
#  u'high school',
#  u'trigger chain',
#  u'maximum gpa',
#  u'ambigu error',
#  u'low level trigger',
#  u'ancestor relationship',
#  u'book author',
#  u'text',
#  u'attribut id',
#  u'type descriptor dtd',
#  u'data element',
#  u'refer author',
#  u'document valid',
#  u'descriptor dtd',
#  u'ref attribut',
#  u'refer book',
#  u'xml adher',
#  u'rep',
#  u'form xml',
#  u'document type descriptor dtd',
#  u'statement level trigger',
#  u'key violat',
#  u'row level trigger',
#  u'high school size',
#  u'relat algebra queri',
#  u'hub relat',
#  u'author node',
#  u'nontrivi function depend',
#  u'make',
#  u'complic queri',
#  u'map box',
#  u'unbound comput',
#  u'higher level model',
#  u'xpath queri',
#  u'constraint system',
#  u'complet relationship',
#  u'lesser privileg',
#  u'transact t1',
#  u'magazin element',
#  u'appli relat',
#  u'writer function',
#  u'root element',
#  u'arbitrari depth',
#  u'updat view',
#  u'select claus',
#  u'constraint violat',
#  u'small relat',
#  u'depend attribut',
#  u'form',
#  u'uml design',
#  u'manag relationship',
#  u'hub node',
#  u'data type',
#  u'book titl',
#  u'store id',
#  u'colleg tabl',
#  u'split rule',
#  u'program languag',
#  u'tradit relat databas system',
#  u'mutual recurs',
#  u'xml stream',
#  u'command line',
#  u'open tag',
#  u'meaning translat',
#  u'previou queri',
#  u'nosql solut',
#  u'tradit databas system',
#  u'item id',
#  u'author relat',
#  u'month',
#  u'irregular',
#  u'major combin',
#  u'dimens attribut',
#  u'relat design',
#  u'student gpa',
#  u'select condit',
#  u'student coupl',
#  u'price attribut',
#  u'book pair',
#  u'automat applic',
#  u'ab pair',
#  u'high gpa',
#  u'equal condit',
#  u'applic record',
#  u'xml queri',
#  u'option',
#  u'parent child relationship',
#  u'trigger condit',
#  u'recurs queri',
#  u'combin function',
#  u'referenti integr constraint',
#  u'star schema',
#  u'friend relationship',
#  u'input record',
#  u'select oper',
#  u'mapreduc job',
#  u'data structur',
#  u'previou video',
#  u'highest gpa',
#  u'relat schema',
#  u'privileg system',
#  u'check constraint',
#  u'attribut call',
#  u'price',
#  u'gener assert',
#  u'complex queri',
#  u'nosql system',
#  u'custom id',
#  u'type attribut',
#  u'bookstor book',
#  u'book author book',
#  u'virtual view',
#  u'ullman jefferi',
#  u'terribl type',
#  u'element type kleen',
#  u'plural id ref',
#  u'identifi hg',
#  u'singular id ref',
#  u'loos type data',
#  u'nil type',
#  u'titl subel',
#  u'bang attribut list',
#  u'super class',
#  u'persist data structur',
#  u'foreign key constraint',
#  u'altern notat',
#  u'output record',
#  u'simpl queri',
#  u'set oper',
#  u'xpath express',
#  u'larg number',
#  u'share attribut',
#  u'regular tabl',
#  u'map function',
#  u'joint condit',
#  u'automat translat',
#  u'irregular document',
#  u'path express',
#  u'select statement',
#  u'formal foundat',
#  u'fact tabl',
#  u'massiv databas',
#  u'express tree',
#  u'specif queri',
#  u'singl attribut',
#  u'dimens tabl',
#  u'dtd specif',
#  u'attribut addit',
#  u'xml data',
#  u'relat system',
#  u'sql system',
#  u'user queri',
#  u'separ relat',
#  u'element attribut',
#  u'attribut book',
#  u'graph databas',
#  u'transit closur',
#  u'key constraint',
#  u'specif major',
#  u'sql standard',
#  u'queri optim',
#  u'psycholog major',
#  u'integr constraint',
#  u'total salari',
#  u'tabl variabl',
#  u'leaf data',
#  u'biolog major',
#  u'isbn attribut',
#  u'xml schema specif',
#  u'singl root element',
#  u'trigger action',
#  u'independ fact',
#  u'econom major',
#  u'refer relat',
#  u'attribut ident',
#  u'total price',
#  u'open sourc system',
#  u'nice featur',
#  u'colleg enrol',
#  u'attribut refer',
#  u'interest construct',
#  u'web log',
#  u'databas system',
#  u'earlier video',
#  u'book wrap',
#  u'larg high school',
#  u'schema',
#  u'relat databas system',
#  u'sibl relationship',
#  u'uniqu code',
#  u'small high school',
#  u'exam question',
#  u'databas schema',
#  u'reserv word',
#  u'addit',
#  u'schema descript',
#  u'command line shell',
#  u'subsequ video',
#  u'colleg applic',
#  u'primari key',
#  u'queri result',
#  u'foreign key',
#  u'live demo',
#  u'good design',
#  u'logic express',
#  u'venn diagram',
#  u'titl tag',
#  u'add',
#  u'databas administr',
#  u'specif attribut',
#  u'ap student',
#  u'biggest benefit',
#  u'sql queri',
#  u'system crash',
#  u'effici implement',
#  u'berkeley student',
#  u'domest student',
#  u'author attribut',
#  u'simpler program',
#  u'arbitrari number',
#  u'california colleg',
#  u'sql statement',
#  u'titl element',
#  u'video learn',
#  u'year',
#  u'run command',
#  u'attribut list',
#  u'previou document',
#  u'cartesian product',
#  u'left hand side',
#  u'error check',
#  u'schema specif',
#  u'direct edg',
#  u'run',
#  u'databas applic',
#  u'addit constraint',
#  u'cross product',
#  u'base tabl',
#  u'addit input',
#  u'ee applic',
#  u'queri languag',
#  u'student relat',
#  u'addit condit',
#  u'specif languag',
#  u'purchas order',
#  u'fact',
#  u'order',
#  u'similar data',
#  u'type attribut call id',
#  u'special type attribut',
#  u'point book',
#  u'refer author element',
#  u'special type attribut call',
#  u'type attribut call',
#  u'lot error',
#  u'document document type descriptor',
#  u'id rep attribut refer',
#  u'ref string',
#  u'attribut month',
#  u'attribut month year',
#  u'id ref string',
#  u'untyp',
#  u'document fact',
#  u'string attribut',
#  u'string element',
#  u'ref id',
#  u'id ref id',
#  u'valid satisfi',
#  u'document parser',
#  u'document document type',
#  u'attribut call id',
#  u'element string',
#  u'document correct',
#  u'assum structur',
#  u'id book',
#  u'author special',
#  u'xml compani',
#  u'author subel',
#  u'id id ref',
#  u'll dtd',
#  u'valid xml valid',
#  u'valid xml valid xml',
#  u'pc data element',
#  u'pc data element type',
#  u'document time',
#  u'pc data string',
#  u'data element type',
#  u'document specif',
#  u'grammar',
#  u'isbn number price',
#  u'element dtd',
#  u'talk book',
#  u'refer hg',
#  u'book isbn number price',
#  u'string id',
#  u'parser document',
#  u'call author',
#  u'call author author',
#  u'call ident',
#  u'kleen',
#  u'program assum structur',
#  u'messi',
#  u'hg ju',
#  u'number price',
#  u'rep attribut refer',
#  u'call book',
#  u'dangl pointer',
#  u'text element',
#  u'lower left corner',
#  u'decis support system',
#  u'text data',
#  u'jeffrey ullman',
#  u'structur data',
#  u'system failur',
#  u'larg databas',
#  u'schema languag',
#  u'data item',
#  u'prematur end',
#  u'xml parser',
#  u'simpler',
#  u'data model',
#  u'basic oper',
#  u'xml tree',
#  u'act score',
#  u'data exchang',
#  u'tradit system',
#  u'social secur number',
#  u'specif book',
#  u'applic develop',
#  u'power languag',
#  u'interest thing',
#  u'empti',
#  u'key point',
#  u'author list',
#  u'databas manag system',
#  u'key word',
#  u'import concept',
#  u'bank system',
#  u'regular class',
#  u'squar bracket',
#  u'joint oper',
#  u'colleg class',
#  u'correct order',
#  u'relat databas',
#  u'ap class',
#  u'regular',
#  u'structur program',
#  u'document error',
#  u'dtd id',
#  u'book id',
#  u'type pointer',
#  u'put book',
#  u'check document',
#  u'content specif specif',
#  u'save file',
#  u'effect pointer',
#  u'content specif',
#  u'sheet languag',
#  u'xml adher basic',
#  u'xml adher basic structur',
#  u'subel book',
#  u'element call bookstor',
#  u'call bookstor',
#  u'make edit',
#  u'specif document',
#  u'pointer dtd',
#  u'price edit',
#  u'xml schema xsd',
#  u'element number',
#  u'schema xsd',
#  u'singular',
#  u'file system',
#  u'separ video',
#  u'page view',
#  u'uniqu',
#  u'question mark',
#  u'direct flight',
#  u'complet book',
#  u'great thing',
#  u'import thing',
#  u'larg portion',
#  u'talk',
#  u'instanc',
#  u'consist',
#  u'data format',
#  u'import aspect',
#  u'foreign student',
#  u'specif type',
#  u'data string',
#  u'compani',
#  u'meet',
#  u'sheet',
#  u'magazin ll',
#  u'book edit',
#  u'document form',
#  u'adher basic',
#  u'adher basic structur',
#  u'posit',
#  u'valid fact',
#  u'xsd xml',
#  u'adher basic structur requir',
#  u'book ll',
#  u'month year',
#  u'close',
#  u'effect',
#  u'left side',
#  u'put',
#  u'error error',
#  u'book isbn number',
#  u'titl author',
#  u'element titl',
#  u'id id',
#  u'pars',
#  u'leaf',
#  u'data xml',
#  u'number',
#  u'construct',
#  u'rule',
#  u'element author element',
#  u'ullman',
#  u'author element author',
#  u'type element',
#  u'book magazin',
#  u'languag xml',
#  u'save',
#  u'book isbn',
#  u'return',
#  u'correct',
#  u'video',
#  u'basic',
#  u'type data',
#  u'mix',
#  u'element book',
#  u'specif xml',
#  u'assum',
#  u'bookstor databas',
#  u'tupl gener depend',
#  u'match student tupl',
#  u'nest trigger invoc',
#  u'author object',
#  u'appli coupl',
#  u'syntact necess',
#  u'larg databas applic',
#  u'implicit existenti quantif',
#  u'match transform',
#  u'csee view',
#  u'insert attempt',
#  u'ap student subclass',
#  u'big cross product',
#  u'grand final queri',
#  u'maximum number item',
#  u'isbn price titl',
#  u'medium downsid',
#  u'row level variabl',
#  u'balanc tree',
#  u'author start relat',
#  u'case tabl student',
#  u'margin downsid',
#  u'gpa prioriti',
#  u'final queri',
#  u'outermost object',
#  u'conclus transact',
#  u'a2 dot cname',
#  u'author concept',
#  u'margin bottom',
#  u'rollup command',
#  u'pad left',
#  u'margin top',
#  u'outer refer tabl',
#  u'rollup claus',
#  u'recurs construct',
#  u'social secur number multi',
#  u'mari tupl',
#  u'social secur number pair',
#  u'cse major',
#  u'absolut basic cube queri',
#  u'relat specif',
#  u'venn diagram format',
#  u'nice big queri',
#  u'equival sequenti order',
#  u'a1 dot cname',
#  u'standard construct',
#  u'clear constraint',
#  u'hudson author',
#  u'clean underli algebra',
#  u'berkeley stanford',
#  u'bookstor data',
#  u'book properti',
#  u'popular oper',
#  u'pad top',
#  u'impli function depend',
#  u'origin fact data',
#  u'row level modif',
#  u'pointer work',
#  u'start tabl',
#  u'pad bottom',
#  u'support view modif',
#  u'a1 a2 dot dot',
#  u'remaind boyc codd',
#  u'ap student relat',
#  u'cs gpa',
#  u'origin mega relat',
#  u'popular high level languag',
#  u'econom databas hint',
#  u'modif overview',
#  u'pre aggreg data',
#  u'sql wear condit',
#  u'nice error',
#  u'uniqu enrol',
#  u'pre aggreg',
#  u'invert bookstor',
#  u'combin relat',
#  u'similar parallel joke',
#  u'concurr control problem',
#  u'roll level trigger',
#  u'preced tupl',
#  u'postgr system',
#  u'toy applic code',
#  u'hub note',
#  u'larg social graph',
#  u'toy databas',
#  u'total salari class',
#  u'squar bracket a1',
#  u'hot queri',
#  u'demo queri',
#  u'bad relat design',
#  u'document databas system',
#  u'fourth tupl',
#  u'root tuppl',
#  u'rigid relat model',
#  u'match schema',
#  u'bad relat algebra',
#  u'uniqu student id',
#  u'nice queri',
#  u'claus product',
#  u'abbrevi rdbm',
#  u'larg scale data analys',
#  u'nest composit object',
#  u'nice languag',
#  u'recurs half',
#  u'larg onlin vendor',
#  u'sqlite system',
#  u'post grist system',
#  u'intuit trigger',
#  u'pre defin user',
#  u'role level trigger',
#  u'pre reduc phase',
#  u'larg realist databas',
#  u'store s3',
#  u'sqlite session',
#  u'demonstr simpl',
#  u'neg subqueri',
#  u'relat tip',
#  u'nest develop',
#  u'posari system',
#  u'costum id',
#  u'sqlite trigger',
#  u'rough approxim gpa',
#  u'postgr implement',
#  u'cube extens',
#  u'empti object',
#  u'author key',
#  u'complet student tabl',
#  u'demo postgr',
#  u'author standpoint',
#  u'databas v1',
#  u'tradit databas queri process',
#  u'nice underli algebra',
#  u'equival specif',
#  u'match book element',
#  u'hub start relat',
#  u'book titl element',
#  u'insert bob',
#  u'uniqu key constraint',
#  u'imaginari colleg admiss databas',
#  u'imaginari databas',
#  u'nest behavior',
#  u'match student id',
#  u'origin queri result',
#  u'tradit templat match style',
#  u'imaginari modif',
#  u'complex oper overload',
#  u'complet disjoint',
#  u'hub author',
#  u'queri find',
#  u'origin queri group',
#  u'equival serial order',
#  u'mass produc architectur',
#  u'cube tabl',
#  u'intersect express',
#  u'rollback command',
#  u'max gpa',
#  u'constraint featur',
#  u'recurs modifi',
#  u'predefin aggreg',
#  u'nice high level languag',
#  u'abbrevi bcnf',
#  u'intra tabl referenti integr',
#  u'complet subclass relationship',
#  u'book store data',
#  u'constraint check featur',
#  u'book store databas',
#  u'book store element',
#  u'match sid',
#  u'constraint enforc system',
#  u'express trigger system',
#  u'berkeley mit',
#  u'match close tag',
#  u'cube queri',
#  u'origin tuple1',
#  u'sql3 standard',
#  u'nice setup',
#  u'total total sale',
#  u'symant error',
#  u'abbrevi 4nf',
#  u'doc bookstor',
#  u'exist constraint',
#  u'sql2 standard',
#  u'nice theori',
#  u'tupl level insert',
#  u'match book',
#  u'implicit prioriti scheme',
#  u'subclass relationship',
#  u'databas base author',
#  u'data javascript object notat',
#  u'washington jacket',
#  u'queri tomorrow',
#  u'higher level design model',
#  u'view cs burk',
#  u'view cs berk',
#  u'higher level design tool',
#  u'select student id',
#  u'view cs accept',
#  u'web access record',
#  u'occurr constraint',
#  u'view creator',
#  u'student id tabl',
#  u'complic xslt program',
#  u'weaker consist guarante',
#  u'weaker isol level',
#  u'weakest guarante',
#  u'long bit',
#  u'select star version',
#  u'higher level databas design',
#  u'specif costum',
#  u'good constraint check system',
#  u'data kind',
#  u'addit joint condit',
#  u'fact tabl sort',
#  u'colleg pair',
#  u'event condit action rule',
#  u'event condit action role',
#  u'high level design model',
#  u'referenti integr point',
#  u'colleg applic inform databas',
#  u'data level modif',
#  u'attribut base constraint',
#  u'attribut base check constraint',
#  u'templat match rule',
#  u'colleg applic databas',
#  u'addit express power',
#  u'high gpa applic',
#  u'referenti integr system',
#  u'referenti integr talk',
#  u'databas author',
#  u'longer condit',
#  u'subel structur',
#  u'altern isol level',
#  u'determinist answer',
#  u'attribut price',
#  u'object kind',
#  u'select predic',
#  u'good schema design',
#  u'higher prioriti templat',
#  u'ambigu modif',
#  u'uml model video',
#  u'ambigu rule match',
#  u'weird queri',
#  u'colleg standford',
#  u'incomplet disjoint',
#  u'transact t9',
#  u'incomplet complet subclass relationship',
#  u'mysql today',
#  u'colleg stanford',
#  u'subqueri return',
#  u'ambigu warn',
#  u'john tupl',
#  u'basic aggreg function',
#  u'mysteri cmh',
#  u'includ transform',
#  u'parent tag',
#  u'parent tupl',
#  u'ambigu attribut refer',
#  u'databas construct',
#  u'peski attribut',
#  u'uml data model subset',
#  u'key ref',
#  u'select row',
#  u'webkit box shadow',
#  u'webkit transit delay',
#  u'webkit transit durat',
#  u'webkit transit properti',
#  u'logic implic symbol',
#  u'databas connoisseur',
#  u'webkit transit time function',
#  u'specif attributesonli',
#  u'weblog applic',
#  u'phantom tupl',
#  u'good queri processor',
#  u'student id match',
#  u'good relat design',
#  u'fact json schema',
#  u'uml languag',
#  u'increment mainten algorithm',
#  u'gener assert featur',
#  u'select gpa',
#  u'lower consist guarante',
#  u'composit relationship',
#  u'sequel languag',
#  u'sequal system',
#  u'basic sql languag',
#  u'bcnf composit',
#  u'bcnf decomposit',
#  u'californian male',
#  u'separ tupl',
#  u'bcnf decomposit algorithm',
#  u'gigant databas',
#  u'separ privileg privileg',
#  u'multiattribut foreign key constraint',
#  u'specif nosql solut',
#  u'gigant disk',
#  u'gigant queri',
#  u'basic select statement',
#  u'c1 natur',
#  u'attribut date',
#  u'gigant warehous',
#  u'result berkeley',
#  u'json demo',
#  u'gener insert',
#  u'view tupl',
#  u'aggreg view',
#  u'type sql queri',
#  u'batch data analysi applic',
#  u'exact delet',
#  u'exact sequenti order',
#  u'data scenario',
#  u'aggreg column',
#  u'basic syntact error',
#  u'json path languag',
#  u'json path',
#  u'aggreg attribut',
#  u'exact transit',
#  u'aggreg aggreg function',
#  u'serializ behavior',
#  u'gener mason',
#  u'k1 01',
#  u'gener virtual view',
#  u'k2 02',
#  u'sequenti serial orderof',
#  u'c2 object',
#  u'typic comput system',
#  u'multi set oper',
#  u'quantiti time price',
#  u'partial full effect',
#  u'key document pair',
#  u'favorit tradit notion',
#  u'begin end bracket',
#  u'gener class c1',
#  u'indispens companion',
#  u'basic nativ data model',
#  u'refer relat r1',
#  u'addit tupl',
#  u'addit trigger activ',
#  u'data mine type oper',
#  u'multi set model',
#  u'referenti integr constraint enforc',
#  u'tag html',
#  u'individu subclass relat',
#  u'multi attribut key',
#  u'multi attribut',
#  u'specif formal notion',
#  u'ms widom',
#  u'referenti integr constraint violat',
#  u'high level queri languag',
#  u'major equal cs',
#  u'favorit queri',
#  u'airlin seat reserv',
#  u'favorit oper',
#  u'comput closur',
#  u'view modif command',
#  u'put author',
#  u'multi set',
#  u'transit closur flavor',
#  u'bcnf violat',
#  u'queri workload',
#  u'transit case',
#  u'basic oper languag',
#  u'specif locat',
#  u'high school code',
#  u'burn modif',
#  u'key constraint violat',
#  u'event trigger event',
#  u'key declar',
#  u'data model subset',
#  u'typic middl ware',
#  u'favorit misspel',
#  u'data model portion',
#  u'descend descend',
#  u'fact graph databas',
#  u'friend edg',
#  u'extran text',
#  u'correct function depend',
#  u'transact guarente',
#  u'berk view',
#  u'constraint repair logic',
#  u'relat algebra queri languag',
#  u'correct json',
#  u'project list',
#  u'correct json file',
#  u'transact guarante',
#  u'close tag book titl',
#  u'border width',
#  u'recurs statement',
#  u'correct modif',
#  u'cycl lot',
#  u'relat algebra style',
#  u'open sourc databas system',
#  u'answer condit',
#  u'relat algebra tree',
#  u'r1 natur',
#  u'label column',
#  u'student dot sid',
#  u'databas privileg',
#  u'error rais command',
#  u'correct decomposit',
#  u'data base activ',
#  ...]

# %%
matches
# Out:
# OrderedDict([('01_01_Introduction.txt',
#               [u'applic',
#                u'databas administr',
#                u'databas',
#                u'data model',
#                u'databas design',
#                u'databas manag system',
#                u'middl ware',
#                u'user',
#                u'databas system',
#                u'data']),
#              ('02_01_The_Relational_Model.txt',
#               [u'relat model',
#                u'relat',
#                u'queri',
#                u'tabl',
#                u'key',
#                u'tupl',
#                u'null',
#                u'attribut']),
#              ('02_02_Querying_Relational_Databases.txt',
#               [u'specif queri',
#                u'relat databas',
#                u'queri',
#                u'relat',
#                u'queri languag',
#                u'sql',
#                u'relat algebra']),
#              ('03_01_Well_Formed_XML_Part_1.txt',
#               [u'open tag',
#                u'xml',
#                u'remark',
#                u'close tag',
#                u'relat model',
#                u'structur',
#                u'html',
#                u'attribut',
#                u'order',
#                u'schema']),
#              ('03_01_Well_Formed_XML_Part_2.txt',
#               [u'xml',
#                u'xml parser',
#                u'css',
#                u'xml document',
#                u'pars xml',
#                u'xsl']),
#              ('03_02_DTDs_IDs_and_IDREFs.txt',
#               [u'remark',
#                u'document type descriptor',
#                u'dtd',
#                u'valid',
#                u'xsd',
#                u'id',
#                u'id ref',
#                u'attribut']),
#              ('03_02_XML_Schema.txt',
#               [u'key',
#                u'dtd',
#                u'occurr constraint',
#                u'valid',
#                u'xsd',
#                u'xml schema']),
#              ('04_01_Introduction_to_JSON_Data_Part_1.txt',
#               [u'nosql system', u'object', u'array', u'relat model', u'json']),
#              ('04_01_Introduction_to_JSON_Data_Part_2.txt',
#               [u'xml',
#                u'json schema',
#                u'json',
#                u'valid',
#                u'xml schema',
#                u'schema']),
#              ('04_02_JSON_Demo.txt',
#               [u'json data',
#                u'string',
#                u'object',
#                u'properti',
#                u'integ',
#                u'json schema',
#                u'valid',
#                u'array',
#                u'syntact correct',
#                u'schema']),
#              ('05_01_Select_Project_Join_Part_1.txt',
#               [u'oper',
#                u'project oper',
#                u'queri',
#                u'relat algebra',
#                u'select oper',
#                u'sigma']),
#              ('05_01_Select_Project_Join_Part_2.txt',
#               [u'cross product', u'cartesian product']),
#              ('05_01_Select_Project_Join_Part_3.txt',
#               [u'cross product', u'natur join']),
#              ('05_01_Select_Project_Join_Part_4.txt',
#               [u'theta', u'theta join', u'theta join oper']),
#              ('05_02_Set_Operators_Renaming_Notation_Part_1.txt',
#               [u'set oper', u'intersect']),
#              ('05_02_Set_Operators_Renaming_Notation_Part_2.txt',
#               [u'renam oper']),
#              ('05_02_Set_Operators_Renaming_Notation_Part_3.txt',
#               [u'oper',
#                u'express tree',
#                u'relat algebra',
#                u'relat algebra express',
#                u'assign statement',
#                u'select condit',
#                u'natur join']),
#              ('06_01_Introduction_to_SQL.txt',
#               [u'data manipul', u'sql', u'select', u'select statement']),
#              ('06_02_Basic_SELECT_Statement.txt',
#               [u'queri', u'join', u'select', u'attribut']),
#              ('06_03_Table_Variables_and_Set_Operators.txt',
#               [u'intersect oper', u'tabl variabl']),
#              ('06_04_Subqueries_in_FROM_and_SELECT.txt',
#               [u'select claus', u'select']),
#              ('06_04_Subqueries_in_WHERE_Clause.txt', []),
#              ('06_05_Aggregation.txt',
#               [u'count',
#                u'group',
#                u'aggreg function',
#                u'aggreg',
#                u'select claus',
#                u'averag']),
#              ('06_06_NULL_Values.txt', [u'null']),
#              ('06_07_Data_Modification_Statements.txt', [u'insert', u'delet']),
#              ('06_08_The_JOIN_Family_of_Operators.txt',
#               [u'join', u'theta join', u'natur join', u'outer join']),
#              ('07_01_Functional_Dependencies_Part_5.txt',
#               [u'function depend']),
#              ('07_01_Relational_Design_Overview_Part_1.txt',
#               [u'design', u'anomali']),
#              ('07_01_Relational_Design_Overview_Part_2.txt',
#               [u'function depend']),
#              ('07_01_Relational_Design_Overview_Part_3.txt', []),
#              ('07_01_Relational_Design_Overview_Part_4.txt', []),
#              ('07_02_Functional_Dependencies_Part_1.txt',
#               [u'function depend']),
#              ('07_02_Functional_Dependencies_Part_2.txt',
#               [u'function depend']),
#              ('07_02_Functional_Dependencies_Part_3.txt',
#               [u'split rule',
#                u'closur',
#                u'trivial',
#                u'function depend',
#                u'key']),
#              ('07_02_Functional_Dependencies_Part_4.txt',
#               [u'function depend']),
#              ('07_03_Boyce_Codd_Normal_Form_Part_1.txt',
#               [u'function depend', u'key', u'decomposit']),
#              ('07_03_Boyce_Codd_Normal_Form_Part_2.txt',
#               [u'function depend', u'decomposit']),
#              ('07_03_Boyce_Codd_Normal_Form_Part_3.txt',
#               [u'bcnf', u'function depend', u'decompos']),
#              ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_1.txt',
#               [u'function depend']),
#              ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_2.txt',
#               [u'multivalu depend']),
#              ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_3.txt',
#               [u'left hand side',
#                u'function depend',
#                u'rule',
#                u'multivalu depend']),
#              ('07_04_Multivalued_Dependencies_and_4th_Normal_Form_Part_4.txt',
#               [u'design process', u'depend']),
#              ('07_05_Shortcomings_of_BCNF_and_4NF.txt',
#               [u'left hand side', u'function depend']),
#              ('08_01_XPath_Introduction.txt',
#               [u'function',
#                u'xml',
#                u'xpath',
#                u'xslt',
#                u'path express',
#                u'tree',
#                u'descend',
#                u'slash',
#                u'squar bracket',
#                u'condit',
#                u'axi']),
#              ('08_02_XPath_Demo.txt',
#               [u'xpath',
#                u'navig',
#                u'path express',
#                u'queri',
#                u'slash',
#                u'condit',
#                u'squar bracket']),
#              ('08_03_XQuery_Introduction.txt',
#               [u'xpath',
#                u'xqueri',
#                u'curli brace',
#                u'flwor',
#                u'express languag',
#                u'queri',
#                u'flwor express']),
#              ('08_04_XQuery_Demo.txt',
#               [u'queri', u'xqueri', u'xqueri languag', u'return claus']),
#              ('08_05_XSLT.txt',
#               [u'xpath',
#                u'templat match',
#                u'xslt',
#                u'replac',
#                u'tree',
#                u'transform',
#                u'templat',
#                u'xslt specif']),
#              ('09_01_UML_Data_Modeling.txt',
#               [u'primari key',
#                u'multipl',
#                u'complet relationship',
#                u'higher level model',
#                u'data model',
#                u'databas design',
#                u'super class',
#                u'uml',
#                u'composit',
#                u'star',
#                u'class']),
#              ('09_02_UML_to_Relations_Part_1.txt',
#               [u'relat', u'translat', u'key', u'class']),
#              ('09_02_UML_to_Relations_Part_2.txt',
#               [u'automat translat',
#                u'relat',
#                u'super class',
#                u'translat',
#                u'key',
#                u'attribut']),
#              ('09_02_UML_to_Relations_Part_3.txt', [u'composit', u'translat']),
#              ('10_01_Indexes_Part_1.txt',
#               [u'condit', u'hash tabl', u'balanc tree', u'index']),
#              ('10_01_Indexes_Part_2.txt', [u'index', u'design advisor']),
#              ('11_01_Introduction_to_Transactions.txt', [u'transact']),
#              ('11_02_Transactions_Properties_Part_1.txt',
#               [u'transact', u'isol']),
#              ('11_02_Transactions_Properties_Part_2.txt', [u'transact']),
#              ('11_02_Transactions_Properties_Part_3.txt',
#               [u'transact', u'rollback']),
#              ('11_03_Isolation_Levels_Part_1.txt',
#               [u'isol level',
#                u'transact',
#                u'serializ',
#                u'dirti read',
#                u'isol']),
#              ('11_03_Isolation_Levels_Part_2.txt', [u'isol level']),
#              ('11_03_Isolation_Levels_Part_3.txt', [u'repeat read']),
#              ('11_03_Isolation_Levels_Part_4.txt',
#               [u'isol level', u'transact', u'repeat read']),
#              ('12_01_Motivation_and_Overview.txt',
#               [u'tupl base constraint',
#                u'constraint',
#                u'trigger',
#                u'constraint system',
#                u'key constraint',
#                u'integr constraint']),
#              ('12_02_Constraints_of_Several_Types_Part_1.txt',
#               [u'key constraint',
#                u'tupl base constraint',
#                u'assert',
#                u'check constraint',
#                u'constraint']),
#              ('12_02_Constraints_of_Several_Types_Part_2.txt', []),
#              ('12_03_Referential_Integrity_Part_1.txt', [u'referenti integr']),
#              ('12_03_Referential_Integrity_Part_2.txt', [u'foreign key']),
#              ('12_03_Referential_Integrity_Part_3.txt',
#               [u'referenti integr constraint', u'referenti integr']),
#              ('12_04_Triggers_Introduction.txt',
#               [u'statement level', u'trigger']),
#              ('12_05_Triggers_Demo_Part_1.txt',
#               [u'delet', u'insert command', u'trigger', u'insert']),
#              ('12_05_Triggers_Demo_Part_2.txt', []),
#              ('13_01_Defining_and_Using_Views.txt',
#               [u'temporari tabl', u'view']),
#              ('13_02_View_Modifications_Introduction_Part_1.txt',
#               [u'base tabl', u'modif', u'modif command']),
#              ('13_02_View_Modifications_Introduction_Part_2.txt', []),
#              ('13_03_View_Modifications_Using_Triggers.txt',
#               [u'insert', u'trigger']),
#              ('13_04_Automatic_View_Modifications.txt',
#               [u'insert',
#                u'check option',
#                u'updat view',
#                u'delet',
#                u'modif',
#                u'modif command',
#                u'updat']),
#              ('13_05_Materialized_Views_Part_1.txt',
#               [u'virtual view', u'queri', u'materi view']),
#              ('13_05_Materialized_Views_Part_2.txt',
#               [u'view queri', u'modif', u'materi view', u'queri']),
#              ('13_05_Materialized_Views_Part_3.txt', []),
#              ('14_01_Authorization_Part_1.txt', [u'privileg']),
#              ('14_01_Authorization_Part_2.txt', [u'privileg', u'view']),
#              ('14_01_Authorization_Part_3.txt',
#               [u'revok', u'privileg', u'revok privileg', u'cascad']),
#              ('14_01_Authorization_Part_4.txt', []),
#              ('15_01_Basic_Recursive_WITH_Statement_Introduction.txt',
#               [u'queri', u'recurs', u'unbound comput', u'recurs queri']),
#              ('15_02_Basic_Recursive_WITH_Statement_Demo.txt',
#               [u'recurs', u'superior', u'root', u'recurs queri']),
#              ('15_03_Nonlinear_and_Mutual_Recursion_Part_1.txt',
#               [u'recurs', u'linear recurs']),
#              ('15_03_Nonlinear_and_Mutual_Recursion_Part_2.txt',
#               [u'mutual recurs', u'recurs', u'hub', u'author']),
#              ('16_01_Introduction_to_OLAP_Part_1.txt',
#               [u'olap', u'star schema', u'cube', u'olap queri', u'aggreg']),
#              ('16_01_Introduction_to_OLAP_Part_2.txt',
#               [u'olap', u'cube', u'rollup', u'dimens attribut']),
#              ('16_02_OLAP_Demo.txt',
#               [u'cube', u'slice', u'aggreg', u'data cube']),
#              ('17_01_NoSQLMotivation.txt',
#               [u'nosql system', u'nosql', u'tradit relat databas system']),
#              ('17_01_NoSQLOverview.txt',
#               [u'reduc',
#                u'mapper',
#                u'document store',
#                u'mapreduc',
#                u'graph databas system',
#                u'map',
#                u'reduc function',
#                u'writer function',
#                u'hadoop',
#                u'hive',
#                u'pig',
#                u'user',
#                u'key',
#                u'nosql system',
#                u'map function',
#                u'mapreduc framework'])])

# %%
reverse(extracted[''])
