# %%
import nltk
import os
    
from collections import defaultdict

import numpy as np

# %%
# Stem all the keywords 
stemmer = nltk.PorterStemmer()
# Collect all n-grams that raters extract.
# We count a phrase if it is a 1-gram or it is a n-gram and any rater tagged it
ngrams = defaultdict(set)
# Each rater is a dict (filename, phrase) => ranking. 
# Ranking is 0 if it is not in the top-5.
raters = []

for name in os.listdir('../../../data/keywords/'):
    with open('../../../data/keywords/' + name) as f:
        rater = {}
        for line in f:
            file, term, _, rank = line.strip().split(',')
            rank = int(rank)
            tokens = term.lower().split(' ')
            stemmed = ' '.join(stemmer.stem(token) for token in tokens)
            rater[file, stemmed] = rank
            
            if len(tokens) > 1:
                ngrams[file].add(stemmed)
                
        raters.append(rater)
            
all_keys = set()

for name in os.listdir('../../../data/Introduction_to_Databases_Captions'):
    with open('../../../data/Introduction_to_Databases_Captions/' + name) as f:
        # Open up each transcript file and stem it.
        lines = []
        for line in f:
            line = line.strip('.| \n')

            stemmed = ' '.join([stemmer.stem(token) for token in line.split(' ')])
            lines.append(stemmed)
        document = ' '.join(lines)
        document = document.lower()
        
        # Remove all n-grams from the document and add them as keys.
        for ngram in ngrams[name]:
            document = document.replace(ngram, '')
            all_keys.add((name, ngram))
            
        # Add all the remaining 1-grams as keys.
        for token in document.split(' '):
            all_keys.add((name, token))

data = []
# Data is a list with tuples (rater num, (file, phrase), category)
for key in all_keys:
    for i, rater in enumerate(raters):
        if key in rater:
            data.append((i, key, 'keyword'))
        else:
            data.append((i, key, 'not keyword'))
        
# Filter the dataset to files that all raters have tagged.
intersection_files = reduce(
    lambda x, y: set(x).intersection(y),
    [set(zip(*rater.keys())[0]) for rater in raters]
)

data = [item for item in data if item[1][0] in intersection_files]

# %%
data
# Out:
# [(0, ('06_06_NULL_Values.txt', u'someth'), 'not keyword'),
#  (1, ('06_06_NULL_Values.txt', u'someth'), 'not keyword'),
#  (0, ('06_07_Data_Modification_Statements.txt', u'id'), 'not keyword'),
#  (1, ('06_07_Data_Modification_Statements.txt', u'id'), 'not keyword'),
#  (0, ('04_02_JSON_Demo.txt', u'parallel'), 'not keyword'),
#  (1, ('04_02_JSON_Demo.txt', u'parallel'), 'not keyword'),
#  (0, ('04_02_JSON_Demo.txt', u'taken'), 'not keyword'),
#  (1, ('04_02_JSON_Demo.txt', u'taken'), 'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_3.txt', u'automat'), 'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_3.txt', u'automat'), 'not keyword'),
#  (0, ('06_08_The_JOIN_Family_of_Operators.txt', u'e,'), 'not keyword'),
#  (1, ('06_08_The_JOIN_Family_of_Operators.txt', u'e,'), 'not keyword'),
#  (0, ('06_06_NULL_Values.txt', u'logic'), 'not keyword'),
#  (1, ('06_06_NULL_Values.txt', u'logic'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', u'abbrevi'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', u'abbrevi'),
#   'not keyword'),
#  (0, ('06_04_Subqueries_in_WHERE_Clause.txt', u'with'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_WHERE_Clause.txt', u'with'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u"we'r"),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u"we'r"),
#   'not keyword'),
#  (0,
#   ('04_01_Introduction_to_JSON_Data_Part_2.txt', u'mismatch'),
#   'not keyword'),
#  (1,
#   ('04_01_Introduction_to_JSON_Data_Part_2.txt', u'mismatch'),
#   'not keyword'),
#  (0, ('02_01_The_Relational_Model.txt', u'develop'), 'not keyword'),
#  (1, ('02_01_The_Relational_Model.txt', u'develop'), 'not keyword'),
#  (0, ('06_05_Aggregation.txt', u'filter'), 'not keyword'),
#  (1, ('06_05_Aggregation.txt', u'filter'), 'not keyword'),
#  (0, ('02_02_Querying_Relational_Databases.txt', u'and'), 'not keyword'),
#  (1, ('02_02_Querying_Relational_Databases.txt', u'and'), 'not keyword'),
#  (0, ('06_05_Aggregation.txt', u'addit'), 'not keyword'),
#  (1, ('06_05_Aggregation.txt', u'addit'), 'not keyword'),
#  (0, ('06_02_Basic_SELECT_Statement.txt', u'are'), 'not keyword'),
#  (1, ('06_02_Basic_SELECT_Statement.txt', u'are'), 'not keyword'),
#  (0, ('06_04_Subqueries_in_WHERE_Clause.txt', u'from'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_WHERE_Clause.txt', u'from'), 'not keyword'),
#  (0, ('03_02_XML_Schema.txt', u'price'), 'not keyword'),
#  (1, ('03_02_XML_Schema.txt', u'price'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u'essenti'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u'essenti'),
#   'not keyword'),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', u'chang'), 'not keyword'),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', u'chang'), 'not keyword'),
#  (0, ('06_03_Table_Variables_and_Set_Operators.txt', u'chose'), 'not keyword'),
#  (1, ('06_03_Table_Variables_and_Set_Operators.txt', u'chose'), 'not keyword'),
#  (0, ('06_06_NULL_Values.txt', u'simpl'), 'not keyword'),
#  (1, ('06_06_NULL_Values.txt', u'simpl'), 'not keyword'),
#  (0, ('06_02_Basic_SELECT_Statement.txt', u'again,'), 'not keyword'),
#  (1, ('06_02_Basic_SELECT_Statement.txt', u'again,'), 'not keyword'),
#  (0, ('03_02_XML_Schema.txt', u'itself'), 'not keyword'),
#  (1, ('03_02_XML_Schema.txt', u'itself'), 'not keyword'),
#  (0, ('03_02_XML_Schema.txt', u'confirm'), 'not keyword'),
#  (1, ('03_02_XML_Schema.txt', u'confirm'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u'okay?'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u'okay?'),
#   'not keyword'),
#  (0, ('06_05_Aggregation.txt', u'total'), 'not keyword'),
#  (1, ('06_05_Aggregation.txt', u'total'), 'not keyword'),
#  (0, ('06_02_Basic_SELECT_Statement.txt', u'execute,'), 'not keyword'),
#  (1, ('06_02_Basic_SELECT_Statement.txt', u'execute,'), 'not keyword'),
#  (0, ('06_05_Aggregation.txt', u'column'), 'not keyword'),
#  (1, ('06_05_Aggregation.txt', u'column'), 'not keyword'),
#  (0, ('06_04_Subqueries_in_WHERE_Clause.txt', u'cs'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_WHERE_Clause.txt', u'cs'), 'not keyword'),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', u'demo'), 'not keyword'),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', u'demo'), 'not keyword'),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', u'add'), 'not keyword'),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', u'add'), 'not keyword'),
#  (0, ('03_02_XML_Schema.txt', u'too'), 'not keyword'),
#  (1, ('03_02_XML_Schema.txt', u'too'), 'not keyword'),
#  (0, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'might'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'might'), 'not keyword'),
#  (0, ('06_04_Subqueries_in_WHERE_Clause.txt', u'us'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_WHERE_Clause.txt', u'us'), 'not keyword'),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', u"author'"), 'not keyword'),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', u"author'"), 'not keyword'),
#  (0, ('06_03_Table_Variables_and_Set_Operators.txt', u'into'), 'not keyword'),
#  (1, ('06_03_Table_Variables_and_Set_Operators.txt', u'into'), 'not keyword'),
#  (0, ('04_02_JSON_Demo.txt', u'defin'), 'not keyword'),
#  (1, ('04_02_JSON_Demo.txt', u'defin'), 'not keyword'),
#  (0, ('02_01_The_Relational_Model.txt', u'consist'), 'not keyword'),
#  (1, ('02_01_The_Relational_Model.txt', u'consist'), 'not keyword'),
#  (0, ('03_02_XML_Schema.txt', u'me'), 'not keyword'),
#  (1, ('03_02_XML_Schema.txt', u'me'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', u'ha'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', u'ha'),
#   'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_1.txt', u"don't"), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_1.txt', u"don't"), 'not keyword'),
#  (0, ('06_04_Subqueries_in_WHERE_Clause.txt', u'high'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_WHERE_Clause.txt', u'high'), 'not keyword'),
#  (0, ('02_02_Querying_Relational_Databases.txt', u'call'), 'not keyword'),
#  (1, ('02_02_Querying_Relational_Databases.txt', u'call'), 'not keyword'),
#  (0, ('06_02_Basic_SELECT_Statement.txt', u'further'), 'not keyword'),
#  (1, ('06_02_Basic_SELECT_Statement.txt', u'further'), 'not keyword'),
#  (0, ('06_02_Basic_SELECT_Statement.txt', u'without'), 'not keyword'),
#  (1, ('06_02_Basic_SELECT_Statement.txt', u'without'), 'not keyword'),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', u'separately,'), 'not keyword'),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', u'separately,'), 'not keyword'),
#  (0, ('04_02_JSON_Demo.txt', u'words,'), 'not keyword'),
#  (1, ('04_02_JSON_Demo.txt', u'words,'), 'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_2.txt', u'mani'), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_2.txt', u'mani'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', u'think'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', u'think'),
#   'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', u'complic'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', u'complic'),
#   'not keyword'),
#  (0, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'everyth'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'everyth'), 'not keyword'),
#  (0, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'ambigu'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'ambigu'), 'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_3.txt', u'gpa'), 'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_3.txt', u'gpa'), 'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_2.txt', u'videos,'), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_2.txt', u'videos,'), 'not keyword'),
#  (0, ('06_01_Introduction_to_SQL.txt', u'say'), 'not keyword'),
#  (1, ('06_01_Introduction_to_SQL.txt', u'say'), 'not keyword'),
#  (0,
#   ('06_03_Table_Variables_and_Set_Operators.txt', u'sorted,'),
#   'not keyword'),
#  (1,
#   ('06_03_Table_Variables_and_Set_Operators.txt', u'sorted,'),
#   'not keyword'),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'other'), 'not keyword'),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'other'), 'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_2.txt', u'within'), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_2.txt', u'within'), 'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_1.txt', u'entir'), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_1.txt', u'entir'), 'not keyword'),
#  (0, ('06_05_Aggregation.txt', u'variabl'), 'not keyword'),
#  (1, ('06_05_Aggregation.txt', u'variabl'), 'not keyword'),
#  (0, ('06_01_Introduction_to_SQL.txt', u'current'), 'not keyword'),
#  (1, ('06_01_Introduction_to_SQL.txt', u'current'), 'not keyword'),
#  (0,
#   ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'instead'),
#   'not keyword'),
#  (1,
#   ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'instead'),
#   'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_2.txt', u'out'), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_2.txt', u'out'), 'not keyword'),
#  (0, ('06_08_The_JOIN_Family_of_Operators.txt', u'you'), 'not keyword'),
#  (1, ('06_08_The_JOIN_Family_of_Operators.txt', u'you'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', u'cross-product'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', u'cross-product'),
#   'not keyword'),
#  (0, ('06_05_Aggregation.txt', u'id'), 'not keyword'),
#  (1, ('06_05_Aggregation.txt', u'id'), 'not keyword'),
#  (0, ('06_01_Introduction_to_SQL.txt', u'how'), 'not keyword'),
#  (1, ('06_01_Introduction_to_SQL.txt', u'how'), 'not keyword'),
#  (0,
#   ('04_01_Introduction_to_JSON_Data_Part_2.txt', u'summarize,'),
#   'not keyword'),
#  (1,
#   ('04_01_Introduction_to_JSON_Data_Part_2.txt', u'summarize,'),
#   'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_1.txt', u'for'), 'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_1.txt', u'for'), 'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_2.txt', u"it'"), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_2.txt', u"it'"), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', u'two'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', u'two'),
#   'not keyword'),
#  (0, ('06_03_Table_Variables_and_Set_Operators.txt', u'sort'), 'not keyword'),
#  (1, ('06_03_Table_Variables_and_Set_Operators.txt', u'sort'), 'not keyword'),
#  (0, ('06_07_Data_Modification_Statements.txt', u'on,'), 'not keyword'),
#  (1, ('06_07_Data_Modification_Statements.txt', u'on,'), 'not keyword'),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_2.txt', u'call'), 'not keyword'),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_2.txt', u'call'), 'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_2.txt', u'pattern'), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_2.txt', u'pattern'), 'not keyword'),
#  (0, ('02_02_Querying_Relational_Databases.txt', u'thing'), 'not keyword'),
#  (1, ('02_02_Querying_Relational_Databases.txt', u'thing'), 'not keyword'),
#  (0, ('03_02_XML_Schema.txt', u'global'), 'not keyword'),
#  (1, ('03_02_XML_Schema.txt', u'global'), 'not keyword'),
#  (0, ('03_02_XML_Schema.txt', u'xml schema descriptor'), 'keyword'),
#  (1, ('03_02_XML_Schema.txt', u'xml schema descriptor'), 'keyword'),
#  (0, ('03_02_XML_Schema.txt', u"i'm"), 'not keyword'),
#  (1, ('03_02_XML_Schema.txt', u"i'm"), 'not keyword'),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', u'proper'), 'not keyword'),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', u'proper'), 'not keyword'),
#  (0, ('04_02_JSON_Demo.txt', u'could'), 'not keyword'),
#  (1, ('04_02_JSON_Demo.txt', u'could'), 'not keyword'),
#  (0, ('06_04_Subqueries_in_WHERE_Clause.txt', u'college,'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_WHERE_Clause.txt', u'college,'), 'not keyword'),
#  (0,
#   ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'duplicates,'),
#   'not keyword'),
#  (1,
#   ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'duplicates,'),
#   'not keyword'),
#  (0, ('06_06_NULL_Values.txt', u'should'), 'not keyword'),
#  (1, ('06_06_NULL_Values.txt', u'should'), 'not keyword'),
#  (0, ('03_02_XML_Schema.txt', u'defin'), 'not keyword'),
#  (1, ('03_02_XML_Schema.txt', u'defin'), 'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_2.txt', u'major'), 'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_2.txt', u'major'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', u'top'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', u'top'),
#   'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', u"i'll"),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', u"i'll"),
#   'not keyword'),
#  (0, ('02_02_Querying_Relational_Databases.txt', u'anoth'), 'not keyword'),
#  (1, ('02_02_Querying_Relational_Databases.txt', u'anoth'), 'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_1.txt', u'may'), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_1.txt', u'may'), 'not keyword'),
#  (0, ('06_01_Introduction_to_SQL.txt', u'standard languag'), 'not keyword'),
#  (1, ('06_01_Introduction_to_SQL.txt', u'standard languag'), 'keyword'),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', u'taken'), 'not keyword'),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', u'taken'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', u'saw'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', u'saw'),
#   'not keyword'),
#  (0, ('06_04_Subqueries_in_WHERE_Clause.txt', u'type,'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_WHERE_Clause.txt', u'type,'), 'not keyword'),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', u'get'), 'not keyword'),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', u'get'), 'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_1.txt', u'size'), 'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_1.txt', u'size'), 'not keyword'),
#  (0, ('02_01_The_Relational_Model.txt', u'whop'), 'not keyword'),
#  (1, ('02_01_The_Relational_Model.txt', u'whop'), 'not keyword'),
#  (0, ('04_02_JSON_Demo.txt', u'mean'), 'not keyword'),
#  (1, ('04_02_JSON_Demo.txt', u'mean'), 'not keyword'),
#  (0, ('06_04_Subqueries_in_WHERE_Clause.txt', u'tabl'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_WHERE_Clause.txt', u'tabl'), 'not keyword'),
#  (0,
#   ('05_01_Select_Project_Join_Part_2.txt', u'cross-product oper'),
#   'not keyword'),
#  (1,
#   ('05_01_Select_Project_Join_Part_2.txt', u'cross-product oper'),
#   'keyword'),
#  (0, ('06_02_Basic_SELECT_Statement.txt', u'gpa'), 'not keyword'),
#  (1, ('06_02_Basic_SELECT_Statement.txt', u'gpa'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', u'learn'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', u'learn'),
#   'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_1.txt', u'next'), 'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_1.txt', u'next'), 'not keyword'),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', u'space'), 'not keyword'),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', u'space'), 'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_2.txt', u'schema'), 'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_2.txt', u'schema'), 'not keyword'),
#  (0, ('06_03_Table_Variables_and_Set_Operators.txt', u'word'), 'not keyword'),
#  (1, ('06_03_Table_Variables_and_Set_Operators.txt', u'word'), 'not keyword'),
#  (0, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'time'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'time'), 'not keyword'),
#  (0, ('06_05_Aggregation.txt', u'multipl'), 'not keyword'),
#  (1, ('06_05_Aggregation.txt', u'multipl'), 'not keyword'),
#  (0, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'come'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'come'), 'not keyword'),
#  (0,
#   ('05_01_Select_Project_Join_Part_3.txt', u'cross product'),
#   'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_3.txt', u'cross product'), 'keyword'),
#  (0, ('06_08_The_JOIN_Family_of_Operators.txt', u'satisfi'), 'not keyword'),
#  (1, ('06_08_The_JOIN_Family_of_Operators.txt', u'satisfi'), 'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_1.txt', u'leaf'), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_1.txt', u'leaf'), 'not keyword'),
#  (0,
#   ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'advantag'),
#   'not keyword'),
#  (1,
#   ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'advantag'),
#   'not keyword'),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', u'twice'), 'not keyword'),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', u'twice'), 'not keyword'),
#  (0, ('06_04_Subqueries_in_WHERE_Clause.txt', u'against'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_WHERE_Clause.txt', u'against'), 'not keyword'),
#  (0, ('06_05_Aggregation.txt', u'person'), 'not keyword'),
#  (1, ('06_05_Aggregation.txt', u'person'), 'not keyword'),
#  (0, ('06_07_Data_Modification_Statements.txt', u'high'), 'not keyword'),
#  (1, ('06_07_Data_Modification_Statements.txt', u'high'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', u'same'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', u'same'),
#   'not keyword'),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'json,'), 'not keyword'),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'json,'), 'not keyword'),
#  (0, ('03_02_XML_Schema.txt', u'ju,'), 'not keyword'),
#  (1, ('03_02_XML_Schema.txt', u'ju,'), 'not keyword'),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'watch'), 'not keyword'),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'watch'), 'not keyword'),
#  (0, ('06_05_Aggregation.txt', u'people,'), 'not keyword'),
#  (1, ('06_05_Aggregation.txt', u'people,'), 'not keyword'),
#  (0, ('04_02_JSON_Demo.txt', u'perfectli'), 'not keyword'),
#  (1, ('04_02_JSON_Demo.txt', u'perfectli'), 'not keyword'),
#  (0, ('06_02_Basic_SELECT_Statement.txt', u'data'), 'not keyword'),
#  (1, ('06_02_Basic_SELECT_Statement.txt', u'data'), 'not keyword'),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'cours'), 'not keyword'),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'cours'), 'not keyword'),
#  (0, ('06_05_Aggregation.txt', u"who'v"), 'not keyword'),
#  (1, ('06_05_Aggregation.txt', u"who'v"), 'not keyword'),
#  (0, ('06_08_The_JOIN_Family_of_Operators.txt', u'time'), 'not keyword'),
#  (1, ('06_08_The_JOIN_Family_of_Operators.txt', u'time'), 'not keyword'),
#  (0, ('06_06_NULL_Values.txt', u'alway'), 'not keyword'),
#  (1, ('06_06_NULL_Values.txt', u'alway'), 'not keyword'),
#  (0, ('03_02_XML_Schema.txt', u'complicated,'), 'not keyword'),
#  (1, ('03_02_XML_Schema.txt', u'complicated,'), 'not keyword'),
#  (0, ('06_04_Subqueries_in_WHERE_Clause.txt', u'out'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_WHERE_Clause.txt', u'out'), 'not keyword'),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_2.txt', u'think'), 'not keyword'),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_2.txt', u'think'), 'not keyword'),
#  (0,
#   ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'furthermore,'),
#   'not keyword'),
#  (1,
#   ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'furthermore,'),
#   'not keyword'),
#  (0, ('02_02_Querying_Relational_Databases.txt', u'rid'), 'not keyword'),
#  (1, ('02_02_Querying_Relational_Databases.txt', u'rid'), 'not keyword'),
#  (0, ('04_02_JSON_Demo.txt', u'part'), 'not keyword'),
#  (1, ('04_02_JSON_Demo.txt', u'part'), 'not keyword'),
#  (0, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'treat'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'treat'), 'not keyword'),
#  (0, ('06_07_Data_Modification_Statements.txt', u'right-hand'), 'not keyword'),
#  (1, ('06_07_Data_Modification_Statements.txt', u'right-hand'), 'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_2.txt', u'actual'), 'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_2.txt', u'actual'), 'not keyword'),
#  (0, ('06_04_Subqueries_in_WHERE_Clause.txt', u'now,'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_WHERE_Clause.txt', u'now,'), 'not keyword'),
#  (0, ('04_02_JSON_Demo.txt', u'exampl'), 'not keyword'),
#  (1, ('04_02_JSON_Demo.txt', u'exampl'), 'not keyword'),
#  (0, ('02_02_Querying_Relational_Databases.txt', u'what'), 'not keyword'),
#  (1, ('02_02_Querying_Relational_Databases.txt', u'what'), 'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_3.txt', u'alway'), 'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_3.txt', u'alway'), 'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_2.txt', u'that'), 'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_2.txt', u'that'), 'not keyword'),
#  (0, ('03_02_XML_Schema.txt', u'prohibit'), 'not keyword'),
#  (1, ('03_02_XML_Schema.txt', u'prohibit'), 'not keyword'),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', u'if'), 'not keyword'),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', u'if'), 'not keyword'),
#  (0, ('06_01_Introduction_to_SQL.txt', u'just'), 'not keyword'),
#  (1, ('06_01_Introduction_to_SQL.txt', u'just'), 'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_2.txt', u'with'), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_2.txt', u'with'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u'realli'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u'realli'),
#   'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_1.txt', u'to'), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_1.txt', u'to'), 'not keyword'),
#  (0, ('06_06_NULL_Values.txt', u'thi'), 'not keyword'),
#  (1, ('06_06_NULL_Values.txt', u'thi'), 'not keyword'),
#  (0, ('02_01_The_Relational_Model.txt', u'pointer'), 'not keyword'),
#  (1, ('02_01_The_Relational_Model.txt', u'pointer'), 'not keyword'),
#  (0, ('06_01_Introduction_to_SQL.txt', u'triggers,'), 'not keyword'),
#  (1, ('06_01_Introduction_to_SQL.txt', u'triggers,'), 'not keyword'),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', u'alway'), 'not keyword'),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', u'alway'), 'not keyword'),
#  (0, ('06_07_Data_Modification_Statements.txt', u'got'), 'not keyword'),
#  (1, ('06_07_Data_Modification_Statements.txt', u'got'), 'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_1.txt', u'certain'), 'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_1.txt', u'certain'), 'not keyword'),
#  (0, ('06_05_Aggregation.txt', u'favorit'), 'not keyword'),
#  (1, ('06_05_Aggregation.txt', u'favorit'), 'not keyword'),
#  (0, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'appli'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'appli'), 'not keyword'),
#  (0, ('06_06_NULL_Values.txt', u'find'), 'not keyword'),
#  (1, ('06_06_NULL_Values.txt', u'find'), 'not keyword'),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_2.txt', u'next'), 'not keyword'),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_2.txt', u'next'), 'not keyword'),
#  (0, ('06_01_Introduction_to_SQL.txt', u'drop'), 'not keyword'),
#  (1, ('06_01_Introduction_to_SQL.txt', u'drop'), 'not keyword'),
#  (0, ('06_01_Introduction_to_SQL.txt', u'or'), 'not keyword'),
#  (1, ('06_01_Introduction_to_SQL.txt', u'or'), 'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_1.txt', u'select oper'), 'keyword'),
#  (1, ('05_01_Select_Project_Join_Part_1.txt', u'select oper'), 'keyword'),
#  (0,
#   ('06_03_Table_Variables_and_Set_Operators.txt', u'elimin'),
#   'not keyword'),
#  (1,
#   ('06_03_Table_Variables_and_Set_Operators.txt', u'elimin'),
#   'not keyword'),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', u'messy,'), 'not keyword'),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', u'messy,'), 'not keyword'),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', u'sinc'), 'not keyword'),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', u'sinc'), 'not keyword'),
#  (0, ('02_02_Querying_Relational_Databases.txt', u'user'), 'not keyword'),
#  (1, ('02_02_Querying_Relational_Databases.txt', u'user'), 'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_1.txt', u"there'"), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_1.txt', u"there'"), 'not keyword'),
#  (0, ('06_06_NULL_Values.txt', u'exampl'), 'not keyword'),
#  (1, ('06_06_NULL_Values.txt', u'exampl'), 'not keyword'),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', u'them'), 'not keyword'),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', u'them'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', u'then'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', u'then'),
#   'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_1.txt', u'through'), 'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_1.txt', u'through'), 'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_1.txt', u'with'), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_1.txt', u'with'), 'not keyword'),
#  (0, ('06_08_The_JOIN_Family_of_Operators.txt', u'special'), 'not keyword'),
#  (1, ('06_08_The_JOIN_Family_of_Operators.txt', u'special'), 'not keyword'),
#  (0, ('02_01_The_Relational_Model.txt', u'confid'), 'not keyword'),
#  (1, ('02_01_The_Relational_Model.txt', u'confid'), 'not keyword'),
#  (0, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'includ'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'includ'), 'not keyword'),
#  (0, ('04_02_JSON_Demo.txt', u'hundred,'), 'not keyword'),
#  (1, ('04_02_JSON_Demo.txt', u'hundred,'), 'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_1.txt', u'allow'), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_1.txt', u'allow'), 'not keyword'),
#  (0, ('04_02_JSON_Demo.txt', u'context'), 'not keyword'),
#  (1, ('04_02_JSON_Demo.txt', u'context'), 'not keyword'),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'some'), 'not keyword'),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'some'), 'not keyword'),
#  (0, ('06_04_Subqueries_in_WHERE_Clause.txt', u'slightli'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_WHERE_Clause.txt', u'slightli'), 'not keyword'),
#  (0, ('04_02_JSON_Demo.txt', u'json schema'), 'keyword'),
#  (1, ('04_02_JSON_Demo.txt', u'json schema'), 'keyword'),
#  (0, ('03_02_XML_Schema.txt', u'data file'), 'not keyword'),
#  (1, ('03_02_XML_Schema.txt', u'data file'), 'keyword'),
#  (0, ('06_04_Subqueries_in_WHERE_Clause.txt', u'sid,'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_WHERE_Clause.txt', u'sid,'), 'not keyword'),
#  (0, ('04_02_JSON_Demo.txt', u'pretti'), 'not keyword'),
#  (1, ('04_02_JSON_Demo.txt', u'pretti'), 'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_2.txt', u's-tupl'), 'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_2.txt', u's-tupl'), 'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_2.txt', u'size'), 'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_2.txt', u'size'), 'not keyword'),
#  (0, ('02_01_The_Relational_Model.txt', u'construct'), 'not keyword'),
#  (1, ('02_01_The_Relational_Model.txt', u'construct'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', u'all'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', u'all'),
#   'not keyword'),
#  (0, ('06_05_Aggregation.txt', u'here'), 'not keyword'),
#  (1, ('06_05_Aggregation.txt', u'here'), 'not keyword'),
#  (0,
#   ('06_03_Table_Variables_and_Set_Operators.txt', u"doesn't"),
#   'not keyword'),
#  (1,
#   ('06_03_Table_Variables_and_Set_Operators.txt', u"doesn't"),
#   'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u'renam oper'),
#   'keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u'renam oper'),
#   'keyword'),
#  (0, ('04_02_JSON_Demo.txt', u'magazin'), 'not keyword'),
#  (1, ('04_02_JSON_Demo.txt', u'magazin'), 'not keyword'),
#  (0, ('03_02_XML_Schema.txt', u'again,'), 'not keyword'),
#  (1, ('03_02_XML_Schema.txt', u'again,'), 'not keyword'),
#  (0,
#   ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'introduc'),
#   'not keyword'),
#  (1,
#   ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'introduc'),
#   'not keyword'),
#  (0, ('04_02_JSON_Demo.txt', u'month'), 'not keyword'),
#  (1, ('04_02_JSON_Demo.txt', u'month'), 'not keyword'),
#  (0, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'can'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'can'), 'not keyword'),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', u'messi'), 'not keyword'),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', u'messi'), 'not keyword'),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_2.txt', u'case'), 'not keyword'),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_2.txt', u'case'), 'not keyword'),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'do'), 'not keyword'),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'do'), 'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_1.txt', u'relat'), 'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_1.txt', u'relat'), 'not keyword'),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', u'id rep attribut'), 'not keyword'),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', u'id rep attribut'), 'keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u'on'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u'on'),
#   'not keyword'),
#  (0, ('03_02_XML_Schema.txt', u'place'), 'not keyword'),
#  (1, ('03_02_XML_Schema.txt', u'place'), 'not keyword'),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_2.txt', u'know'), 'not keyword'),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_2.txt', u'know'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', u'oper'),
#   'not keyword'),
#  (1, ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', u'oper'), 'keyword'),
#  (0, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'rememb'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'rememb'), 'not keyword'),
#  (0, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'queri'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'queri'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', u'entir'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', u'entir'),
#   'not keyword'),
#  (0, ('06_05_Aggregation.txt', u'ahead'), 'not keyword'),
#  (1, ('06_05_Aggregation.txt', u'ahead'), 'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_1.txt', u'ad'), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_1.txt', u'ad'), 'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_2.txt', u'littl'), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_2.txt', u'littl'), 'not keyword'),
#  (0, ('02_01_The_Relational_Model.txt', u'stake'), 'not keyword'),
#  (1, ('02_01_The_Relational_Model.txt', u'stake'), 'not keyword'),
#  (0, ('06_06_NULL_Values.txt', u'query,'), 'not keyword'),
#  (1, ('06_06_NULL_Values.txt', u'query,'), 'not keyword'),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', u'bear'), 'not keyword'),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', u'bear'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u'they'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u'they'),
#   'not keyword'),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'few'), 'not keyword'),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'few'), 'not keyword'),
#  (0, ('06_05_Aggregation.txt', u'function'), 'not keyword'),
#  (1, ('06_05_Aggregation.txt', u'function'), 'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_4.txt', u'databas'), 'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_4.txt', u'databas'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', u'veri'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', u'veri'),
#   'not keyword'),
#  (0, ('04_02_JSON_Demo.txt', u'json properti'), 'not keyword'),
#  (1, ('04_02_JSON_Demo.txt', u'json properti'), 'not keyword'),
#  (0, ('06_01_Introduction_to_SQL.txt', u'realli'), 'not keyword'),
#  (1, ('06_01_Introduction_to_SQL.txt', u'realli'), 'not keyword'),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', u'key'), 'not keyword'),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', u'key'), 'not keyword'),
#  (0, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'what'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'what'), 'not keyword'),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'get'), 'not keyword'),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'get'), 'not keyword'),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'me'), 'not keyword'),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'me'), 'not keyword'),
#  (0, ('06_07_Data_Modification_Statements.txt', u'that,'), 'not keyword'),
#  (1, ('06_07_Data_Modification_Statements.txt', u'that,'), 'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_1.txt', u"hasn't"), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_1.txt', u"hasn't"), 'not keyword'),
#  (0, ('06_04_Subqueries_in_WHERE_Clause.txt', u'fact,'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_WHERE_Clause.txt', u'fact,'), 'not keyword'),
#  (0, ('03_02_XML_Schema.txt', u'by'), 'not keyword'),
#  (1, ('03_02_XML_Schema.txt', u'by'), 'not keyword'),
#  (0,
#   ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'interchang'),
#   'not keyword'),
#  (1,
#   ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'interchang'),
#   'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_2.txt', u'cover,'), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_2.txt', u'cover,'), 'not keyword'),
#  (0, ('03_02_XML_Schema.txt', u'doe'), 'not keyword'),
#  (1, ('03_02_XML_Schema.txt', u'doe'), 'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_1.txt', u'those'), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_1.txt', u'those'), 'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_4.txt', u'set'), 'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_4.txt', u'set'), 'not keyword'),
#  (0, ('03_02_XML_Schema.txt', u'mesh'), 'not keyword'),
#  (1, ('03_02_XML_Schema.txt', u'mesh'), 'not keyword'),
#  (0, ('06_02_Basic_SELECT_Statement.txt', u'were'), 'not keyword'),
#  (1, ('06_02_Basic_SELECT_Statement.txt', u'were'), 'not keyword'),
#  (0, ('04_02_JSON_Demo.txt', u'json array'), 'not keyword'),
#  (1, ('04_02_JSON_Demo.txt', u'json array'), 'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_2.txt', u'make'), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_2.txt', u'make'), 'not keyword'),
#  (0,
#   ('06_03_Table_Variables_and_Set_Operators.txt', u'system,'),
#   'not keyword'),
#  (1,
#   ('06_03_Table_Variables_and_Set_Operators.txt', u'system,'),
#   'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_1.txt', u'most'), 'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_1.txt', u'most'), 'not keyword'),
#  (0, ('06_05_Aggregation.txt', u'eight'), 'not keyword'),
#  (1, ('06_05_Aggregation.txt', u'eight'), 'not keyword'),
#  (0, ('06_04_Subqueries_in_WHERE_Clause.txt', u'video'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_WHERE_Clause.txt', u'video'), 'not keyword'),
#  (0, ('06_06_NULL_Values.txt', u'involv'), 'not keyword'),
#  (1, ('06_06_NULL_Values.txt', u'involv'), 'not keyword'),
#  (0, ('02_01_The_Relational_Model.txt', u'though'), 'not keyword'),
#  (1, ('02_01_The_Relational_Model.txt', u'though'), 'not keyword'),
#  (0, ('06_08_The_JOIN_Family_of_Operators.txt', u'effect'), 'not keyword'),
#  (1, ('06_08_The_JOIN_Family_of_Operators.txt', u'effect'), 'not keyword'),
#  (0, ('06_06_NULL_Values.txt', u'final'), 'not keyword'),
#  (1, ('06_06_NULL_Values.txt', u'final'), 'not keyword'),
#  (0, ('04_02_JSON_Demo.txt', u'expect'), 'not keyword'),
#  (1, ('04_02_JSON_Demo.txt', u'expect'), 'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_1.txt', u'opinion,'), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_1.txt', u'opinion,'), 'not keyword'),
#  (0, ('06_04_Subqueries_in_WHERE_Clause.txt', u'queri'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_WHERE_Clause.txt', u'queri'), 'not keyword'),
#  (0, ('06_02_Basic_SELECT_Statement.txt', u'go'), 'not keyword'),
#  (1, ('06_02_Basic_SELECT_Statement.txt', u'go'), 'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_3.txt', u'exampl'), 'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_3.txt', u'exampl'), 'not keyword'),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', u'see'), 'not keyword'),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', u'see'), 'not keyword'),
#  (0, ('03_02_XML_Schema.txt', u'zero'), 'not keyword'),
#  (1, ('03_02_XML_Schema.txt', u'zero'), 'not keyword'),
#  (0, ('06_05_Aggregation.txt', u"it'll"), 'not keyword'),
#  (1, ('06_05_Aggregation.txt', u"it'll"), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', u'sometim'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', u'sometim'),
#   'not keyword'),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'from'), 'not keyword'),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'from'), 'not keyword'),
#  (0, ('06_01_Introduction_to_SQL.txt', u'lead'), 'not keyword'),
#  (1, ('06_01_Introduction_to_SQL.txt', u'lead'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', u'differ oper'),
#   'keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', u'differ oper'),
#   'keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u'comput'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u'comput'),
#   'not keyword'),
#  (0, ('03_02_XML_Schema.txt', u'occurr constraint'), 'not keyword'),
#  (1, ('03_02_XML_Schema.txt', u'occurr constraint'), 'keyword'),
#  (0, ('06_06_NULL_Values.txt', u'learn'), 'not keyword'),
#  (1, ('06_06_NULL_Values.txt', u'learn'), 'not keyword'),
#  (0, ('06_08_The_JOIN_Family_of_Operators.txt', u'seen'), 'not keyword'),
#  (1, ('06_08_The_JOIN_Family_of_Operators.txt', u'seen'), 'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_1.txt', u'id'), 'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_1.txt', u'id'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', u'result'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', u'result'),
#   'not keyword'),
#  (0, ('06_04_Subqueries_in_WHERE_Clause.txt', u'everybodi'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_WHERE_Clause.txt', u'everybodi'), 'not keyword'),
#  (0, ('06_08_The_JOIN_Family_of_Operators.txt', u'away'), 'not keyword'),
#  (1, ('06_08_The_JOIN_Family_of_Operators.txt', u'away'), 'not keyword'),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_2.txt', u'model'), 'not keyword'),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_2.txt', u'model'), 'not keyword'),
#  (0,
#   ('06_03_Table_Variables_and_Set_Operators.txt', u'readabl'),
#   'not keyword'),
#  (1,
#   ('06_03_Table_Variables_and_Set_Operators.txt', u'readabl'),
#   'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', u"you'r"),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', u"you'r"),
#   'not keyword'),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'larg'), 'not keyword'),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'larg'), 'not keyword'),
#  (0, ('06_03_Table_Variables_and_Set_Operators.txt', u'sql,'), 'not keyword'),
#  (1, ('06_03_Table_Variables_and_Set_Operators.txt', u'sql,'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', u'colleg'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', u'colleg'),
#   'not keyword'),
#  (0, ('06_05_Aggregation.txt', u"gpa'"), 'not keyword'),
#  (1, ('06_05_Aggregation.txt', u"gpa'"), 'not keyword'),
#  (0, ('06_04_Subqueries_in_WHERE_Clause.txt', u'least'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_WHERE_Clause.txt', u'least'), 'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_3.txt', u'want'), 'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_3.txt', u'want'), 'not keyword'),
#  (0, ('06_05_Aggregation.txt', u'do?'), 'not keyword'),
#  (1, ('06_05_Aggregation.txt', u'do?'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', u'equival'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', u'equival'),
#   'not keyword'),
#  (0, ('06_03_Table_Variables_and_Set_Operators.txt', u'about'), 'not keyword'),
#  (1, ('06_03_Table_Variables_and_Set_Operators.txt', u'about'), 'not keyword'),
#  (0, ('06_05_Aggregation.txt', u'names,'), 'not keyword'),
#  (1, ('06_05_Aggregation.txt', u'names,'), 'not keyword'),
#  (0, ('06_02_Basic_SELECT_Statement.txt', u'id'), 'not keyword'),
#  (1, ('06_02_Basic_SELECT_Statement.txt', u'id'), 'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_2.txt', u'model,'), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_2.txt', u'model,'), 'not keyword'),
#  (0, ('06_05_Aggregation.txt', u'have condit'), 'keyword'),
#  (1, ('06_05_Aggregation.txt', u'have condit'), 'keyword'),
#  (0, ('06_03_Table_Variables_and_Set_Operators.txt', u'shoot'), 'not keyword'),
#  (1, ('06_03_Table_Variables_and_Set_Operators.txt', u'shoot'), 'not keyword'),
#  (0,
#   ('04_01_Introduction_to_JSON_Data_Part_2.txt', u'specifi'),
#   'not keyword'),
#  (1,
#   ('04_01_Introduction_to_JSON_Data_Part_2.txt', u'specifi'),
#   'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', u'core'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', u'core'),
#   'not keyword'),
#  (0, ('06_07_Data_Modification_Statements.txt', u'mellon'), 'not keyword'),
#  (1, ('06_07_Data_Modification_Statements.txt', u'mellon'), 'not keyword'),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_2.txt', u'by'), 'not keyword'),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_2.txt', u'by'), 'not keyword'),
#  (0, ('06_07_Data_Modification_Statements.txt', u'there'), 'not keyword'),
#  (1, ('06_07_Data_Modification_Statements.txt', u'there'), 'not keyword'),
#  (0, ('06_04_Subqueries_in_WHERE_Clause.txt', u'littl'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_WHERE_Clause.txt', u'littl'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u'those'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u'those'),
#   'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_1.txt', u'again'), 'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_1.txt', u'again'), 'not keyword'),
#  (0, ('02_01_The_Relational_Model.txt', u'we'), 'not keyword'),
#  (1, ('02_01_The_Relational_Model.txt', u'we'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', u'better'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', u'better'),
#   'not keyword'),
#  (0, ('06_05_Aggregation.txt', u'about'), 'not keyword'),
#  (1, ('06_05_Aggregation.txt', u'about'), 'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_4.txt', u'tuples,'), 'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_4.txt', u'tuples,'), 'not keyword'),
#  (0, ('06_02_Basic_SELECT_Statement.txt', u"that'"), 'not keyword'),
#  (1, ('06_02_Basic_SELECT_Statement.txt', u"that'"), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u'here,'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u'here,'),
#   'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u'differ'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u'differ'),
#   'not keyword'),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', u'how'), 'not keyword'),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', u'how'), 'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_1.txt', u'creat'), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_1.txt', u'creat'), 'not keyword'),
#  (0, ('06_08_The_JOIN_Family_of_Operators.txt', u'course,'), 'not keyword'),
#  (1, ('06_08_The_JOIN_Family_of_Operators.txt', u'course,'), 'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_1.txt', u'combin'), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_1.txt', u'combin'), 'not keyword'),
#  (0, ('06_07_Data_Modification_Statements.txt', u'exactli'), 'not keyword'),
#  (1, ('06_07_Data_Modification_Statements.txt', u'exactli'), 'not keyword'),
#  (0, ('06_06_NULL_Values.txt', u'away'), 'not keyword'),
#  (1, ('06_06_NULL_Values.txt', u'away'), 'not keyword'),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'there'), 'not keyword'),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'there'), 'not keyword'),
#  (0,
#   ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'newest,'),
#   'not keyword'),
#  (1,
#   ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'newest,'),
#   'not keyword'),
#  (0, ('04_02_JSON_Demo.txt', u'parser'), 'not keyword'),
#  (1, ('04_02_JSON_Demo.txt', u'parser'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u'our'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u'our'),
#   'not keyword'),
#  (0, ('06_03_Table_Variables_and_Set_Operators.txt', u"123'"), 'not keyword'),
#  (1, ('06_03_Table_Variables_and_Set_Operators.txt', u"123'"), 'not keyword'),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'peopl'), 'not keyword'),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'peopl'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', u'relation,'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', u'relation,'),
#   'not keyword'),
#  (0, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'statement'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'statement'), 'not keyword'),
#  (0, ('02_02_Querying_Relational_Databases.txt', u'program'), 'not keyword'),
#  (1, ('02_02_Querying_Relational_Databases.txt', u'program'), 'not keyword'),
#  (0, ('06_02_Basic_SELECT_Statement.txt', u'some'), 'not keyword'),
#  (1, ('06_02_Basic_SELECT_Statement.txt', u'some'), 'not keyword'),
#  (0, ('06_07_Data_Modification_Statements.txt', u'more'), 'not keyword'),
#  (1, ('06_07_Data_Modification_Statements.txt', u'more'), 'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_2.txt', u'should'), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_2.txt', u'should'), 'not keyword'),
#  (0, ('06_08_The_JOIN_Family_of_Operators.txt', u'to'), 'not keyword'),
#  (1, ('06_08_The_JOIN_Family_of_Operators.txt', u'to'), 'not keyword'),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_2.txt', u'in'), 'not keyword'),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_2.txt', u'in'), 'not keyword'),
#  (0, ('04_02_JSON_Demo.txt', u'visit'), 'not keyword'),
#  (1, ('04_02_JSON_Demo.txt', u'visit'), 'not keyword'),
#  (0, ('06_07_Data_Modification_Statements.txt', u'it,'), 'not keyword'),
#  (1, ('06_07_Data_Modification_Statements.txt', u'it,'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', u'want'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', u'want'),
#   'not keyword'),
#  (0, ('06_03_Table_Variables_and_Set_Operators.txt', u'whole'), 'not keyword'),
#  (1, ('06_03_Table_Variables_and_Set_Operators.txt', u'whole'), 'not keyword'),
#  (0, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'also'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'also'), 'not keyword'),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_2.txt', u'but'), 'not keyword'),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_2.txt', u'but'), 'not keyword'),
#  (0, ('06_05_Aggregation.txt', u'say'), 'not keyword'),
#  (1, ('06_05_Aggregation.txt', u'say'), 'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_2.txt', u'way'), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_2.txt', u'way'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', u'then'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', u'then'),
#   'not keyword'),
#  (0, ('03_02_XML_Schema.txt', u'id'), 'not keyword'),
#  (1, ('03_02_XML_Schema.txt', u'id'), 'not keyword'),
#  (0, ('06_01_Introduction_to_SQL.txt', u'prompt'), 'not keyword'),
#  (1, ('06_01_Introduction_to_SQL.txt', u'prompt'), 'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_1.txt', u'also'), 'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_1.txt', u'also'), 'not keyword'),
#  (0, ('06_06_NULL_Values.txt', u'undefin'), 'not keyword'),
#  (1, ('06_06_NULL_Values.txt', u'undefin'), 'not keyword'),
#  (0, ('02_02_Querying_Relational_Databases.txt', u'though'), 'not keyword'),
#  (1, ('02_02_Querying_Relational_Databases.txt', u'though'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', u'small'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', u'small'),
#   'not keyword'),
#  (0, ('02_01_The_Relational_Model.txt', u'relat'), 'keyword'),
#  (1, ('02_01_The_Relational_Model.txt', u'relat'), 'keyword'),
#  (0, ('06_06_NULL_Values.txt', u'certainli'), 'not keyword'),
#  (1, ('06_06_NULL_Values.txt', u'certainli'), 'not keyword'),
# ...
#  (1, ('02_02_Querying_Relational_Databases.txt', u'move'), 'not keyword'),
#  (0, ('06_02_Basic_SELECT_Statement.txt', u'biolog'), 'not keyword'),
#  (1, ('06_02_Basic_SELECT_Statement.txt', u'biolog'), 'not keyword'),
#  (0, ('04_02_JSON_Demo.txt', u'were'), 'not keyword'),
#  (1, ('04_02_JSON_Demo.txt', u'were'), 'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_2.txt', u'rejected,'), 'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_2.txt', u'rejected,'), 'not keyword'),
#  (0, ('06_08_The_JOIN_Family_of_Operators.txt', u'requir'), 'not keyword'),
#  (1, ('06_08_The_JOIN_Family_of_Operators.txt', u'requir'), 'not keyword'),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', u'dtd,'), 'not keyword'),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', u'dtd,'), 'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_1.txt', u'addit'), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_1.txt', u'addit'), 'not keyword'),
#  (0, ('06_07_Data_Modification_Statements.txt', u'someon'), 'not keyword'),
#  (1, ('06_07_Data_Modification_Statements.txt', u'someon'), 'not keyword'),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'out'), 'not keyword'),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'out'), 'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_4.txt', u'project oper'), 'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_4.txt', u'project oper'), 'not keyword'),
#  (0, ('06_03_Table_Variables_and_Set_Operators.txt', u'do'), 'not keyword'),
#  (1, ('06_03_Table_Variables_and_Set_Operators.txt', u'do'), 'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_1.txt', u'design'), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_1.txt', u'design'), 'not keyword'),
#  (0, ('04_02_JSON_Demo.txt', u'similarli'), 'not keyword'),
#  (1, ('04_02_JSON_Demo.txt', u'similarli'), 'not keyword'),
#  (0, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'see'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'see'), 'not keyword'),
#  (0, ('03_02_XML_Schema.txt', u'focu'), 'not keyword'),
#  (1, ('03_02_XML_Schema.txt', u'focu'), 'not keyword'),
#  (0, ('06_05_Aggregation.txt', u'verifi'), 'not keyword'),
#  (1, ('06_05_Aggregation.txt', u'verifi'), 'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_1.txt', u'column'), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_1.txt', u'column'), 'not keyword'),
#  (0, ('06_04_Subqueries_in_WHERE_Clause.txt', u'school'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_WHERE_Clause.txt', u'school'), 'not keyword'),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', u'author'), 'not keyword'),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', u'author'), 'not keyword'),
#  (0, ('06_05_Aggregation.txt', u'construct,'), 'not keyword'),
#  (1, ('06_05_Aggregation.txt', u'construct,'), 'not keyword'),
#  (0, ('06_04_Subqueries_in_WHERE_Clause.txt', u'relat'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_WHERE_Clause.txt', u'relat'), 'not keyword'),
#  (0, ('06_01_Introduction_to_SQL.txt', u'delet'), 'not keyword'),
#  (1, ('06_01_Introduction_to_SQL.txt', u'delet'), 'not keyword'),
#  (0, ('06_07_Data_Modification_Statements.txt', u'words,'), 'not keyword'),
#  (1, ('06_07_Data_Modification_Statements.txt', u'words,'), 'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_1.txt', u'key'), 'keyword'),
#  (1, ('05_01_Select_Project_Join_Part_1.txt', u'key'), 'keyword'),
#  (0, ('04_02_JSON_Demo.txt', u'sens'), 'not keyword'),
#  (1, ('04_02_JSON_Demo.txt', u'sens'), 'not keyword'),
#  (0, ('06_07_Data_Modification_Statements.txt', u'entir'), 'not keyword'),
#  (1, ('06_07_Data_Modification_Statements.txt', u'entir'), 'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_4.txt', u'might'), 'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_4.txt', u'might'), 'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_1.txt', u'those'), 'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_1.txt', u'those'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', u'etc'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', u'etc'),
#   'not keyword'),
#  (0,
#   ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'download'),
#   'not keyword'),
#  (1,
#   ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'download'),
#   'not keyword'),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', u'format'), 'not keyword'),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', u'format'), 'not keyword'),
#  (0, ('02_01_The_Relational_Model.txt', u'spawn'), 'not keyword'),
#  (1, ('02_01_The_Relational_Model.txt', u'spawn'), 'not keyword'),
#  (0, ('06_07_Data_Modification_Statements.txt', u'whew!'), 'not keyword'),
#  (1, ('06_07_Data_Modification_Statements.txt', u'whew!'), 'not keyword'),
#  (0, ('03_02_XML_Schema.txt', u'effect'), 'not keyword'),
#  (1, ('03_02_XML_Schema.txt', u'effect'), 'not keyword'),
#  (0, ('06_06_NULL_Values.txt', u'influenc'), 'not keyword'),
#  (1, ('06_06_NULL_Values.txt', u'influenc'), 'not keyword'),
#  (0, ('06_08_The_JOIN_Family_of_Operators.txt', u'join'), 'not keyword'),
#  (1, ('06_08_The_JOIN_Family_of_Operators.txt', u'join'), 'keyword'),
#  (0, ('06_03_Table_Variables_and_Set_Operators.txt', u'where'), 'not keyword'),
#  (1, ('06_03_Table_Variables_and_Set_Operators.txt', u'where'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u'similarli'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u'similarli'),
#   'not keyword'),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_2.txt', u'touch'), 'not keyword'),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_2.txt', u'touch'), 'not keyword'),
#  (0, ('06_06_NULL_Values.txt', u'interact'), 'not keyword'),
#  (1, ('06_06_NULL_Values.txt', u'interact'), 'not keyword'),
#  (0, ('04_02_JSON_Demo.txt', u'name'), 'not keyword'),
#  (1, ('04_02_JSON_Demo.txt', u'name'), 'not keyword'),
#  (0, ('06_03_Table_Variables_and_Set_Operators.txt', u'not'), 'not keyword'),
#  (1, ('06_03_Table_Variables_and_Set_Operators.txt', u'not'), 'not keyword'),
#  (0, ('06_03_Table_Variables_and_Set_Operators.txt', u'unifi'), 'not keyword'),
#  (1, ('06_03_Table_Variables_and_Set_Operators.txt', u'unifi'), 'not keyword'),
#  (0, ('04_02_JSON_Demo.txt', u'all'), 'not keyword'),
#  (1, ('04_02_JSON_Demo.txt', u'all'), 'not keyword'),
#  (0, ('03_02_XML_Schema.txt', u'were'), 'not keyword'),
#  (1, ('03_02_XML_Schema.txt', u'were'), 'not keyword'),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'it'), 'not keyword'),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'it'), 'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_1.txt', u'caret,'), 'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_1.txt', u'caret,'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', u'sound'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', u'sound'),
#   'not keyword'),
#  (0, ('06_04_Subqueries_in_WHERE_Clause.txt', u'outer'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_WHERE_Clause.txt', u'outer'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u'did'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u'did'),
#   'not keyword'),
#  (0, ('06_07_Data_Modification_Statements.txt', u'keyword'), 'not keyword'),
#  (1, ('06_07_Data_Modification_Statements.txt', u'keyword'), 'not keyword'),
#  (0, ('04_02_JSON_Demo.txt', u'few'), 'not keyword'),
#  (1, ('04_02_JSON_Demo.txt', u'few'), 'not keyword'),
#  (0, ('02_02_Querying_Relational_Databases.txt', u'reality,'), 'not keyword'),
#  (1, ('02_02_Querying_Relational_Databases.txt', u'reality,'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', u'inform'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', u'inform'),
#   'not keyword'),
#  (0, ('06_08_The_JOIN_Family_of_Operators.txt', u'now,'), 'not keyword'),
#  (1, ('06_08_The_JOIN_Family_of_Operators.txt', u'now,'), 'not keyword'),
#  (0, ('06_02_Basic_SELECT_Statement.txt', u'berkeley,'), 'not keyword'),
#  (1, ('06_02_Basic_SELECT_Statement.txt', u'berkeley,'), 'not keyword'),
#  (0, ('06_04_Subqueries_in_WHERE_Clause.txt', u'mani'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_WHERE_Clause.txt', u'mani'), 'not keyword'),
#  (0, ('02_01_The_Relational_Model.txt', u'support'), 'not keyword'),
#  (1, ('02_01_The_Relational_Model.txt', u'support'), 'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_1.txt', u'wa'), 'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_1.txt', u'wa'), 'not keyword'),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', u'use'), 'not keyword'),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', u'use'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', u'c1'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_3.txt', u'c1'),
#   'not keyword'),
#  (0, ('03_02_XML_Schema.txt', u'ref'), 'not keyword'),
#  (1, ('03_02_XML_Schema.txt', u'ref'), 'not keyword'),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', u'each'), 'not keyword'),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', u'each'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u'if'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u'if'),
#   'not keyword'),
#  (0,
#   ('06_03_Table_Variables_and_Set_Operators.txt', u'tabl variabl'),
#   'keyword'),
#  (1,
#   ('06_03_Table_Variables_and_Set_Operators.txt', u'tabl variabl'),
#   'keyword'),
#  (0, ('05_01_Select_Project_Join_Part_4.txt', u'relations;'), 'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_4.txt', u'relations;'), 'not keyword'),
#  (0, ('02_01_The_Relational_Model.txt', u'point'), 'not keyword'),
#  (1, ('02_01_The_Relational_Model.txt', u'point'), 'not keyword'),
#  (0, ('06_02_Basic_SELECT_Statement.txt', u'bio'), 'not keyword'),
#  (1, ('06_02_Basic_SELECT_Statement.txt', u'bio'), 'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_2.txt', u'as'), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_2.txt', u'as'), 'not keyword'),
#  (0, ('02_01_The_Relational_Model.txt', u'null'), 'keyword'),
#  (1, ('02_01_The_Relational_Model.txt', u'null'), 'keyword'),
#  (0, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'a'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'a'), 'not keyword'),
#  (0, ('06_08_The_JOIN_Family_of_Operators.txt', u'exactli'), 'not keyword'),
#  (1, ('06_08_The_JOIN_Family_of_Operators.txt', u'exactli'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', u'the'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_1.txt', u'the'),
#   'not keyword'),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', u'save'), 'not keyword'),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', u'save'), 'not keyword'),
#  (0, ('06_07_Data_Modification_Statements.txt', u'bunch'), 'not keyword'),
#  (1, ('06_07_Data_Modification_Statements.txt', u'bunch'), 'not keyword'),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_2.txt', u'thing'), 'not keyword'),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_2.txt', u'thing'), 'not keyword'),
#  (0, ('04_02_JSON_Demo.txt', u'then'), 'not keyword'),
#  (1, ('04_02_JSON_Demo.txt', u'then'), 'not keyword'),
#  (0, ('06_05_Aggregation.txt', u'berkeley'), 'not keyword'),
#  (1, ('06_05_Aggregation.txt', u'berkeley'), 'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_2.txt', u'and,'), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_2.txt', u'and,'), 'not keyword'),
#  (0, ('03_02_XML_Schema.txt', u'language,'), 'not keyword'),
#  (1, ('03_02_XML_Schema.txt', u'language,'), 'not keyword'),
#  (0, ('06_05_Aggregation.txt', u"what'"), 'not keyword'),
#  (1, ('06_05_Aggregation.txt', u"what'"), 'not keyword'),
#  (0, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'although,'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'although,'), 'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_2.txt', u'tree'), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_2.txt', u'tree'), 'not keyword'),
#  (0, ('04_02_JSON_Demo.txt', u'own'), 'not keyword'),
#  (1, ('04_02_JSON_Demo.txt', u'own'), 'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_2.txt', u'talk'), 'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_2.txt', u'talk'), 'not keyword'),
#  (0, ('04_02_JSON_Demo.txt', u'2009'), 'not keyword'),
#  (1, ('04_02_JSON_Demo.txt', u'2009'), 'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_2.txt', u'use'), 'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_2.txt', u'use'), 'not keyword'),
#  (0, ('06_02_Basic_SELECT_Statement.txt', u'start'), 'not keyword'),
#  (1, ('06_02_Basic_SELECT_Statement.txt', u'start'), 'not keyword'),
#  (0, ('06_05_Aggregation.txt', u'select'), 'not keyword'),
#  (1, ('06_05_Aggregation.txt', u'select'), 'not keyword'),
#  (0, ('06_04_Subqueries_in_WHERE_Clause.txt', u'member'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_WHERE_Clause.txt', u'member'), 'not keyword'),
#  (0, ('06_06_NULL_Values.txt', u'aggreg'), 'not keyword'),
#  (1, ('06_06_NULL_Values.txt', u'aggreg'), 'not keyword'),
#  (0, ('04_02_JSON_Demo.txt', u'four'), 'not keyword'),
#  (1, ('04_02_JSON_Demo.txt', u'four'), 'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u'pair'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u'pair'),
#   'not keyword'),
#  (0, ('03_02_DTDs_IDs_and_IDREFs.txt', u'assum'), 'not keyword'),
#  (1, ('03_02_DTDs_IDs_and_IDREFs.txt', u'assum'), 'not keyword'),
#  (0, ('06_06_NULL_Values.txt', u'seri'), 'not keyword'),
#  (1, ('06_06_NULL_Values.txt', u'seri'), 'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_1.txt', u'author'), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_1.txt', u'author'), 'not keyword'),
#  (0, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'equal'), 'not keyword'),
#  (1, ('06_04_Subqueries_in_FROM_and_SELECT.txt', u'equal'), 'not keyword'),
#  (0,
#   ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'certainli'),
#   'not keyword'),
#  (1,
#   ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'certainli'),
#   'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u'doe'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u'doe'),
#   'not keyword'),
#  (0,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u'ators,'),
#   'not keyword'),
#  (1,
#   ('05_02_Set_Operators_Renaming_Notation_Part_2.txt', u'ators,'),
#   'not keyword'),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_2.txt', u'and,'), 'not keyword'),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_2.txt', u'and,'), 'not keyword'),
#  (0, ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'model'), 'not keyword'),
#  (1, ('04_01_Introduction_to_JSON_Data_Part_1.txt', u'model'), 'not keyword'),
#  (0, ('04_02_JSON_Demo.txt', u'word'), 'not keyword'),
#  (1, ('04_02_JSON_Demo.txt', u'word'), 'not keyword'),
#  (0, ('06_01_Introduction_to_SQL.txt', u'foundat'), 'not keyword'),
#  (1, ('06_01_Introduction_to_SQL.txt', u'foundat'), 'not keyword'),
#  (0,
#   ('06_03_Table_Variables_and_Set_Operators.txt', u'explain'),
#   'not keyword'),
#  (1,
#   ('06_03_Table_Variables_and_Set_Operators.txt', u'explain'),
#   'not keyword'),
#  (0, ('03_02_XML_Schema.txt', u'off,'), 'not keyword'),
#  (1, ('03_02_XML_Schema.txt', u'off,'), 'not keyword'),
#  (0, ('04_02_JSON_Demo.txt', u'2'), 'not keyword'),
#  (1, ('04_02_JSON_Demo.txt', u'2'), 'not keyword'),
#  (0, ('03_01_Well_Formed_XML_Part_1.txt', u'sql'), 'not keyword'),
#  (1, ('03_01_Well_Formed_XML_Part_1.txt', u'sql'), 'keyword'),
#  (0, ('06_02_Basic_SELECT_Statement.txt', u'is,'), 'not keyword'),
#  (1, ('06_02_Basic_SELECT_Statement.txt', u'is,'), 'not keyword'),
#  (0, ('05_01_Select_Project_Join_Part_1.txt', u'are'), 'not keyword'),
#  (1, ('05_01_Select_Project_Join_Part_1.txt', u'are'), 'not keyword'),
#  (0, ('06_01_Introduction_to_SQL.txt', u'an'), 'not keyword'),
#  (1, ('06_01_Introduction_to_SQL.txt', u'an'), 'not keyword'),
#  (0, ('06_02_Basic_SELECT_Statement.txt', u'after'), 'not keyword'),
#  (1, ('06_02_Basic_SELECT_Statement.txt', u'after'), 'not keyword'),
#  (0, ('06_02_Basic_SELECT_Statement.txt', u'say'), 'not keyword'),
#  (1, ('06_02_Basic_SELECT_Statement.txt', u'say'), 'not keyword'),
#  (0, ('06_05_Aggregation.txt', u'exceed'), 'not keyword'),
#  (1, ('06_05_Aggregation.txt', u'exceed'), 'not keyword'),
#  ...]

# %%
rater_0 = {}
rater_1 = {}

for item in data:
    if item[0] == 0:
        rater_0[item[1]] = item[2]
    elif item[0] == 1:
        rater_1[item[1]] = item[2]

# %%
len([key for key in rater_0 if rater_0[key] == 'not keyword' and rater_1[key] == 'not keyword'])
# Out:
# 9041

# %%
# Print a few random data points to spot check
for i in np.random.choice(range(len(data)), size=10, replace=False):
    print(data[i])
    
print('#'*80)

# Print a few that are included in the index
cat_1 = [item for item in data if item[2] == 'keyword']
for i in np.random.choice(range(len(cat_1)), size=10, replace=False):
    print(cat_1[i])
print('#'*80)
    
# Print a few that aren't included in the index
cat_2 = [item for item in data if item[2] == 'not keyword']
for i in np.random.choice(range(len(cat_2)), size=10, replace=False):
    print(cat_2[i])

# %%
# Get the kappa.
t = nltk.AnnotationTask(data=data)
t.multi_kappa()
# Out:
# 0.327447316762549

# %%
t.kappa_pairwise(0, 1)
# Out:
# 0.3714989389464814

# %%
t.kappa_pairwise(0, 2)
# Out:
# 0.27181561700679585

# %%
t.kappa_pairwise(1, 2)
# Out:
# 0.31090735838258493

# %%
t.S()
# Out:
# 0.9459306440198159
